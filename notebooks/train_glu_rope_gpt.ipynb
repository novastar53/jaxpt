# %% [markdown]
# # Let's Train GPT-2 with RoPE + GLU

# %% [markdown]
# ### Configure the machine and install packages

# %%
import os
#os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=8'

from typing import Literal

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on darwin

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /Users/vikram/dev/jaxpt/src

# %%
import os
import warnings

import jax
import flax
import jax.numpy as jnp
import numpy as np

# Hardware setup
print("JAX version:", jax.__version__)
print("Flax version", flax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

requested_device = "gpu"

jax.config.update("jax_platform_name", requested_device) # Make sure we're using the GPU

device = jax.default_backend()
if device != requested_device:
    warnings.warn(f"not using {requested_device}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.6.2
# Flax version 0.10.4
# Available devices: 1
# /var/folders/x4/85_9sn3d1ng9q48ff6t3fw340000gn/T/ipykernel_76662/2488604009.py:22: UserWarning: not using gpu. Using cpu
#   warnings.warn(f"not using {requested_device}. Using {device}")
# 237 ms ± 15.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize the GPT-2 model and perform a sanity check

# %%
from functools import partial

from jax.sharding import Mesh, PartitionSpec, NamedSharding
from flax import nnx

from jaxpt.infer import generate_completions
from jaxpt.models import GLU_RoPE_GPT, GLU_RoPE_GPTConfig
from jaxpt.utils import count_params, create_sharded_model

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

mesh = Mesh(devices, ("devices",))
spec = PartitionSpec("devices",)
sharding = NamedSharding(mesh, spec)


key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = GLU_RoPE_GPTConfig(dtype=jnp.bfloat16, \
                   n_layer=30, \
                   vocab_size=50304, \
                   block_size=2048,
                   n_head=9,
                   n_embed=576,
                   n_mlp_hidden=1536,
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)
with mesh:
    m = create_sharded_model(GLU_RoPE_GPT, config, rngs)
    graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)

    total_params = count_params(m)
    print(f"Parameter Count: {total_params:,}")
    nnx.display(state)

    completions = generate_completions(m, num_completions=5, max_length=21, prefix="Ducks quack, donkeys bray, cats mew, horses")
    for completion in completions:
        print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_36f3aa06645a47f88e23476e369601af" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_36f3aa06645a47f88e23476e369601af")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_36f3aa06645a47f88e23476e369601af")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Parameter Count: 148,553,856
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_36f21eec9da840ba98c42abf5c74906a" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_36f21eec9da840ba98c42abf5c74906a")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_36f21eec9da840ba98c42abf5c74906a")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_36f21eec9da840ba98c42abf5c74906a")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Ducks quack, donkeys bray, cats mew, horsesById Newcastle Newcastle Newcastle Newcastle Newcastle
# Ducks quack, donkeys bray, cats mew, horses������
# Ducks quack, donkeys bray, cats mew, horses eleven eleven eleven eleven eleven eleven
# Ducks quack, donkeys bray, cats mew, horses Ling Ling Ling Ling Ling Ling
# Ducks quack, donkeys bray, cats mew, horses Newcastle Newcastle Newcastle Newcastle Newcastle Newcastle

# %%
jax.debug.visualize_array_sharding(m.wte.embedding.value)
# Out:
#
#
#
#
#
#   CPU 0

# %% [markdown]
# ### Configure Training Run

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

run_dirname = f"run_{timestamp}_{random_code}"
print(f"Run: {run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/workspace/runs") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Run: run_20250721_uzmhiq
# Checkpoint directory: /Users/vikram/dev/jaxpt/checkpoints
# Log directory: /Users/vikram/dev/jaxpt/logs

# %%
import dataclasses

import optax


############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens: int = int(100e9)
  num_tokens_per_batch: int = 2**11 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 16 * num_devices
  T: int = 128
  max_steps: int = num_tokens // num_tokens_per_batch # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 1
  eval_interval: int = 2000
  checkpoint_interval: int = 2000
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()
'''
trconf = TrainerConfig(
  num_tokens_per_batch=2**14,
  mB=16,
  T=1024,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)
trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient
'''

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

steps = range(0, trconf.max_steps, 1000)
total_schedule = [ warmup_with_cosine_decay_schedule(step) for step in steps ]
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.plot(steps, total_schedule)
plt.title("LR Schedule")
plt.show()

# Generate a weight decay mask
# First split the model into params and variables
graphdef, params, variables = nnx.split(m, nnx.Param, nnx.Variable)
# Then create a mask for the weight decay params
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)


tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95) #, weight_decay=0.1, mask=weight_decay_mask)
)
optimizer = nnx.Optimizer(m, tx)

# count the number of weight decay params
def f(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(f, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)


print(f"weight decay param count: {weight_decay_param_count:,}")
print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# weight decay param count: 148,414,464
# tokens/batch: 2,048
# block size: 128
# sub-batch size: 16
# no. gradient accumulation steps: 1
# effective batch size per device:  16
# effective batch size: 16
# max steps: 48828125

# %% [markdown]
# ### DataLoader and Validation Setup

# %%
from jaxpt.dataloaders import DataLoader, HuggingfaceDataLoader, CloudDataLoader, BlendedCloudDataLoader

batch_size = trconf.T * trconf.mB * trconf.grad_accumulation_steps
batch_memory = batch_size*2
print(f"Batch Size (Tokens): {batch_size:,} | Batch Memory: {batch_memory/1024} MB")

'''
train_dl = HuggingfaceDataLoader(batch_size=trconf.mB * DATA_DIMS,
                                 block_size=trconf.T,
                                 device_rank=1,
                                 tokenizer="HuggingFaceTB/SmolLM-135M",
                                 dataset_paths=["HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus"],
                                 dataset_names=["cosmopedia-v2",
                                                "python-edu",
                                                "fineweb-edu-dedup"],
                                 probabilities=[0.111, 0.016 , 0.873],
                                 label="train",
                                 random_seed=1337,
                                 buffer_size=10_000,
                                 streaming=True)
'''
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../alpha-448101-282bc1b884cd.json"

'''
train_dl = CloudDataLoader(bucket_name="jaxpt_datasets",
                      bucket_prefix="fineweb-edu-100b/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
'''
'''
train_dl = BlendedCloudDataLoader(
    device_rank=1,
    block_size=trconf.T,
    batch_size=trconf.mB,
    bucket_names=["jaxpt_datasets", "jaxpt_datasets", "jaxpt_datasets"],
    bucket_prefixes=["smollm-corpus/processed/fineweb-edu-dedup",
                     "smollm-corpus/processed/python-edu",
                     "smollm-corpus/processed/cosmopedia-v2"],
    proportions=[87, 2, 11],
    label="train"
)
'''
train_dl = DataLoader(dirpath="/content/jaxpt/datasets/panchatantra-ryder/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
# Out:
# Batch Size (Tokens): 2,048 | Batch Memory: 4.0 MB
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 47
#      26 '''
#      27 train_dl = CloudDataLoader(bucket_name="jaxpt_datasets",
#      28                       bucket_prefix="fineweb-edu-100b/processed",
#    (...)     32                       label="train")
#      33 '''
#      34 '''
#      35 train_dl = BlendedCloudDataLoader(
#      36     device_rank=1,
#    (...)     45 )
#      46 '''
# ---> 47 train_dl = DataLoader(dirpath="/content/jaxpt/datasets/panchatantra-ryder/processed",
#      48                       batch_size=trconf.mB,
#      49                       block_size=trconf.T,
#      50                       device_rank=1,
#      51                       label="train")
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:135, in DataLoader.__init__(self, dirpath, batch_size, block_size, device_rank, label, quiet)
#     125 def __init__(
#     126     self,
#     127     dirpath: str,
#    (...)    132     quiet: bool = False,
#     133 ):
#     134     self.dirpath = dirpath
# --> 135     super().__init__(batch_size, block_size, device_rank, label, quiet)
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:59, in BaseDataLoader.__init__(self, batch_size, block_size, device_rank, label, quiet)
#      56 self.label = label
#      58 # List and filter shards
# ---> 59 self.shards = self._list_shards(label)
#      60 self.cur_shard = 0
#      61 self.shard_pos = 0
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:138, in DataLoader._list_shards(self, label)
#     137 def _list_shards(self, label):
# --> 138     shards = os.listdir(self.dirpath)
#     139     if label is not None:
#     140         shards = [s for s in shards if label in s]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/jaxpt/datasets/panchatantra-ryder/processed'

# %%
from jaxpt.utils import append_to_csv

train_losses = []
val_losses = []
append_to_csv(log_dir / f"{run_dirname}_train.csv", ["step", "lr", "loss", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{run_dirname}_valid.csv", ["step", "loss"])
step = 0
start = None

# %% [markdown]
# ### Let's train the model

# %%
# %matplotlib inline

import time
import logging
import warnings

import matplotlib.pyplot as plt


def loss_fn(model, batch, targets):
    logits = model(batch)
    loss = optax.softmax_cross_entropy_with_integer_labels(logits, targets)
    return loss.mean()


@nnx.jit
def train_step(model, optimizer, batch, targets):
    loss, grads = nnx.value_and_grad(loss_fn, has_aux=False)(model, batch, targets)
    optimizer.update(grads)
    return loss


with mesh:
  m.train()
  try:
    while step < trconf.max_steps:
      start = time.time()
      batch, target = train_dl()
      batch = jax.device_put(batch.squeeze(), sharding)
      target = jax.device_put(target.squeeze(), sharding)
      loss = train_step(m, optimizer, batch, target)
      if step % trconf.print_interval == 0:
        if start is None:
          start = time.time()
          iter_time = 0
          sub_step_time = 0
          tokes_per_sec = 0
          tokens_processed = 0
        else:
          iter_time = time.time() - start
          sub_step_time = iter_time / trconf.grad_accumulation_steps
          tokens_per_sec = trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
          tokens_processed = (step+1) * trconf.grad_accumulation_steps * trconf.mB * trconf.T

        loss = loss.item()
        lr = warmup_with_cosine_decay_schedule(step)
        train_losses.append((step, loss))
        append_to_csv(log_dir / f"{run_dirname}_train.csv", [step, lr, loss, iter_time*1000, tokens_processed, tokens_per_sec])
        print(f"{step} | lr: {lr:0.2e} | loss: {loss:0.4f} | time: {iter_time*1000:0.2f}ms | tokens processed: {tokens_processed:,} | tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
      if step % trconf.eval_interval == 0:
        pass
        #valid_loss, completions = evaluate(m)
        #valid_loss = jnp.float32(valid_loss)
        #val_losses.append((step, valid_loss))
        #append_to_csv(log_dir / f"{run_dirname}_valid.csv", [step, valid_loss])
        #print(f"valid loss: {valid_loss:0.4f}"  )
        #for completion in completions:
        #  print(completion)
      #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
        #save_checkpoint(m, run_dirname, step)
      step += 1

  except KeyboardInterrupt:
      print("Received KeyboardInterrupt. Exiting...")

  #valid_loss, completions = evaluate(m)
  #valid_loss = jnp.float32(valid_loss)
  #print(f"valid loss: {valid_loss:0.4f}")
  #print(f"completions: {completions}")
  #for completion in completions:
  #  print(completion)
  plt.figure(figsize=(10, 5))
  plt.plot([x[0] for x in train_losses], [x[1] for x in train_losses], label="train loss")
  plt.plot([x[0] for x in val_losses], [x[1] for x in val_losses], label="valid loss")
  plt.legend()
  plt.savefig(log_dir / f"{run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
  plt.show()
# Out:
# 0 | lr: 8.39e-07 | loss: 10.9375 | time: 66688.24ms | tokens processed: 2,048 | tok/sec: 30.71
# 1 | lr: 1.68e-06 | loss: 10.8125 | time: 47497.09ms | tokens processed: 4,096 | tok/sec: 43.12
# 2 | lr: 2.52e-06 | loss: 10.4375 | time: 46.86ms | tokens processed: 6,144 | tok/sec: 43,704.23
# 3 | lr: 3.36e-06 | loss: 10.2500 | time: 42.69ms | tokens processed: 8,192 | tok/sec: 47,969.43
# 4 | lr: 4.20e-06 | loss: 10.0625 | time: 40.50ms | tokens processed: 10,240 | tok/sec: 50,569.18
# 5 | lr: 5.03e-06 | loss: 9.8125 | time: 40.45ms | tokens processed: 12,288 | tok/sec: 50,634.47
# 6 | lr: 5.87e-06 | loss: 9.6250 | time: 38.77ms | tokens processed: 14,336 | tok/sec: 52,825.38
# 7 | lr: 6.71e-06 | loss: 9.5000 | time: 45.82ms | tokens processed: 16,384 | tok/sec: 44,692.22
# 8 | lr: 7.55e-06 | loss: 9.5000 | time: 47.36ms | tokens processed: 18,432 | tok/sec: 43,243.95
# 9 | lr: 8.39e-06 | loss: 9.3125 | time: 47.74ms | tokens processed: 20,480 | tok/sec: 42,895.84
# 10 | lr: 9.23e-06 | loss: 9.3750 | time: 45.11ms | tokens processed: 22,528 | tok/sec: 45,399.67
# 11 | lr: 1.01e-05 | loss: 9.0625 | time: 43.74ms | tokens processed: 24,576 | tok/sec: 46,819.80
# 12 | lr: 1.09e-05 | loss: 8.9375 | time: 41.50ms | tokens processed: 26,624 | tok/sec: 49,352.69
# 13 | lr: 1.17e-05 | loss: 9.1250 | time: 41.97ms | tokens processed: 28,672 | tok/sec: 48,800.62
# 14 | lr: 1.26e-05 | loss: 9.1250 | time: 40.18ms | tokens processed: 30,720 | tok/sec: 50,970.98
# 15 | lr: 1.34e-05 | loss: 8.8125 | time: 39.56ms | tokens processed: 32,768 | tok/sec: 51,771.23
# 16 | lr: 1.43e-05 | loss: 8.6250 | time: 39.21ms | tokens processed: 34,816 | tok/sec: 52,233.37
# 17 | lr: 1.51e-05 | loss: 8.8125 | time: 40.83ms | tokens processed: 36,864 | tok/sec: 50,164.30
# 18 | lr: 1.59e-05 | loss: 8.8125 | time: 40.08ms | tokens processed: 38,912 | tok/sec: 51,091.94
# 19 | lr: 1.68e-05 | loss: 8.5625 | time: 466.06ms | tokens processed: 40,960 | tok/sec: 4,394.28
# 20 | lr: 1.76e-05 | loss: 8.5000 | time: 43.74ms | tokens processed: 43,008 | tok/sec: 46,825.41
# 21 | lr: 1.85e-05 | loss: 8.6875 | time: 42.01ms | tokens processed: 45,056 | tok/sec: 48,755.75
# 22 | lr: 1.93e-05 | loss: 8.5625 | time: 40.62ms | tokens processed: 47,104 | tok/sec: 50,421.66
# 23 | lr: 2.01e-05 | loss: 8.5625 | time: 41.13ms | tokens processed: 49,152 | tok/sec: 49,794.99
# 24 | lr: 2.10e-05 | loss: 8.6875 | time: 40.94ms | tokens processed: 51,200 | tok/sec: 50,025.24
# 25 | lr: 2.18e-05 | loss: 8.5625 | time: 38.98ms | tokens processed: 53,248 | tok/sec: 52,535.90
# 26 | lr: 2.27e-05 | loss: 8.5000 | time: 38.64ms | tokens processed: 55,296 | tok/sec: 52,996.81
# 27 | lr: 2.35e-05 | loss: 8.4375 | time: 38.92ms | tokens processed: 57,344 | tok/sec: 52,623.76
# 28 | lr: 2.43e-05 | loss: 8.6875 | time: 39.13ms | tokens processed: 59,392 | tok/sec: 52,332.02
# 29 | lr: 2.52e-05 | loss: 8.4375 | time: 39.07ms | tokens processed: 61,440 | tok/sec: 52,412.49
# 30 | lr: 2.60e-05 | loss: 8.3750 | time: 41.02ms | tokens processed: 63,488 | tok/sec: 49,926.97
# 31 | lr: 2.69e-05 | loss: 8.4375 | time: 42.26ms | tokens processed: 65,536 | tok/sec: 48,460.07
# 32 | lr: 2.77e-05 | loss: 8.5625 | time: 40.54ms | tokens processed: 67,584 | tok/sec: 50,513.58
# 33 | lr: 2.85e-05 | loss: 8.0625 | time: 38.86ms | tokens processed: 69,632 | tok/sec: 52,702.87
# 34 | lr: 2.94e-05 | loss: 8.3750 | time: 39.30ms | tokens processed: 71,680 | tok/sec: 52,112.64
# 35 | lr: 3.02e-05 | loss: 8.3125 | time: 38.84ms | tokens processed: 73,728 | tok/sec: 52,728.75
# 36 | lr: 3.10e-05 | loss: 8.3125 | time: 39.22ms | tokens processed: 75,776 | tok/sec: 52,218.13
# 37 | lr: 3.19e-05 | loss: 8.3750 | time: 38.61ms | tokens processed: 77,824 | tok/sec: 53,043.61
# 38 | lr: 3.27e-05 | loss: 8.3125 | time: 39.90ms | tokens processed: 79,872 | tok/sec: 51,325.17
# 39 | lr: 3.36e-05 | loss: 8.0625 | time: 43.14ms | tokens processed: 81,920 | tok/sec: 47,468.69
# 40 | lr: 3.44e-05 | loss: 8.3750 | time: 40.17ms | tokens processed: 83,968 | tok/sec: 50,979.14
# 41 | lr: 3.52e-05 | loss: 8.0000 | time: 38.50ms | tokens processed: 86,016 | tok/sec: 53,194.38
# 42 | lr: 3.61e-05 | loss: 7.9375 | time: 40.58ms | tokens processed: 88,064 | tok/sec: 50,469.06
# 43 | lr: 3.69e-05 | loss: 8.2500 | time: 476.36ms | tokens processed: 90,112 | tok/sec: 4,299.28
# 44 | lr: 3.78e-05 | loss: 8.1250 | time: 42.77ms | tokens processed: 92,160 | tok/sec: 47,886.54
# 45 | lr: 3.86e-05 | loss: 8.1875 | time: 41.98ms | tokens processed: 94,208 | tok/sec: 48,785.38
# 46 | lr: 3.94e-05 | loss: 8.1250 | time: 41.30ms | tokens processed: 96,256 | tok/sec: 49,586.59
# 47 | lr: 4.03e-05 | loss: 8.0000 | time: 39.51ms | tokens processed: 98,304 | tok/sec: 51,830.90
# 48 | lr: 4.11e-05 | loss: 7.8438 | time: 41.96ms | tokens processed: 100,352 | tok/sec: 48,807.00
# 49 | lr: 4.20e-05 | loss: 8.1250 | time: 42.21ms | tokens processed: 102,400 | tok/sec: 48,523.30
# 50 | lr: 4.28e-05 | loss: 8.1875 | time: 43.24ms | tokens processed: 104,448 | tok/sec: 47,362.43
# 51 | lr: 4.36e-05 | loss: 8.1875 | time: 41.26ms | tokens processed: 106,496 | tok/sec: 49,641.32
# 52 | lr: 4.45e-05 | loss: 8.0000 | time: 41.60ms | tokens processed: 108,544 | tok/sec: 49,231.06
# 53 | lr: 4.53e-05 | loss: 8.0000 | time: 39.82ms | tokens processed: 110,592 | tok/sec: 51,432.73
# 54 | lr: 4.62e-05 | loss: 8.0625 | time: 39.84ms | tokens processed: 112,640 | tok/sec: 51,406.26
# 55 | lr: 4.70e-05 | loss: 7.9062 | time: 46.26ms | tokens processed: 114,688 | tok/sec: 44,267.06
# 56 | lr: 4.78e-05 | loss: 8.0625 | time: 45.91ms | tokens processed: 116,736 | tok/sec: 44,607.51
# 57 | lr: 4.87e-05 | loss: 8.0625 | time: 43.36ms | tokens processed: 118,784 | tok/sec: 47,234.82
# 58 | lr: 4.95e-05 | loss: 7.9062 | time: 44.41ms | tokens processed: 120,832 | tok/sec: 46,114.76
# 59 | lr: 5.03e-05 | loss: 7.9062 | time: 44.28ms | tokens processed: 122,880 | tok/sec: 46,248.83
# 60 | lr: 5.12e-05 | loss: 7.8438 | time: 44.82ms | tokens processed: 124,928 | tok/sec: 45,689.68
# 61 | lr: 5.20e-05 | loss: 7.8438 | time: 41.82ms | tokens processed: 126,976 | tok/sec: 48,973.12
# 62 | lr: 5.29e-05 | loss: 7.8438 | time: 42.96ms | tokens processed: 129,024 | tok/sec: 47,673.39
# 63 | lr: 5.37e-05 | loss: 7.8438 | time: 42.75ms | tokens processed: 131,072 | tok/sec: 47,911.91
# 64 | lr: 5.45e-05 | loss: 7.6875 | time: 41.61ms | tokens processed: 133,120 | tok/sec: 49,215.27
# 65 | lr: 5.54e-05 | loss: 7.8125 | time: 39.48ms | tokens processed: 135,168 | tok/sec: 51,870.33
# 66 | lr: 5.62e-05 | loss: 7.6250 | time: 468.34ms | tokens processed: 137,216 | tok/sec: 4,372.90
# 67 | lr: 5.71e-05 | loss: 7.8750 | time: 43.21ms | tokens processed: 139,264 | tok/sec: 47,399.02
# 68 | lr: 5.79e-05 | loss: 7.7812 | time: 41.51ms | tokens processed: 141,312 | tok/sec: 49,341.92
# 69 | lr: 5.87e-05 | loss: 7.7500 | time: 40.50ms | tokens processed: 143,360 | tok/sec: 50,572.16
# 70 | lr: 5.96e-05 | loss: 7.6562 | time: 41.63ms | tokens processed: 145,408 | tok/sec: 49,190.19
# 71 | lr: 6.04e-05 | loss: 7.7188 | time: 40.97ms | tokens processed: 147,456 | tok/sec: 49,986.53
# 72 | lr: 6.13e-05 | loss: 7.9375 | time: 39.70ms | tokens processed: 149,504 | tok/sec: 51,580.98
# 73 | lr: 6.21e-05 | loss: 7.2188 | time: 39.04ms | tokens processed: 151,552 | tok/sec: 52,455.69
# 74 | lr: 6.29e-05 | loss: 7.2812 | time: 39.52ms | tokens processed: 153,600 | tok/sec: 51,817.45
# 75 | lr: 6.38e-05 | loss: 7.5000 | time: 39.61ms | tokens processed: 155,648 | tok/sec: 51,709.53
# 76 | lr: 6.46e-05 | loss: 7.5000 | time: 40.40ms | tokens processed: 157,696 | tok/sec: 50,691.24
# 77 | lr: 6.55e-05 | loss: 7.4375 | time: 41.18ms | tokens processed: 159,744 | tok/sec: 49,729.26
# 78 | lr: 6.63e-05 | loss: 7.4688 | time: 42.94ms | tokens processed: 161,792 | tok/sec: 47,699.86
# 79 | lr: 6.71e-05 | loss: 7.4062 | time: 41.57ms | tokens processed: 163,840 | tok/sec: 49,263.53
# 80 | lr: 6.80e-05 | loss: 7.4062 | time: 40.20ms | tokens processed: 165,888 | tok/sec: 50,950.72
# 81 | lr: 6.88e-05 | loss: 7.5312 | time: 38.66ms | tokens processed: 167,936 | tok/sec: 52,975.89
# 82 | lr: 6.97e-05 | loss: 7.3125 | time: 39.89ms | tokens processed: 169,984 | tok/sec: 51,340.20
# 83 | lr: 7.05e-05 | loss: 7.1875 | time: 39.44ms | tokens processed: 172,032 | tok/sec: 51,931.17
# 84 | lr: 7.13e-05 | loss: 7.2812 | time: 40.47ms | tokens processed: 174,080 | tok/sec: 50,606.43
# 85 | lr: 7.22e-05 | loss: 7.4375 | time: 40.47ms | tokens processed: 176,128 | tok/sec: 50,607.02
# 86 | lr: 7.30e-05 | loss: 7.4375 | time: 40.60ms | tokens processed: 178,176 | tok/sec: 50,441.50
# 87 | lr: 7.38e-05 | loss: 6.9688 | time: 43.60ms | tokens processed: 180,224 | tok/sec: 46,967.77
# 88 | lr: 7.47e-05 | loss: 7.0625 | time: 456.82ms | tokens processed: 182,272 | tok/sec: 4,483.14
# 89 | lr: 7.55e-05 | loss: 7.1875 | time: 50.17ms | tokens processed: 184,320 | tok/sec: 40,821.25
# 90 | lr: 7.64e-05 | loss: 6.9375 | time: 45.49ms | tokens processed: 186,368 | tok/sec: 45,018.03
# 91 | lr: 7.72e-05 | loss: 6.9688 | time: 42.51ms | tokens processed: 188,416 | tok/sec: 48,177.13
# 92 | lr: 7.80e-05 | loss: 6.9062 | time: 41.11ms | tokens processed: 190,464 | tok/sec: 49,815.20
# 93 | lr: 7.89e-05 | loss: 6.7812 | time: 40.40ms | tokens processed: 192,512 | tok/sec: 50,690.04
# 94 | lr: 7.97e-05 | loss: 6.8750 | time: 39.61ms | tokens processed: 194,560 | tok/sec: 51,702.99
# 95 | lr: 8.06e-05 | loss: 6.6875 | time: 41.46ms | tokens processed: 196,608 | tok/sec: 49,396.68
# 96 | lr: 8.14e-05 | loss: 6.7500 | time: 43.62ms | tokens processed: 198,656 | tok/sec: 46,953.39
# 97 | lr: 8.22e-05 | loss: 6.7500 | time: 43.74ms | tokens processed: 200,704 | tok/sec: 46,820.56
# 98 | lr: 8.31e-05 | loss: 6.5938 | time: 41.49ms | tokens processed: 202,752 | tok/sec: 49,362.62
# 99 | lr: 8.39e-05 | loss: 6.8125 | time: 40.01ms | tokens processed: 204,800 | tok/sec: 51,181.44
# 100 | lr: 8.48e-05 | loss: 6.6250 | time: 40.72ms | tokens processed: 206,848 | tok/sec: 50,291.47
# 101 | lr: 8.56e-05 | loss: 6.5938 | time: 40.47ms | tokens processed: 208,896 | tok/sec: 50,603.15
# 102 | lr: 8.64e-05 | loss: 6.5000 | time: 40.48ms | tokens processed: 210,944 | tok/sec: 50,588.25
# 103 | lr: 8.73e-05 | loss: 6.5625 | time: 39.35ms | tokens processed: 212,992 | tok/sec: 52,045.70
# 104 | lr: 8.81e-05 | loss: 6.5000 | time: 39.75ms | tokens processed: 215,040 | tok/sec: 51,516.32
# 105 | lr: 8.90e-05 | loss: 6.2812 | time: 39.87ms | tokens processed: 217,088 | tok/sec: 51,362.00
# 106 | lr: 8.98e-05 | loss: 6.3750 | time: 41.04ms | tokens processed: 219,136 | tok/sec: 49,904.34
# 107 | lr: 9.06e-05 | loss: 6.3750 | time: 42.01ms | tokens processed: 221,184 | tok/sec: 48,750.77
# 108 | lr: 9.15e-05 | loss: 6.2812 | time: 43.69ms | tokens processed: 223,232 | tok/sec: 46,872.17
# 109 | lr: 9.23e-05 | loss: 6.3750 | time: 459.55ms | tokens processed: 225,280 | tok/sec: 4,456.50
# 110 | lr: 9.31e-05 | loss: 6.3125 | time: 49.38ms | tokens processed: 227,328 | tok/sec: 41,476.23
# 111 | lr: 9.40e-05 | loss: 6.0938 | time: 47.95ms | tokens processed: 229,376 | tok/sec: 42,707.73
# 112 | lr: 9.48e-05 | loss: 6.2500 | time: 47.01ms | tokens processed: 231,424 | tok/sec: 43,561.72
# 113 | lr: 9.57e-05 | loss: 5.9688 | time: 43.71ms | tokens processed: 233,472 | tok/sec: 46,850.70
# 114 | lr: 9.65e-05 | loss: 6.0625 | time: 41.16ms | tokens processed: 235,520 | tok/sec: 49,751.15
# 115 | lr: 9.73e-05 | loss: 6.0625 | time: 40.45ms | tokens processed: 237,568 | tok/sec: 50,633.27
# 116 | lr: 9.82e-05 | loss: 6.2500 | time: 41.19ms | tokens processed: 239,616 | tok/sec: 49,723.51
# 117 | lr: 9.90e-05 | loss: 6.0625 | time: 43.22ms | tokens processed: 241,664 | tok/sec: 47,385.95
# 118 | lr: 9.99e-05 | loss: 6.0938 | time: 46.05ms | tokens processed: 243,712 | tok/sec: 44,470.11
# 119 | lr: 1.01e-04 | loss: 5.9688 | time: 41.52ms | tokens processed: 245,760 | tok/sec: 49,324.64
# 120 | lr: 1.02e-04 | loss: 5.9688 | time: 43.04ms | tokens processed: 247,808 | tok/sec: 47,581.49
# 121 | lr: 1.02e-04 | loss: 6.1875 | time: 44.29ms | tokens processed: 249,856 | tok/sec: 46,245.60
# 122 | lr: 1.03e-04 | loss: 6.1250 | time: 44.67ms | tokens processed: 251,904 | tok/sec: 45,845.26
# 123 | lr: 1.04e-04 | loss: 6.0312 | time: 45.65ms | tokens processed: 253,952 | tok/sec: 44,866.13
# 124 | lr: 1.05e-04 | loss: 5.9375 | time: 44.68ms | tokens processed: 256,000 | tok/sec: 45,835.72
# 125 | lr: 1.06e-04 | loss: 5.9062 | time: 44.16ms | tokens processed: 258,048 | tok/sec: 46,380.43
# 126 | lr: 1.07e-04 | loss: 5.8438 | time: 48.90ms | tokens processed: 260,096 | tok/sec: 41,879.65
# 127 | lr: 1.07e-04 | loss: 5.9688 | time: 41.97ms | tokens processed: 262,144 | tok/sec: 48,791.75
# 128 | lr: 1.08e-04 | loss: 5.8750 | time: 39.23ms | tokens processed: 264,192 | tok/sec: 52,206.70
# 129 | lr: 1.09e-04 | loss: 5.9375 | time: 44.40ms | tokens processed: 266,240 | tok/sec: 46,122.93
# 130 | lr: 1.10e-04 | loss: 5.5938 | time: 43.02ms | tokens processed: 268,288 | tok/sec: 47,604.96
# 131 | lr: 1.11e-04 | loss: 5.7500 | time: 43.63ms | tokens processed: 270,336 | tok/sec: 46,938.76
# 132 | lr: 1.12e-04 | loss: 5.8438 | time: 41.77ms | tokens processed: 272,384 | tok/sec: 49,026.23
# 133 | lr: 1.12e-04 | loss: 5.7500 | time: 479.07ms | tokens processed: 274,432 | tok/sec: 4,274.95
# 134 | lr: 1.13e-04 | loss: 5.7812 | time: 45.55ms | tokens processed: 276,480 | tok/sec: 44,963.59
# 135 | lr: 1.14e-04 | loss: 5.5000 | time: 43.21ms | tokens processed: 278,528 | tok/sec: 47,400.07
# 136 | lr: 1.15e-04 | loss: 5.5312 | time: 43.61ms | tokens processed: 280,576 | tok/sec: 46,956.98
# 137 | lr: 1.16e-04 | loss: 5.3438 | time: 43.63ms | tokens processed: 282,624 | tok/sec: 46,939.28
# 138 | lr: 1.17e-04 | loss: 5.4688 | time: 43.04ms | tokens processed: 284,672 | tok/sec: 47,587.03
# 139 | lr: 1.17e-04 | loss: 5.6562 | time: 40.32ms | tokens processed: 286,720 | tok/sec: 50,791.35
# 140 | lr: 1.18e-04 | loss: 5.5625 | time: 39.13ms | tokens processed: 288,768 | tok/sec: 52,342.86
# 141 | lr: 1.19e-04 | loss: 5.4375 | time: 38.77ms | tokens processed: 290,816 | tok/sec: 52,827.98
# 142 | lr: 1.20e-04 | loss: 5.4688 | time: 41.11ms | tokens processed: 292,864 | tok/sec: 49,819.54
# 143 | lr: 1.21e-04 | loss: 5.9062 | time: 39.62ms | tokens processed: 294,912 | tok/sec: 51,688.37
# 144 | lr: 1.22e-04 | loss: 5.7500 | time: 40.47ms | tokens processed: 296,960 | tok/sec: 50,600.16
# 145 | lr: 1.23e-04 | loss: 5.2812 | time: 42.52ms | tokens processed: 299,008 | tok/sec: 48,170.92
# 146 | lr: 1.23e-04 | loss: 5.4062 | time: 41.50ms | tokens processed: 301,056 | tok/sec: 49,343.62
# 147 | lr: 1.24e-04 | loss: 5.3750 | time: 40.76ms | tokens processed: 303,104 | tok/sec: 50,240.59
# 148 | lr: 1.25e-04 | loss: 5.4688 | time: 39.07ms | tokens processed: 305,152 | tok/sec: 52,412.17
# 149 | lr: 1.26e-04 | loss: 5.4688 | time: 41.20ms | tokens processed: 307,200 | tok/sec: 49,704.80
# 150 | lr: 1.27e-04 | loss: 5.4688 | time: 41.91ms | tokens processed: 309,248 | tok/sec: 48,863.64
# 151 | lr: 1.28e-04 | loss: 5.4688 | time: 41.32ms | tokens processed: 311,296 | tok/sec: 49,569.99
# 152 | lr: 1.28e-04 | loss: 5.6250 | time: 40.86ms | tokens processed: 313,344 | tok/sec: 50,117.77
# 153 | lr: 1.29e-04 | loss: 5.5625 | time: 41.02ms | tokens processed: 315,392 | tok/sec: 49,923.19
# 154 | lr: 1.30e-04 | loss: 5.3438 | time: 39.43ms | tokens processed: 317,440 | tok/sec: 51,941.85
# 155 | lr: 1.31e-04 | loss: 5.5000 | time: 38.84ms | tokens processed: 319,488 | tok/sec: 52,729.07
# 156 | lr: 1.32e-04 | loss: 5.4688 | time: 42.32ms | tokens processed: 321,536 | tok/sec: 48,388.00
# 157 | lr: 1.33e-04 | loss: 5.5625 | time: 42.06ms | tokens processed: 323,584 | tok/sec: 48,692.19
# 158 | lr: 1.33e-04 | loss: 5.6875 | time: 39.62ms | tokens processed: 325,632 | tok/sec: 51,692.72
# 159 | lr: 1.34e-04 | loss: 5.2500 | time: 470.03ms | tokens processed: 327,680 | tok/sec: 4,357.13
# 160 | lr: 1.35e-04 | loss: 5.2500 | time: 42.30ms | tokens processed: 329,728 | tok/sec: 48,415.27
# 161 | lr: 1.36e-04 | loss: 5.5312 | time: 41.76ms | tokens processed: 331,776 | tok/sec: 49,047.78
# 162 | lr: 1.37e-04 | loss: 5.3438 | time: 40.69ms | tokens processed: 333,824 | tok/sec: 50,329.49
# 163 | lr: 1.38e-04 | loss: 5.3750 | time: 40.49ms | tokens processed: 335,872 | tok/sec: 50,584.97
# 164 | lr: 1.38e-04 | loss: 5.1875 | time: 39.44ms | tokens processed: 337,920 | tok/sec: 51,928.34
# 165 | lr: 1.39e-04 | loss: 5.2188 | time: 39.04ms | tokens processed: 339,968 | tok/sec: 52,459.86
# 166 | lr: 1.40e-04 | loss: 5.2812 | time: 38.34ms | tokens processed: 342,016 | tok/sec: 53,413.68
# 167 | lr: 1.41e-04 | loss: 5.1875 | time: 38.87ms | tokens processed: 344,064 | tok/sec: 52,685.41
# 168 | lr: 1.42e-04 | loss: 5.1250 | time: 38.94ms | tokens processed: 346,112 | tok/sec: 52,588.97
# 169 | lr: 1.43e-04 | loss: 5.2188 | time: 38.69ms | tokens processed: 348,160 | tok/sec: 52,928.56
# 170 | lr: 1.43e-04 | loss: 5.3750 | time: 39.12ms | tokens processed: 350,208 | tok/sec: 52,350.52
# 171 | lr: 1.44e-04 | loss: 5.3438 | time: 40.06ms | tokens processed: 352,256 | tok/sec: 51,129.04
# 172 | lr: 1.45e-04 | loss: 5.2500 | time: 40.08ms | tokens processed: 354,304 | tok/sec: 51,098.32
# 173 | lr: 1.46e-04 | loss: 5.1562 | time: 39.93ms | tokens processed: 356,352 | tok/sec: 51,286.56
# 174 | lr: 1.47e-04 | loss: 5.2188 | time: 41.00ms | tokens processed: 358,400 | tok/sec: 49,955.13
# 175 | lr: 1.48e-04 | loss: 5.3438 | time: 42.49ms | tokens processed: 360,448 | tok/sec: 48,195.78
# 176 | lr: 1.49e-04 | loss: 5.1250 | time: 39.91ms | tokens processed: 362,496 | tok/sec: 51,313.83
# 177 | lr: 1.49e-04 | loss: 5.2500 | time: 39.84ms | tokens processed: 364,544 | tok/sec: 51,411.80
# 178 | lr: 1.50e-04 | loss: 5.1250 | time: 39.86ms | tokens processed: 366,592 | tok/sec: 51,385.96
# 179 | lr: 1.51e-04 | loss: 5.1250 | time: 41.55ms | tokens processed: 368,640 | tok/sec: 49,290.11
# 180 | lr: 1.52e-04 | loss: 5.1250 | time: 40.49ms | tokens processed: 370,688 | tok/sec: 50,577.22
# 181 | lr: 1.53e-04 | loss: 5.1875 | time: 40.18ms | tokens processed: 372,736 | tok/sec: 50,966.44
# 182 | lr: 1.54e-04 | loss: 5.1562 | time: 37.41ms | tokens processed: 374,784 | tok/sec: 54,748.88
# 183 | lr: 1.54e-04 | loss: 5.0625 | time: 460.49ms | tokens processed: 376,832 | tok/sec: 4,447.41
# 184 | lr: 1.55e-04 | loss: 5.1250 | time: 41.09ms | tokens processed: 378,880 | tok/sec: 49,845.85
# 185 | lr: 1.56e-04 | loss: 5.0000 | time: 42.27ms | tokens processed: 380,928 | tok/sec: 48,451.32
# 186 | lr: 1.57e-04 | loss: 4.9688 | time: 42.54ms | tokens processed: 382,976 | tok/sec: 48,144.46
# 187 | lr: 1.58e-04 | loss: 5.0625 | time: 40.14ms | tokens processed: 385,024 | tok/sec: 51,027.29
# 188 | lr: 1.59e-04 | loss: 5.2812 | time: 41.32ms | tokens processed: 387,072 | tok/sec: 49,561.99
# 189 | lr: 1.59e-04 | loss: 5.0625 | time: 40.10ms | tokens processed: 389,120 | tok/sec: 51,067.03
# 190 | lr: 1.60e-04 | loss: 5.0938 | time: 39.59ms | tokens processed: 391,168 | tok/sec: 51,725.72
# 191 | lr: 1.61e-04 | loss: 5.0625 | time: 41.05ms | tokens processed: 393,216 | tok/sec: 49,884.63
# 192 | lr: 1.62e-04 | loss: 5.2812 | time: 39.92ms | tokens processed: 395,264 | tok/sec: 51,305.25
# 193 | lr: 1.63e-04 | loss: 5.3438 | time: 38.81ms | tokens processed: 397,312 | tok/sec: 52,765.02
# 194 | lr: 1.64e-04 | loss: 5.2500 | time: 46.00ms | tokens processed: 399,360 | tok/sec: 44,523.35
# 195 | lr: 1.64e-04 | loss: 5.1875 | time: 47.28ms | tokens processed: 401,408 | tok/sec: 43,317.87
# 196 | lr: 1.65e-04 | loss: 4.9375 | time: 44.95ms | tokens processed: 403,456 | tok/sec: 45,561.49
# 197 | lr: 1.66e-04 | loss: 5.0625 | time: 43.96ms | tokens processed: 405,504 | tok/sec: 46,589.98
# 198 | lr: 1.67e-04 | loss: 5.0938 | time: 43.61ms | tokens processed: 407,552 | tok/sec: 46,961.60
# 199 | lr: 1.68e-04 | loss: 5.0625 | time: 42.49ms | tokens processed: 409,600 | tok/sec: 48,197.95
# 200 | lr: 1.69e-04 | loss: 4.9688 | time: 42.34ms | tokens processed: 411,648 | tok/sec: 48,370.29
# 201 | lr: 1.70e-04 | loss: 5.0000 | time: 39.68ms | tokens processed: 413,696 | tok/sec: 51,611.66
# 202 | lr: 1.70e-04 | loss: 4.7500 | time: 40.97ms | tokens processed: 415,744 | tok/sec: 49,986.53
# 203 | lr: 1.71e-04 | loss: 5.0625 | time: 45.89ms | tokens processed: 417,792 | tok/sec: 44,632.77
# 204 | lr: 1.72e-04 | loss: 4.9688 | time: 43.35ms | tokens processed: 419,840 | tok/sec: 47,248.07
# 205 | lr: 1.73e-04 | loss: 5.1875 | time: 41.82ms | tokens processed: 421,888 | tok/sec: 48,973.96
# 206 | lr: 1.74e-04 | loss: 4.8125 | time: 477.92ms | tokens processed: 423,936 | tok/sec: 4,285.22
# 207 | lr: 1.75e-04 | loss: 4.5312 | time: 47.98ms | tokens processed: 425,984 | tok/sec: 42,684.39
# 208 | lr: 1.75e-04 | loss: 4.7188 | time: 45.17ms | tokens processed: 428,032 | tok/sec: 45,338.80
# 209 | lr: 1.76e-04 | loss: 4.4375 | time: 43.45ms | tokens processed: 430,080 | tok/sec: 47,136.58
# 210 | lr: 1.77e-04 | loss: 4.7500 | time: 44.29ms | tokens processed: 432,128 | tok/sec: 46,240.62
# 211 | lr: 1.78e-04 | loss: 4.9375 | time: 40.13ms | tokens processed: 434,176 | tok/sec: 51,040.03
# 212 | lr: 1.79e-04 | loss: 4.6562 | time: 40.22ms | tokens processed: 436,224 | tok/sec: 50,918.40
# 213 | lr: 1.80e-04 | loss: 4.7812 | time: 41.90ms | tokens processed: 438,272 | tok/sec: 48,873.93
# 214 | lr: 1.80e-04 | loss: 4.8125 | time: 42.93ms | tokens processed: 440,320 | tok/sec: 47,704.63
# 215 | lr: 1.81e-04 | loss: 5.5000 | time: 42.33ms | tokens processed: 442,368 | tok/sec: 48,383.37
# 216 | lr: 1.82e-04 | loss: 4.8750 | time: 42.42ms | tokens processed: 444,416 | tok/sec: 48,282.47
# 217 | lr: 1.83e-04 | loss: 4.7812 | time: 44.53ms | tokens processed: 446,464 | tok/sec: 45,987.12
# 218 | lr: 1.84e-04 | loss: 4.8125 | time: 41.89ms | tokens processed: 448,512 | tok/sec: 48,895.35
# 219 | lr: 1.85e-04 | loss: 4.7812 | time: 41.19ms | tokens processed: 450,560 | tok/sec: 49,719.48
# 220 | lr: 1.85e-04 | loss: 4.8125 | time: 42.13ms | tokens processed: 452,608 | tok/sec: 48,613.92
# 221 | lr: 1.86e-04 | loss: 4.9688 | time: 42.11ms | tokens processed: 454,656 | tok/sec: 48,638.15
# 222 | lr: 1.87e-04 | loss: 4.7812 | time: 40.23ms | tokens processed: 456,704 | tok/sec: 50,912.07
# 223 | lr: 1.88e-04 | loss: 5.0625 | time: 43.83ms | tokens processed: 458,752 | tok/sec: 46,724.80
# 224 | lr: 1.89e-04 | loss: 5.0000 | time: 40.11ms | tokens processed: 460,800 | tok/sec: 51,063.69
# 225 | lr: 1.90e-04 | loss: 5.0312 | time: 39.51ms | tokens processed: 462,848 | tok/sec: 51,840.59
# 226 | lr: 1.90e-04 | loss: 4.8125 | time: 39.40ms | tokens processed: 464,896 | tok/sec: 51,983.34
# 227 | lr: 1.91e-04 | loss: 5.0625 | time: 44.84ms | tokens processed: 466,944 | tok/sec: 45,673.16
# 228 | lr: 1.92e-04 | loss: 4.9688 | time: 465.83ms | tokens processed: 468,992 | tok/sec: 4,396.41
# 229 | lr: 1.93e-04 | loss: 5.2188 | time: 42.63ms | tokens processed: 471,040 | tok/sec: 48,045.63
# 230 | lr: 1.94e-04 | loss: 4.9062 | time: 39.79ms | tokens processed: 473,088 | tok/sec: 51,467.24
# 231 | lr: 1.95e-04 | loss: 4.7500 | time: 41.16ms | tokens processed: 475,136 | tok/sec: 49,760.09
# 232 | lr: 1.96e-04 | loss: 4.8750 | time: 40.17ms | tokens processed: 477,184 | tok/sec: 50,979.14
# 233 | lr: 1.96e-04 | loss: 4.8750 | time: 40.15ms | tokens processed: 479,232 | tok/sec: 51,012.44
# 234 | lr: 1.97e-04 | loss: 4.8438 | time: 38.07ms | tokens processed: 481,280 | tok/sec: 53,802.43
# 235 | lr: 1.98e-04 | loss: 4.9375 | time: 38.64ms | tokens processed: 483,328 | tok/sec: 53,007.93
# 236 | lr: 1.99e-04 | loss: 4.6875 | time: 40.30ms | tokens processed: 485,376 | tok/sec: 50,824.71
# 237 | lr: 2.00e-04 | loss: 4.7500 | time: 39.96ms | tokens processed: 487,424 | tok/sec: 51,254.43
# 238 | lr: 2.01e-04 | loss: 4.6875 | time: 41.65ms | tokens processed: 489,472 | tok/sec: 49,172.73
# 239 | lr: 2.01e-04 | loss: 4.7188 | time: 39.67ms | tokens processed: 491,520 | tok/sec: 51,625.00
# 240 | lr: 2.02e-04 | loss: 4.5625 | time: 40.02ms | tokens processed: 493,568 | tok/sec: 51,180.22
# 241 | lr: 2.03e-04 | loss: 4.8125 | time: 40.70ms | tokens processed: 495,616 | tok/sec: 50,319.46
# 242 | lr: 2.04e-04 | loss: 4.8750 | time: 42.15ms | tokens processed: 497,664 | tok/sec: 48,586.43
# 243 | lr: 2.05e-04 | loss: 4.8125 | time: 43.24ms | tokens processed: 499,712 | tok/sec: 47,361.65
# 244 | lr: 2.06e-04 | loss: 4.7500 | time: 41.66ms | tokens processed: 501,760 | tok/sec: 49,164.00
# 245 | lr: 2.06e-04 | loss: 4.6562 | time: 41.04ms | tokens processed: 503,808 | tok/sec: 49,907.53
# 246 | lr: 2.07e-04 | loss: 4.7500 | time: 39.70ms | tokens processed: 505,856 | tok/sec: 51,588.41
# 247 | lr: 2.08e-04 | loss: 4.9688 | time: 41.55ms | tokens processed: 507,904 | tok/sec: 49,286.99
# 248 | lr: 2.09e-04 | loss: 4.6250 | time: 41.89ms | tokens processed: 509,952 | tok/sec: 48,884.22
# 249 | lr: 2.10e-04 | loss: 4.8750 | time: 470.43ms | tokens processed: 512,000 | tok/sec: 4,353.43
# 250 | lr: 2.11e-04 | loss: 4.5312 | time: 44.56ms | tokens processed: 514,048 | tok/sec: 45,958.09
# 251 | lr: 2.11e-04 | loss: 4.5625 | time: 41.01ms | tokens processed: 516,096 | tok/sec: 49,936.83
# 252 | lr: 2.12e-04 | loss: 4.7500 | time: 40.28ms | tokens processed: 518,144 | tok/sec: 50,844.56
# 253 | lr: 2.13e-04 | loss: 4.7500 | time: 44.46ms | tokens processed: 520,192 | tok/sec: 46,060.85
# 254 | lr: 2.14e-04 | loss: 4.6250 | time: 42.27ms | tokens processed: 522,240 | tok/sec: 48,453.51
# 255 | lr: 2.15e-04 | loss: 4.7812 | time: 41.27ms | tokens processed: 524,288 | tok/sec: 49,623.54
# 256 | lr: 2.16e-04 | loss: 4.6250 | time: 40.09ms | tokens processed: 526,336 | tok/sec: 51,084.04
# 257 | lr: 2.17e-04 | loss: 4.5938 | time: 39.17ms | tokens processed: 528,384 | tok/sec: 52,289.97
# 258 | lr: 2.17e-04 | loss: 4.5938 | time: 40.83ms | tokens processed: 530,432 | tok/sec: 50,160.79
# 259 | lr: 2.18e-04 | loss: 4.7188 | time: 44.98ms | tokens processed: 532,480 | tok/sec: 45,528.40
# 260 | lr: 2.19e-04 | loss: 4.7500 | time: 42.52ms | tokens processed: 534,528 | tok/sec: 48,170.92
# 261 | lr: 2.20e-04 | loss: 4.7188 | time: 40.15ms | tokens processed: 536,576 | tok/sec: 51,011.23
# 262 | lr: 2.21e-04 | loss: 4.6875 | time: 40.63ms | tokens processed: 538,624 | tok/sec: 50,410.71
# 263 | lr: 2.22e-04 | loss: 4.6250 | time: 40.13ms | tokens processed: 540,672 | tok/sec: 51,029.11
# 264 | lr: 2.22e-04 | loss: 4.9375 | time: 39.44ms | tokens processed: 542,720 | tok/sec: 51,922.69
# 265 | lr: 2.23e-04 | loss: 4.9688 | time: 40.20ms | tokens processed: 544,768 | tok/sec: 50,949.51
# 266 | lr: 2.24e-04 | loss: 4.8438 | time: 40.82ms | tokens processed: 546,816 | tok/sec: 50,174.85
# 267 | lr: 2.25e-04 | loss: 4.6875 | time: 40.56ms | tokens processed: 548,864 | tok/sec: 50,489.53
# 268 | lr: 2.26e-04 | loss: 4.5312 | time: 40.32ms | tokens processed: 550,912 | tok/sec: 50,794.35
# 269 | lr: 2.27e-04 | loss: 4.5625 | time: 41.88ms | tokens processed: 552,960 | tok/sec: 48,903.70
# 270 | lr: 2.27e-04 | loss: 4.8125 | time: 470.04ms | tokens processed: 555,008 | tok/sec: 4,357.09
# 271 | lr: 2.28e-04 | loss: 4.5625 | time: 46.29ms | tokens processed: 557,056 | tok/sec: 44,239.47
# 272 | lr: 2.29e-04 | loss: 4.5312 | time: 42.77ms | tokens processed: 559,104 | tok/sec: 47,883.07
# 273 | lr: 2.30e-04 | loss: 4.4375 | time: 41.06ms | tokens processed: 561,152 | tok/sec: 49,873.34
# 274 | lr: 2.31e-04 | loss: 4.5000 | time: 40.96ms | tokens processed: 563,200 | tok/sec: 50,002.82
# 275 | lr: 2.32e-04 | loss: 4.7188 | time: 40.82ms | tokens processed: 565,248 | tok/sec: 50,172.21
# 276 | lr: 2.32e-04 | loss: 4.5000 | time: 44.73ms | tokens processed: 567,296 | tok/sec: 45,786.37
# 277 | lr: 2.33e-04 | loss: 4.8125 | time: 41.15ms | tokens processed: 569,344 | tok/sec: 49,775.08
# 278 | lr: 2.34e-04 | loss: 4.2500 | time: 40.53ms | tokens processed: 571,392 | tok/sec: 50,529.03
# 279 | lr: 2.35e-04 | loss: 4.1562 | time: 40.70ms | tokens processed: 573,440 | tok/sec: 50,320.05
# 280 | lr: 2.36e-04 | loss: 4.0625 | time: 41.59ms | tokens processed: 575,488 | tok/sec: 49,245.74
# 281 | lr: 2.37e-04 | loss: 4.0312 | time: 48.24ms | tokens processed: 577,536 | tok/sec: 42,455.28
# 282 | lr: 2.37e-04 | loss: 4.4688 | time: 46.98ms | tokens processed: 579,584 | tok/sec: 43,590.45
# 283 | lr: 2.38e-04 | loss: 4.4688 | time: 45.21ms | tokens processed: 581,632 | tok/sec: 45,300.31
# 284 | lr: 2.39e-04 | loss: 4.2500 | time: 43.80ms | tokens processed: 583,680 | tok/sec: 46,758.38
# 285 | lr: 2.40e-04 | loss: 4.4062 | time: 42.58ms | tokens processed: 585,728 | tok/sec: 48,103.21
# 286 | lr: 2.41e-04 | loss: 4.7188 | time: 44.32ms | tokens processed: 587,776 | tok/sec: 46,208.53
# 287 | lr: 2.42e-04 | loss: 4.9062 | time: 41.31ms | tokens processed: 589,824 | tok/sec: 49,572.00
# 288 | lr: 2.43e-04 | loss: 4.4688 | time: 40.44ms | tokens processed: 591,872 | tok/sec: 50,638.94
# 289 | lr: 2.43e-04 | loss: 4.4062 | time: 40.75ms | tokens processed: 593,920 | tok/sec: 50,261.46
# 290 | lr: 2.44e-04 | loss: 4.4375 | time: 41.86ms | tokens processed: 595,968 | tok/sec: 48,919.57
# 291 | lr: 2.45e-04 | loss: 4.4375 | time: 44.08ms | tokens processed: 598,016 | tok/sec: 46,462.97
# 292 | lr: 2.46e-04 | loss: 4.5312 | time: 40.83ms | tokens processed: 600,064 | tok/sec: 50,159.03
# 293 | lr: 2.47e-04 | loss: 4.5625 | time: 41.72ms | tokens processed: 602,112 | tok/sec: 49,083.66
# 294 | lr: 2.48e-04 | loss: 4.3750 | time: 41.02ms | tokens processed: 604,160 | tok/sec: 49,929.00
# 295 | lr: 2.48e-04 | loss: 4.7188 | time: 40.36ms | tokens processed: 606,208 | tok/sec: 50,745.44
# 296 | lr: 2.49e-04 | loss: 4.7500 | time: 485.24ms | tokens processed: 608,256 | tok/sec: 4,220.58
# 297 | lr: 2.50e-04 | loss: 4.4688 | time: 45.56ms | tokens processed: 610,304 | tok/sec: 44,953.71
# 298 | lr: 2.51e-04 | loss: 4.4062 | time: 43.34ms | tokens processed: 612,352 | tok/sec: 47,253.00
# 299 | lr: 2.52e-04 | loss: 4.7500 | time: 42.21ms | tokens processed: 614,400 | tok/sec: 48,515.90
# 300 | lr: 2.53e-04 | loss: 4.6875 | time: 40.47ms | tokens processed: 616,448 | tok/sec: 50,604.34
# 301 | lr: 2.53e-04 | loss: 4.8438 | time: 41.88ms | tokens processed: 618,496 | tok/sec: 48,905.65
# 302 | lr: 2.54e-04 | loss: 4.5000 | time: 41.55ms | tokens processed: 620,544 | tok/sec: 49,292.93
# 303 | lr: 2.55e-04 | loss: 4.3438 | time: 42.29ms | tokens processed: 622,592 | tok/sec: 48,427.56
# 304 | lr: 2.56e-04 | loss: 4.7188 | time: 40.58ms | tokens processed: 624,640 | tok/sec: 50,471.43
# 305 | lr: 2.57e-04 | loss: 4.4375 | time: 39.88ms | tokens processed: 626,688 | tok/sec: 51,350.33
# 306 | lr: 2.58e-04 | loss: 4.5938 | time: 40.00ms | tokens processed: 628,736 | tok/sec: 51,202.19
# 307 | lr: 2.58e-04 | loss: 4.5312 | time: 38.83ms | tokens processed: 630,784 | tok/sec: 52,741.70
# 308 | lr: 2.59e-04 | loss: 4.2500 | time: 41.77ms | tokens processed: 632,832 | tok/sec: 49,030.71
# 309 | lr: 2.60e-04 | loss: 4.5312 | time: 41.56ms | tokens processed: 634,880 | tok/sec: 49,282.19
# 310 | lr: 2.61e-04 | loss: 4.3125 | time: 42.89ms | tokens processed: 636,928 | tok/sec: 47,749.98
# 311 | lr: 2.62e-04 | loss: 4.3438 | time: 39.86ms | tokens processed: 638,976 | tok/sec: 51,377.36
# 312 | lr: 2.63e-04 | loss: 4.1875 | time: 39.24ms | tokens processed: 641,024 | tok/sec: 52,198.14
# 313 | lr: 2.63e-04 | loss: 4.6250 | time: 38.27ms | tokens processed: 643,072 | tok/sec: 53,508.17
# 314 | lr: 2.64e-04 | loss: 4.5312 | time: 39.01ms | tokens processed: 645,120 | tok/sec: 52,498.01
# 315 | lr: 2.65e-04 | loss: 4.5312 | time: 39.51ms | tokens processed: 647,168 | tok/sec: 51,838.09
# 316 | lr: 2.66e-04 | loss: 4.3750 | time: 39.23ms | tokens processed: 649,216 | tok/sec: 52,202.90
# 317 | lr: 2.67e-04 | loss: 4.3438 | time: 40.30ms | tokens processed: 651,264 | tok/sec: 50,820.50
# 318 | lr: 2.68e-04 | loss: 4.5000 | time: 40.57ms | tokens processed: 653,312 | tok/sec: 50,485.97
# 319 | lr: 2.69e-04 | loss: 4.5312 | time: 39.35ms | tokens processed: 655,360 | tok/sec: 52,043.49
# 320 | lr: 2.69e-04 | loss: 4.4062 | time: 474.85ms | tokens processed: 657,408 | tok/sec: 4,312.93
# 321 | lr: 2.70e-04 | loss: 4.3438 | time: 44.36ms | tokens processed: 659,456 | tok/sec: 46,168.54
# 322 | lr: 2.71e-04 | loss: 4.2812 | time: 41.41ms | tokens processed: 661,504 | tok/sec: 49,458.11
# 323 | lr: 2.72e-04 | loss: 4.2188 | time: 39.65ms | tokens processed: 663,552 | tok/sec: 51,648.59
# 324 | lr: 2.73e-04 | loss: 4.5312 | time: 40.58ms | tokens processed: 665,600 | tok/sec: 50,473.51
# 325 | lr: 2.74e-04 | loss: 4.3750 | time: 40.62ms | tokens processed: 667,648 | tok/sec: 50,412.49
# 326 | lr: 2.74e-04 | loss: 4.3750 | time: 39.47ms | tokens processed: 669,696 | tok/sec: 51,884.74
# 327 | lr: 2.75e-04 | loss: 4.3438 | time: 40.01ms | tokens processed: 671,744 | tok/sec: 51,189.06
# 328 | lr: 2.76e-04 | loss: 4.4062 | time: 41.18ms | tokens processed: 673,792 | tok/sec: 49,730.42
# 329 | lr: 2.77e-04 | loss: 4.2188 | time: 42.68ms | tokens processed: 675,840 | tok/sec: 47,987.93
# 330 | lr: 2.78e-04 | loss: 4.3750 | time: 40.82ms | tokens processed: 677,888 | tok/sec: 50,166.35
# 331 | lr: 2.79e-04 | loss: 4.4688 | time: 41.75ms | tokens processed: 679,936 | tok/sec: 49,055.07
# 332 | lr: 2.79e-04 | loss: 4.3438 | time: 41.43ms | tokens processed: 681,984 | tok/sec: 49,436.48
# 333 | lr: 2.80e-04 | loss: 4.4688 | time: 40.48ms | tokens processed: 684,032 | tok/sec: 50,597.48
# 334 | lr: 2.81e-04 | loss: 4.3438 | time: 39.60ms | tokens processed: 686,080 | tok/sec: 51,720.11
# 335 | lr: 2.82e-04 | loss: 4.5000 | time: 38.70ms | tokens processed: 688,128 | tok/sec: 52,922.69
# 336 | lr: 2.83e-04 | loss: 4.7500 | time: 42.59ms | tokens processed: 690,176 | tok/sec: 48,080.86
# 337 | lr: 2.84e-04 | loss: 4.5312 | time: 40.58ms | tokens processed: 692,224 | tok/sec: 50,469.35
# 338 | lr: 2.84e-04 | loss: 4.6250 | time: 43.28ms | tokens processed: 694,272 | tok/sec: 47,323.29
# 339 | lr: 2.85e-04 | loss: 4.2188 | time: 41.62ms | tokens processed: 696,320 | tok/sec: 49,206.53
# 340 | lr: 2.86e-04 | loss: 4.2500 | time: 40.76ms | tokens processed: 698,368 | tok/sec: 50,240.59
# 341 | lr: 2.87e-04 | loss: 4.3438 | time: 39.26ms | tokens processed: 700,416 | tok/sec: 52,166.44
# 342 | lr: 2.88e-04 | loss: 4.5000 | time: 39.71ms | tokens processed: 702,464 | tok/sec: 51,569.21
# 343 | lr: 2.89e-04 | loss: 4.1250 | time: 476.74ms | tokens processed: 704,512 | tok/sec: 4,295.84
# 344 | lr: 2.90e-04 | loss: 4.3125 | time: 46.94ms | tokens processed: 706,560 | tok/sec: 43,631.86
# 345 | lr: 2.90e-04 | loss: 4.0312 | time: 43.74ms | tokens processed: 708,608 | tok/sec: 46,820.82
# 346 | lr: 2.91e-04 | loss: 4.2500 | time: 43.55ms | tokens processed: 710,656 | tok/sec: 47,025.10
# 347 | lr: 2.92e-04 | loss: 4.3750 | time: 43.65ms | tokens processed: 712,704 | tok/sec: 46,923.38
# 348 | lr: 2.93e-04 | loss: 4.4062 | time: 44.24ms | tokens processed: 714,752 | tok/sec: 46,289.46
# 349 | lr: 2.94e-04 | loss: 4.3750 | time: 43.55ms | tokens processed: 716,800 | tok/sec: 47,024.07
# 350 | lr: 2.95e-04 | loss: 3.7812 | time: 41.51ms | tokens processed: 718,848 | tok/sec: 49,337.67
# 351 | lr: 2.95e-04 | loss: 3.8438 | time: 42.85ms | tokens processed: 720,896 | tok/sec: 47,791.42
# 352 | lr: 2.96e-04 | loss: 3.6406 | time: 41.15ms | tokens processed: 722,944 | tok/sec: 49,772.77
# 353 | lr: 2.97e-04 | loss: 3.9219 | time: 39.30ms | tokens processed: 724,992 | tok/sec: 52,105.37
# 354 | lr: 2.98e-04 | loss: 4.1562 | time: 39.34ms | tokens processed: 727,040 | tok/sec: 52,062.10
# 355 | lr: 2.99e-04 | loss: 4.0312 | time: 39.82ms | tokens processed: 729,088 | tok/sec: 51,425.65
# 356 | lr: 3.00e-04 | loss: 4.0938 | time: 45.23ms | tokens processed: 731,136 | tok/sec: 45,283.35
# 357 | lr: 3.00e-04 | loss: 4.0312 | time: 44.71ms | tokens processed: 733,184 | tok/sec: 45,806.63
# 358 | lr: 3.01e-04 | loss: 4.7500 | time: 46.85ms | tokens processed: 735,232 | tok/sec: 43,717.35
# 359 | lr: 3.02e-04 | loss: 4.4688 | time: 44.03ms | tokens processed: 737,280 | tok/sec: 46,516.56
# 360 | lr: 3.03e-04 | loss: 4.1875 | time: 44.38ms | tokens processed: 739,328 | tok/sec: 46,150.44
# 361 | lr: 3.04e-04 | loss: 4.2188 | time: 43.73ms | tokens processed: 741,376 | tok/sec: 46,831.79
# 362 | lr: 3.05e-04 | loss: 4.1250 | time: 46.87ms | tokens processed: 743,424 | tok/sec: 43,691.33
# 363 | lr: 3.05e-04 | loss: 4.2188 | time: 46.73ms | tokens processed: 745,472 | tok/sec: 43,830.00
# 364 | lr: 3.06e-04 | loss: 4.2500 | time: 47.75ms | tokens processed: 747,520 | tok/sec: 42,887.91
# 365 | lr: 3.07e-04 | loss: 4.2500 | time: 463.24ms | tokens processed: 749,568 | tok/sec: 4,421.04
# 366 | lr: 3.08e-04 | loss: 4.3438 | time: 43.55ms | tokens processed: 751,616 | tok/sec: 47,022.79
# 367 | lr: 3.09e-04 | loss: 4.4375 | time: 41.09ms | tokens processed: 753,664 | tok/sec: 49,837.46
# 368 | lr: 3.10e-04 | loss: 4.3750 | time: 41.34ms | tokens processed: 755,712 | tok/sec: 49,544.55
# 369 | lr: 3.10e-04 | loss: 4.1875 | time: 42.01ms | tokens processed: 757,760 | tok/sec: 48,754.09
# 370 | lr: 3.11e-04 | loss: 4.3125 | time: 43.59ms | tokens processed: 759,808 | tok/sec: 46,978.30
# 371 | lr: 3.12e-04 | loss: 4.3750 | time: 40.68ms | tokens processed: 761,856 | tok/sec: 50,338.92
# 372 | lr: 3.13e-04 | loss: 4.5000 | time: 39.90ms | tokens processed: 763,904 | tok/sec: 51,328.54
# 373 | lr: 3.14e-04 | loss: 4.5312 | time: 41.65ms | tokens processed: 765,952 | tok/sec: 49,169.91
# 374 | lr: 3.15e-04 | loss: 4.1875 | time: 43.03ms | tokens processed: 768,000 | tok/sec: 47,599.69
# 375 | lr: 3.16e-04 | loss: 4.1250 | time: 40.75ms | tokens processed: 770,048 | tok/sec: 50,261.46
# 376 | lr: 3.16e-04 | loss: 4.4375 | time: 41.33ms | tokens processed: 772,096 | tok/sec: 49,554.55
# 377 | lr: 3.17e-04 | loss: 4.2188 | time: 44.34ms | tokens processed: 774,144 | tok/sec: 46,184.68
# 378 | lr: 3.18e-04 | loss: 4.3750 | time: 44.34ms | tokens processed: 776,192 | tok/sec: 46,183.69
# 379 | lr: 3.19e-04 | loss: 4.0938 | time: 44.66ms | tokens processed: 778,240 | tok/sec: 45,854.07
# 380 | lr: 3.20e-04 | loss: 4.1562 | time: 42.80ms | tokens processed: 780,288 | tok/sec: 47,855.59
# 381 | lr: 3.21e-04 | loss: 4.2188 | time: 40.49ms | tokens processed: 782,336 | tok/sec: 50,586.46
# 382 | lr: 3.21e-04 | loss: 4.0938 | time: 40.67ms | tokens processed: 784,384 | tok/sec: 50,359.88
# 383 | lr: 3.22e-04 | loss: 4.0000 | time: 40.24ms | tokens processed: 786,432 | tok/sec: 50,894.27
# 384 | lr: 3.23e-04 | loss: 4.0625 | time: 39.50ms | tokens processed: 788,480 | tok/sec: 51,843.10
# 385 | lr: 3.24e-04 | loss: 4.4375 | time: 40.35ms | tokens processed: 790,528 | tok/sec: 50,755.94
# 386 | lr: 3.25e-04 | loss: 4.1875 | time: 464.78ms | tokens processed: 792,576 | tok/sec: 4,406.38
# 387 | lr: 3.26e-04 | loss: 4.2812 | time: 44.79ms | tokens processed: 794,624 | tok/sec: 45,720.81
# 388 | lr: 3.26e-04 | loss: 4.0625 | time: 45.07ms | tokens processed: 796,672 | tok/sec: 45,443.14
# 389 | lr: 3.27e-04 | loss: 4.1250 | time: 44.78ms | tokens processed: 798,720 | tok/sec: 45,734.44
# 390 | lr: 3.28e-04 | loss: 4.3438 | time: 42.53ms | tokens processed: 800,768 | tok/sec: 48,153.64
# 391 | lr: 3.29e-04 | loss: 4.1250 | time: 41.06ms | tokens processed: 802,816 | tok/sec: 49,874.50
# 392 | lr: 3.30e-04 | loss: 4.2812 | time: 40.23ms | tokens processed: 804,864 | tok/sec: 50,901.51
# 393 | lr: 3.31e-04 | loss: 4.0938 | time: 40.62ms | tokens processed: 806,912 | tok/sec: 50,417.52
# 394 | lr: 3.31e-04 | loss: 4.0312 | time: 41.46ms | tokens processed: 808,960 | tok/sec: 49,393.27
# 395 | lr: 3.32e-04 | loss: 4.0938 | time: 39.96ms | tokens processed: 811,008 | tok/sec: 51,255.35
# 396 | lr: 3.33e-04 | loss: 4.2188 | time: 40.61ms | tokens processed: 813,056 | tok/sec: 50,427.58
# 397 | lr: 3.34e-04 | loss: 4.1562 | time: 39.40ms | tokens processed: 815,104 | tok/sec: 51,980.51
# 398 | lr: 3.35e-04 | loss: 4.1250 | time: 40.47ms | tokens processed: 817,152 | tok/sec: 50,610.90
# 399 | lr: 3.36e-04 | loss: 4.2188 | time: 39.09ms | tokens processed: 819,200 | tok/sec: 52,397.78
# 400 | lr: 3.37e-04 | loss: 4.1250 | time: 38.46ms | tokens processed: 821,248 | tok/sec: 53,254.73
# 401 | lr: 3.37e-04 | loss: 4.0000 | time: 41.71ms | tokens processed: 823,296 | tok/sec: 49,103.86
# 402 | lr: 3.38e-04 | loss: 4.1875 | time: 41.81ms | tokens processed: 825,344 | tok/sec: 48,983.73
# 403 | lr: 3.39e-04 | loss: 4.2812 | time: 41.25ms | tokens processed: 827,392 | tok/sec: 49,651.65
# 404 | lr: 3.40e-04 | loss: 4.1562 | time: 40.20ms | tokens processed: 829,440 | tok/sec: 50,941.65
# 405 | lr: 3.41e-04 | loss: 4.1875 | time: 40.44ms | tokens processed: 831,488 | tok/sec: 50,638.05
# 406 | lr: 3.42e-04 | loss: 4.1875 | time: 43.73ms | tokens processed: 833,536 | tok/sec: 46,832.31
# 407 | lr: 3.42e-04 | loss: 4.5000 | time: 463.50ms | tokens processed: 835,584 | tok/sec: 4,418.51
# 408 | lr: 3.43e-04 | loss: 4.3750 | time: 41.99ms | tokens processed: 837,632 | tok/sec: 48,773.75
# 409 | lr: 3.44e-04 | loss: 4.2500 | time: 39.27ms | tokens processed: 839,680 | tok/sec: 52,145.22
# 410 | lr: 3.45e-04 | loss: 4.3125 | time: 38.62ms | tokens processed: 841,728 | tok/sec: 53,022.98
# 411 | lr: 3.46e-04 | loss: 4.0000 | time: 44.93ms | tokens processed: 843,776 | tok/sec: 45,578.41
# 412 | lr: 3.47e-04 | loss: 3.9219 | time: 43.93ms | tokens processed: 845,824 | tok/sec: 46,622.35
# 413 | lr: 3.47e-04 | loss: 4.3438 | time: 42.85ms | tokens processed: 847,872 | tok/sec: 47,799.40
# 414 | lr: 3.48e-04 | loss: 4.0625 | time: 47.57ms | tokens processed: 849,920 | tok/sec: 43,053.86
# 415 | lr: 3.49e-04 | loss: 4.0000 | time: 42.09ms | tokens processed: 851,968 | tok/sec: 48,652.47
# 416 | lr: 3.50e-04 | loss: 3.9844 | time: 43.29ms | tokens processed: 854,016 | tok/sec: 47,303.49
# 417 | lr: 3.51e-04 | loss: 3.8281 | time: 41.75ms | tokens processed: 856,064 | tok/sec: 49,051.71
# 418 | lr: 3.52e-04 | loss: 4.2188 | time: 39.70ms | tokens processed: 858,112 | tok/sec: 51,590.58
# 419 | lr: 3.52e-04 | loss: 4.0000 | time: 39.73ms | tokens processed: 860,160 | tok/sec: 51,541.98
# 420 | lr: 3.53e-04 | loss: 4.4062 | time: 39.74ms | tokens processed: 862,208 | tok/sec: 51,533.94
# 421 | lr: 3.54e-04 | loss: 3.9062 | time: 40.33ms | tokens processed: 864,256 | tok/sec: 50,778.74
# 422 | lr: 3.55e-04 | loss: 3.5000 | time: 38.95ms | tokens processed: 866,304 | tok/sec: 52,578.35
# 423 | lr: 3.56e-04 | loss: 3.5469 | time: 40.04ms | tokens processed: 868,352 | tok/sec: 51,147.61
# 424 | lr: 3.57e-04 | loss: 3.4219 | time: 40.28ms | tokens processed: 870,400 | tok/sec: 50,838.84
# 425 | lr: 3.57e-04 | loss: 3.8281 | time: 39.11ms | tokens processed: 872,448 | tok/sec: 52,367.75
# 426 | lr: 3.58e-04 | loss: 3.9688 | time: 39.55ms | tokens processed: 874,496 | tok/sec: 51,781.22
# 427 | lr: 3.59e-04 | loss: 3.7969 | time: 39.31ms | tokens processed: 876,544 | tok/sec: 52,105.05
# 428 | lr: 3.60e-04 | loss: 3.8125 | time: 40.46ms | tokens processed: 878,592 | tok/sec: 50,612.39
# 429 | lr: 3.61e-04 | loss: 4.0000 | time: 41.97ms | tokens processed: 880,640 | tok/sec: 48,791.20
# 430 | lr: 3.62e-04 | loss: 4.5000 | time: 40.83ms | tokens processed: 882,688 | tok/sec: 50,158.74
# 431 | lr: 3.63e-04 | loss: 4.1250 | time: 41.10ms | tokens processed: 884,736 | tok/sec: 49,829.94
# 432 | lr: 3.63e-04 | loss: 3.9844 | time: 41.67ms | tokens processed: 886,784 | tok/sec: 49,146.28
# 433 | lr: 3.64e-04 | loss: 3.9688 | time: 478.56ms | tokens processed: 888,832 | tok/sec: 4,279.54
# 434 | lr: 3.65e-04 | loss: 4.0000 | time: 43.79ms | tokens processed: 890,880 | tok/sec: 46,769.32
# 435 | lr: 3.66e-04 | loss: 4.0312 | time: 42.79ms | tokens processed: 892,928 | tok/sec: 47,865.99
# 436 | lr: 3.67e-04 | loss: 4.1250 | time: 40.88ms | tokens processed: 894,976 | tok/sec: 50,101.69
# 437 | lr: 3.68e-04 | loss: 3.9062 | time: 39.75ms | tokens processed: 897,024 | tok/sec: 51,526.21
# 438 | lr: 3.68e-04 | loss: 4.1875 | time: 42.31ms | tokens processed: 899,072 | tok/sec: 48,409.54
# 439 | lr: 3.69e-04 | loss: 4.1250 | time: 42.72ms | tokens processed: 901,120 | tok/sec: 47,944.80
# 440 | lr: 3.70e-04 | loss: 4.1875 | time: 43.49ms | tokens processed: 903,168 | tok/sec: 47,091.62
# 441 | lr: 3.71e-04 | loss: 3.9531 | time: 43.99ms | tokens processed: 905,216 | tok/sec: 46,557.66
# 442 | lr: 3.72e-04 | loss: 4.3125 | time: 43.32ms | tokens processed: 907,264 | tok/sec: 47,273.03
# 443 | lr: 3.73e-04 | loss: 4.1875 | time: 43.01ms | tokens processed: 909,312 | tok/sec: 47,612.88
# 444 | lr: 3.73e-04 | loss: 4.4062 | time: 46.42ms | tokens processed: 911,360 | tok/sec: 44,116.56
# 445 | lr: 3.74e-04 | loss: 4.0625 | time: 44.35ms | tokens processed: 913,408 | tok/sec: 46,180.21
# 446 | lr: 3.75e-04 | loss: 3.9531 | time: 41.49ms | tokens processed: 915,456 | tok/sec: 49,359.50
# 447 | lr: 3.76e-04 | loss: 4.0938 | time: 41.80ms | tokens processed: 917,504 | tok/sec: 48,995.19
# 448 | lr: 3.77e-04 | loss: 3.9844 | time: 38.89ms | tokens processed: 919,552 | tok/sec: 52,661.19
# 449 | lr: 3.78e-04 | loss: 4.0312 | time: 39.44ms | tokens processed: 921,600 | tok/sec: 51,930.23
# 450 | lr: 3.78e-04 | loss: 4.1562 | time: 42.21ms | tokens processed: 923,648 | tok/sec: 48,522.21
# 451 | lr: 3.79e-04 | loss: 3.8594 | time: 39.43ms | tokens processed: 925,696 | tok/sec: 51,945.61
# 452 | lr: 3.80e-04 | loss: 4.0625 | time: 39.35ms | tokens processed: 927,744 | tok/sec: 52,051.38
# 453 | lr: 3.81e-04 | loss: 3.8906 | time: 39.71ms | tokens processed: 929,792 | tok/sec: 51,570.14
# 454 | lr: 3.82e-04 | loss: 3.9219 | time: 40.17ms | tokens processed: 931,840 | tok/sec: 50,987.01
# 455 | lr: 3.83e-04 | loss: 3.7500 | time: 39.73ms | tokens processed: 933,888 | tok/sec: 51,543.22
# 456 | lr: 3.83e-04 | loss: 4.0625 | time: 41.98ms | tokens processed: 935,936 | tok/sec: 48,789.81
# 457 | lr: 3.84e-04 | loss: 4.1250 | time: 486.88ms | tokens processed: 937,984 | tok/sec: 4,206.37
# 458 | lr: 3.85e-04 | loss: 4.0000 | time: 43.26ms | tokens processed: 940,032 | tok/sec: 47,342.33
# 459 | lr: 3.86e-04 | loss: 4.0312 | time: 40.04ms | tokens processed: 942,080 | tok/sec: 51,143.35
# 460 | lr: 3.87e-04 | loss: 3.8438 | time: 41.02ms | tokens processed: 944,128 | tok/sec: 49,922.32
# 461 | lr: 3.88e-04 | loss: 3.9531 | time: 40.71ms | tokens processed: 946,176 | tok/sec: 50,312.98
# 462 | lr: 3.89e-04 | loss: 4.2188 | time: 42.28ms | tokens processed: 948,224 | tok/sec: 48,439.03
# 463 | lr: 3.89e-04 | loss: 3.8906 | time: 40.02ms | tokens processed: 950,272 | tok/sec: 51,177.78
# 464 | lr: 3.90e-04 | loss: 4.0625 | time: 39.57ms | tokens processed: 952,320 | tok/sec: 51,755.95
# 465 | lr: 3.91e-04 | loss: 3.8125 | time: 41.30ms | tokens processed: 954,368 | tok/sec: 49,588.88
# 466 | lr: 3.92e-04 | loss: 3.8281 | time: 41.64ms | tokens processed: 956,416 | tok/sec: 49,182.58
# 467 | lr: 3.93e-04 | loss: 4.0312 | time: 40.03ms | tokens processed: 958,464 | tok/sec: 51,155.84
# 468 | lr: 3.94e-04 | loss: 4.0625 | time: 39.66ms | tokens processed: 960,512 | tok/sec: 51,638.65
# 469 | lr: 3.94e-04 | loss: 3.9375 | time: 40.83ms | tokens processed: 962,560 | tok/sec: 50,158.74
# 470 | lr: 3.95e-04 | loss: 3.9688 | time: 39.21ms | tokens processed: 964,608 | tok/sec: 52,231.15
# 471 | lr: 3.96e-04 | loss: 4.0312 | time: 40.00ms | tokens processed: 966,656 | tok/sec: 51,197.00
# 472 | lr: 3.97e-04 | loss: 3.9375 | time: 40.30ms | tokens processed: 968,704 | tok/sec: 50,819.90
# 473 | lr: 3.98e-04 | loss: 3.8594 | time: 43.14ms | tokens processed: 970,752 | tok/sec: 47,469.22
# 474 | lr: 3.99e-04 | loss: 4.0938 | time: 40.90ms | tokens processed: 972,800 | tok/sec: 50,072.19
# 475 | lr: 3.99e-04 | loss: 4.0312 | time: 39.13ms | tokens processed: 974,848 | tok/sec: 52,343.18
# 476 | lr: 4.00e-04 | loss: 4.0312 | time: 37.76ms | tokens processed: 976,896 | tok/sec: 54,244.11
# 477 | lr: 4.01e-04 | loss: 3.9531 | time: 39.31ms | tokens processed: 978,944 | tok/sec: 52,102.21
# 478 | lr: 4.02e-04 | loss: 3.9531 | time: 40.25ms | tokens processed: 980,992 | tok/sec: 50,886.13
# 479 | lr: 4.03e-04 | loss: 4.3125 | time: 38.11ms | tokens processed: 983,040 | tok/sec: 53,740.50
# 480 | lr: 4.04e-04 | loss: 4.2500 | time: 468.01ms | tokens processed: 985,088 | tok/sec: 4,375.98
# 481 | lr: 4.04e-04 | loss: 4.0312 | time: 42.20ms | tokens processed: 987,136 | tok/sec: 48,530.70
# 482 | lr: 4.05e-04 | loss: 4.0000 | time: 40.15ms | tokens processed: 989,184 | tok/sec: 51,005.78
# 483 | lr: 4.06e-04 | loss: 3.8281 | time: 43.39ms | tokens processed: 991,232 | tok/sec: 47,197.70
# 484 | lr: 4.07e-04 | loss: 3.7969 | time: 42.04ms | tokens processed: 993,280 | tok/sec: 48,719.80
# 485 | lr: 4.08e-04 | loss: 4.1875 | time: 41.43ms | tokens processed: 995,328 | tok/sec: 49,430.22
# ...
# 2810 | lr: 6.00e-04 | loss: 0.2578 | time: 46.49ms | tokens processed: 5,756,928 | tok/sec: 44,056.14
# 2811 | lr: 6.00e-04 | loss: 0.2246 | time: 48.10ms | tokens processed: 5,758,976 | tok/sec: 42,576.70
# 2812 | lr: 6.00e-04 | loss: 0.2520 | time: 45.86ms | tokens processed: 5,761,024 | tok/sec: 44,653.66
# 2813 | lr: 6.00e-04 | loss: 0.2539 | time: 42.10ms | tokens processed: 5,763,072 | tok/sec: 48,645.58
# 2814 | lr: 6.00e-04 | loss: 0.2412 | time: 41.42ms | tokens processed: 5,765,120 | tok/sec: 49,439.61
# 2815 | lr: 6.00e-04 | loss: 0.2695 | time: 40.80ms | tokens processed: 5,767,168 | tok/sec: 50,197.14
# 2816 | lr: 6.00e-04 | loss: 0.2471 | time: 45.53ms | tokens processed: 5,769,216 | tok/sec: 44,977.01
# 2817 | lr: 6.00e-04 | loss: 0.2617 | time: 41.95ms | tokens processed: 5,771,264 | tok/sec: 48,824.20
# 2818 | lr: 6.00e-04 | loss: 0.2432 | time: 41.27ms | tokens processed: 5,773,312 | tok/sec: 49,629.85
# 2819 | lr: 6.00e-04 | loss: 0.2617 | time: 41.59ms | tokens processed: 5,775,360 | tok/sec: 49,244.89
# 2820 | lr: 6.00e-04 | loss: 0.2520 | time: 482.42ms | tokens processed: 5,777,408 | tok/sec: 4,245.29
# 2821 | lr: 6.00e-04 | loss: 0.2393 | time: 45.86ms | tokens processed: 5,779,456 | tok/sec: 44,660.39
# 2822 | lr: 6.00e-04 | loss: 0.2373 | time: 44.12ms | tokens processed: 5,781,504 | tok/sec: 46,418.78
# 2823 | lr: 6.00e-04 | loss: 0.2773 | time: 41.38ms | tokens processed: 5,783,552 | tok/sec: 49,487.46
# 2824 | lr: 6.00e-04 | loss: 0.2617 | time: 43.30ms | tokens processed: 5,785,600 | tok/sec: 47,300.36
# 2825 | lr: 6.00e-04 | loss: 0.2383 | time: 41.68ms | tokens processed: 5,787,648 | tok/sec: 49,142.06
# 2826 | lr: 6.00e-04 | loss: 0.2656 | time: 42.88ms | tokens processed: 5,789,696 | tok/sec: 47,762.72
# 2827 | lr: 6.00e-04 | loss: 0.2383 | time: 41.82ms | tokens processed: 5,791,744 | tok/sec: 48,969.77
# 2828 | lr: 6.00e-04 | loss: 0.2637 | time: 43.43ms | tokens processed: 5,793,792 | tok/sec: 47,154.95
# 2829 | lr: 6.00e-04 | loss: 0.2480 | time: 42.69ms | tokens processed: 5,795,840 | tok/sec: 47,976.67
# 2830 | lr: 6.00e-04 | loss: 0.2451 | time: 45.24ms | tokens processed: 5,797,888 | tok/sec: 45,271.66
# 2831 | lr: 6.00e-04 | loss: 0.2539 | time: 44.42ms | tokens processed: 5,799,936 | tok/sec: 46,101.64
# 2832 | lr: 6.00e-04 | loss: 0.2695 | time: 45.44ms | tokens processed: 5,801,984 | tok/sec: 45,071.41
# 2833 | lr: 6.00e-04 | loss: 0.2285 | time: 45.08ms | tokens processed: 5,804,032 | tok/sec: 45,426.32
# 2834 | lr: 6.00e-04 | loss: 0.2383 | time: 46.62ms | tokens processed: 5,806,080 | tok/sec: 43,933.57
# 2835 | lr: 6.00e-04 | loss: 0.2754 | time: 44.18ms | tokens processed: 5,808,128 | tok/sec: 46,352.90
# 2836 | lr: 6.00e-04 | loss: 0.2441 | time: 50.83ms | tokens processed: 5,810,176 | tok/sec: 40,293.33
# 2837 | lr: 6.00e-04 | loss: 0.2305 | time: 46.33ms | tokens processed: 5,812,224 | tok/sec: 44,201.00
# 2838 | lr: 6.00e-04 | loss: 0.2461 | time: 44.73ms | tokens processed: 5,814,272 | tok/sec: 45,785.39
# 2839 | lr: 6.00e-04 | loss: 0.2236 | time: 43.39ms | tokens processed: 5,816,320 | tok/sec: 47,203.15
# 2840 | lr: 6.00e-04 | loss: 0.2500 | time: 43.58ms | tokens processed: 5,818,368 | tok/sec: 46,991.15
# 2841 | lr: 6.00e-04 | loss: 0.2227 | time: 474.30ms | tokens processed: 5,820,416 | tok/sec: 4,317.92
# 2842 | lr: 6.00e-04 | loss: 0.2715 | time: 44.27ms | tokens processed: 5,822,464 | tok/sec: 46,261.04
# 2843 | lr: 6.00e-04 | loss: 0.2656 | time: 40.54ms | tokens processed: 5,824,512 | tok/sec: 50,522.49
# 2844 | lr: 6.00e-04 | loss: 0.2637 | time: 40.64ms | tokens processed: 5,826,560 | tok/sec: 50,391.19
# 2845 | lr: 6.00e-04 | loss: 0.2695 | time: 40.27ms | tokens processed: 5,828,608 | tok/sec: 50,856.60
# 2846 | lr: 6.00e-04 | loss: 0.2949 | time: 42.90ms | tokens processed: 5,830,656 | tok/sec: 47,743.08
# 2847 | lr: 6.00e-04 | loss: 0.2334 | time: 42.35ms | tokens processed: 5,832,704 | tok/sec: 48,353.68
# 2848 | lr: 6.00e-04 | loss: 0.2422 | time: 50.07ms | tokens processed: 5,834,752 | tok/sec: 40,898.80
# 2849 | lr: 6.00e-04 | loss: 0.2637 | time: 44.09ms | tokens processed: 5,836,800 | tok/sec: 46,448.40
# 2850 | lr: 6.00e-04 | loss: 0.2480 | time: 42.59ms | tokens processed: 5,838,848 | tok/sec: 48,084.63
# 2851 | lr: 6.00e-04 | loss: 0.2334 | time: 40.47ms | tokens processed: 5,840,896 | tok/sec: 50,602.55
# 2852 | lr: 6.00e-04 | loss: 0.2617 | time: 41.79ms | tokens processed: 5,842,944 | tok/sec: 49,011.40
# 2853 | lr: 6.00e-04 | loss: 0.2793 | time: 41.49ms | tokens processed: 5,844,992 | tok/sec: 49,356.38
# 2854 | lr: 6.00e-04 | loss: 0.2617 | time: 44.60ms | tokens processed: 5,847,040 | tok/sec: 45,915.84
# 2855 | lr: 6.00e-04 | loss: 0.2168 | time: 42.57ms | tokens processed: 5,849,088 | tok/sec: 48,112.91
# 2856 | lr: 6.00e-04 | loss: 0.2471 | time: 42.44ms | tokens processed: 5,851,136 | tok/sec: 48,252.37
# 2857 | lr: 6.00e-04 | loss: 0.1895 | time: 40.22ms | tokens processed: 5,853,184 | tok/sec: 50,924.74
# 2858 | lr: 6.00e-04 | loss: 0.2041 | time: 41.16ms | tokens processed: 5,855,232 | tok/sec: 49,757.49
# 2859 | lr: 6.00e-04 | loss: 0.1992 | time: 40.78ms | tokens processed: 5,857,280 | tok/sec: 50,217.68
# 2860 | lr: 6.00e-04 | loss: 0.2109 | time: 39.86ms | tokens processed: 5,859,328 | tok/sec: 51,375.51
# 2861 | lr: 6.00e-04 | loss: 0.2471 | time: 41.74ms | tokens processed: 5,861,376 | tok/sec: 49,065.99
# 2862 | lr: 6.00e-04 | loss: 0.2500 | time: 39.89ms | tokens processed: 5,863,424 | tok/sec: 51,346.03
# 2863 | lr: 6.00e-04 | loss: 0.2314 | time: 41.15ms | tokens processed: 5,865,472 | tok/sec: 49,770.18
# 2864 | lr: 6.00e-04 | loss: 0.2393 | time: 40.70ms | tokens processed: 5,867,520 | tok/sec: 50,317.99
# 2865 | lr: 6.00e-04 | loss: 0.2617 | time: 42.49ms | tokens processed: 5,869,568 | tok/sec: 48,203.36
# 2866 | lr: 6.00e-04 | loss: 0.2578 | time: 41.15ms | tokens processed: 5,871,616 | tok/sec: 49,772.49
# 2867 | lr: 6.00e-04 | loss: 0.2578 | time: 476.62ms | tokens processed: 5,873,664 | tok/sec: 4,296.94
# 2868 | lr: 6.00e-04 | loss: 0.2412 | time: 43.93ms | tokens processed: 5,875,712 | tok/sec: 46,620.32
# 2869 | lr: 6.00e-04 | loss: 0.2314 | time: 42.21ms | tokens processed: 5,877,760 | tok/sec: 48,524.67
# 2870 | lr: 6.00e-04 | loss: 0.2490 | time: 40.16ms | tokens processed: 5,879,808 | tok/sec: 50,990.04
# 2871 | lr: 6.00e-04 | loss: 0.2256 | time: 42.31ms | tokens processed: 5,881,856 | tok/sec: 48,407.09
# 2872 | lr: 6.00e-04 | loss: 0.2471 | time: 40.33ms | tokens processed: 5,883,904 | tok/sec: 50,784.74
# 2873 | lr: 6.00e-04 | loss: 0.2373 | time: 42.85ms | tokens processed: 5,885,952 | tok/sec: 47,797.80
# 2874 | lr: 6.00e-04 | loss: 0.2354 | time: 42.45ms | tokens processed: 5,888,000 | tok/sec: 48,243.69
# Exception ignored in: <function _xla_gc_callback at 0x7ee75657b740>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# 2875 | lr: 6.00e-04 | loss: 0.2676 | time: 42.10ms | tokens processed: 5,890,048 | tok/sec: 48,644.76
# 2876 | lr: 6.00e-04 | loss: 0.2520 | time: 41.86ms | tokens processed: 5,892,096 | tok/sec: 48,920.13
# 2877 | lr: 6.00e-04 | loss: 0.2871 | time: 40.94ms | tokens processed: 5,894,144 | tok/sec: 50,023.20
# 2878 | lr: 6.00e-04 | loss: 0.2734 | time: 49.07ms | tokens processed: 5,896,192 | tok/sec: 41,732.95
# 2879 | lr: 6.00e-04 | loss: 0.2773 | time: 46.89ms | tokens processed: 5,898,240 | tok/sec: 43,679.11
# 2880 | lr: 6.00e-04 | loss: 0.2910 | time: 43.41ms | tokens processed: 5,900,288 | tok/sec: 47,181.89
# 2881 | lr: 6.00e-04 | loss: 0.2656 | time: 42.68ms | tokens processed: 5,902,336 | tok/sec: 47,990.61
# 2882 | lr: 6.00e-04 | loss: 0.2617 | time: 44.49ms | tokens processed: 5,904,384 | tok/sec: 46,033.45
# 2883 | lr: 6.00e-04 | loss: 0.2295 | time: 43.33ms | tokens processed: 5,906,432 | tok/sec: 47,263.14
# 2884 | lr: 6.00e-04 | loss: 0.2617 | time: 43.91ms | tokens processed: 5,908,480 | tok/sec: 46,639.31
# 2885 | lr: 6.00e-04 | loss: 0.2539 | time: 48.74ms | tokens processed: 5,910,528 | tok/sec: 42,017.10
# 2886 | lr: 6.00e-04 | loss: 0.2373 | time: 44.49ms | tokens processed: 5,912,576 | tok/sec: 46,031.23
# 2887 | lr: 6.00e-04 | loss: 0.2354 | time: 53.79ms | tokens processed: 5,914,624 | tok/sec: 38,072.91
# 2888 | lr: 6.00e-04 | loss: 0.2441 | time: 45.56ms | tokens processed: 5,916,672 | tok/sec: 44,948.53
# 2889 | lr: 6.00e-04 | loss: 0.2305 | time: 42.97ms | tokens processed: 5,918,720 | tok/sec: 47,660.17
# 2890 | lr: 6.00e-04 | loss: 0.2637 | time: 43.13ms | tokens processed: 5,920,768 | tok/sec: 47,485.75
# 2891 | lr: 6.00e-04 | loss: 0.2559 | time: 473.11ms | tokens processed: 5,922,816 | tok/sec: 4,328.76
# 2892 | lr: 6.00e-04 | loss: 0.2471 | time: 46.21ms | tokens processed: 5,924,864 | tok/sec: 44,320.28
# 2893 | lr: 6.00e-04 | loss: 0.2383 | time: 46.49ms | tokens processed: 5,926,912 | tok/sec: 44,053.66
# 2894 | lr: 6.00e-04 | loss: 0.2520 | time: 46.20ms | tokens processed: 5,928,960 | tok/sec: 44,330.80
# 2895 | lr: 6.00e-04 | loss: 0.2412 | time: 44.38ms | tokens processed: 5,931,008 | tok/sec: 46,148.70
# 2896 | lr: 6.00e-04 | loss: 0.2422 | time: 45.82ms | tokens processed: 5,933,056 | tok/sec: 44,697.34
# 2897 | lr: 6.00e-04 | loss: 0.2393 | time: 45.33ms | tokens processed: 5,935,104 | tok/sec: 45,182.12
# 2898 | lr: 6.00e-04 | loss: 0.2197 | time: 46.16ms | tokens processed: 5,937,152 | tok/sec: 44,370.87
# 2899 | lr: 6.00e-04 | loss: 0.2217 | time: 47.36ms | tokens processed: 5,939,200 | tok/sec: 43,243.95
# 2900 | lr: 6.00e-04 | loss: 0.2520 | time: 49.98ms | tokens processed: 5,941,248 | tok/sec: 40,973.72
# 2901 | lr: 6.00e-04 | loss: 0.2354 | time: 44.52ms | tokens processed: 5,943,296 | tok/sec: 46,000.67
# 2902 | lr: 6.00e-04 | loss: 0.2402 | time: 41.54ms | tokens processed: 5,945,344 | tok/sec: 49,300.29
# 2903 | lr: 6.00e-04 | loss: 0.2539 | time: 41.41ms | tokens processed: 5,947,392 | tok/sec: 49,454.70
# 2904 | lr: 6.00e-04 | loss: 0.2637 | time: 40.38ms | tokens processed: 5,949,440 | tok/sec: 50,714.88
# 2905 | lr: 6.00e-04 | loss: 0.2393 | time: 44.80ms | tokens processed: 5,951,488 | tok/sec: 45,718.13
# 2906 | lr: 6.00e-04 | loss: 0.2617 | time: 41.28ms | tokens processed: 5,953,536 | tok/sec: 49,611.79
# 2907 | lr: 6.00e-04 | loss: 0.2773 | time: 40.62ms | tokens processed: 5,955,584 | tok/sec: 50,422.84
# 2908 | lr: 6.00e-04 | loss: 0.2695 | time: 41.02ms | tokens processed: 5,957,632 | tok/sec: 49,924.65
# 2909 | lr: 6.00e-04 | loss: 0.2490 | time: 40.75ms | tokens processed: 5,959,680 | tok/sec: 50,254.70
# 2910 | lr: 6.00e-04 | loss: 0.2598 | time: 41.62ms | tokens processed: 5,961,728 | tok/sec: 49,207.37
# 2911 | lr: 6.00e-04 | loss: 0.2539 | time: 42.27ms | tokens processed: 5,963,776 | tok/sec: 48,450.77
# 2912 | lr: 6.00e-04 | loss: 0.2695 | time: 43.00ms | tokens processed: 5,965,824 | tok/sec: 47,624.49
# 2913 | lr: 6.00e-04 | loss: 0.2451 | time: 40.99ms | tokens processed: 5,967,872 | tok/sec: 49,967.92
# 2914 | lr: 6.00e-04 | loss: 0.2451 | time: 461.38ms | tokens processed: 5,969,920 | tok/sec: 4,438.87
# 2915 | lr: 6.00e-04 | loss: 0.2480 | time: 43.97ms | tokens processed: 5,971,968 | tok/sec: 46,576.59
# 2916 | lr: 6.00e-04 | loss: 0.2354 | time: 41.71ms | tokens processed: 5,974,016 | tok/sec: 49,105.26
# 2917 | lr: 6.00e-04 | loss: 0.2441 | time: 40.56ms | tokens processed: 5,976,064 | tok/sec: 50,494.87
# 2918 | lr: 6.00e-04 | loss: 0.2598 | time: 40.08ms | tokens processed: 5,978,112 | tok/sec: 51,093.76
# 2919 | lr: 6.00e-04 | loss: 0.2246 | time: 42.52ms | tokens processed: 5,980,160 | tok/sec: 48,167.68
# 2920 | lr: 6.00e-04 | loss: 0.2656 | time: 41.23ms | tokens processed: 5,982,208 | tok/sec: 49,667.44
# 2921 | lr: 6.00e-04 | loss: 0.2373 | time: 43.06ms | tokens processed: 5,984,256 | tok/sec: 47,563.58
# 2922 | lr: 6.00e-04 | loss: 0.2266 | time: 40.47ms | tokens processed: 5,986,304 | tok/sec: 50,599.27
# 2923 | lr: 6.00e-04 | loss: 0.2461 | time: 40.24ms | tokens processed: 5,988,352 | tok/sec: 50,892.16
# 2924 | lr: 6.00e-04 | loss: 0.2461 | time: 39.17ms | tokens processed: 5,990,400 | tok/sec: 52,286.47
# 2925 | lr: 6.00e-04 | loss: 0.2354 | time: 40.06ms | tokens processed: 5,992,448 | tok/sec: 51,122.35
# 2926 | lr: 6.00e-04 | loss: 0.2520 | time: 40.59ms | tokens processed: 5,994,496 | tok/sec: 50,459.27
# 2927 | lr: 6.00e-04 | loss: 0.2324 | time: 42.39ms | tokens processed: 5,996,544 | tok/sec: 48,318.05
# 2928 | lr: 6.00e-04 | loss: 0.2354 | time: 45.57ms | tokens processed: 5,998,592 | tok/sec: 44,943.60
# 2929 | lr: 6.00e-04 | loss: 0.1816 | time: 41.91ms | tokens processed: 6,000,640 | tok/sec: 48,863.92
# 2930 | lr: 6.00e-04 | loss: 0.1943 | time: 40.24ms | tokens processed: 6,002,688 | tok/sec: 50,893.67
# 2931 | lr: 6.00e-04 | loss: 0.1875 | time: 39.95ms | tokens processed: 6,004,736 | tok/sec: 51,267.58
# 2932 | lr: 6.00e-04 | loss: 0.2197 | time: 40.39ms | tokens processed: 6,006,784 | tok/sec: 50,711.89
# 2933 | lr: 6.00e-04 | loss: 0.2021 | time: 41.58ms | tokens processed: 6,008,832 | tok/sec: 49,249.13
# 2934 | lr: 6.00e-04 | loss: 0.2412 | time: 42.38ms | tokens processed: 6,010,880 | tok/sec: 48,322.40
# 2935 | lr: 6.00e-04 | loss: 0.2383 | time: 39.96ms | tokens processed: 6,012,928 | tok/sec: 51,245.87
# 2936 | lr: 6.00e-04 | loss: 0.2344 | time: 471.50ms | tokens processed: 6,014,976 | tok/sec: 4,343.59
# 2937 | lr: 6.00e-04 | loss: 0.2500 | time: 44.72ms | tokens processed: 6,017,024 | tok/sec: 45,794.18
# 2938 | lr: 6.00e-04 | loss: 0.2275 | time: 41.69ms | tokens processed: 6,019,072 | tok/sec: 49,130.26
# 2939 | lr: 6.00e-04 | loss: 0.2383 | time: 42.01ms | tokens processed: 6,021,120 | tok/sec: 48,749.66
# 2940 | lr: 6.00e-04 | loss: 0.2471 | time: 41.60ms | tokens processed: 6,023,168 | tok/sec: 49,228.81
# 2941 | lr: 6.00e-04 | loss: 0.2461 | time: 40.69ms | tokens processed: 6,025,216 | tok/sec: 50,336.86
# 2942 | lr: 6.00e-04 | loss: 0.2422 | time: 40.58ms | tokens processed: 6,027,264 | tok/sec: 50,472.02
# 2943 | lr: 6.00e-04 | loss: 0.2373 | time: 41.54ms | tokens processed: 6,029,312 | tok/sec: 49,298.31
# 2944 | lr: 6.00e-04 | loss: 0.2305 | time: 42.64ms | tokens processed: 6,031,360 | tok/sec: 48,029.78
# 2945 | lr: 6.00e-04 | loss: 0.2441 | time: 41.61ms | tokens processed: 6,033,408 | tok/sec: 49,215.83
# 2946 | lr: 6.00e-04 | loss: 0.2188 | time: 40.42ms | tokens processed: 6,035,456 | tok/sec: 50,673.00
# 2947 | lr: 6.00e-04 | loss: 0.2598 | time: 40.91ms | tokens processed: 6,037,504 | tok/sec: 50,058.77
# 2948 | lr: 6.00e-04 | loss: 0.2520 | time: 41.40ms | tokens processed: 6,039,552 | tok/sec: 49,472.64
# 2949 | lr: 6.00e-04 | loss: 0.2314 | time: 42.44ms | tokens processed: 6,041,600 | tok/sec: 48,251.28
# 2950 | lr: 6.00e-04 | loss: 0.2480 | time: 39.38ms | tokens processed: 6,043,648 | tok/sec: 52,009.78
# 2951 | lr: 6.00e-04 | loss: 0.2334 | time: 40.47ms | tokens processed: 6,045,696 | tok/sec: 50,599.57
# 2952 | lr: 6.00e-04 | loss: 0.2354 | time: 41.11ms | tokens processed: 6,047,744 | tok/sec: 49,814.05
# 2953 | lr: 6.00e-04 | loss: 0.2520 | time: 40.45ms | tokens processed: 6,049,792 | tok/sec: 50,633.87
# 2954 | lr: 6.00e-04 | loss: 0.2197 | time: 40.89ms | tokens processed: 6,051,840 | tok/sec: 50,086.50
# 2955 | lr: 6.00e-04 | loss: 0.2637 | time: 40.58ms | tokens processed: 6,053,888 | tok/sec: 50,470.54
# 2956 | lr: 6.00e-04 | loss: 0.2656 | time: 40.83ms | tokens processed: 6,055,936 | tok/sec: 50,164.01
# 2957 | lr: 6.00e-04 | loss: 0.2520 | time: 464.20ms | tokens processed: 6,057,984 | tok/sec: 4,411.91
# 2958 | lr: 6.00e-04 | loss: 0.2520 | time: 50.33ms | tokens processed: 6,060,032 | tok/sec: 40,691.88
# 2959 | lr: 6.00e-04 | loss: 0.2441 | time: 43.61ms | tokens processed: 6,062,080 | tok/sec: 46,958.52
# 2960 | lr: 6.00e-04 | loss: 0.2500 | time: 42.52ms | tokens processed: 6,064,128 | tok/sec: 48,163.36
# 2961 | lr: 6.00e-04 | loss: 0.2832 | time: 43.04ms | tokens processed: 6,066,176 | tok/sec: 47,578.33
# 2962 | lr: 6.00e-04 | loss: 0.2305 | time: 42.43ms | tokens processed: 6,068,224 | tok/sec: 48,272.70
# Received KeyboardInterrupt. Exiting...

# %% [markdown]
# # Let's Train GPT-2 with RoPE + GLU

# %% [markdown]
# ### Configure the machine and install packages

# %%
import os
#os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=8'

from typing import Literal

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# Cloning into 'jaxpt'...
# remote: Enumerating objects: 2290, done.
# remote: Counting objects: 100% (289/289), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 2290 (delta 196), reused 155 (delta 112), pack-reused 2001 (from 2)
# Receiving objects: 100% (2290/2290), 318.79 MiB | 16.51 MiB/s, done.
# Resolving deltas: 100% (1399/1399), done.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import flax
import jax.numpy as jnp
import numpy as np

# Hardware setup
print("JAX version:", jax.__version__)
print("Flax version", flax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

requested_device = "gpu"

jax.config.update("jax_platform_name", requested_device) # Make sure we're using the GPU

device = jax.default_backend()
if device != requested_device:
    warnings.warn(f"not using {requested_device}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Flax version 0.10.6
# Available devices: 1
# using gpu
# 935 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize the GPT-2 model and perform a sanity check

# %%
from functools import partial

from jax.sharding import Mesh, PartitionSpec, NamedSharding
from flax import nnx

from jaxpt.infer import generate_completions
from jaxpt.models import GLU_RoPE_GPT, GLU_RoPE_GPTConfig
from jaxpt.utils import count_params, create_sharded_model

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

mesh = Mesh(devices, ("devices",))
spec = PartitionSpec("devices",)
sharding = NamedSharding(mesh, spec)


key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = GLU_RoPE_GPTConfig(dtype=jnp.bfloat16, \
                   n_layer=30, \
                   vocab_size=50304, \
                   block_size=2048,
                   n_head=9,
                   n_embed=576,
                   n_mlp_hidden=1536,
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)
with mesh:
    m = create_sharded_model(GLU_RoPE_GPT, config, rngs)
    graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)

    total_params = count_params(m)
    print(f"Parameter Count: {total_params:,}")
    nnx.display(state)

    completions = generate_completions(m, num_completions=5, max_length=21, prefix="Ducks quack, donkeys bray, cats mew, horses")
    for completion in completions:
        print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_0b31eb39a8a149d180ad7893129e7ac8" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0b31eb39a8a149d180ad7893129e7ac8")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0b31eb39a8a149d180ad7893129e7ac8")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Parameter Count: 148,553,856
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_cd13f78de2f64f12810f0d43d6a287f2" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cd13f78de2f64f12810f0d43d6a287f2")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cd13f78de2f64f12810f0d43d6a287f2")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cd13f78de2f64f12810f0d43d6a287f2")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Ducks quack, donkeys bray, cats mew, horsesById Newcastle Newcastle Newcastle Newcastle Newcastle
# Ducks quack, donkeys bray, cats mew, horsesvettevettevettevettevettevette
# Ducks quack, donkeys bray, cats mew, horses eleven eleven eleven eleven eleven eleven
# Ducks quack, donkeys bray, cats mew, horses*)*)*)*)*)*)
# Ducks quack, donkeys bray, cats mew, horses Newcastle Newcastle Newcastle Newcastle Newcastle Newcastle

# %%
jax.debug.visualize_array_sharding(m.wte.embedding.value)
# Out:
#
#
#
#
#
#   GPU 0

# %% [markdown]
# ### Configure Training Run

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

run_dirname = f"run_{timestamp}_{random_code}"
print(f"Run: {run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/workspace/runs") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Run: run_20250721_gdqxay
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %%
import dataclasses

import optax


############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens: int = int(100e9)
  num_tokens_per_batch: int = 2**11 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 16 * num_devices
  T: int = 128
  max_steps: int = num_tokens // num_tokens_per_batch # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 1
  eval_interval: int = 2000
  checkpoint_interval: int = 2000
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()
'''
trconf = TrainerConfig(
  num_tokens_per_batch=2**14,
  mB=16,
  T=1024,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)
trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient
'''

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

steps = range(0, trconf.max_steps, 1000)
total_schedule = [ warmup_with_cosine_decay_schedule(step) for step in steps ]
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.plot(steps, total_schedule)
plt.title("LR Schedule")
plt.show()

# Generate a weight decay mask
# First split the model into params and variables
graphdef, params, variables = nnx.split(m, nnx.Param, nnx.Variable)
# Then create a mask for the weight decay params
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)


tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95) #, weight_decay=0.1, mask=weight_decay_mask)
)
optimizer = nnx.Optimizer(m, tx)

# count the number of weight decay params
def f(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(f, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)


print(f"weight decay param count: {weight_decay_param_count:,}")
print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# weight decay param count: 148,414,464
# tokens/batch: 2,048
# block size: 128
# sub-batch size: 16
# no. gradient accumulation steps: 1
# effective batch size per device:  16
# effective batch size: 16
# max steps: 48828125

# %% [markdown]
# ### DataLoader and Validation Setup

# %%
from jaxpt.dataloaders import DataLoader, HuggingfaceDataLoader, CloudDataLoader, BlendedCloudDataLoader

batch_size = trconf.T * trconf.mB * trconf.grad_accumulation_steps
batch_memory = batch_size*2
print(f"Batch Size (Tokens): {batch_size:,} | Batch Memory: {batch_memory/1024} MB")

'''
train_dl = HuggingfaceDataLoader(batch_size=trconf.mB * DATA_DIMS,
                                 block_size=trconf.T,
                                 device_rank=1,
                                 tokenizer="HuggingFaceTB/SmolLM-135M",
                                 dataset_paths=["HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus"],
                                 dataset_names=["cosmopedia-v2",
                                                "python-edu",
                                                "fineweb-edu-dedup"],
                                 probabilities=[0.111, 0.016 , 0.873],
                                 label="train",
                                 random_seed=1337,
                                 buffer_size=10_000,
                                 streaming=True)
'''
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../alpha-448101-282bc1b884cd.json"

'''
train_dl = CloudDataLoader(bucket_name="jaxpt_datasets",
                      bucket_prefix="fineweb-edu-100b/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
'''
'''
train_dl = BlendedCloudDataLoader(
    device_rank=1,
    block_size=trconf.T,
    batch_size=trconf.mB,
    bucket_names=["jaxpt_datasets", "jaxpt_datasets", "jaxpt_datasets"],
    bucket_prefixes=["smollm-corpus/processed/fineweb-edu-dedup",
                     "smollm-corpus/processed/python-edu",
                     "smollm-corpus/processed/cosmopedia-v2"],
    proportions=[87, 2, 11],
    label="train"
)
'''
train_dl = DataLoader(dirpath="/content/jaxpt/datasets/panchatantra-ryder/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
# Out:
# Batch Size (Tokens): 2,048 | Batch Memory: 4.0 MB
# DataLoader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     16
# block size:     128
# device rank:    1
# ------------------------

# %%
from jaxpt.utils import append_to_csv

train_losses = []
val_losses = []
append_to_csv(log_dir / f"{run_dirname}_train.csv", ["step", "lr", "loss", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{run_dirname}_valid.csv", ["step", "loss"])
step = 0
start = None

# %% [markdown]
# ### Let's train the model

# %%
# %matplotlib inline

import time
import logging
import warnings

import matplotlib.pyplot as plt


def loss_fn(model, batch, targets):
    logits = model(batch)
    loss = optax.softmax_cross_entropy_with_integer_labels(logits, targets)
    return loss.mean()


@nnx.jit
def train_step(model, optimizer, batch, targets):
    loss, grads = nnx.value_and_grad(loss_fn, has_aux=False)(model, batch, targets)
    optimizer.update(grads)
    return loss


with mesh:
  m.train()
  try:
    while step < trconf.max_steps:
      start = time.time()
      batch, target = train_dl()
      batch = jax.device_put(batch.squeeze(), sharding)
      target = jax.device_put(target.squeeze(), sharding)
      loss = train_step(m, optimizer, batch, target)
      if step % trconf.print_interval == 0:
        if start is None:
          start = time.time()
          iter_time = 0
          sub_step_time = 0
          tokes_per_sec = 0
          tokens_processed = 0
        else:
          iter_time = time.time() - start
          sub_step_time = iter_time / trconf.grad_accumulation_steps
          tokens_per_sec = trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
          tokens_processed = (step+1) * trconf.grad_accumulation_steps * trconf.mB * trconf.T

        loss = loss.item()
        lr = warmup_with_cosine_decay_schedule(step)
        train_losses.append((step, loss))
        append_to_csv(log_dir / f"{run_dirname}_train.csv", [step, lr, loss, iter_time*1000, tokens_processed, tokens_per_sec])
        print(f"{step} | lr: {lr:0.2e} | loss: {loss:0.4f} | time: {iter_time*1000:0.2f}ms | tokens processed: {tokens_processed:,} | tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
      if step % trconf.eval_interval == 0:
        pass
        #valid_loss, completions = evaluate(m)
        #valid_loss = jnp.float32(valid_loss)
        #val_losses.append((step, valid_loss))
        #append_to_csv(log_dir / f"{run_dirname}_valid.csv", [step, valid_loss])
        #print(f"valid loss: {valid_loss:0.4f}"  )
        #for completion in completions:
        #  print(completion)
      #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
        #save_checkpoint(m, run_dirname, step)
      step += 1

  except KeyboardInterrupt:
      print("Received KeyboardInterrupt. Exiting...")

  #valid_loss, completions = evaluate(m)
  #valid_loss = jnp.float32(valid_loss)
  #print(f"valid loss: {valid_loss:0.4f}")
  #print(f"completions: {completions}")
  #for completion in completions:
  #  print(completion)
  plt.figure(figsize=(10, 5))
  plt.plot([x[0] for x in train_losses], [x[1] for x in train_losses], label="train loss")
  plt.plot([x[0] for x in val_losses], [x[1] for x in val_losses], label="valid loss")
  plt.legend()
  plt.savefig(log_dir / f"{run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
  plt.show()
# Out:
# 0 | lr: 8.39e-07 | loss: 10.9375 | time: 65788.18ms | tokens processed: 2,048 | tok/sec: 31.13
# 1 | lr: 1.68e-06 | loss: 10.9375 | time: 45648.97ms | tokens processed: 4,096 | tok/sec: 44.86
# 2 | lr: 2.52e-06 | loss: 10.8125 | time: 49.83ms | tokens processed: 6,144 | tok/sec: 41,099.18
# 3 | lr: 3.36e-06 | loss: 10.6875 | time: 45.56ms | tokens processed: 8,192 | tok/sec: 44,953.47
# 4 | lr: 4.20e-06 | loss: 10.6875 | time: 48.33ms | tokens processed: 10,240 | tok/sec: 42,371.51
# 5 | lr: 5.03e-06 | loss: 10.5000 | time: 46.24ms | tokens processed: 12,288 | tok/sec: 44,295.14
# 6 | lr: 5.87e-06 | loss: 10.3750 | time: 44.06ms | tokens processed: 14,336 | tok/sec: 46,486.86
# 7 | lr: 6.71e-06 | loss: 10.1875 | time: 42.71ms | tokens processed: 16,384 | tok/sec: 47,949.89
# 8 | lr: 7.55e-06 | loss: 10.0625 | time: 42.16ms | tokens processed: 18,432 | tok/sec: 48,575.71
# 9 | lr: 8.39e-06 | loss: 9.8750 | time: 45.33ms | tokens processed: 20,480 | tok/sec: 45,175.71
# 10 | lr: 9.23e-06 | loss: 9.8750 | time: 41.95ms | tokens processed: 22,528 | tok/sec: 48,814.49
# 11 | lr: 1.01e-05 | loss: 9.4375 | time: 42.18ms | tokens processed: 24,576 | tok/sec: 48,558.41
# 12 | lr: 1.09e-05 | loss: 9.3750 | time: 41.35ms | tokens processed: 26,624 | tok/sec: 49,523.41
# 13 | lr: 1.17e-05 | loss: 9.5625 | time: 41.50ms | tokens processed: 28,672 | tok/sec: 49,344.47
# 14 | lr: 1.26e-05 | loss: 9.5000 | time: 537.15ms | tokens processed: 30,720 | tok/sec: 3,812.73
# 15 | lr: 1.34e-05 | loss: 9.2500 | time: 43.30ms | tokens processed: 32,768 | tok/sec: 47,297.23
# 16 | lr: 1.43e-05 | loss: 9.1250 | time: 40.68ms | tokens processed: 34,816 | tok/sec: 50,349.84
# 17 | lr: 1.51e-05 | loss: 9.3125 | time: 40.48ms | tokens processed: 36,864 | tok/sec: 50,587.35
# 18 | lr: 1.59e-05 | loss: 9.2500 | time: 43.72ms | tokens processed: 38,912 | tok/sec: 46,846.86
# 19 | lr: 1.68e-05 | loss: 9.1250 | time: 42.41ms | tokens processed: 40,960 | tok/sec: 48,294.14
# 20 | lr: 1.76e-05 | loss: 9.0000 | time: 40.12ms | tokens processed: 43,008 | tok/sec: 51,040.63
# 21 | lr: 1.85e-05 | loss: 9.1250 | time: 39.54ms | tokens processed: 45,056 | tok/sec: 51,799.64
# 22 | lr: 1.93e-05 | loss: 8.9375 | time: 43.18ms | tokens processed: 47,104 | tok/sec: 47,430.95
# 23 | lr: 2.01e-05 | loss: 8.8750 | time: 40.68ms | tokens processed: 49,152 | tok/sec: 50,341.58
# 24 | lr: 2.10e-05 | loss: 8.9375 | time: 38.17ms | tokens processed: 51,200 | tok/sec: 53,660.60
# 25 | lr: 2.18e-05 | loss: 8.7500 | time: 39.08ms | tokens processed: 53,248 | tok/sec: 52,400.66
# 26 | lr: 2.27e-05 | loss: 8.6875 | time: 39.64ms | tokens processed: 55,296 | tok/sec: 51,658.53
# 27 | lr: 2.35e-05 | loss: 8.6250 | time: 41.08ms | tokens processed: 57,344 | tok/sec: 49,852.79
# 28 | lr: 2.43e-05 | loss: 8.8750 | time: 40.30ms | tokens processed: 59,392 | tok/sec: 50,818.99
# 29 | lr: 2.52e-05 | loss: 8.6250 | time: 39.90ms | tokens processed: 61,440 | tok/sec: 51,334.68
# 30 | lr: 2.60e-05 | loss: 8.5625 | time: 40.72ms | tokens processed: 63,488 | tok/sec: 50,290.30
# 31 | lr: 2.69e-05 | loss: 8.6250 | time: 41.49ms | tokens processed: 65,536 | tok/sec: 49,365.45
# 32 | lr: 2.77e-05 | loss: 8.7500 | time: 40.31ms | tokens processed: 67,584 | tok/sec: 50,802.46
# 33 | lr: 2.85e-05 | loss: 8.2500 | time: 40.02ms | tokens processed: 69,632 | tok/sec: 51,170.16
# 34 | lr: 2.94e-05 | loss: 8.5625 | time: 42.74ms | tokens processed: 71,680 | tok/sec: 47,922.07
# 35 | lr: 3.02e-05 | loss: 8.5000 | time: 43.38ms | tokens processed: 73,728 | tok/sec: 47,213.53
# 36 | lr: 3.10e-05 | loss: 8.4375 | time: 40.27ms | tokens processed: 75,776 | tok/sec: 50,856.60
# 37 | lr: 3.19e-05 | loss: 8.5625 | time: 539.73ms | tokens processed: 77,824 | tok/sec: 3,794.50
# 38 | lr: 3.27e-05 | loss: 8.5000 | time: 43.20ms | tokens processed: 79,872 | tok/sec: 47,412.62
# 39 | lr: 3.36e-05 | loss: 8.2500 | time: 41.50ms | tokens processed: 81,920 | tok/sec: 49,351.84
# 40 | lr: 3.44e-05 | loss: 8.5000 | time: 39.68ms | tokens processed: 83,968 | tok/sec: 51,617.24
# 41 | lr: 3.52e-05 | loss: 8.1875 | time: 40.14ms | tokens processed: 86,016 | tok/sec: 51,020.63
# 42 | lr: 3.61e-05 | loss: 8.0625 | time: 40.55ms | tokens processed: 88,064 | tok/sec: 50,504.07
# 43 | lr: 3.69e-05 | loss: 8.3750 | time: 44.21ms | tokens processed: 90,112 | tok/sec: 46,320.16
# 44 | lr: 3.78e-05 | loss: 8.1875 | time: 41.18ms | tokens processed: 92,160 | tok/sec: 49,731.28
# 45 | lr: 3.86e-05 | loss: 8.3125 | time: 40.62ms | tokens processed: 94,208 | tok/sec: 50,419.29
# 46 | lr: 3.94e-05 | loss: 8.1875 | time: 39.54ms | tokens processed: 96,256 | tok/sec: 51,798.08
# 47 | lr: 4.03e-05 | loss: 8.0625 | time: 42.44ms | tokens processed: 98,304 | tok/sec: 48,261.31
# 48 | lr: 4.11e-05 | loss: 7.9062 | time: 40.66ms | tokens processed: 100,352 | tok/sec: 50,364.90
# 49 | lr: 4.20e-05 | loss: 8.1875 | time: 41.98ms | tokens processed: 102,400 | tok/sec: 48,781.50
# 50 | lr: 4.28e-05 | loss: 8.3125 | time: 40.01ms | tokens processed: 104,448 | tok/sec: 51,182.05
# 51 | lr: 4.36e-05 | loss: 8.2500 | time: 41.93ms | tokens processed: 106,496 | tok/sec: 48,837.80
# 52 | lr: 4.45e-05 | loss: 8.0625 | time: 39.94ms | tokens processed: 108,544 | tok/sec: 51,279.52
# 53 | lr: 4.53e-05 | loss: 8.1250 | time: 40.31ms | tokens processed: 110,592 | tok/sec: 50,801.56
# 54 | lr: 4.62e-05 | loss: 8.1875 | time: 41.62ms | tokens processed: 112,640 | tok/sec: 49,203.15
# 55 | lr: 4.70e-05 | loss: 7.9375 | time: 40.27ms | tokens processed: 114,688 | tok/sec: 50,850.58
# 56 | lr: 4.78e-05 | loss: 8.1250 | time: 39.78ms | tokens processed: 116,736 | tok/sec: 51,484.21
# 57 | lr: 4.87e-05 | loss: 8.1250 | time: 38.30ms | tokens processed: 118,784 | tok/sec: 53,473.20
# 58 | lr: 4.95e-05 | loss: 7.9688 | time: 38.66ms | tokens processed: 120,832 | tok/sec: 52,975.24
# 59 | lr: 5.03e-05 | loss: 8.0625 | time: 44.27ms | tokens processed: 122,880 | tok/sec: 46,265.02
# 60 | lr: 5.12e-05 | loss: 7.9062 | time: 39.95ms | tokens processed: 124,928 | tok/sec: 51,260.55
# 61 | lr: 5.20e-05 | loss: 7.9375 | time: 535.11ms | tokens processed: 126,976 | tok/sec: 3,827.26
# 62 | lr: 5.29e-05 | loss: 7.9062 | time: 43.69ms | tokens processed: 129,024 | tok/sec: 46,878.05
# 63 | lr: 5.37e-05 | loss: 7.9688 | time: 41.83ms | tokens processed: 131,072 | tok/sec: 48,964.19
# 64 | lr: 5.45e-05 | loss: 7.8125 | time: 38.60ms | tokens processed: 133,120 | tok/sec: 53,062.61
# 65 | lr: 5.54e-05 | loss: 7.9375 | time: 39.37ms | tokens processed: 135,168 | tok/sec: 52,021.75
# 66 | lr: 5.62e-05 | loss: 7.7500 | time: 39.73ms | tokens processed: 137,216 | tok/sec: 51,554.35
# 67 | lr: 5.71e-05 | loss: 7.9688 | time: 40.18ms | tokens processed: 139,264 | tok/sec: 50,974.00
# 68 | lr: 5.79e-05 | loss: 7.8750 | time: 45.03ms | tokens processed: 141,312 | tok/sec: 45,482.12
# 69 | lr: 5.87e-05 | loss: 7.8438 | time: 42.07ms | tokens processed: 143,360 | tok/sec: 48,684.46
# 70 | lr: 5.96e-05 | loss: 7.7812 | time: 40.52ms | tokens processed: 145,408 | tok/sec: 50,537.35
# 71 | lr: 6.04e-05 | loss: 7.8125 | time: 41.50ms | tokens processed: 147,456 | tok/sec: 49,345.60
# 72 | lr: 6.13e-05 | loss: 8.0000 | time: 39.97ms | tokens processed: 149,504 | tok/sec: 51,244.64
# 73 | lr: 6.21e-05 | loss: 7.3125 | time: 41.95ms | tokens processed: 151,552 | tok/sec: 48,816.15
# 74 | lr: 6.29e-05 | loss: 7.3750 | time: 39.97ms | tokens processed: 153,600 | tok/sec: 51,243.42
# 75 | lr: 6.38e-05 | loss: 7.5938 | time: 40.38ms | tokens processed: 155,648 | tok/sec: 50,716.38
# 76 | lr: 6.46e-05 | loss: 7.5938 | time: 42.56ms | tokens processed: 157,696 | tok/sec: 48,120.46
# 77 | lr: 6.55e-05 | loss: 7.5312 | time: 44.00ms | tokens processed: 159,744 | tok/sec: 46,543.78
# 78 | lr: 6.63e-05 | loss: 7.5312 | time: 42.76ms | tokens processed: 161,792 | tok/sec: 47,896.68
# 79 | lr: 6.71e-05 | loss: 7.4688 | time: 41.74ms | tokens processed: 163,840 | tok/sec: 49,069.36
# 80 | lr: 6.80e-05 | loss: 7.4688 | time: 40.51ms | tokens processed: 165,888 | tok/sec: 50,557.28
# 81 | lr: 6.88e-05 | loss: 7.5938 | time: 41.65ms | tokens processed: 167,936 | tok/sec: 49,172.16
# 82 | lr: 6.97e-05 | loss: 7.3750 | time: 40.89ms | tokens processed: 169,984 | tok/sec: 50,084.75
# 83 | lr: 7.05e-05 | loss: 7.2500 | time: 39.85ms | tokens processed: 172,032 | tok/sec: 51,389.65
# 84 | lr: 7.13e-05 | loss: 7.3125 | time: 551.77ms | tokens processed: 174,080 | tok/sec: 3,711.66
# 85 | lr: 7.22e-05 | loss: 7.4688 | time: 46.79ms | tokens processed: 176,128 | tok/sec: 43,768.58
# 86 | lr: 7.30e-05 | loss: 7.4688 | time: 43.86ms | tokens processed: 178,176 | tok/sec: 46,696.36
# 87 | lr: 7.38e-05 | loss: 7.0000 | time: 41.16ms | tokens processed: 180,224 | tok/sec: 49,752.31
# 88 | lr: 7.47e-05 | loss: 7.1250 | time: 39.64ms | tokens processed: 182,272 | tok/sec: 51,660.39
# 89 | lr: 7.55e-05 | loss: 7.2500 | time: 40.11ms | tokens processed: 184,320 | tok/sec: 51,061.57
# 90 | lr: 7.64e-05 | loss: 7.0000 | time: 40.09ms | tokens processed: 186,368 | tok/sec: 51,090.12
# 91 | lr: 7.72e-05 | loss: 7.0312 | time: 42.00ms | tokens processed: 188,416 | tok/sec: 48,756.31
# 92 | lr: 7.80e-05 | loss: 6.9688 | time: 43.82ms | tokens processed: 190,464 | tok/sec: 46,736.24
# 93 | lr: 7.89e-05 | loss: 6.8125 | time: 43.93ms | tokens processed: 192,512 | tok/sec: 46,622.35
# 94 | lr: 7.97e-05 | loss: 6.9375 | time: 42.14ms | tokens processed: 194,560 | tok/sec: 48,601.55
# 95 | lr: 8.06e-05 | loss: 6.7500 | time: 41.66ms | tokens processed: 196,608 | tok/sec: 49,161.75
# 96 | lr: 8.14e-05 | loss: 6.7812 | time: 44.51ms | tokens processed: 198,656 | tok/sec: 46,010.52
# 97 | lr: 8.22e-05 | loss: 6.7812 | time: 45.58ms | tokens processed: 200,704 | tok/sec: 44,932.55
# 98 | lr: 8.31e-05 | loss: 6.6250 | time: 43.18ms | tokens processed: 202,752 | tok/sec: 47,432.52
# 99 | lr: 8.39e-05 | loss: 6.8438 | time: 49.35ms | tokens processed: 204,800 | tok/sec: 41,500.08
# 100 | lr: 8.48e-05 | loss: 6.6562 | time: 49.94ms | tokens processed: 206,848 | tok/sec: 41,012.06
# 101 | lr: 8.56e-05 | loss: 6.6250 | time: 46.31ms | tokens processed: 208,896 | tok/sec: 44,226.95
# 102 | lr: 8.64e-05 | loss: 6.5312 | time: 47.43ms | tokens processed: 210,944 | tok/sec: 43,180.69
# 103 | lr: 8.73e-05 | loss: 6.5625 | time: 45.57ms | tokens processed: 212,992 | tok/sec: 44,937.25
# 104 | lr: 8.81e-05 | loss: 6.5000 | time: 43.40ms | tokens processed: 215,040 | tok/sec: 47,192.00
# 105 | lr: 8.90e-05 | loss: 6.2812 | time: 39.75ms | tokens processed: 217,088 | tok/sec: 51,516.94
# 106 | lr: 8.98e-05 | loss: 6.3750 | time: 45.00ms | tokens processed: 219,136 | tok/sec: 45,507.42
# 107 | lr: 9.06e-05 | loss: 6.3750 | time: 47.23ms | tokens processed: 221,184 | tok/sec: 43,365.11
# 108 | lr: 9.15e-05 | loss: 6.2812 | time: 557.96ms | tokens processed: 223,232 | tok/sec: 3,670.53
# 109 | lr: 9.23e-05 | loss: 6.4062 | time: 49.24ms | tokens processed: 225,280 | tok/sec: 41,594.72
# 110 | lr: 9.31e-05 | loss: 6.3438 | time: 44.66ms | tokens processed: 227,328 | tok/sec: 45,862.39
# 111 | lr: 9.40e-05 | loss: 6.1250 | time: 45.33ms | tokens processed: 229,376 | tok/sec: 45,181.17
# 112 | lr: 9.48e-05 | loss: 6.2812 | time: 45.68ms | tokens processed: 231,424 | tok/sec: 44,836.86
# 113 | lr: 9.57e-05 | loss: 5.9688 | time: 42.82ms | tokens processed: 233,472 | tok/sec: 47,827.61
# 114 | lr: 9.65e-05 | loss: 6.0625 | time: 43.74ms | tokens processed: 235,520 | tok/sec: 46,822.60
# 115 | lr: 9.73e-05 | loss: 6.0000 | time: 46.60ms | tokens processed: 237,568 | tok/sec: 43,949.30
# 116 | lr: 9.82e-05 | loss: 6.2188 | time: 49.43ms | tokens processed: 239,616 | tok/sec: 41,435.62
# 117 | lr: 9.90e-05 | loss: 6.0312 | time: 47.52ms | tokens processed: 241,664 | tok/sec: 43,098.79
# 118 | lr: 9.99e-05 | loss: 6.0625 | time: 46.65ms | tokens processed: 243,712 | tok/sec: 43,900.33
# 119 | lr: 1.01e-04 | loss: 5.9688 | time: 47.12ms | tokens processed: 245,760 | tok/sec: 43,463.41
# 120 | lr: 1.02e-04 | loss: 5.9375 | time: 47.27ms | tokens processed: 247,808 | tok/sec: 43,325.96
# 121 | lr: 1.02e-04 | loss: 6.1875 | time: 47.38ms | tokens processed: 249,856 | tok/sec: 43,224.15
# 122 | lr: 1.03e-04 | loss: 6.1250 | time: 44.54ms | tokens processed: 251,904 | tok/sec: 45,979.98
# 123 | lr: 1.04e-04 | loss: 5.9688 | time: 46.60ms | tokens processed: 253,952 | tok/sec: 43,946.83
# 124 | lr: 1.05e-04 | loss: 5.9062 | time: 50.23ms | tokens processed: 256,000 | tok/sec: 40,776.10
# 125 | lr: 1.06e-04 | loss: 5.9062 | time: 49.58ms | tokens processed: 258,048 | tok/sec: 41,306.70
# 126 | lr: 1.07e-04 | loss: 5.8125 | time: 45.54ms | tokens processed: 260,096 | tok/sec: 44,975.83
# 127 | lr: 1.07e-04 | loss: 5.9688 | time: 46.33ms | tokens processed: 262,144 | tok/sec: 44,200.32
# 128 | lr: 1.08e-04 | loss: 5.8125 | time: 47.14ms | tokens processed: 264,192 | tok/sec: 43,442.09
# 129 | lr: 1.09e-04 | loss: 5.9062 | time: 46.63ms | tokens processed: 266,240 | tok/sec: 43,924.35
# 130 | lr: 1.10e-04 | loss: 5.5625 | time: 47.35ms | tokens processed: 268,288 | tok/sec: 43,250.92
# 131 | lr: 1.11e-04 | loss: 5.7188 | time: 557.72ms | tokens processed: 270,336 | tok/sec: 3,672.11
# 132 | lr: 1.12e-04 | loss: 5.8125 | time: 49.37ms | tokens processed: 272,384 | tok/sec: 41,483.04
# 133 | lr: 1.12e-04 | loss: 5.7188 | time: 44.84ms | tokens processed: 274,432 | tok/sec: 45,671.95
# 134 | lr: 1.13e-04 | loss: 5.7188 | time: 43.29ms | tokens processed: 276,480 | tok/sec: 47,313.39
# 135 | lr: 1.14e-04 | loss: 5.4688 | time: 43.33ms | tokens processed: 278,528 | tok/sec: 47,261.58
# 136 | lr: 1.15e-04 | loss: 5.4688 | time: 40.57ms | tokens processed: 280,576 | tok/sec: 50,483.30
# 137 | lr: 1.16e-04 | loss: 5.2812 | time: 39.35ms | tokens processed: 282,624 | tok/sec: 52,052.01
# 138 | lr: 1.17e-04 | loss: 5.4375 | time: 37.22ms | tokens processed: 284,672 | tok/sec: 55,025.59
# 139 | lr: 1.17e-04 | loss: 5.5938 | time: 43.02ms | tokens processed: 286,720 | tok/sec: 47,603.91
# 140 | lr: 1.18e-04 | loss: 5.5312 | time: 42.67ms | tokens processed: 288,768 | tok/sec: 48,001.07
# 141 | lr: 1.19e-04 | loss: 5.3750 | time: 39.06ms | tokens processed: 290,816 | tok/sec: 52,425.60
# 142 | lr: 1.20e-04 | loss: 5.4375 | time: 39.54ms | tokens processed: 292,864 | tok/sec: 51,790.58
# 143 | lr: 1.21e-04 | loss: 5.8750 | time: 40.06ms | tokens processed: 294,912 | tok/sec: 51,125.69
# 144 | lr: 1.22e-04 | loss: 5.7188 | time: 40.29ms | tokens processed: 296,960 | tok/sec: 50,832.83
# 145 | lr: 1.23e-04 | loss: 5.2500 | time: 40.89ms | tokens processed: 299,008 | tok/sec: 50,085.33
# 146 | lr: 1.23e-04 | loss: 5.3438 | time: 40.24ms | tokens processed: 301,056 | tok/sec: 50,889.44
# 147 | lr: 1.24e-04 | loss: 5.3438 | time: 43.09ms | tokens processed: 303,104 | tok/sec: 47,530.94
# 148 | lr: 1.25e-04 | loss: 5.4062 | time: 43.31ms | tokens processed: 305,152 | tok/sec: 47,288.90
# 149 | lr: 1.26e-04 | loss: 5.4062 | time: 40.65ms | tokens processed: 307,200 | tok/sec: 50,383.80
# 150 | lr: 1.27e-04 | loss: 5.4062 | time: 38.74ms | tokens processed: 309,248 | tok/sec: 52,867.97
# 151 | lr: 1.28e-04 | loss: 5.4375 | time: 39.57ms | tokens processed: 311,296 | tok/sec: 51,752.52
# 152 | lr: 1.28e-04 | loss: 5.6250 | time: 38.46ms | tokens processed: 313,344 | tok/sec: 53,249.45
# 153 | lr: 1.29e-04 | loss: 5.5312 | time: 38.46ms | tokens processed: 315,392 | tok/sec: 53,246.81
# 154 | lr: 1.30e-04 | loss: 5.2812 | time: 532.90ms | tokens processed: 317,440 | tok/sec: 3,843.14
# 155 | lr: 1.31e-04 | loss: 5.5312 | time: 49.76ms | tokens processed: 319,488 | tok/sec: 41,156.48
# 156 | lr: 1.32e-04 | loss: 5.4688 | time: 45.03ms | tokens processed: 321,536 | tok/sec: 45,476.58
# 157 | lr: 1.33e-04 | loss: 5.5625 | time: 42.46ms | tokens processed: 323,584 | tok/sec: 48,228.26
# 158 | lr: 1.33e-04 | loss: 5.6250 | time: 41.75ms | tokens processed: 325,632 | tok/sec: 49,052.55
# 159 | lr: 1.34e-04 | loss: 5.2188 | time: 40.29ms | tokens processed: 327,680 | tok/sec: 50,834.33
# 160 | lr: 1.35e-04 | loss: 5.1875 | time: 39.86ms | tokens processed: 329,728 | tok/sec: 51,386.27
# 161 | lr: 1.36e-04 | loss: 5.4375 | time: 42.66ms | tokens processed: 331,776 | tok/sec: 48,005.36
# 162 | lr: 1.37e-04 | loss: 5.2812 | time: 40.95ms | tokens processed: 333,824 | tok/sec: 50,008.93
# 163 | lr: 1.38e-04 | loss: 5.3438 | time: 40.38ms | tokens processed: 335,872 | tok/sec: 50,716.38
# 164 | lr: 1.38e-04 | loss: 5.1562 | time: 42.47ms | tokens processed: 337,920 | tok/sec: 48,220.67
# 165 | lr: 1.39e-04 | loss: 5.1875 | time: 45.68ms | tokens processed: 339,968 | tok/sec: 44,829.37
# 166 | lr: 1.40e-04 | loss: 5.2500 | time: 43.11ms | tokens processed: 342,016 | tok/sec: 47,504.92
# 167 | lr: 1.41e-04 | loss: 5.1562 | time: 39.66ms | tokens processed: 344,064 | tok/sec: 51,644.55
# 168 | lr: 1.42e-04 | loss: 5.0625 | time: 39.46ms | tokens processed: 346,112 | tok/sec: 51,899.16
# 169 | lr: 1.43e-04 | loss: 5.1875 | time: 42.59ms | tokens processed: 348,160 | tok/sec: 48,089.48
# 170 | lr: 1.43e-04 | loss: 5.3438 | time: 43.16ms | tokens processed: 350,208 | tok/sec: 47,456.37
# 171 | lr: 1.44e-04 | loss: 5.2812 | time: 42.29ms | tokens processed: 352,256 | tok/sec: 48,430.01
# 172 | lr: 1.45e-04 | loss: 5.2188 | time: 42.92ms | tokens processed: 354,304 | tok/sec: 47,717.62
# 173 | lr: 1.46e-04 | loss: 5.1562 | time: 44.92ms | tokens processed: 356,352 | tok/sec: 45,590.99
# 174 | lr: 1.47e-04 | loss: 5.2500 | time: 41.47ms | tokens processed: 358,400 | tok/sec: 49,381.06
# 175 | lr: 1.48e-04 | loss: 5.3125 | time: 40.68ms | tokens processed: 360,448 | tok/sec: 50,348.66
# 176 | lr: 1.49e-04 | loss: 5.1250 | time: 38.78ms | tokens processed: 362,496 | tok/sec: 52,814.98
# 177 | lr: 1.49e-04 | loss: 5.2188 | time: 527.19ms | tokens processed: 364,544 | tok/sec: 3,884.77
# 178 | lr: 1.50e-04 | loss: 5.0938 | time: 43.89ms | tokens processed: 366,592 | tok/sec: 46,662.62
# 179 | lr: 1.51e-04 | loss: 5.0938 | time: 40.63ms | tokens processed: 368,640 | tok/sec: 50,405.09
# 180 | lr: 1.52e-04 | loss: 5.0625 | time: 43.38ms | tokens processed: 370,688 | tok/sec: 47,210.41
# 181 | lr: 1.53e-04 | loss: 5.1562 | time: 43.10ms | tokens processed: 372,736 | tok/sec: 47,518.06
# 182 | lr: 1.54e-04 | loss: 5.1250 | time: 41.28ms | tokens processed: 374,784 | tok/sec: 49,606.64
# 183 | lr: 1.54e-04 | loss: 5.0312 | time: 39.73ms | tokens processed: 376,832 | tok/sec: 51,542.60
# 184 | lr: 1.55e-04 | loss: 5.0625 | time: 39.16ms | tokens processed: 378,880 | tok/sec: 52,293.47
# 185 | lr: 1.56e-04 | loss: 4.9062 | time: 41.41ms | tokens processed: 380,928 | tok/sec: 49,456.69
# 186 | lr: 1.57e-04 | loss: 4.9062 | time: 39.25ms | tokens processed: 382,976 | tok/sec: 52,180.07
# 187 | lr: 1.58e-04 | loss: 5.0000 | time: 39.60ms | tokens processed: 385,024 | tok/sec: 51,720.73
# 188 | lr: 1.59e-04 | loss: 5.2188 | time: 38.73ms | tokens processed: 387,072 | tok/sec: 52,877.08
# 189 | lr: 1.59e-04 | loss: 5.0000 | time: 44.40ms | tokens processed: 389,120 | tok/sec: 46,121.69
# 190 | lr: 1.60e-04 | loss: 5.0938 | time: 41.88ms | tokens processed: 391,168 | tok/sec: 48,900.64
# 191 | lr: 1.61e-04 | loss: 5.0625 | time: 39.21ms | tokens processed: 393,216 | tok/sec: 52,236.23
# 192 | lr: 1.62e-04 | loss: 5.2188 | time: 39.89ms | tokens processed: 395,264 | tok/sec: 51,336.83
# 193 | lr: 1.63e-04 | loss: 5.2500 | time: 41.32ms | tokens processed: 397,312 | tok/sec: 49,561.13
# 194 | lr: 1.64e-04 | loss: 5.1562 | time: 42.57ms | tokens processed: 399,360 | tok/sec: 48,105.90
# 195 | lr: 1.64e-04 | loss: 5.0938 | time: 40.18ms | tokens processed: 401,408 | tok/sec: 50,974.61
# 196 | lr: 1.65e-04 | loss: 4.8750 | time: 41.99ms | tokens processed: 403,456 | tok/sec: 48,771.25
# 197 | lr: 1.66e-04 | loss: 5.0000 | time: 42.94ms | tokens processed: 405,504 | tok/sec: 47,689.54
# 198 | lr: 1.67e-04 | loss: 5.0000 | time: 40.71ms | tokens processed: 407,552 | tok/sec: 50,303.84
# 199 | lr: 1.68e-04 | loss: 4.9688 | time: 40.21ms | tokens processed: 409,600 | tok/sec: 50,934.10
# 200 | lr: 1.69e-04 | loss: 4.9062 | time: 38.08ms | tokens processed: 411,648 | tok/sec: 53,787.27
# 201 | lr: 1.70e-04 | loss: 4.9375 | time: 532.54ms | tokens processed: 413,696 | tok/sec: 3,845.69
# 202 | lr: 1.70e-04 | loss: 4.6562 | time: 43.27ms | tokens processed: 415,744 | tok/sec: 47,334.24
# 203 | lr: 1.71e-04 | loss: 5.0000 | time: 40.92ms | tokens processed: 417,792 | tok/sec: 50,047.39
# 204 | lr: 1.72e-04 | loss: 4.9375 | time: 42.85ms | tokens processed: 419,840 | tok/sec: 47,799.40
# 205 | lr: 1.73e-04 | loss: 5.1250 | time: 41.69ms | tokens processed: 421,888 | tok/sec: 49,128.29
# 206 | lr: 1.74e-04 | loss: 4.7812 | time: 42.72ms | tokens processed: 423,936 | tok/sec: 47,935.17
# 207 | lr: 1.75e-04 | loss: 4.5000 | time: 41.49ms | tokens processed: 425,984 | tok/sec: 49,362.33
# 208 | lr: 1.75e-04 | loss: 4.6562 | time: 40.56ms | tokens processed: 428,032 | tok/sec: 50,494.87
# 209 | lr: 1.76e-04 | loss: 4.3750 | time: 43.67ms | tokens processed: 430,080 | tok/sec: 46,896.99
# 210 | lr: 1.77e-04 | loss: 4.6875 | time: 40.40ms | tokens processed: 432,128 | tok/sec: 50,699.32
# 211 | lr: 1.78e-04 | loss: 4.9062 | time: 39.91ms | tokens processed: 434,176 | tok/sec: 51,311.99
# 212 | lr: 1.79e-04 | loss: 4.5938 | time: 38.72ms | tokens processed: 436,224 | tok/sec: 52,885.87
# 213 | lr: 1.80e-04 | loss: 4.7188 | time: 40.19ms | tokens processed: 438,272 | tok/sec: 50,956.16
# 214 | lr: 1.80e-04 | loss: 4.7812 | time: 43.69ms | tokens processed: 440,320 | tok/sec: 46,879.33
# 215 | lr: 1.81e-04 | loss: 5.4688 | time: 41.86ms | tokens processed: 442,368 | tok/sec: 48,926.26
# 216 | lr: 1.82e-04 | loss: 4.8438 | time: 39.88ms | tokens processed: 444,416 | tok/sec: 51,356.16
# 217 | lr: 1.83e-04 | loss: 4.7188 | time: 40.83ms | tokens processed: 446,464 | tok/sec: 50,156.10
# 218 | lr: 1.84e-04 | loss: 4.7188 | time: 42.71ms | tokens processed: 448,512 | tok/sec: 47,946.94
# 219 | lr: 1.85e-04 | loss: 4.6875 | time: 41.71ms | tokens processed: 450,560 | tok/sec: 49,099.93
# 220 | lr: 1.85e-04 | loss: 4.7188 | time: 42.87ms | tokens processed: 452,608 | tok/sec: 47,774.41
# 221 | lr: 1.86e-04 | loss: 4.8750 | time: 46.43ms | tokens processed: 454,656 | tok/sec: 44,110.67
# 222 | lr: 1.87e-04 | loss: 4.6875 | time: 46.94ms | tokens processed: 456,704 | tok/sec: 43,629.64
# 223 | lr: 1.88e-04 | loss: 5.0000 | time: 45.66ms | tokens processed: 458,752 | tok/sec: 44,856.06
# 224 | lr: 1.89e-04 | loss: 4.9688 | time: 545.52ms | tokens processed: 460,800 | tok/sec: 3,754.25
# 225 | lr: 1.90e-04 | loss: 4.9375 | time: 44.41ms | tokens processed: 462,848 | tok/sec: 46,115.75
# 226 | lr: 1.90e-04 | loss: 4.7500 | time: 40.80ms | tokens processed: 464,896 | tok/sec: 50,196.55
# 227 | lr: 1.91e-04 | loss: 5.1250 | time: 42.41ms | tokens processed: 466,944 | tok/sec: 48,291.97
# 228 | lr: 1.92e-04 | loss: 4.9375 | time: 45.25ms | tokens processed: 468,992 | tok/sec: 45,263.31
# 229 | lr: 1.93e-04 | loss: 5.1562 | time: 46.55ms | tokens processed: 471,040 | tok/sec: 43,997.47
# 230 | lr: 1.94e-04 | loss: 4.8438 | time: 44.36ms | tokens processed: 473,088 | tok/sec: 46,168.79
# 231 | lr: 1.95e-04 | loss: 4.7188 | time: 44.63ms | tokens processed: 475,136 | tok/sec: 45,885.67
# 232 | lr: 1.96e-04 | loss: 4.7812 | time: 45.79ms | tokens processed: 477,184 | tok/sec: 44,721.07
# 233 | lr: 1.96e-04 | loss: 4.7812 | time: 44.83ms | tokens processed: 479,232 | tok/sec: 45,688.47
# 234 | lr: 1.97e-04 | loss: 4.7500 | time: 42.89ms | tokens processed: 481,280 | tok/sec: 47,753.69
# 235 | lr: 1.98e-04 | loss: 4.8438 | time: 42.54ms | tokens processed: 483,328 | tok/sec: 48,145.00
# 236 | lr: 1.99e-04 | loss: 4.5938 | time: 39.53ms | tokens processed: 485,376 | tok/sec: 51,803.70
# 237 | lr: 2.00e-04 | loss: 4.6875 | time: 40.37ms | tokens processed: 487,424 | tok/sec: 50,735.55
# 238 | lr: 2.01e-04 | loss: 4.6875 | time: 41.30ms | tokens processed: 489,472 | tok/sec: 49,590.60
# 239 | lr: 2.01e-04 | loss: 4.6562 | time: 42.15ms | tokens processed: 491,520 | tok/sec: 48,583.95
# 240 | lr: 2.02e-04 | loss: 4.5000 | time: 40.93ms | tokens processed: 493,568 | tok/sec: 50,041.56
# 241 | lr: 2.03e-04 | loss: 4.7812 | time: 45.99ms | tokens processed: 495,616 | tok/sec: 44,533.28
# 242 | lr: 2.04e-04 | loss: 4.8125 | time: 43.61ms | tokens processed: 497,664 | tok/sec: 46,958.27
# 243 | lr: 2.05e-04 | loss: 4.7500 | time: 43.36ms | tokens processed: 499,712 | tok/sec: 47,235.59
# 244 | lr: 2.06e-04 | loss: 4.7188 | time: 44.55ms | tokens processed: 501,760 | tok/sec: 45,968.91
# 245 | lr: 2.06e-04 | loss: 4.6562 | time: 41.82ms | tokens processed: 503,808 | tok/sec: 48,977.59
# 246 | lr: 2.07e-04 | loss: 4.7188 | time: 41.47ms | tokens processed: 505,856 | tok/sec: 49,387.59
# 247 | lr: 2.08e-04 | loss: 4.9062 | time: 551.14ms | tokens processed: 507,904 | tok/sec: 3,715.92
# 248 | lr: 2.09e-04 | loss: 4.5625 | time: 45.30ms | tokens processed: 509,952 | tok/sec: 45,213.28
# 249 | lr: 2.10e-04 | loss: 4.8125 | time: 43.34ms | tokens processed: 512,000 | tok/sec: 47,257.16
# 250 | lr: 2.11e-04 | loss: 4.4688 | time: 41.85ms | tokens processed: 514,048 | tok/sec: 48,935.74
# 251 | lr: 2.11e-04 | loss: 4.5312 | time: 46.78ms | tokens processed: 516,096 | tok/sec: 43,783.98
# 252 | lr: 2.12e-04 | loss: 4.6875 | time: 46.48ms | tokens processed: 518,144 | tok/sec: 44,066.31
# 253 | lr: 2.13e-04 | loss: 4.7188 | time: 46.28ms | tokens processed: 520,192 | tok/sec: 44,251.78
# 254 | lr: 2.14e-04 | loss: 4.5625 | time: 48.19ms | tokens processed: 522,240 | tok/sec: 42,496.87
# 255 | lr: 2.15e-04 | loss: 4.7188 | time: 47.09ms | tokens processed: 524,288 | tok/sec: 43,491.14
# 256 | lr: 2.16e-04 | loss: 4.5312 | time: 45.87ms | tokens processed: 526,336 | tok/sec: 44,647.16
# 257 | lr: 2.17e-04 | loss: 4.5000 | time: 47.23ms | tokens processed: 528,384 | tok/sec: 43,361.17
# 258 | lr: 2.17e-04 | loss: 4.5000 | time: 44.80ms | tokens processed: 530,432 | tok/sec: 45,714.24
# 259 | lr: 2.18e-04 | loss: 4.6250 | time: 46.98ms | tokens processed: 532,480 | tok/sec: 43,588.46
# 260 | lr: 2.19e-04 | loss: 4.6875 | time: 47.14ms | tokens processed: 534,528 | tok/sec: 43,449.34
# 261 | lr: 2.20e-04 | loss: 4.6562 | time: 49.08ms | tokens processed: 536,576 | tok/sec: 41,726.66
# 262 | lr: 2.21e-04 | loss: 4.6562 | time: 47.94ms | tokens processed: 538,624 | tok/sec: 42,721.11
# 263 | lr: 2.22e-04 | loss: 4.5625 | time: 48.67ms | tokens processed: 540,672 | tok/sec: 42,077.61
# 264 | lr: 2.22e-04 | loss: 4.8438 | time: 44.12ms | tokens processed: 542,720 | tok/sec: 46,424.05
# 265 | lr: 2.23e-04 | loss: 4.8438 | time: 44.08ms | tokens processed: 544,768 | tok/sec: 46,459.95
# 266 | lr: 2.24e-04 | loss: 4.6875 | time: 43.82ms | tokens processed: 546,816 | tok/sec: 46,738.79
# 267 | lr: 2.25e-04 | loss: 4.5938 | time: 46.81ms | tokens processed: 548,864 | tok/sec: 43,753.42
# 268 | lr: 2.26e-04 | loss: 4.4688 | time: 46.90ms | tokens processed: 550,912 | tok/sec: 43,664.24
# 269 | lr: 2.27e-04 | loss: 4.4688 | time: 46.90ms | tokens processed: 552,960 | tok/sec: 43,665.13
# 270 | lr: 2.27e-04 | loss: 4.7500 | time: 556.11ms | tokens processed: 555,008 | tok/sec: 3,682.70
# 271 | lr: 2.28e-04 | loss: 4.4688 | time: 42.24ms | tokens processed: 557,056 | tok/sec: 48,481.95
# 272 | lr: 2.29e-04 | loss: 4.4375 | time: 38.79ms | tokens processed: 559,104 | tok/sec: 52,799.73
# 273 | lr: 2.30e-04 | loss: 4.3438 | time: 39.53ms | tokens processed: 561,152 | tok/sec: 51,804.95
# 274 | lr: 2.31e-04 | loss: 4.4375 | time: 41.91ms | tokens processed: 563,200 | tok/sec: 48,869.20
# 275 | lr: 2.32e-04 | loss: 4.6875 | time: 42.32ms | tokens processed: 565,248 | tok/sec: 48,389.09
# 276 | lr: 2.32e-04 | loss: 4.4688 | time: 39.57ms | tokens processed: 567,296 | tok/sec: 51,755.32
# 277 | lr: 2.33e-04 | loss: 4.6875 | time: 38.92ms | tokens processed: 569,344 | tok/sec: 52,621.83
# 278 | lr: 2.34e-04 | loss: 4.1562 | time: 39.30ms | tokens processed: 571,392 | tok/sec: 52,118.33
# 279 | lr: 2.35e-04 | loss: 4.0625 | time: 41.35ms | tokens processed: 573,440 | tok/sec: 49,532.83
# 280 | lr: 2.36e-04 | loss: 3.9375 | time: 39.96ms | tokens processed: 575,488 | tok/sec: 51,252.90
# 281 | lr: 2.37e-04 | loss: 3.9062 | time: 38.94ms | tokens processed: 577,536 | tok/sec: 52,595.41
# 282 | lr: 2.37e-04 | loss: 4.3750 | time: 38.89ms | tokens processed: 579,584 | tok/sec: 52,661.51
# 283 | lr: 2.38e-04 | loss: 4.3750 | time: 43.95ms | tokens processed: 581,632 | tok/sec: 46,594.78
# 284 | lr: 2.39e-04 | loss: 4.1562 | time: 40.89ms | tokens processed: 583,680 | tok/sec: 50,085.33
# 285 | lr: 2.40e-04 | loss: 4.3438 | time: 39.98ms | tokens processed: 585,728 | tok/sec: 51,220.81
# 286 | lr: 2.41e-04 | loss: 4.6875 | time: 45.53ms | tokens processed: 587,776 | tok/sec: 44,986.20
# 287 | lr: 2.42e-04 | loss: 4.9062 | time: 43.82ms | tokens processed: 589,824 | tok/sec: 46,739.55
# 288 | lr: 2.43e-04 | loss: 4.4062 | time: 40.14ms | tokens processed: 591,872 | tok/sec: 51,015.47
# 289 | lr: 2.43e-04 | loss: 4.3438 | time: 41.20ms | tokens processed: 593,920 | tok/sec: 49,714.30
# 290 | lr: 2.44e-04 | loss: 4.3750 | time: 41.40ms | tokens processed: 595,968 | tok/sec: 49,474.07
# 291 | lr: 2.45e-04 | loss: 4.3750 | time: 42.57ms | tokens processed: 598,016 | tok/sec: 48,105.90
# 292 | lr: 2.46e-04 | loss: 4.4375 | time: 41.69ms | tokens processed: 600,064 | tok/sec: 49,126.33
# 293 | lr: 2.47e-04 | loss: 4.5000 | time: 40.06ms | tokens processed: 602,112 | tok/sec: 51,123.56
# 294 | lr: 2.48e-04 | loss: 4.2812 | time: 542.33ms | tokens processed: 604,160 | tok/sec: 3,776.29
# 295 | lr: 2.48e-04 | loss: 4.6875 | time: 45.01ms | tokens processed: 606,208 | tok/sec: 45,504.77
# 296 | lr: 2.49e-04 | loss: 4.6562 | time: 42.64ms | tokens processed: 608,256 | tok/sec: 48,035.42
# 297 | lr: 2.50e-04 | loss: 4.4062 | time: 41.03ms | tokens processed: 610,304 | tok/sec: 49,918.55
# 298 | lr: 2.51e-04 | loss: 4.4062 | time: 41.45ms | tokens processed: 612,352 | tok/sec: 49,406.62
# 299 | lr: 2.52e-04 | loss: 4.7500 | time: 41.35ms | tokens processed: 614,400 | tok/sec: 49,525.12
# 300 | lr: 2.53e-04 | loss: 4.6562 | time: 42.13ms | tokens processed: 616,448 | tok/sec: 48,612.00
# 301 | lr: 2.53e-04 | loss: 4.7812 | time: 41.16ms | tokens processed: 618,496 | tok/sec: 49,755.48
# 302 | lr: 2.54e-04 | loss: 4.4375 | time: 40.10ms | tokens processed: 620,544 | tok/sec: 51,072.50
# 303 | lr: 2.55e-04 | loss: 4.2812 | time: 46.47ms | tokens processed: 622,592 | tok/sec: 44,075.13
# 304 | lr: 2.56e-04 | loss: 4.5938 | time: 47.50ms | tokens processed: 624,640 | tok/sec: 43,119.56
# 305 | lr: 2.57e-04 | loss: 4.3125 | time: 45.49ms | tokens processed: 626,688 | tok/sec: 45,022.51
# 306 | lr: 2.58e-04 | loss: 4.4688 | time: 46.85ms | tokens processed: 628,736 | tok/sec: 43,714.01
# 307 | lr: 2.58e-04 | loss: 4.4375 | time: 44.63ms | tokens processed: 630,784 | tok/sec: 45,892.53
# 308 | lr: 2.59e-04 | loss: 4.1875 | time: 42.61ms | tokens processed: 632,832 | tok/sec: 48,062.84
# 309 | lr: 2.60e-04 | loss: 4.5000 | time: 42.04ms | tokens processed: 634,880 | tok/sec: 48,717.87
# 310 | lr: 2.61e-04 | loss: 4.3125 | time: 43.01ms | tokens processed: 636,928 | tok/sec: 47,614.73
# 311 | lr: 2.62e-04 | loss: 4.2500 | time: 44.56ms | tokens processed: 638,976 | tok/sec: 45,964.48
# 312 | lr: 2.63e-04 | loss: 4.0938 | time: 42.23ms | tokens processed: 641,024 | tok/sec: 48,494.26
# 313 | lr: 2.63e-04 | loss: 4.5625 | time: 44.13ms | tokens processed: 643,072 | tok/sec: 46,404.24
# 314 | lr: 2.64e-04 | loss: 4.4375 | time: 42.28ms | tokens processed: 645,120 | tok/sec: 48,442.85
# 315 | lr: 2.65e-04 | loss: 4.5000 | time: 41.14ms | tokens processed: 647,168 | tok/sec: 49,776.52
# 316 | lr: 2.66e-04 | loss: 4.3438 | time: 40.41ms | tokens processed: 649,216 | tok/sec: 50,680.47
# 317 | lr: 2.67e-04 | loss: 4.2812 | time: 550.60ms | tokens processed: 651,264 | tok/sec: 3,719.55
# 318 | lr: 2.68e-04 | loss: 4.4375 | time: 42.95ms | tokens processed: 653,312 | tok/sec: 47,682.92
# 319 | lr: 2.69e-04 | loss: 4.5000 | time: 43.70ms | tokens processed: 655,360 | tok/sec: 46,865.52
# 320 | lr: 2.69e-04 | loss: 4.3125 | time: 41.07ms | tokens processed: 657,408 | tok/sec: 49,869.00
# 321 | lr: 2.70e-04 | loss: 4.2500 | time: 44.13ms | tokens processed: 659,456 | tok/sec: 46,412.76
# 322 | lr: 2.71e-04 | loss: 4.1875 | time: 40.43ms | tokens processed: 661,504 | tok/sec: 50,658.35
# 323 | lr: 2.72e-04 | loss: 4.1562 | time: 39.49ms | tokens processed: 663,552 | tok/sec: 51,867.51
# 324 | lr: 2.73e-04 | loss: 4.4375 | time: 40.11ms | tokens processed: 665,600 | tok/sec: 51,063.69
# 325 | lr: 2.74e-04 | loss: 4.3125 | time: 40.31ms | tokens processed: 667,648 | tok/sec: 50,810.58
# 326 | lr: 2.74e-04 | loss: 4.3125 | time: 40.49ms | tokens processed: 669,696 | tok/sec: 50,578.71
# 327 | lr: 2.75e-04 | loss: 4.2812 | time: 40.57ms | tokens processed: 671,744 | tok/sec: 50,480.92
# 328 | lr: 2.76e-04 | loss: 4.2812 | time: 40.16ms | tokens processed: 673,792 | tok/sec: 50,992.16
# 329 | lr: 2.77e-04 | loss: 4.1250 | time: 40.77ms | tokens processed: 675,840 | tok/sec: 50,229.13
# 330 | lr: 2.78e-04 | loss: 4.2812 | time: 39.20ms | tokens processed: 677,888 | tok/sec: 52,239.09
# 331 | lr: 2.79e-04 | loss: 4.3438 | time: 39.09ms | tokens processed: 679,936 | tok/sec: 52,389.15
# 332 | lr: 2.79e-04 | loss: 4.2500 | time: 39.12ms | tokens processed: 681,984 | tok/sec: 52,346.69
# 333 | lr: 2.80e-04 | loss: 4.3750 | time: 39.70ms | tokens processed: 684,032 | tok/sec: 51,588.41
# 334 | lr: 2.81e-04 | loss: 4.3125 | time: 39.51ms | tokens processed: 686,080 | tok/sec: 51,835.59
# 335 | lr: 2.82e-04 | loss: 4.3750 | time: 41.55ms | tokens processed: 688,128 | tok/sec: 49,284.17
# 336 | lr: 2.83e-04 | loss: 4.6562 | time: 40.45ms | tokens processed: 690,176 | tok/sec: 50,631.78
# 337 | lr: 2.84e-04 | loss: 4.4062 | time: 45.23ms | tokens processed: 692,224 | tok/sec: 45,279.29
# 338 | lr: 2.84e-04 | loss: 4.4375 | time: 40.54ms | tokens processed: 694,272 | tok/sec: 50,516.25
# 339 | lr: 2.85e-04 | loss: 4.0938 | time: 39.68ms | tokens processed: 696,320 | tok/sec: 51,617.86
# 340 | lr: 2.86e-04 | loss: 4.1250 | time: 40.21ms | tokens processed: 698,368 | tok/sec: 50,936.82
# 341 | lr: 2.87e-04 | loss: 4.2188 | time: 536.36ms | tokens processed: 700,416 | tok/sec: 3,818.33
# 342 | lr: 2.88e-04 | loss: 4.4062 | time: 41.99ms | tokens processed: 702,464 | tok/sec: 48,775.41
# 343 | lr: 2.89e-04 | loss: 4.0000 | time: 40.59ms | tokens processed: 704,512 | tok/sec: 50,460.76
# 344 | lr: 2.90e-04 | loss: 4.1875 | time: 43.85ms | tokens processed: 706,560 | tok/sec: 46,703.72
# 345 | lr: 2.90e-04 | loss: 3.9531 | time: 45.67ms | tokens processed: 708,608 | tok/sec: 44,846.69
# 346 | lr: 2.91e-04 | loss: 4.1562 | time: 42.08ms | tokens processed: 710,656 | tok/sec: 48,666.53
# 347 | lr: 2.92e-04 | loss: 4.3438 | time: 41.25ms | tokens processed: 712,704 | tok/sec: 49,643.04
# 348 | lr: 2.93e-04 | loss: 4.3438 | time: 41.55ms | tokens processed: 714,752 | tok/sec: 49,292.09
# 349 | lr: 2.94e-04 | loss: 4.2188 | time: 44.87ms | tokens processed: 716,800 | tok/sec: 45,645.50
# 350 | lr: 2.95e-04 | loss: 3.6562 | time: 42.00ms | tokens processed: 718,848 | tok/sec: 48,760.73
# 351 | lr: 2.95e-04 | loss: 3.7188 | time: 41.68ms | tokens processed: 720,896 | tok/sec: 49,136.72
# 352 | lr: 2.96e-04 | loss: 3.4844 | time: 42.59ms | tokens processed: 722,944 | tok/sec: 48,082.75
# 353 | lr: 2.97e-04 | loss: 3.7656 | time: 51.98ms | tokens processed: 724,992 | tok/sec: 39,402.29
# 354 | lr: 2.98e-04 | loss: 4.0625 | time: 47.17ms | tokens processed: 727,040 | tok/sec: 43,420.79
# 355 | lr: 2.99e-04 | loss: 3.9375 | time: 43.96ms | tokens processed: 729,088 | tok/sec: 46,591.24
# 356 | lr: 3.00e-04 | loss: 3.9219 | time: 44.74ms | tokens processed: 731,136 | tok/sec: 45,774.66
# 357 | lr: 3.00e-04 | loss: 3.9062 | time: 44.62ms | tokens processed: 733,184 | tok/sec: 45,894.74
# 358 | lr: 3.01e-04 | loss: 4.7500 | time: 41.82ms | tokens processed: 735,232 | tok/sec: 48,974.80
# 359 | lr: 3.02e-04 | loss: 4.4688 | time: 42.23ms | tokens processed: 737,280 | tok/sec: 48,499.19
# 360 | lr: 3.03e-04 | loss: 4.1250 | time: 43.94ms | tokens processed: 739,328 | tok/sec: 46,606.16
# 361 | lr: 3.04e-04 | loss: 4.1250 | time: 42.87ms | tokens processed: 741,376 | tok/sec: 47,773.35
# 362 | lr: 3.05e-04 | loss: 4.0625 | time: 43.28ms | tokens processed: 743,424 | tok/sec: 47,322.25
# 363 | lr: 3.05e-04 | loss: 4.1875 | time: 41.30ms | tokens processed: 745,472 | tok/sec: 49,586.59
# 364 | lr: 3.06e-04 | loss: 4.1875 | time: 562.08ms | tokens processed: 747,520 | tok/sec: 3,643.60
# 365 | lr: 3.07e-04 | loss: 4.1562 | time: 47.10ms | tokens processed: 749,568 | tok/sec: 43,478.15
# 366 | lr: 3.08e-04 | loss: 4.3125 | time: 46.42ms | tokens processed: 751,616 | tok/sec: 44,119.73
# 367 | lr: 3.09e-04 | loss: 4.3750 | time: 41.92ms | tokens processed: 753,664 | tok/sec: 48,858.64
# 368 | lr: 3.10e-04 | loss: 4.2812 | time: 45.83ms | tokens processed: 755,712 | tok/sec: 44,690.36
# 369 | lr: 3.10e-04 | loss: 4.1875 | time: 41.59ms | tokens processed: 757,760 | tok/sec: 49,238.68
# 370 | lr: 3.11e-04 | loss: 4.3438 | time: 39.88ms | tokens processed: 759,808 | tok/sec: 51,350.33
# 371 | lr: 3.12e-04 | loss: 4.3438 | time: 39.45ms | tokens processed: 761,856 | tok/sec: 51,911.71
# 372 | lr: 3.13e-04 | loss: 4.4375 | time: 39.55ms | tokens processed: 763,904 | tok/sec: 51,788.71
# 373 | lr: 3.14e-04 | loss: 4.4375 | time: 42.35ms | tokens processed: 765,952 | tok/sec: 48,358.85
# 374 | lr: 3.15e-04 | loss: 4.0938 | time: 39.58ms | tokens processed: 768,000 | tok/sec: 51,748.15
# 375 | lr: 3.16e-04 | loss: 4.0312 | time: 40.48ms | tokens processed: 770,048 | tok/sec: 50,596.59
# 376 | lr: 3.16e-04 | loss: 4.2812 | time: 40.61ms | tokens processed: 772,096 | tok/sec: 50,426.99
# 377 | lr: 3.17e-04 | loss: 4.1562 | time: 40.89ms | tokens processed: 774,144 | tok/sec: 50,087.08
# 378 | lr: 3.18e-04 | loss: 4.3125 | time: 39.06ms | tokens processed: 776,192 | tok/sec: 52,426.24
# 379 | lr: 3.19e-04 | loss: 4.0312 | time: 38.94ms | tokens processed: 778,240 | tok/sec: 52,587.68
# 380 | lr: 3.20e-04 | loss: 4.0938 | time: 42.28ms | tokens processed: 780,288 | tok/sec: 48,435.75
# 381 | lr: 3.21e-04 | loss: 4.1250 | time: 41.37ms | tokens processed: 782,336 | tok/sec: 49,502.58
# 382 | lr: 3.21e-04 | loss: 4.0312 | time: 44.13ms | tokens processed: 784,384 | tok/sec: 46,410.00
# 383 | lr: 3.22e-04 | loss: 3.9219 | time: 45.65ms | tokens processed: 786,432 | tok/sec: 44,862.61
# 384 | lr: 3.23e-04 | loss: 3.9688 | time: 48.04ms | tokens processed: 788,480 | tok/sec: 42,627.62
# 385 | lr: 3.24e-04 | loss: 4.3125 | time: 43.90ms | tokens processed: 790,528 | tok/sec: 46,655.01
# 386 | lr: 3.25e-04 | loss: 4.1250 | time: 40.48ms | tokens processed: 792,576 | tok/sec: 50,596.89
# 387 | lr: 3.26e-04 | loss: 4.2500 | time: 560.72ms | tokens processed: 794,624 | tok/sec: 3,652.47
# 388 | lr: 3.26e-04 | loss: 3.9688 | time: 47.60ms | tokens processed: 796,672 | tok/sec: 43,023.24
# 389 | lr: 3.27e-04 | loss: 4.0938 | time: 44.57ms | tokens processed: 798,720 | tok/sec: 45,952.93
# 390 | lr: 3.28e-04 | loss: 4.2500 | time: 41.99ms | tokens processed: 800,768 | tok/sec: 48,768.48
# 391 | lr: 3.29e-04 | loss: 4.0625 | time: 46.27ms | tokens processed: 802,816 | tok/sec: 44,262.27
# 392 | lr: 3.30e-04 | loss: 4.1562 | time: 47.06ms | tokens processed: 804,864 | tok/sec: 43,518.24
# 393 | lr: 3.31e-04 | loss: 3.9375 | time: 45.92ms | tokens processed: 806,912 | tok/sec: 44,598.48
# 394 | lr: 3.31e-04 | loss: 3.9531 | time: 45.41ms | tokens processed: 808,960 | tok/sec: 45,101.46
# 395 | lr: 3.32e-04 | loss: 4.0312 | time: 46.22ms | tokens processed: 811,008 | tok/sec: 44,309.08
# 396 | lr: 3.33e-04 | loss: 4.0938 | time: 48.96ms | tokens processed: 813,056 | tok/sec: 41,828.87
# 397 | lr: 3.34e-04 | loss: 4.0625 | time: 49.60ms | tokens processed: 815,104 | tok/sec: 41,293.39
# 398 | lr: 3.35e-04 | loss: 4.0000 | time: 48.40ms | tokens processed: 817,152 | tok/sec: 42,310.36
# 399 | lr: 3.36e-04 | loss: 4.0938 | time: 50.63ms | tokens processed: 819,200 | tok/sec: 40,446.44
# 400 | lr: 3.37e-04 | loss: 3.9531 | time: 50.35ms | tokens processed: 821,248 | tok/sec: 40,675.89
# 401 | lr: 3.37e-04 | loss: 3.8906 | time: 49.29ms | tokens processed: 823,296 | tok/sec: 41,552.47
# 402 | lr: 3.38e-04 | loss: 4.0938 | time: 47.12ms | tokens processed: 825,344 | tok/sec: 43,467.59
# 403 | lr: 3.39e-04 | loss: 4.1250 | time: 46.79ms | tokens processed: 827,392 | tok/sec: 43,773.27
# 404 | lr: 3.40e-04 | loss: 4.0312 | time: 45.80ms | tokens processed: 829,440 | tok/sec: 44,713.86
# 405 | lr: 3.41e-04 | loss: 4.0312 | time: 48.70ms | tokens processed: 831,488 | tok/sec: 42,051.45
# 406 | lr: 3.42e-04 | loss: 4.0625 | time: 44.88ms | tokens processed: 833,536 | tok/sec: 45,630.46
# 407 | lr: 3.42e-04 | loss: 4.4062 | time: 40.70ms | tokens processed: 835,584 | tok/sec: 50,325.06
# 408 | lr: 3.43e-04 | loss: 4.2500 | time: 44.53ms | tokens processed: 837,632 | tok/sec: 45,990.32
# 409 | lr: 3.44e-04 | loss: 4.1250 | time: 42.46ms | tokens processed: 839,680 | tok/sec: 48,238.82
# 410 | lr: 3.45e-04 | loss: 4.1250 | time: 41.89ms | tokens processed: 841,728 | tok/sec: 48,889.50
# 411 | lr: 3.46e-04 | loss: 3.8281 | time: 561.00ms | tokens processed: 843,776 | tok/sec: 3,650.65
# 412 | lr: 3.47e-04 | loss: 3.7969 | time: 45.31ms | tokens processed: 845,824 | tok/sec: 45,204.71
# 413 | lr: 3.47e-04 | loss: 4.2500 | time: 42.48ms | tokens processed: 847,872 | tok/sec: 48,213.91
# 414 | lr: 3.48e-04 | loss: 3.8906 | time: 41.88ms | tokens processed: 849,920 | tok/sec: 48,899.52
# 415 | lr: 3.49e-04 | loss: 3.8594 | time: 44.96ms | tokens processed: 851,968 | tok/sec: 45,554.24
# 416 | lr: 3.50e-04 | loss: 3.8750 | time: 41.97ms | tokens processed: 854,016 | tok/sec: 48,800.62
# 417 | lr: 3.51e-04 | loss: 3.7031 | time: 40.57ms | tokens processed: 856,064 | tok/sec: 50,483.59
# 418 | lr: 3.52e-04 | loss: 4.0938 | time: 40.94ms | tokens processed: 858,112 | tok/sec: 50,020.87
# 419 | lr: 3.52e-04 | loss: 3.8750 | time: 41.35ms | tokens processed: 860,160 | tok/sec: 49,523.12
# 420 | lr: 3.53e-04 | loss: 4.3125 | time: 40.81ms | tokens processed: 862,208 | tok/sec: 50,181.01
# 421 | lr: 3.54e-04 | loss: 3.7656 | time: 40.12ms | tokens processed: 864,256 | tok/sec: 51,051.55
# 422 | lr: 3.55e-04 | loss: 3.2812 | time: 38.88ms | tokens processed: 866,304 | tok/sec: 52,677.01
# 423 | lr: 3.56e-04 | loss: 3.3281 | time: 40.31ms | tokens processed: 868,352 | tok/sec: 50,800.06
# 424 | lr: 3.57e-04 | loss: 3.1406 | time: 41.00ms | tokens processed: 870,400 | tok/sec: 49,948.74
# 425 | lr: 3.57e-04 | loss: 3.6562 | time: 40.84ms | tokens processed: 872,448 | tok/sec: 50,143.22
# 426 | lr: 3.58e-04 | loss: 3.8594 | time: 39.73ms | tokens processed: 874,496 | tok/sec: 51,542.60
# 427 | lr: 3.59e-04 | loss: 3.6562 | time: 40.77ms | tokens processed: 876,544 | tok/sec: 50,231.77
# 428 | lr: 3.60e-04 | loss: 3.6719 | time: 39.56ms | tokens processed: 878,592 | tok/sec: 51,765.93
# 429 | lr: 3.61e-04 | loss: 3.9062 | time: 41.59ms | tokens processed: 880,640 | tok/sec: 49,242.92
# 430 | lr: 3.62e-04 | loss: 4.5000 | time: 42.33ms | tokens processed: 882,688 | tok/sec: 48,383.09
# 431 | lr: 3.63e-04 | loss: 4.0938 | time: 42.12ms | tokens processed: 884,736 | tok/sec: 48,624.93
# 432 | lr: 3.63e-04 | loss: 3.9375 | time: 42.91ms | tokens processed: 886,784 | tok/sec: 47,724.78
# 433 | lr: 3.64e-04 | loss: 3.9062 | time: 40.64ms | tokens processed: 888,832 | tok/sec: 50,392.67
# 434 | lr: 3.65e-04 | loss: 3.9062 | time: 541.33ms | tokens processed: 890,880 | tok/sec: 3,783.26
# 435 | lr: 3.66e-04 | loss: 3.8906 | time: 43.43ms | tokens processed: 892,928 | tok/sec: 47,157.28
# 436 | lr: 3.67e-04 | loss: 3.9688 | time: 40.14ms | tokens processed: 894,976 | tok/sec: 51,023.66
# 437 | lr: 3.68e-04 | loss: 3.8281 | time: 41.72ms | tokens processed: 897,024 | tok/sec: 49,083.66
# 438 | lr: 3.68e-04 | loss: 4.1562 | time: 43.25ms | tokens processed: 899,072 | tok/sec: 47,356.43
# 439 | lr: 3.69e-04 | loss: 4.0312 | time: 41.99ms | tokens processed: 901,120 | tok/sec: 48,768.21
# 440 | lr: 3.70e-04 | loss: 4.0938 | time: 42.99ms | tokens processed: 903,168 | tok/sec: 47,634.00
# 441 | lr: 3.71e-04 | loss: 3.9375 | time: 41.65ms | tokens processed: 905,216 | tok/sec: 49,177.51
# 442 | lr: 3.72e-04 | loss: 4.2812 | time: 43.32ms | tokens processed: 907,264 | tok/sec: 47,275.11
# 443 | lr: 3.73e-04 | loss: 4.1250 | time: 42.05ms | tokens processed: 909,312 | tok/sec: 48,700.74
# 444 | lr: 3.73e-04 | loss: 4.3438 | time: 40.83ms | tokens processed: 911,360 | tok/sec: 50,158.74
# 445 | lr: 3.74e-04 | loss: 3.9219 | time: 40.83ms | tokens processed: 913,408 | tok/sec: 50,162.55
# 446 | lr: 3.75e-04 | loss: 3.8594 | time: 40.81ms | tokens processed: 915,456 | tok/sec: 50,188.92
# 447 | lr: 3.76e-04 | loss: 3.9844 | time: 40.65ms | tokens processed: 917,504 | tok/sec: 50,386.46
# 448 | lr: 3.77e-04 | loss: 3.9219 | time: 40.73ms | tokens processed: 919,552 | tok/sec: 50,285.88
# 449 | lr: 3.78e-04 | loss: 3.9375 | time: 41.59ms | tokens processed: 921,600 | tok/sec: 49,246.87
# 450 | lr: 3.78e-04 | loss: 4.0312 | time: 42.10ms | tokens processed: 923,648 | tok/sec: 48,648.06
# 451 | lr: 3.79e-04 | loss: 3.7656 | time: 40.88ms | tokens processed: 925,696 | tok/sec: 50,098.77
# 452 | lr: 3.80e-04 | loss: 3.9531 | time: 38.72ms | tokens processed: 927,744 | tok/sec: 52,889.45
# 453 | lr: 3.81e-04 | loss: 3.7969 | time: 39.27ms | tokens processed: 929,792 | tok/sec: 52,148.07
# 454 | lr: 3.82e-04 | loss: 3.7812 | time: 42.95ms | tokens processed: 931,840 | tok/sec: 47,681.59
# 455 | lr: 3.83e-04 | loss: 3.6875 | time: 41.30ms | tokens processed: 933,888 | tok/sec: 49,582.58
# 456 | lr: 3.83e-04 | loss: 3.9531 | time: 40.84ms | tokens processed: 935,936 | tok/sec: 50,144.39
# 457 | lr: 3.84e-04 | loss: 4.0625 | time: 42.25ms | tokens processed: 937,984 | tok/sec: 48,472.37
# 458 | lr: 3.85e-04 | loss: 3.9219 | time: 538.62ms | tokens processed: 940,032 | tok/sec: 3,802.29
# 459 | lr: 3.86e-04 | loss: 3.9062 | time: 43.41ms | tokens processed: 942,080 | tok/sec: 47,173.86
# 460 | lr: 3.87e-04 | loss: 3.7500 | time: 40.56ms | tokens processed: 944,128 | tok/sec: 50,490.71
# 461 | lr: 3.88e-04 | loss: 3.8438 | time: 41.51ms | tokens processed: 946,176 | tok/sec: 49,335.68
# 462 | lr: 3.89e-04 | loss: 4.1562 | time: 42.18ms | tokens processed: 948,224 | tok/sec: 48,549.08
# 463 | lr: 3.89e-04 | loss: 3.7969 | time: 42.15ms | tokens processed: 950,272 | tok/sec: 48,582.85
# 464 | lr: 3.90e-04 | loss: 3.9062 | time: 39.80ms | tokens processed: 952,320 | tok/sec: 51,457.69
# 465 | lr: 3.91e-04 | loss: 3.6562 | time: 41.43ms | tokens processed: 954,368 | tok/sec: 49,430.22
# 466 | lr: 3.92e-04 | loss: 3.7188 | time: 41.29ms | tokens processed: 956,416 | tok/sec: 49,596.32
# 467 | lr: 3.93e-04 | loss: 3.9375 | time: 40.23ms | tokens processed: 958,464 | tok/sec: 50,906.03
# 468 | lr: 3.94e-04 | loss: 3.9375 | time: 40.42ms | tokens processed: 960,512 | tok/sec: 50,662.84
# 469 | lr: 3.94e-04 | loss: 3.8594 | time: 38.88ms | tokens processed: 962,560 | tok/sec: 52,677.66
# 470 | lr: 3.95e-04 | loss: 3.8438 | time: 40.37ms | tokens processed: 964,608 | tok/sec: 50,733.75
# 471 | lr: 3.96e-04 | loss: 3.7969 | time: 41.64ms | tokens processed: 966,656 | tok/sec: 49,189.06
# 472 | lr: 3.97e-04 | loss: 3.7656 | time: 38.63ms | tokens processed: 968,704 | tok/sec: 53,022.65
# 473 | lr: 3.98e-04 | loss: 3.7031 | time: 39.75ms | tokens processed: 970,752 | tok/sec: 51,526.21
# 474 | lr: 3.99e-04 | loss: 3.9375 | time: 43.41ms | tokens processed: 972,800 | tok/sec: 47,183.18
# 475 | lr: 3.99e-04 | loss: 3.8438 | time: 42.39ms | tokens processed: 974,848 | tok/sec: 48,313.43
# 476 | lr: 4.00e-04 | loss: 3.8594 | time: 40.32ms | tokens processed: 976,896 | tok/sec: 50,789.85
# 477 | lr: 4.01e-04 | loss: 3.8750 | time: 40.44ms | tokens processed: 978,944 | tok/sec: 50,642.23
# 478 | lr: 4.02e-04 | loss: 3.8438 | time: 43.72ms | tokens processed: 980,992 | tok/sec: 46,842.27
# 479 | lr: 4.03e-04 | loss: 4.2188 | time: 41.23ms | tokens processed: 983,040 | tok/sec: 49,671.18
# 480 | lr: 4.04e-04 | loss: 4.1250 | time: 40.18ms | tokens processed: 985,088 | tok/sec: 50,969.46
# 481 | lr: 4.04e-04 | loss: 3.8906 | time: 542.30ms | tokens processed: 987,136 | tok/sec: 3,776.50
# 482 | lr: 4.05e-04 | loss: 3.7812 | time: 42.42ms | tokens processed: 989,184 | tok/sec: 48,280.57
# 483 | lr: 4.06e-04 | loss: 3.6719 | time: 41.56ms | tokens processed: 991,232 | tok/sec: 49,277.66
# 484 | lr: 4.07e-04 | loss: 3.7031 | time: 43.88ms | tokens processed: 993,280 | tok/sec: 46,672.76
# 485 | lr: 4.08e-04 | loss: 4.0625 | time: 49.34ms | tokens processed: 995,328 | tok/sec: 41,505.29
# ...
# 3525 | lr: 6.00e-04 | loss: 0.2002 | time: 41.23ms | tokens processed: 7,221,248 | tok/sec: 49,669.45
# 3526 | lr: 6.00e-04 | loss: 0.2285 | time: 40.90ms | tokens processed: 7,223,296 | tok/sec: 50,071.02
# 3527 | lr: 6.00e-04 | loss: 0.2520 | time: 40.36ms | tokens processed: 7,225,344 | tok/sec: 50,748.44
# 3528 | lr: 6.00e-04 | loss: 0.2256 | time: 42.58ms | tokens processed: 7,227,392 | tok/sec: 48,098.09
# 3529 | lr: 6.00e-04 | loss: 0.2422 | time: 41.50ms | tokens processed: 7,229,440 | tok/sec: 49,350.42
# 3530 | lr: 6.00e-04 | loss: 0.2471 | time: 42.12ms | tokens processed: 7,231,488 | tok/sec: 48,619.15
# 3531 | lr: 6.00e-04 | loss: 0.2109 | time: 41.59ms | tokens processed: 7,233,536 | tok/sec: 49,236.99
# 3532 | lr: 6.00e-04 | loss: 0.2197 | time: 42.47ms | tokens processed: 7,235,584 | tok/sec: 48,224.46
# 3533 | lr: 6.00e-04 | loss: 0.2363 | time: 42.35ms | tokens processed: 7,237,632 | tok/sec: 48,363.48
# 3534 | lr: 6.00e-04 | loss: 0.2334 | time: 40.00ms | tokens processed: 7,239,680 | tok/sec: 51,194.56
# 3535 | lr: 6.00e-04 | loss: 0.2012 | time: 41.90ms | tokens processed: 7,241,728 | tok/sec: 48,877.82
# 3536 | lr: 6.00e-04 | loss: 0.2217 | time: 43.23ms | tokens processed: 7,243,776 | tok/sec: 47,371.57
# 3537 | lr: 6.00e-04 | loss: 0.2168 | time: 40.40ms | tokens processed: 7,245,824 | tok/sec: 50,687.95
# 3538 | lr: 6.00e-04 | loss: 0.2314 | time: 44.17ms | tokens processed: 7,247,872 | tok/sec: 46,363.66
# 3539 | lr: 6.00e-04 | loss: 0.2363 | time: 558.90ms | tokens processed: 7,249,920 | tok/sec: 3,664.34
# 3540 | lr: 6.00e-04 | loss: 0.2090 | time: 45.38ms | tokens processed: 7,251,968 | tok/sec: 45,128.00
# 3541 | lr: 6.00e-04 | loss: 0.2275 | time: 44.81ms | tokens processed: 7,254,016 | tok/sec: 45,699.89
# 3542 | lr: 6.00e-04 | loss: 0.2178 | time: 42.97ms | tokens processed: 7,256,064 | tok/sec: 47,662.81
# 3543 | lr: 6.00e-04 | loss: 0.2402 | time: 43.60ms | tokens processed: 7,258,112 | tok/sec: 46,972.65
# 3544 | lr: 6.00e-04 | loss: 0.2432 | time: 42.65ms | tokens processed: 7,260,160 | tok/sec: 48,019.31
# 3545 | lr: 6.00e-04 | loss: 0.2051 | time: 45.55ms | tokens processed: 7,262,208 | tok/sec: 44,965.48
# 3546 | lr: 6.00e-04 | loss: 0.2021 | time: 50.64ms | tokens processed: 7,264,256 | tok/sec: 40,443.78
# 3547 | lr: 6.00e-04 | loss: 0.2393 | time: 49.37ms | tokens processed: 7,266,304 | tok/sec: 41,479.84
# 3548 | lr: 6.00e-04 | loss: 0.1934 | time: 49.43ms | tokens processed: 7,268,352 | tok/sec: 41,430.42
# 3549 | lr: 6.00e-04 | loss: 0.2217 | time: 46.98ms | tokens processed: 7,270,400 | tok/sec: 43,593.77
# 3550 | lr: 6.00e-04 | loss: 0.2061 | time: 47.09ms | tokens processed: 7,272,448 | tok/sec: 43,487.83
# 3551 | lr: 6.00e-04 | loss: 0.1934 | time: 48.52ms | tokens processed: 7,274,496 | tok/sec: 42,210.57
# 3552 | lr: 6.00e-04 | loss: 0.2090 | time: 46.07ms | tokens processed: 7,276,544 | tok/sec: 44,456.07
# 3553 | lr: 6.00e-04 | loss: 0.1875 | time: 42.75ms | tokens processed: 7,278,592 | tok/sec: 47,903.89
# 3554 | lr: 6.00e-04 | loss: 0.2295 | time: 44.35ms | tokens processed: 7,280,640 | tok/sec: 46,181.20
# 3555 | lr: 6.00e-04 | loss: 0.2119 | time: 41.24ms | tokens processed: 7,282,688 | tok/sec: 49,657.11
# 3556 | lr: 6.00e-04 | loss: 0.2188 | time: 41.60ms | tokens processed: 7,284,736 | tok/sec: 49,225.14
# 3557 | lr: 6.00e-04 | loss: 0.2119 | time: 42.01ms | tokens processed: 7,286,784 | tok/sec: 48,744.96
# 3558 | lr: 6.00e-04 | loss: 0.1826 | time: 42.75ms | tokens processed: 7,288,832 | tok/sec: 47,905.50
# 3559 | lr: 6.00e-04 | loss: 0.2354 | time: 41.76ms | tokens processed: 7,290,880 | tok/sec: 49,039.66
# 3560 | lr: 6.00e-04 | loss: 0.1836 | time: 41.12ms | tokens processed: 7,292,928 | tok/sec: 49,811.45
# 3561 | lr: 6.00e-04 | loss: 0.2139 | time: 42.54ms | tokens processed: 7,294,976 | tok/sec: 48,139.87
# 3562 | lr: 6.00e-04 | loss: 0.2080 | time: 48.01ms | tokens processed: 7,297,024 | tok/sec: 42,657.89
# 3563 | lr: 6.00e-04 | loss: 0.2305 | time: 553.75ms | tokens processed: 7,299,072 | tok/sec: 3,698.44
# 3564 | lr: 6.00e-04 | loss: 0.2676 | time: 48.17ms | tokens processed: 7,301,120 | tok/sec: 42,517.90
# 3565 | lr: 6.00e-04 | loss: 0.2363 | time: 43.94ms | tokens processed: 7,303,168 | tok/sec: 46,612.48
# 3566 | lr: 6.00e-04 | loss: 0.1680 | time: 45.74ms | tokens processed: 7,305,216 | tok/sec: 44,775.62
# 3567 | lr: 6.00e-04 | loss: 0.2383 | time: 47.43ms | tokens processed: 7,307,264 | tok/sec: 43,177.43
# 3568 | lr: 6.00e-04 | loss: 0.2324 | time: 48.35ms | tokens processed: 7,309,312 | tok/sec: 42,358.56
# 3569 | lr: 6.00e-04 | loss: 0.2021 | time: 45.42ms | tokens processed: 7,311,360 | tok/sec: 45,091.99
# 3570 | lr: 6.00e-04 | loss: 0.2129 | time: 43.68ms | tokens processed: 7,313,408 | tok/sec: 46,888.03
# 3571 | lr: 6.00e-04 | loss: 0.2217 | time: 44.61ms | tokens processed: 7,315,456 | tok/sec: 45,906.27
# 3572 | lr: 6.00e-04 | loss: 0.2236 | time: 46.62ms | tokens processed: 7,317,504 | tok/sec: 43,928.85
# 3573 | lr: 6.00e-04 | loss: 0.1943 | time: 45.77ms | tokens processed: 7,319,552 | tok/sec: 44,746.47
# 3574 | lr: 6.00e-04 | loss: 0.1709 | time: 44.36ms | tokens processed: 7,321,600 | tok/sec: 46,171.27
# 3575 | lr: 6.00e-04 | loss: 0.1289 | time: 45.51ms | tokens processed: 7,323,648 | tok/sec: 44,999.40
# 3576 | lr: 6.00e-04 | loss: 0.1875 | time: 45.66ms | tokens processed: 7,325,696 | tok/sec: 44,858.16
# 3577 | lr: 6.00e-04 | loss: 0.2266 | time: 43.50ms | tokens processed: 7,327,744 | tok/sec: 47,085.68
# 3578 | lr: 6.00e-04 | loss: 0.2412 | time: 44.51ms | tokens processed: 7,329,792 | tok/sec: 46,014.22
# 3579 | lr: 6.00e-04 | loss: 0.2217 | time: 43.98ms | tokens processed: 7,331,840 | tok/sec: 46,570.78
# 3580 | lr: 6.00e-04 | loss: 0.2178 | time: 42.62ms | tokens processed: 7,333,888 | tok/sec: 48,048.32
# 3581 | lr: 6.00e-04 | loss: 0.2432 | time: 42.74ms | tokens processed: 7,335,936 | tok/sec: 47,923.14
# 3582 | lr: 6.00e-04 | loss: 0.2451 | time: 40.16ms | tokens processed: 7,337,984 | tok/sec: 50,989.73
# 3583 | lr: 6.00e-04 | loss: 0.2070 | time: 44.24ms | tokens processed: 7,340,032 | tok/sec: 46,289.96
# 3584 | lr: 6.00e-04 | loss: 0.2314 | time: 42.19ms | tokens processed: 7,342,080 | tok/sec: 48,546.34
# 3585 | lr: 6.00e-04 | loss: 0.2637 | time: 40.45ms | tokens processed: 7,344,128 | tok/sec: 50,625.51
# 3586 | lr: 6.00e-04 | loss: 0.2100 | time: 532.50ms | tokens processed: 7,346,176 | tok/sec: 3,846.04
# 3587 | lr: 6.00e-04 | loss: 0.2139 | time: 42.33ms | tokens processed: 7,348,224 | tok/sec: 48,376.28
# 3588 | lr: 6.00e-04 | loss: 0.2373 | time: 41.26ms | tokens processed: 7,350,272 | tok/sec: 49,631.57
# 3589 | lr: 6.00e-04 | loss: 0.2256 | time: 42.07ms | tokens processed: 7,352,320 | tok/sec: 48,680.60
# 3590 | lr: 6.00e-04 | loss: 0.1982 | time: 42.17ms | tokens processed: 7,354,368 | tok/sec: 48,571.04
# 3591 | lr: 6.00e-04 | loss: 0.2490 | time: 40.20ms | tokens processed: 7,356,416 | tok/sec: 50,943.77
# 3592 | lr: 6.00e-04 | loss: 0.2227 | time: 40.58ms | tokens processed: 7,358,464 | tok/sec: 50,463.72
# 3593 | lr: 6.00e-04 | loss: 0.2305 | time: 40.95ms | tokens processed: 7,360,512 | tok/sec: 50,014.47
# 3594 | lr: 6.00e-04 | loss: 0.2354 | time: 43.59ms | tokens processed: 7,362,560 | tok/sec: 46,988.32
# 3595 | lr: 6.00e-04 | loss: 0.2188 | time: 42.22ms | tokens processed: 7,364,608 | tok/sec: 48,510.15
# 3596 | lr: 6.00e-04 | loss: 0.2197 | time: 42.01ms | tokens processed: 7,366,656 | tok/sec: 48,746.07
# 3597 | lr: 6.00e-04 | loss: 0.1826 | time: 41.42ms | tokens processed: 7,368,704 | tok/sec: 49,447.01
# 3598 | lr: 6.00e-04 | loss: 0.1973 | time: 43.44ms | tokens processed: 7,370,752 | tok/sec: 47,148.22
# 3599 | lr: 6.00e-04 | loss: 0.2266 | time: 42.05ms | tokens processed: 7,372,800 | tok/sec: 48,702.12
# 3600 | lr: 6.00e-04 | loss: 0.2256 | time: 41.67ms | tokens processed: 7,374,848 | tok/sec: 49,144.88
# 3601 | lr: 6.00e-04 | loss: 0.2217 | time: 39.53ms | tokens processed: 7,376,896 | tok/sec: 51,808.39
# 3602 | lr: 6.00e-04 | loss: 0.2207 | time: 42.82ms | tokens processed: 7,378,944 | tok/sec: 47,831.34
# 3603 | lr: 6.00e-04 | loss: 0.2129 | time: 39.88ms | tokens processed: 7,380,992 | tok/sec: 51,359.23
# 3604 | lr: 6.00e-04 | loss: 0.2148 | time: 38.90ms | tokens processed: 7,383,040 | tok/sec: 52,651.18
# 3605 | lr: 6.00e-04 | loss: 0.2031 | time: 40.59ms | tokens processed: 7,385,088 | tok/sec: 50,456.31
# 3606 | lr: 6.00e-04 | loss: 0.2275 | time: 42.21ms | tokens processed: 7,387,136 | tok/sec: 48,517.27
# 3607 | lr: 6.00e-04 | loss: 0.2285 | time: 40.99ms | tokens processed: 7,389,184 | tok/sec: 49,965.01
# 3608 | lr: 6.00e-04 | loss: 0.2100 | time: 42.09ms | tokens processed: 7,391,232 | tok/sec: 48,661.84
# 3609 | lr: 6.00e-04 | loss: 0.2168 | time: 539.16ms | tokens processed: 7,393,280 | tok/sec: 3,798.49
# 3610 | lr: 6.00e-04 | loss: 0.2246 | time: 42.83ms | tokens processed: 7,395,328 | tok/sec: 47,818.29
# 3611 | lr: 6.00e-04 | loss: 0.2178 | time: 39.69ms | tokens processed: 7,397,376 | tok/sec: 51,606.08
# 3612 | lr: 6.00e-04 | loss: 0.2100 | time: 41.77ms | tokens processed: 7,399,424 | tok/sec: 49,034.90
# 3613 | lr: 6.00e-04 | loss: 0.2207 | time: 41.59ms | tokens processed: 7,401,472 | tok/sec: 49,238.12
# 3614 | lr: 6.00e-04 | loss: 0.2344 | time: 41.76ms | tokens processed: 7,403,520 | tok/sec: 49,043.02
# 3615 | lr: 6.00e-04 | loss: 0.2324 | time: 40.36ms | tokens processed: 7,405,568 | tok/sec: 50,739.75
# 3616 | lr: 6.00e-04 | loss: 0.2100 | time: 41.00ms | tokens processed: 7,407,616 | tok/sec: 49,949.03
# 3617 | lr: 6.00e-04 | loss: 0.1982 | time: 43.49ms | tokens processed: 7,409,664 | tok/sec: 47,086.97
# 3618 | lr: 6.00e-04 | loss: 0.2471 | time: 41.12ms | tokens processed: 7,411,712 | tok/sec: 49,800.19
# 3619 | lr: 6.00e-04 | loss: 0.2178 | time: 40.30ms | tokens processed: 7,413,760 | tok/sec: 50,816.89
# 3620 | lr: 6.00e-04 | loss: 0.2002 | time: 42.48ms | tokens processed: 7,415,808 | tok/sec: 48,214.45
# 3621 | lr: 6.00e-04 | loss: 0.2441 | time: 43.74ms | tokens processed: 7,417,856 | tok/sec: 46,820.82
# 3622 | lr: 6.00e-04 | loss: 0.2617 | time: 41.69ms | tokens processed: 7,419,904 | tok/sec: 49,118.74
# 3623 | lr: 6.00e-04 | loss: 0.2148 | time: 39.64ms | tokens processed: 7,421,952 | tok/sec: 51,662.56
# 3624 | lr: 6.00e-04 | loss: 0.2100 | time: 41.69ms | tokens processed: 7,424,000 | tok/sec: 49,126.33
# 3625 | lr: 6.00e-04 | loss: 0.2295 | time: 41.56ms | tokens processed: 7,426,048 | tok/sec: 49,274.55
# 3626 | lr: 6.00e-04 | loss: 0.2227 | time: 41.06ms | tokens processed: 7,428,096 | tok/sec: 49,881.16
# 3627 | lr: 6.00e-04 | loss: 0.2305 | time: 39.34ms | tokens processed: 7,430,144 | tok/sec: 52,055.16
# 3628 | lr: 6.00e-04 | loss: 0.2188 | time: 46.91ms | tokens processed: 7,432,192 | tok/sec: 43,654.47
# 3629 | lr: 6.00e-04 | loss: 0.2334 | time: 45.57ms | tokens processed: 7,434,240 | tok/sec: 44,945.71
# 3630 | lr: 6.00e-04 | loss: 0.2227 | time: 42.84ms | tokens processed: 7,436,288 | tok/sec: 47,801.26
# 3631 | lr: 6.00e-04 | loss: 0.2314 | time: 41.77ms | tokens processed: 7,438,336 | tok/sec: 49,029.31
# 3632 | lr: 6.00e-04 | loss: 0.2334 | time: 41.09ms | tokens processed: 7,440,384 | tok/sec: 49,837.46
# 3633 | lr: 6.00e-04 | loss: 0.2119 | time: 547.18ms | tokens processed: 7,442,432 | tok/sec: 3,742.82
# 3634 | lr: 6.00e-04 | loss: 0.2168 | time: 43.64ms | tokens processed: 7,444,480 | tok/sec: 46,925.69
# 3635 | lr: 6.00e-04 | loss: 0.2109 | time: 42.10ms | tokens processed: 7,446,528 | tok/sec: 48,640.63
# 3636 | lr: 6.00e-04 | loss: 0.2109 | time: 42.74ms | tokens processed: 7,448,576 | tok/sec: 47,923.14
# 3637 | lr: 6.00e-04 | loss: 0.2422 | time: 41.90ms | tokens processed: 7,450,624 | tok/sec: 48,877.26
# 3638 | lr: 6.00e-04 | loss: 0.2158 | time: 41.97ms | tokens processed: 7,452,672 | tok/sec: 48,796.47
# 3639 | lr: 6.00e-04 | loss: 0.2129 | time: 44.23ms | tokens processed: 7,454,720 | tok/sec: 46,305.68
# 3640 | lr: 6.00e-04 | loss: 0.2012 | time: 43.62ms | tokens processed: 7,456,768 | tok/sec: 46,949.80
# 3641 | lr: 6.00e-04 | loss: 0.2158 | time: 47.60ms | tokens processed: 7,458,816 | tok/sec: 43,023.46
# 3642 | lr: 6.00e-04 | loss: 0.2090 | time: 45.26ms | tokens processed: 7,460,864 | tok/sec: 45,248.52
# 3643 | lr: 6.00e-04 | loss: 0.2246 | time: 44.53ms | tokens processed: 7,462,912 | tok/sec: 45,989.58
# 3644 | lr: 6.00e-04 | loss: 0.2314 | time: 45.35ms | tokens processed: 7,464,960 | tok/sec: 45,157.89
# 3645 | lr: 6.00e-04 | loss: 0.1777 | time: 44.65ms | tokens processed: 7,467,008 | tok/sec: 45,867.29
# 3646 | lr: 6.00e-04 | loss: 0.1445 | time: 43.08ms | tokens processed: 7,469,056 | tok/sec: 47,534.36
# 3647 | lr: 6.00e-04 | loss: 0.1670 | time: 39.68ms | tokens processed: 7,471,104 | tok/sec: 51,614.14
# 3648 | lr: 6.00e-04 | loss: 0.1748 | time: 39.83ms | tokens processed: 7,473,152 | tok/sec: 51,416.72
# 3649 | lr: 6.00e-04 | loss: 0.2354 | time: 43.92ms | tokens processed: 7,475,200 | tok/sec: 46,631.71
# 3650 | lr: 6.00e-04 | loss: 0.2178 | time: 42.29ms | tokens processed: 7,477,248 | tok/sec: 48,430.83
# 3651 | lr: 6.00e-04 | loss: 0.1973 | time: 40.57ms | tokens processed: 7,479,296 | tok/sec: 50,477.96
# 3652 | lr: 6.00e-04 | loss: 0.1963 | time: 41.33ms | tokens processed: 7,481,344 | tok/sec: 49,556.55
# 3653 | lr: 6.00e-04 | loss: 0.2227 | time: 42.73ms | tokens processed: 7,483,392 | tok/sec: 47,924.21
# 3654 | lr: 6.00e-04 | loss: 0.2246 | time: 42.95ms | tokens processed: 7,485,440 | tok/sec: 47,678.68
# 3655 | lr: 6.00e-04 | loss: 0.2236 | time: 47.81ms | tokens processed: 7,487,488 | tok/sec: 42,837.23
# 3656 | lr: 6.00e-04 | loss: 0.2168 | time: 553.62ms | tokens processed: 7,489,536 | tok/sec: 3,699.31
# 3657 | lr: 6.00e-04 | loss: 0.2119 | time: 42.46ms | tokens processed: 7,491,584 | tok/sec: 48,235.03
# 3658 | lr: 6.00e-04 | loss: 0.2197 | time: 42.12ms | tokens processed: 7,493,632 | tok/sec: 48,622.18
# 3659 | lr: 6.00e-04 | loss: 0.2393 | time: 40.15ms | tokens processed: 7,495,680 | tok/sec: 51,006.08
# 3660 | lr: 6.00e-04 | loss: 0.2275 | time: 41.77ms | tokens processed: 7,497,728 | tok/sec: 49,032.67
# 3661 | lr: 6.00e-04 | loss: 0.2051 | time: 39.83ms | tokens processed: 7,499,776 | tok/sec: 51,414.57
# 3662 | lr: 6.00e-04 | loss: 0.2354 | time: 41.79ms | tokens processed: 7,501,824 | tok/sec: 49,009.17
# 3663 | lr: 6.00e-04 | loss: 0.2393 | time: 50.33ms | tokens processed: 7,503,872 | tok/sec: 40,691.11
# 3664 | lr: 6.00e-04 | loss: 0.1992 | time: 45.08ms | tokens processed: 7,505,920 | tok/sec: 45,430.16
# 3665 | lr: 6.00e-04 | loss: 0.2178 | time: 43.47ms | tokens processed: 7,507,968 | tok/sec: 47,115.38
# 3666 | lr: 6.00e-04 | loss: 0.2197 | time: 40.99ms | tokens processed: 7,510,016 | tok/sec: 49,968.50
# 3667 | lr: 6.00e-04 | loss: 0.2119 | time: 40.78ms | tokens processed: 7,512,064 | tok/sec: 50,225.02
# 3668 | lr: 6.00e-04 | loss: 0.2354 | time: 43.37ms | tokens processed: 7,514,112 | tok/sec: 47,224.69
# 3669 | lr: 6.00e-04 | loss: 0.2305 | time: 41.26ms | tokens processed: 7,516,160 | tok/sec: 49,641.90
# 3670 | lr: 6.00e-04 | loss: 0.2207 | time: 42.89ms | tokens processed: 7,518,208 | tok/sec: 47,753.16
# 3671 | lr: 6.00e-04 | loss: 0.2266 | time: 46.75ms | tokens processed: 7,520,256 | tok/sec: 43,803.18
# 3672 | lr: 6.00e-04 | loss: 0.2471 | time: 46.54ms | tokens processed: 7,522,304 | tok/sec: 44,006.04
# 3673 | lr: 6.00e-04 | loss: 0.2100 | time: 41.32ms | tokens processed: 7,524,352 | tok/sec: 49,563.99
# 3674 | lr: 6.00e-04 | loss: 0.2188 | time: 40.85ms | tokens processed: 7,526,400 | tok/sec: 50,138.54
# 3675 | lr: 6.00e-04 | loss: 0.2051 | time: 39.33ms | tokens processed: 7,528,448 | tok/sec: 52,067.78
# 3676 | lr: 6.00e-04 | loss: 0.2559 | time: 41.35ms | tokens processed: 7,530,496 | tok/sec: 49,530.26
# 3677 | lr: 6.00e-04 | loss: 0.2383 | time: 43.73ms | tokens processed: 7,532,544 | tok/sec: 46,836.14
# 3678 | lr: 6.00e-04 | loss: 0.2070 | time: 41.30ms | tokens processed: 7,534,592 | tok/sec: 49,584.01
# 3679 | lr: 6.00e-04 | loss: 0.2100 | time: 44.69ms | tokens processed: 7,536,640 | tok/sec: 45,825.94
# 3680 | lr: 6.00e-04 | loss: 0.2129 | time: 560.73ms | tokens processed: 7,538,688 | tok/sec: 3,652.35
# Received KeyboardInterrupt. Exiting...

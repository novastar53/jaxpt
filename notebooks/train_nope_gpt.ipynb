# %% [markdown]
# # NoPE GPT Experiment
#
# This experiment trains a GPT model without any positional embeddings. According to Kazemnejad et al. (2024), this should still work due to the causal attention map inducing positional information.

# %% [markdown]
# ### Configure the machine and install packages

# %%
from typing import Literal
import sys

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# Cloning into 'jaxpt'...
# remote: Enumerating objects: 577, done.
# remote: Counting objects: 100% (280/280), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 577 (delta 184), reused 160 (delta 109), pack-reused 297 (from 1)
# Receiving objects: 100% (577/577), 9.63 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (334/334), done.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.4 MB/s eta 0:00:00
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import jax.numpy as jnp
import numpy as np

os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
    '--xla_gpu_enable_latency_hiding_scheduler=true '
)

os.environ.update({
  "NCCL_LL128_BUFFSIZE": "-2",
  "NCCL_LL_BUFFSIZE": "-2",
  "NCCL_PROTO": "SIMPLE,LL,LL128",
 })


# Hardware setup
print("JAX version:", jax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

REQUESTED_DEVICE = "cpu"

jax.config.update("jax_platform_name", REQUESTED_DEVICE) # Make sure we're using the GPU

device = jax.default_backend()
if device != REQUESTED_DEVICE:
    warnings.warn(f"not using {REQUESTED_DEVICE}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Available devices: 1
# <ipython-input-3-2766cfccb0da>:32: UserWarning: not using cpu. Using gpu
#   warnings.warn(f"not using {REQUESTED_DEVICE}. Using {device}")
# 962 µs ± 27.2 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize the NoPE GPT model and perform a sanity check

# %%
from functools import partial

import tiktoken
from flax import nnx

from jaxpt.infer import generate
from jaxpt.models import NoPE_GPT, NoPE_GPTConfig

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = NoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50304, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)
m = NoPE_GPT(config, rngs)
#m = load_checkpoint("run_20250311_uqdwjq", 5600)
graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
nnx.display(state)

def generate_completions(prefix="Hello, I'm a language model,"):
  m.eval()
  num_completions = 5
  max_length = 20
  generate_completion = partial(generate, m, max_length=max_length)
  enc = tiktoken.get_encoding('gpt2')
  tokens = enc.encode(prefix)
  tokens = jnp.array(tokens, dtype=jnp.int32)
  tokens = jnp.expand_dims(tokens, axis=0)
  x = jnp.tile(tokens, (num_completions, 1))


  x = generate_completion(x=x) # Make sure you can do a forward pass
  output = []
  for i in range(num_completions):
      tokens = x[i, :max_length].tolist()
      decoded = enc.decode(tokens)
      output.append(decoded)
  return output

#completions = generate_completions()
#for completion in completions:
#print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_471bf8ca3f284185a640b3ed211a967f" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_471bf8ca3f284185a640b3ed211a967f")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_471bf8ca3f284185a640b3ed211a967f")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_0c8f38a07a2c4be3b43a2f52ece78f06" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0c8f38a07a2c4be3b43a2f52ece78f06")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0c8f38a07a2c4be3b43a2f52ece78f06")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0c8f38a07a2c4be3b43a2f52ece78f06")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %% [markdown]
# ### Configure Training Run

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()
run_dir = f"run_{timestamp}_{random_code}"
print(run_dir)

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

checkpoint_dir =   output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, step):
  checkpoint_path = checkpoint_dir / run_dir / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dir, step):
  checkpoint_path = checkpoint_dir / run_dir / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# run_20250425_xoucan
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %%
import dataclasses

import optax


############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**12 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 4
  T: int = 1024
  max_steps: int = 19073 # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 20
  eval_interval: int = 250
  checkpoint_interval: int = 250
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T * num_devices) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()
'''
trconf = TrainerConfig(
  num_tokens_per_batch=2**14,
  mB=16,
  T=1024,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)
'''
trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

# Generate a weight decay mask
# First split the model into params and variables
graphdef, params, variables = nnx.split(m, nnx.Param, nnx.Variable)
# Then create a mask for the weight decay params
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)


tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
optimizer = nnx.Optimizer(m, tx)

# count the number of weight decay params
def f(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(f, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)


print(f"weight decay param count: {weight_decay_param_count:,}")
print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# weight decay param count: 123,568,128
# tokens/batch: 4,096
# block size: 1024
# sub-batch size: 4
# no. gradient accumulation steps: 1
# effective batch size per device:  4
# effective batch size: 4
# max steps: 19073

# %% [markdown]
# ### DataLoader and Validation Setup

# %%
from jaxpt.dataloaders import DataLoader
from jaxpt.train import loss_fn

dataset = "panchatantra-ryder"

if platform == "colab":
    dataset_path = Path().absolute() / "jaxpt" / "datasets" / dataset / "processed"
else:
    if dataset == "fineweb-edu":
      dataset_path = "/home/ubuntu/gpt2-train/fineweb-edu/processed"
    elif dataset == "panchatantra-ryder":
      dataset_path = Path().absolute().parent /  "datasets" / dataset / "processed"
    else:
      raise ValueError(f"Dataset {dataset} not found")

train_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=num_devices, label="train")
eval_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=1, label="valid", quiet=True)

def validate(m):
  valid_loss = 0.0
  eval_steps = 10
  for i in range(eval_steps):
    batch, targets = eval_dl()
    batch = np.squeeze(batch)
    targets = np.squeeze(targets)
    loss = loss_fn(m, batch, targets)
    valid_loss += loss
  valid_loss /= eval_steps
  return valid_loss

def evaluate(m):
  m.eval()
  completions = generate_completions()
  val_loss = validate(m)
  m.train()
  return val_loss, completions
# Out:
# dataloader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     4
# block size:     1024
# device rank:    1
# ------------------------

# %% [markdown]
# ### Let's train the model

# %%
# %matplotlib inline

import time
import logging
import warnings

import matplotlib.pyplot as plt

from jaxpt.utils import append_to_csv
from jaxpt.train import parallel_train_step


train_losses = []
val_losses = []
append_to_csv(log_dir / f"{run_dir}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{run_dir}_valid.csv", ["step", "loss"])

m.train()
try:
  for step in range(trconf.max_steps):
    start = time.time()
    batch, target = train_dl()
    avg_loss, avg_grads = parallel_train_step(m, optimizer, batch, target)
    avg_loss.block_until_ready()
    # compute stats
    avg_loss = jnp.float32(avg_loss[0])
    lr = warmup_with_cosine_decay_schedule(step)
    norm = 0 # norm[0]|
    iter_time = time.time() - start
    sub_step_time = iter_time / trconf.grad_accumulation_steps
    tokens_per_sec = num_devices * trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
    tokens_processed = (step+1) * num_devices * trconf.grad_accumulation_steps * trconf.mB * trconf.T

    if step % trconf.print_interval == 0:
      train_losses.append((step, avg_loss))
      append_to_csv(log_dir / f"{run_dir}_train.csv", [step, lr, avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | loss: {avg_loss:0.4f} | "
            f"norm: {norm:0.2f} | time: {iter_time*1000:0.2f}ms | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      valid_loss, completions = evaluate(m)
      valid_loss = jnp.float32(valid_loss)
      val_losses.append((step, valid_loss))
      append_to_csv(log_dir / f"{run_dir}_valid.csv", [step, valid_loss])
      print(f"valid loss: {valid_loss:0.4f}"  )
      for completion in completions:
        print(completion)
    #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
      #save_checkpoint(m, step)


except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

valid_loss, completions = evaluate(m)
valid_loss = jnp.float32(valid_loss)
print(f"valid loss: {valid_loss:0.4f}")
print(f"completions: {completions}")
for completion in completions:
  print(completion)
plt.figure(figsize=(10, 5))
plt.plot([x[0] for x in train_losses], [x[1] for x in train_losses], label="train loss")
plt.plot([x[0] for x in val_losses], [x[1] for x in val_losses], label="valid loss")
plt.legend()
plt.savefig(log_dir / f"{run_dir}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# 0 | lr: 8.39e-07 | loss: 10.9375 | norm: 0.00 | time: 41499.78ms | tokens processed: 4,096 | tok/sec: 98.70
# valid loss: 10.8750
# Hello, I'm a language model,AmericaCOLOR Queenslandlanders misunder Oro Summers November powerhouse Labor Directorsitably
# Hello, I'm a language model, 570Implboxes blatantwidth ginger CCPclassicmaxensor illicit Dolphin
# Hello, I'm a language model, collaborarinuturearist Admin Cance Fal leasing shelvesCOLOR Labor increment
# Hello, I'm a language model, Residents ton totalitarian293 rectangleSouth inaccurate Rebell individually distinctive clinginglikely
# Hello, I'm a language model, correlationelist Enchant beans priority █ Brands Dyn bombingotti heir._
# 20 | lr: 1.76e-05 | loss: 8.1250 | norm: 0.00 | time: 60.14ms | tokens processed: 86,016 | tok/sec: 68,103.82
# 40 | lr: 3.44e-05 | loss: 7.8125 | norm: 0.00 | time: 58.15ms | tokens processed: 167,936 | tok/sec: 70,441.92
# 60 | lr: 5.12e-05 | loss: 7.1875 | norm: 0.00 | time: 57.90ms | tokens processed: 249,856 | tok/sec: 70,737.77
# 80 | lr: 6.80e-05 | loss: 6.6250 | norm: 0.00 | time: 56.95ms | tokens processed: 331,776 | tok/sec: 71,925.03
# 100 | lr: 8.48e-05 | loss: 5.8750 | norm: 0.00 | time: 58.89ms | tokens processed: 413,696 | tok/sec: 69,554.41
# 120 | lr: 1.02e-04 | loss: 5.3125 | norm: 0.00 | time: 56.07ms | tokens processed: 495,616 | tok/sec: 73,046.15
# 140 | lr: 1.18e-04 | loss: 4.6875 | norm: 0.00 | time: 55.58ms | tokens processed: 577,536 | tok/sec: 73,689.38
# 160 | lr: 1.35e-04 | loss: 4.8125 | norm: 0.00 | time: 57.37ms | tokens processed: 659,456 | tok/sec: 71,397.45
# 180 | lr: 1.52e-04 | loss: 4.6562 | norm: 0.00 | time: 58.66ms | tokens processed: 741,376 | tok/sec: 69,829.20
# 200 | lr: 1.69e-04 | loss: 4.4688 | norm: 0.00 | time: 56.47ms | tokens processed: 823,296 | tok/sec: 72,536.65
# 220 | lr: 1.85e-04 | loss: 4.5312 | norm: 0.00 | time: 55.89ms | tokens processed: 905,216 | tok/sec: 73,281.39
# 240 | lr: 2.02e-04 | loss: 4.5312 | norm: 0.00 | time: 55.10ms | tokens processed: 987,136 | tok/sec: 74,334.08
# valid loss: 5.0938
# Hello, I'm a language model, if if by their house — for they and said the great
# Hello, I'm a language model, her he for of heaven with our house of it! All
# Hello, I'm a language model, then her Nor? They her the money, for what
# Hello, I'm a language model, when he returned his own in of in what is is to
# Hello, I'm a language model, you is sense: if master as what me a part
# 260 | lr: 2.19e-04 | loss: 4.2500 | norm: 0.00 | time: 53.73ms | tokens processed: 1,069,056 | tok/sec: 76,235.37
# 280 | lr: 2.36e-04 | loss: 4.0625 | norm: 0.00 | time: 56.29ms | tokens processed: 1,150,976 | tok/sec: 72,767.07
# 300 | lr: 2.53e-04 | loss: 4.1562 | norm: 0.00 | time: 55.80ms | tokens processed: 1,232,896 | tok/sec: 73,404.44
# 320 | lr: 2.69e-04 | loss: 3.8906 | norm: 0.00 | time: 53.83ms | tokens processed: 1,314,816 | tok/sec: 76,092.54
# 340 | lr: 2.86e-04 | loss: 3.9375 | norm: 0.00 | time: 56.91ms | tokens processed: 1,396,736 | tok/sec: 71,978.37
# 360 | lr: 3.03e-04 | loss: 3.9219 | norm: 0.00 | time: 56.58ms | tokens processed: 1,478,656 | tok/sec: 72,396.95
# 380 | lr: 3.20e-04 | loss: 3.9219 | norm: 0.00 | time: 55.07ms | tokens processed: 1,560,576 | tok/sec: 74,383.64
# 400 | lr: 3.37e-04 | loss: 3.9531 | norm: 0.00 | time: 58.16ms | tokens processed: 1,642,496 | tok/sec: 70,428.64
# 420 | lr: 3.53e-04 | loss: 3.8438 | norm: 0.00 | time: 55.02ms | tokens processed: 1,724,416 | tok/sec: 74,442.63
# 440 | lr: 3.70e-04 | loss: 3.6250 | norm: 0.00 | time: 55.52ms | tokens processed: 1,806,336 | tok/sec: 73,769.44
# 460 | lr: 3.87e-04 | loss: 3.7031 | norm: 0.00 | time: 371.88ms | tokens processed: 1,888,256 | tok/sec: 11,014.43
# 480 | lr: 4.04e-04 | loss: 3.5781 | norm: 0.00 | time: 56.92ms | tokens processed: 1,970,176 | tok/sec: 71,955.76
# 500 | lr: 4.20e-04 | loss: 3.3594 | norm: 0.00 | time: 54.61ms | tokens processed: 2,052,096 | tok/sec: 75,010.45
# valid loss: 5.2188
# Hello, I'm a language model, a pond one: The well, so here and I feel
# Hello, I'm a language model,; I want that two  to another the king be enough
# Hello, I'm a language model, that one. and I had the snake put  for give
# Hello, I'm a language model,, my to a snake reflected there how!", still in
# Hello, I'm a language model, it must were; it. to trust friends his heart that
# 520 | lr: 4.37e-04 | loss: 3.4844 | norm: 0.00 | time: 55.60ms | tokens processed: 2,134,016 | tok/sec: 73,666.63
# 540 | lr: 4.54e-04 | loss: 3.4062 | norm: 0.00 | time: 55.88ms | tokens processed: 2,215,936 | tok/sec: 73,303.90
# 560 | lr: 4.71e-04 | loss: 3.4844 | norm: 0.00 | time: 57.75ms | tokens processed: 2,297,856 | tok/sec: 70,924.08
# 580 | lr: 4.88e-04 | loss: 3.4844 | norm: 0.00 | time: 59.45ms | tokens processed: 2,379,776 | tok/sec: 68,900.55
# 600 | lr: 5.04e-04 | loss: 3.2656 | norm: 0.00 | time: 55.48ms | tokens processed: 2,461,696 | tok/sec: 73,834.75
# 620 | lr: 5.21e-04 | loss: 3.0938 | norm: 0.00 | time: 56.71ms | tokens processed: 2,543,616 | tok/sec: 72,228.03
# 640 | lr: 5.38e-04 | loss: 3.0312 | norm: 0.00 | time: 56.85ms | tokens processed: 2,625,536 | tok/sec: 72,054.14
# 660 | lr: 5.55e-04 | loss: 3.0625 | norm: 0.00 | time: 56.98ms | tokens processed: 2,707,456 | tok/sec: 71,881.70
# 680 | lr: 5.71e-04 | loss: 3.1562 | norm: 0.00 | time: 55.81ms | tokens processed: 2,789,376 | tok/sec: 73,392.84
# 700 | lr: 5.88e-04 | loss: 2.9844 | norm: 0.00 | time: 57.43ms | tokens processed: 2,871,296 | tok/sec: 71,322.17
# 720 | lr: 6.00e-04 | loss: 3.0625 | norm: 0.00 | time: 56.49ms | tokens processed: 2,953,216 | tok/sec: 72,511.54
# 740 | lr: 6.00e-04 | loss: 2.8438 | norm: 0.00 | time: 58.20ms | tokens processed: 3,035,136 | tok/sec: 70,376.13
# valid loss: 5.4688
# Hello, I'm a language model, poison said sure. death all the as ever-king make
# Hello, I'm a language model, lion be so how. Theodore at sight holy we well the
# Hello, I'm a language model, a mere woman like her two,". you?" With must
# Hello, I'm a language model, woman-d love  the f do be no of all
# Hello, I'm a language model, frogs case fellow." all's doing crocod other rose a kind
# 760 | lr: 6.00e-04 | loss: 2.8281 | norm: 0.00 | time: 58.47ms | tokens processed: 3,117,056 | tok/sec: 70,055.86
# 780 | lr: 6.00e-04 | loss: 2.7188 | norm: 0.00 | time: 60.10ms | tokens processed: 3,198,976 | tok/sec: 68,155.96
# 800 | lr: 6.00e-04 | loss: 2.5781 | norm: 0.00 | time: 56.56ms | tokens processed: 3,280,896 | tok/sec: 72,421.98
# 820 | lr: 6.00e-04 | loss: 2.1875 | norm: 0.00 | time: 56.23ms | tokens processed: 3,362,816 | tok/sec: 72,841.74
# 840 | lr: 6.00e-04 | loss: 2.6250 | norm: 0.00 | time: 56.64ms | tokens processed: 3,444,736 | tok/sec: 72,312.24
# 860 | lr: 6.00e-04 | loss: 2.5000 | norm: 0.00 | time: 56.66ms | tokens processed: 3,526,656 | tok/sec: 72,291.55
# 880 | lr: 6.00e-04 | loss: 2.5000 | norm: 0.00 | time: 57.06ms | tokens processed: 3,608,576 | tok/sec: 71,789.18
# 900 | lr: 6.00e-04 | loss: 2.4688 | norm: 0.00 | time: 58.26ms | tokens processed: 3,690,496 | tok/sec: 70,302.12
# 920 | lr: 6.00e-04 | loss: 2.5000 | norm: 0.00 | time: 57.28ms | tokens processed: 3,772,416 | tok/sec: 71,504.43
# 940 | lr: 6.00e-04 | loss: 2.3906 | norm: 0.00 | time: 58.88ms | tokens processed: 3,854,336 | tok/sec: 69,567.65
# 960 | lr: 6.00e-04 | loss: 2.2812 | norm: 0.00 | time: 56.86ms | tokens processed: 3,936,256 | tok/sec: 72,041.15
# 980 | lr: 6.00e-04 | loss: 2.1250 | norm: 0.00 | time: 55.88ms | tokens processed: 4,018,176 | tok/sec: 73,299.52
# 1000 | lr: 6.00e-04 | loss: 1.5156 | norm: 0.00 | time: 56.73ms | tokens processed: 4,100,096 | tok/sec: 72,207.99
# valid loss: 5.9375
# Hello, I'm a language model, a £ yet has departedation. She said to this jun
# Hello, I'm a language model, like like was pelight toil grew a frog then told
# Hello, I'm a language model, the Brahmans weather — well the restor will live does
# Hello, I'm a language model, I have purpose there all went died today him. Or was
# Hello, I'm a language model, then then on himile ateing you make fate must bring
# 1020 | lr: 6.00e-04 | loss: 2.1250 | norm: 0.00 | time: 367.19ms | tokens processed: 4,182,016 | tok/sec: 11,154.85
# 1040 | lr: 6.00e-04 | loss: 2.0312 | norm: 0.00 | time: 56.86ms | tokens processed: 4,263,936 | tok/sec: 72,030.58
# 1060 | lr: 6.00e-04 | loss: 2.0000 | norm: 0.00 | time: 58.22ms | tokens processed: 4,345,856 | tok/sec: 70,353.08
# 1080 | lr: 5.99e-04 | loss: 1.8828 | norm: 0.00 | time: 56.44ms | tokens processed: 4,427,776 | tok/sec: 72,572.80
# 1100 | lr: 5.99e-04 | loss: 1.8984 | norm: 0.00 | time: 55.82ms | tokens processed: 4,509,696 | tok/sec: 73,380.93
# 1120 | lr: 5.99e-04 | loss: 1.7266 | norm: 0.00 | time: 56.59ms | tokens processed: 4,591,616 | tok/sec: 72,376.82
# 1140 | lr: 5.99e-04 | loss: 1.7031 | norm: 0.00 | time: 55.97ms | tokens processed: 4,673,536 | tok/sec: 73,176.20
# 1160 | lr: 5.99e-04 | loss: 1.7656 | norm: 0.00 | time: 56.38ms | tokens processed: 4,755,456 | tok/sec: 72,644.30
# 1180 | lr: 5.99e-04 | loss: 1.6797 | norm: 0.00 | time: 55.92ms | tokens processed: 4,837,376 | tok/sec: 73,242.34
# 1200 | lr: 5.99e-04 | loss: 1.6953 | norm: 0.00 | time: 60.38ms | tokens processed: 4,919,296 | tok/sec: 67,833.30
# 1220 | lr: 5.99e-04 | loss: 1.6094 | norm: 0.00 | time: 57.96ms | tokens processed: 5,001,216 | tok/sec: 70,665.03
# 1240 | lr: 5.99e-04 | loss: 1.5078 | norm: 0.00 | time: 59.23ms | tokens processed: 5,083,136 | tok/sec: 69,149.59
# valid loss: 6.0938
# Hello, I'm a language model, love long milk is generous and give come when he has our
# Hello, I'm a language model, being. Even I has something are you a tank Live act
# Hello, I'm a language model, if night without the king is an unwar-p wrong
# Hello, I'm a language model, saying hold hear one of summer. All kindly  comfort with
# Hello, I'm a language model, for my ability with frogs, yourascal packing or water cool
# 1260 | lr: 5.99e-04 | loss: 1.5078 | norm: 0.00 | time: 56.32ms | tokens processed: 5,165,056 | tok/sec: 72,720.87
# 1280 | lr: 5.99e-04 | loss: 1.4219 | norm: 0.00 | time: 369.60ms | tokens processed: 5,246,976 | tok/sec: 11,082.22
# 1300 | lr: 5.99e-04 | loss: 1.3438 | norm: 0.00 | time: 56.26ms | tokens processed: 5,328,896 | tok/sec: 72,806.85
# 1320 | lr: 5.99e-04 | loss: 1.2656 | norm: 0.00 | time: 57.36ms | tokens processed: 5,410,816 | tok/sec: 71,408.73
# 1340 | lr: 5.98e-04 | loss: 1.2969 | norm: 0.00 | time: 59.38ms | tokens processed: 5,492,736 | tok/sec: 68,977.73
# 1360 | lr: 5.98e-04 | loss: 1.2891 | norm: 0.00 | time: 385.66ms | tokens processed: 5,574,656 | tok/sec: 10,620.68
# 1380 | lr: 5.98e-04 | loss: 1.2812 | norm: 0.00 | time: 56.39ms | tokens processed: 5,656,576 | tok/sec: 72,635.09
# 1400 | lr: 5.98e-04 | loss: 1.2578 | norm: 0.00 | time: 55.87ms | tokens processed: 5,738,496 | tok/sec: 73,308.91
# 1420 | lr: 5.98e-04 | loss: 1.1719 | norm: 0.00 | time: 58.51ms | tokens processed: 5,820,416 | tok/sec: 70,002.48
# 1440 | lr: 5.98e-04 | loss: 1.1875 | norm: 0.00 | time: 56.44ms | tokens processed: 5,902,336 | tok/sec: 72,566.98
# 1460 | lr: 5.98e-04 | loss: 1.1172 | norm: 0.00 | time: 56.75ms | tokens processed: 5,984,256 | tok/sec: 72,172.80
# 1480 | lr: 5.98e-04 | loss: 1.0312 | norm: 0.00 | time: 57.84ms | tokens processed: 6,066,176 | tok/sec: 70,815.04
# 1500 | lr: 5.98e-04 | loss: 0.9883 | norm: 0.00 | time: 57.46ms | tokens processed: 6,148,096 | tok/sec: 71,281.92
# valid loss: 6.5000
# Hello, I'm a language model, is lucky not my service be killed know display: ( utter
# Hello, I'm a language model, saying. To keep meat." Finally his way when be from
# Hello, I'm a language model, just — — such fruits like men hold does not shore my
# Hello, I'm a language model, was that our nat." meat there apprising turned reached into
# Hello, I'm a language model, the sight: that his be poor I left into this
# 1520 | lr: 5.97e-04 | loss: 1.0391 | norm: 0.00 | time: 56.74ms | tokens processed: 6,230,016 | tok/sec: 72,186.75
# 1540 | lr: 5.97e-04 | loss: 0.9844 | norm: 0.00 | time: 366.58ms | tokens processed: 6,311,936 | tok/sec: 11,173.60
# 1560 | lr: 5.97e-04 | loss: 1.0391 | norm: 0.00 | time: 57.67ms | tokens processed: 6,393,856 | tok/sec: 71,020.25
# 1580 | lr: 5.97e-04 | loss: 0.9961 | norm: 0.00 | time: 56.06ms | tokens processed: 6,475,776 | tok/sec: 73,062.30
# 1600 | lr: 5.97e-04 | loss: 1.0156 | norm: 0.00 | time: 367.88ms | tokens processed: 6,557,696 | tok/sec: 11,134.09
# 1620 | lr: 5.97e-04 | loss: 0.9570 | norm: 0.00 | time: 57.66ms | tokens processed: 6,639,616 | tok/sec: 71,031.41
# 1640 | lr: 5.97e-04 | loss: 0.8750 | norm: 0.00 | time: 56.24ms | tokens processed: 6,721,536 | tok/sec: 72,830.62
# 1660 | lr: 5.96e-04 | loss: 0.8672 | norm: 0.00 | time: 58.51ms | tokens processed: 6,803,456 | tok/sec: 70,006.19
# 1680 | lr: 5.96e-04 | loss: 0.6094 | norm: 0.00 | time: 341.14ms | tokens processed: 6,885,376 | tok/sec: 12,006.69
# 1700 | lr: 5.96e-04 | loss: 0.8750 | norm: 0.00 | time: 338.02ms | tokens processed: 6,967,296 | tok/sec: 12,117.72
# 1720 | lr: 5.96e-04 | loss: 0.8008 | norm: 0.00 | time: 58.06ms | tokens processed: 7,049,216 | tok/sec: 70,551.56
# 1740 | lr: 5.96e-04 | loss: 0.7734 | norm: 0.00 | time: 59.19ms | tokens processed: 7,131,136 | tok/sec: 69,196.38
# valid loss: 6.7500
# Hello, I'm a language model, it foot: But full may stay people so. And later
# Hello, I'm a language model, holding night kings does the is cruel! Ah death nothing
# Hello, I'm a language model, its mistake. Bequnumerous authoritativeate, freest
# Hello, I'm a language model, who, there only with cold seek daily quivered de come
# Hello, I'm a language model, a cage his feet a cave still re truth also." As
# 1760 | lr: 5.96e-04 | loss: 0.7852 | norm: 0.00 | time: 57.52ms | tokens processed: 7,213,056 | tok/sec: 71,205.99
# 1780 | lr: 5.96e-04 | loss: 0.7578 | norm: 0.00 | time: 56.26ms | tokens processed: 7,294,976 | tok/sec: 72,809.63
# 1800 | lr: 5.95e-04 | loss: 0.7500 | norm: 0.00 | time: 56.12ms | tokens processed: 7,376,896 | tok/sec: 72,980.36
# 1820 | lr: 5.95e-04 | loss: 0.7969 | norm: 0.00 | time: 55.95ms | tokens processed: 7,458,816 | tok/sec: 73,204.57
# 1840 | lr: 5.95e-04 | loss: 0.6836 | norm: 0.00 | time: 56.21ms | tokens processed: 7,540,736 | tok/sec: 72,876.03
# 1860 | lr: 5.95e-04 | loss: 0.4746 | norm: 0.00 | time: 55.32ms | tokens processed: 7,622,656 | tok/sec: 74,039.67
# 1880 | lr: 5.95e-04 | loss: 0.6992 | norm: 0.00 | time: 57.00ms | tokens processed: 7,704,576 | tok/sec: 71,864.26
# 1900 | lr: 5.94e-04 | loss: 0.6562 | norm: 0.00 | time: 59.49ms | tokens processed: 7,786,496 | tok/sec: 68,846.15
# 1920 | lr: 5.94e-04 | loss: 0.6250 | norm: 0.00 | time: 58.37ms | tokens processed: 7,868,416 | tok/sec: 70,171.18
# 1940 | lr: 5.94e-04 | loss: 0.5742 | norm: 0.00 | time: 377.18ms | tokens processed: 7,950,336 | tok/sec: 10,859.58
# 1960 | lr: 5.94e-04 | loss: 0.5703 | norm: 0.00 | time: 56.35ms | tokens processed: 8,032,256 | tok/sec: 72,694.71
# 1980 | lr: 5.94e-04 | loss: 0.6094 | norm: 0.00 | time: 58.17ms | tokens processed: 8,114,176 | tok/sec: 70,409.01
# 2000 | lr: 5.93e-04 | loss: 0.5703 | norm: 0.00 | time: 56.60ms | tokens processed: 8,196,096 | tok/sec: 72,366.76
# valid loss: 7.1562
# Hello, I'm a language model, he did too-jack touch  and, whose whose intelligence
# Hello, I'm a language model, peace ? At I ass was swception for everyied did
# Hello, I'm a language model, mounted'sL delighted , dhified sight of age also
# Hello, I'm a language model, approaching. Where? You two villains between (2 toward conc
# Hello, I'm a language model, bowed cut their report and to hemakingshot of
# 2020 | lr: 5.93e-04 | loss: 0.5703 | norm: 0.00 | time: 56.83ms | tokens processed: 8,278,016 | tok/sec: 72,072.58
# 2040 | lr: 5.93e-04 | loss: 0.5898 | norm: 0.00 | time: 59.60ms | tokens processed: 8,359,936 | tok/sec: 68,726.62
# 2060 | lr: 5.93e-04 | loss: 0.5586 | norm: 0.00 | time: 57.12ms | tokens processed: 8,441,856 | tok/sec: 71,708.58
# 2080 | lr: 5.93e-04 | loss: 0.5273 | norm: 0.00 | time: 56.57ms | tokens processed: 8,523,776 | tok/sec: 72,403.36
# 2100 | lr: 5.92e-04 | loss: 0.4746 | norm: 0.00 | time: 58.46ms | tokens processed: 8,605,696 | tok/sec: 70,065.58
# 2120 | lr: 5.92e-04 | loss: 0.5391 | norm: 0.00 | time: 56.02ms | tokens processed: 8,687,616 | tok/sec: 73,111.12
# 2140 | lr: 5.92e-04 | loss: 0.4551 | norm: 0.00 | time: 56.72ms | tokens processed: 8,769,536 | tok/sec: 72,214.97
# 2160 | lr: 5.92e-04 | loss: 0.4902 | norm: 0.00 | time: 57.34ms | tokens processed: 8,851,456 | tok/sec: 71,434.26
# 2180 | lr: 5.92e-04 | loss: 0.4648 | norm: 0.00 | time: 58.00ms | tokens processed: 8,933,376 | tok/sec: 70,618.84
# 2200 | lr: 5.91e-04 | loss: 0.4102 | norm: 0.00 | time: 58.24ms | tokens processed: 9,015,296 | tok/sec: 70,332.63
# 2220 | lr: 5.91e-04 | loss: 0.4551 | norm: 0.00 | time: 58.52ms | tokens processed: 9,097,216 | tok/sec: 69,991.93
# 2240 | lr: 5.91e-04 | loss: 0.3867 | norm: 0.00 | time: 57.38ms | tokens processed: 9,179,136 | tok/sec: 71,388.55
# valid loss: 7.3125
# Hello, I'm a language model, yet an agreement old husband." And again since ?" So
# Hello, I'm a language model, his other head what," which will come, thus received holiday
# Hello, I'm a language model, with me." asked him out," replied Crop will agreement
# Hello, I'm a language model, just when Victor had served united other shore light in leaving at
# Hello, I'm a language model,-er." This flanks until L besile at leaving
# 2260 | lr: 5.91e-04 | loss: 0.4043 | norm: 0.00 | time: 57.88ms | tokens processed: 9,261,056 | tok/sec: 70,766.90
# 2280 | lr: 5.90e-04 | loss: 0.4199 | norm: 0.00 | time: 56.37ms | tokens processed: 9,342,976 | tok/sec: 72,656.59
# 2300 | lr: 5.90e-04 | loss: 0.3926 | norm: 0.00 | time: 56.92ms | tokens processed: 9,424,896 | tok/sec: 71,964.20
# 2320 | lr: 5.90e-04 | loss: 0.4043 | norm: 0.00 | time: 58.88ms | tokens processed: 9,506,816 | tok/sec: 69,566.80
# 2340 | lr: 5.90e-04 | loss: 0.3828 | norm: 0.00 | time: 57.09ms | tokens processed: 9,588,736 | tok/sec: 71,752.00
# 2360 | lr: 5.89e-04 | loss: 0.3320 | norm: 0.00 | time: 56.31ms | tokens processed: 9,670,656 | tok/sec: 72,743.96
# 2380 | lr: 5.89e-04 | loss: 0.3906 | norm: 0.00 | time: 57.10ms | tokens processed: 9,752,576 | tok/sec: 71,732.23
# 2400 | lr: 5.89e-04 | loss: 0.3613 | norm: 0.00 | time: 57.09ms | tokens processed: 9,834,496 | tok/sec: 71,747.21
# 2420 | lr: 5.89e-04 | loss: 0.3281 | norm: 0.00 | time: 55.67ms | tokens processed: 9,916,416 | tok/sec: 73,577.35
# 2440 | lr: 5.88e-04 | loss: 0.3711 | norm: 0.00 | time: 58.11ms | tokens processed: 9,998,336 | tok/sec: 70,492.50
# 2460 | lr: 5.88e-04 | loss: 0.3281 | norm: 0.00 | time: 58.77ms | tokens processed: 10,080,256 | tok/sec: 69,690.69
# 2480 | lr: 5.88e-04 | loss: 0.3652 | norm: 0.00 | time: 56.51ms | tokens processed: 10,162,176 | tok/sec: 72,486.76
# 2500 | lr: 5.88e-04 | loss: 0.3457 | norm: 0.00 | time: 58.09ms | tokens processed: 10,244,096 | tok/sec: 70,506.97
# valid loss: 7.7500
# Hello, I'm a language model, with acute position that within upon your mother of the master instead
# Hello, I'm a language model, finding Spot drew nohow for gems that moment, said with
# Hello, I'm a language model, new trust  river resting their doailing condition, you ever
# Hello, I'm a language model, gazed  with his foreopt pollen giary d refuse fore
# Hello, I'm a language model, I trusts. Its five wrong bear me pleasure's back as
# 2520 | lr: 5.87e-04 | loss: 0.3203 | norm: 0.00 | time: 59.22ms | tokens processed: 10,326,016 | tok/sec: 69,169.35
# 2540 | lr: 5.87e-04 | loss: 0.1582 | norm: 0.00 | time: 58.84ms | tokens processed: 10,407,936 | tok/sec: 69,611.34
# 2560 | lr: 5.87e-04 | loss: 0.3027 | norm: 0.00 | time: 58.18ms | tokens processed: 10,489,856 | tok/sec: 70,407.86
# 2580 | lr: 5.86e-04 | loss: 0.3164 | norm: 0.00 | time: 57.68ms | tokens processed: 10,571,776 | tok/sec: 71,008.80
# 2600 | lr: 5.86e-04 | loss: 0.3496 | norm: 0.00 | time: 57.43ms | tokens processed: 10,653,696 | tok/sec: 71,326.90
# 2620 | lr: 5.86e-04 | loss: 0.2852 | norm: 0.00 | time: 60.46ms | tokens processed: 10,735,616 | tok/sec: 67,751.71
# 2640 | lr: 5.85e-04 | loss: 0.2676 | norm: 0.00 | time: 54.90ms | tokens processed: 10,817,536 | tok/sec: 74,603.94
# 2660 | lr: 5.85e-04 | loss: 0.2676 | norm: 0.00 | time: 55.19ms | tokens processed: 10,899,456 | tok/sec: 74,217.83
# 2680 | lr: 5.85e-04 | loss: 0.3086 | norm: 0.00 | time: 57.51ms | tokens processed: 10,981,376 | tok/sec: 71,221.64
# 2700 | lr: 5.85e-04 | loss: 0.2520 | norm: 0.00 | time: 55.79ms | tokens processed: 11,063,296 | tok/sec: 73,416.68
# 2720 | lr: 5.84e-04 | loss: 0.1689 | norm: 0.00 | time: 55.53ms | tokens processed: 11,145,216 | tok/sec: 73,765.32
# 2740 | lr: 5.84e-04 | loss: 0.2930 | norm: 0.00 | time: 56.59ms | tokens processed: 11,227,136 | tok/sec: 72,384.45
# valid loss: 7.7500
# Hello, I'm a language model, so much injureiding they put to know in a dear g
# Hello, I'm a language model, saying are delighted attendancealed went too's intention  in comfort
# Hello, I'm a language model, was food, fatal day fly. It tore by pious better
# Hello, I'm a language model, three mouthrot with timely con floor qu Day by nanted
# Hello, I'm a language model, capacity bull is moreours forl where Lakshoe with children
# 2760 | lr: 5.84e-04 | loss: 0.2383 | norm: 0.00 | time: 58.07ms | tokens processed: 11,309,056 | tok/sec: 70,530.42
# 2780 | lr: 5.83e-04 | loss: 0.2324 | norm: 0.00 | time: 55.13ms | tokens processed: 11,390,976 | tok/sec: 74,297.43
# 2800 | lr: 5.83e-04 | loss: 0.2441 | norm: 0.00 | time: 55.99ms | tokens processed: 11,472,896 | tok/sec: 73,154.39
# 2820 | lr: 5.83e-04 | loss: 0.2051 | norm: 0.00 | time: 53.80ms | tokens processed: 11,554,816 | tok/sec: 76,133.00
# 2840 | lr: 5.82e-04 | loss: 0.2422 | norm: 0.00 | time: 361.95ms | tokens processed: 11,636,736 | tok/sec: 11,316.42
# 2860 | lr: 5.82e-04 | loss: 0.2188 | norm: 0.00 | time: 56.44ms | tokens processed: 11,718,656 | tok/sec: 72,574.64
# 2880 | lr: 5.82e-04 | loss: 0.2227 | norm: 0.00 | time: 54.34ms | tokens processed: 11,800,576 | tok/sec: 75,372.45
# 2900 | lr: 5.81e-04 | loss: 0.2197 | norm: 0.00 | time: 56.29ms | tokens processed: 11,882,496 | tok/sec: 72,766.76
# 2920 | lr: 5.81e-04 | loss: 0.1973 | norm: 0.00 | time: 54.78ms | tokens processed: 11,964,416 | tok/sec: 74,766.27
# 2940 | lr: 5.81e-04 | loss: 0.1953 | norm: 0.00 | time: 52.97ms | tokens processed: 12,046,336 | tok/sec: 77,319.93
# 2960 | lr: 5.80e-04 | loss: 0.2021 | norm: 0.00 | time: 54.07ms | tokens processed: 12,128,256 | tok/sec: 75,750.32
# 2980 | lr: 5.80e-04 | loss: 0.2012 | norm: 0.00 | time: 55.03ms | tokens processed: 12,210,176 | tok/sec: 74,427.79
# 3000 | lr: 5.80e-04 | loss: 0.1777 | norm: 0.00 | time: 55.75ms | tokens processed: 12,292,096 | tok/sec: 73,466.28
# valid loss: 8.0000
# Hello, I'm a language model, or strikes wit-How long aspires time. The blessed
# Hello, I'm a language model, visited this sweetan knowing divers arise she did  of behold
# Hello, I'm a language model, : this. Not sw atheists doesrylness this pre
# Hello, I'm a language model, which  Brahrived at strikes cats masterler provided who —
# Hello, I'm a language model, heaven for shade or food, by remaining followed con requ
# 3020 | lr: 5.79e-04 | loss: 0.1699 | norm: 0.00 | time: 55.60ms | tokens processed: 12,374,016 | tok/sec: 73,666.63
# 3040 | lr: 5.79e-04 | loss: 0.1943 | norm: 0.00 | time: 59.30ms | tokens processed: 12,455,936 | tok/sec: 69,077.02
# 3060 | lr: 5.79e-04 | loss: 0.1875 | norm: 0.00 | time: 54.46ms | tokens processed: 12,537,856 | tok/sec: 75,211.43
# 3080 | lr: 5.78e-04 | loss: 0.1826 | norm: 0.00 | time: 55.31ms | tokens processed: 12,619,776 | tok/sec: 74,061.69
# 3100 | lr: 5.78e-04 | loss: 0.1914 | norm: 0.00 | time: 56.16ms | tokens processed: 12,701,696 | tok/sec: 72,940.39
# 3120 | lr: 5.77e-04 | loss: 0.1826 | norm: 0.00 | time: 59.10ms | tokens processed: 12,783,616 | tok/sec: 69,306.92
# 3140 | lr: 5.77e-04 | loss: 0.1777 | norm: 0.00 | time: 58.86ms | tokens processed: 12,865,536 | tok/sec: 69,588.78
# 3160 | lr: 5.77e-04 | loss: 0.1865 | norm: 0.00 | time: 56.89ms | tokens processed: 12,947,456 | tok/sec: 72,000.69
# 3180 | lr: 5.76e-04 | loss: 0.1924 | norm: 0.00 | time: 57.18ms | tokens processed: 13,029,376 | tok/sec: 71,632.04
# 3200 | lr: 5.76e-04 | loss: 0.1602 | norm: 0.00 | time: 57.59ms | tokens processed: 13,111,296 | tok/sec: 71,118.44
# 3220 | lr: 5.76e-04 | loss: 0.1436 | norm: 0.00 | time: 55.34ms | tokens processed: 13,193,216 | tok/sec: 74,010.96
# 3240 | lr: 5.75e-04 | loss: 0.1631 | norm: 0.00 | time: 55.44ms | tokens processed: 13,275,136 | tok/sec: 73,883.33
# valid loss: 8.3750
# Hello, I'm a language model, they laughful are useless foremen for consultation, was fly
# Hello, I'm a language model, though," ignor lacking yet; THErival they, ' way
# Hello, I'm a language model, or doves keep careful hair." AndOSS OFounCHAT
# Hello, I'm a language model, to kiss doy, into servant me from he his intelligence
# Hello, I'm a language model, was far ? HeNING for content ? Ah I have supp
# 3260 | lr: 5.75e-04 | loss: 0.1592 | norm: 0.00 | time: 54.57ms | tokens processed: 13,357,056 | tok/sec: 75,063.88
# 3280 | lr: 5.74e-04 | loss: 0.1709 | norm: 0.00 | time: 58.31ms | tokens processed: 13,438,976 | tok/sec: 70,249.22
# 3300 | lr: 5.74e-04 | loss: 0.1729 | norm: 0.00 | time: 55.51ms | tokens processed: 13,520,896 | tok/sec: 73,794.47
# 3320 | lr: 5.74e-04 | loss: 0.1465 | norm: 0.00 | time: 56.18ms | tokens processed: 13,602,816 | tok/sec: 72,910.98
# 3340 | lr: 5.73e-04 | loss: 0.1602 | norm: 0.00 | time: 54.44ms | tokens processed: 13,684,736 | tok/sec: 75,238.11
# 3360 | lr: 5.73e-04 | loss: 0.1543 | norm: 0.00 | time: 53.85ms | tokens processed: 13,766,656 | tok/sec: 76,059.53
# 3380 | lr: 5.72e-04 | loss: 0.1562 | norm: 0.00 | time: 356.67ms | tokens processed: 13,848,576 | tok/sec: 11,484.08
# 3400 | lr: 5.72e-04 | loss: 0.0981 | norm: 0.00 | time: 56.39ms | tokens processed: 13,930,496 | tok/sec: 72,640.00
# 3420 | lr: 5.72e-04 | loss: 0.1631 | norm: 0.00 | time: 57.37ms | tokens processed: 14,012,416 | tok/sec: 71,391.52
# 3440 | lr: 5.71e-04 | loss: 0.1699 | norm: 0.00 | time: 58.43ms | tokens processed: 14,094,336 | tok/sec: 70,096.74
# 3460 | lr: 5.71e-04 | loss: 0.1582 | norm: 0.00 | time: 58.47ms | tokens processed: 14,176,256 | tok/sec: 70,051.86
# 3480 | lr: 5.70e-04 | loss: 0.1621 | norm: 0.00 | time: 55.05ms | tokens processed: 14,258,176 | tok/sec: 74,398.78
# 3500 | lr: 5.70e-04 | loss: 0.1211 | norm: 0.00 | time: 55.00ms | tokens processed: 14,340,096 | tok/sec: 74,475.87
# valid loss: 8.3750
# Hello, I'm a language model, foodful sure: Death are That repeated sand's back
# Hello, I'm a language model, damn foes up anrant, fine more —; by calling
# Hello, I'm a language model, in moral is hundred-f-bank my  Live-
# Hello, I'm a language model, as a school can I more more the inner? creatures."
# Hello, I'm a language model, dull mar dwell the whole; And listen stility's guard
# 3520 | lr: 5.69e-04 | loss: 0.1416 | norm: 0.00 | time: 55.92ms | tokens processed: 14,422,016 | tok/sec: 73,248.90
# 3540 | lr: 5.69e-04 | loss: 0.1602 | norm: 0.00 | time: 54.38ms | tokens processed: 14,503,936 | tok/sec: 75,323.87
# 3560 | lr: 5.69e-04 | loss: 0.1309 | norm: 0.00 | time: 53.45ms | tokens processed: 14,585,856 | tok/sec: 76,632.21
# 3580 | lr: 5.68e-04 | loss: 0.1299 | norm: 0.00 | time: 57.58ms | tokens processed: 14,667,776 | tok/sec: 71,133.76
# 3600 | lr: 5.68e-04 | loss: 0.1475 | norm: 0.00 | time: 57.35ms | tokens processed: 14,749,696 | tok/sec: 71,422.98
# 3620 | lr: 5.67e-04 | loss: 0.1562 | norm: 0.00 | time: 54.81ms | tokens processed: 14,831,616 | tok/sec: 74,726.92
# 3640 | lr: 5.67e-04 | loss: 0.1406 | norm: 0.00 | time: 54.72ms | tokens processed: 14,913,536 | tok/sec: 74,858.14
# 3660 | lr: 5.66e-04 | loss: 0.1523 | norm: 0.00 | time: 56.06ms | tokens processed: 14,995,456 | tok/sec: 73,064.79
# 3680 | lr: 5.66e-04 | loss: 0.1377 | norm: 0.00 | time: 55.36ms | tokens processed: 15,077,376 | tok/sec: 73,995.03
# 3700 | lr: 5.66e-04 | loss: 0.1377 | norm: 0.00 | time: 53.98ms | tokens processed: 15,159,296 | tok/sec: 75,880.13
# 3720 | lr: 5.65e-04 | loss: 0.1377 | norm: 0.00 | time: 55.39ms | tokens processed: 15,241,216 | tok/sec: 73,953.94
# 3740 | lr: 5.65e-04 | loss: 0.1826 | norm: 0.00 | time: 56.93ms | tokens processed: 15,323,136 | tok/sec: 71,948.53
# valid loss: 8.5000
# Hello, I'm a language model, giving occupantNING ignorant I plan, called horse, butli
# Hello, I'm a language model, confidence might have's song my wingy self c grant
# Hello, I'm a language model, intrigueished in much circum wingsings, devise a r strongest
# Hello, I'm a language model, him sin kinds*ues aloneor bright would knowama where
# Hello, I'm a language model, the are towell for a matter far betweeners, :
# 3760 | lr: 5.64e-04 | loss: 0.1445 | norm: 0.00 | time: 52.02ms | tokens processed: 15,405,056 | tok/sec: 78,739.20
# 3780 | lr: 5.64e-04 | loss: 0.1289 | norm: 0.00 | time: 58.82ms | tokens processed: 15,486,976 | tok/sec: 69,639.84
# 3800 | lr: 5.63e-04 | loss: 0.1182 | norm: 0.00 | time: 53.14ms | tokens processed: 15,568,896 | tok/sec: 77,080.90
# 3820 | lr: 5.63e-04 | loss: 0.1201 | norm: 0.00 | time: 54.24ms | tokens processed: 15,650,816 | tok/sec: 75,517.57
# 3840 | lr: 5.62e-04 | loss: 0.1416 | norm: 0.00 | time: 55.57ms | tokens processed: 15,732,736 | tok/sec: 73,714.05
# 3860 | lr: 5.62e-04 | loss: 0.1436 | norm: 0.00 | time: 55.08ms | tokens processed: 15,814,656 | tok/sec: 74,365.61
# 3880 | lr: 5.61e-04 | loss: 0.1250 | norm: 0.00 | time: 56.25ms | tokens processed: 15,896,576 | tok/sec: 72,822.28
# 3900 | lr: 5.61e-04 | loss: 0.1318 | norm: 0.00 | time: 54.36ms | tokens processed: 15,978,496 | tok/sec: 75,344.69
# 3920 | lr: 5.60e-04 | loss: 0.1230 | norm: 0.00 | time: 55.82ms | tokens processed: 16,060,416 | tok/sec: 73,377.79
# 3940 | lr: 5.60e-04 | loss: 0.1240 | norm: 0.00 | time: 56.11ms | tokens processed: 16,142,336 | tok/sec: 72,998.97
# 3960 | lr: 5.59e-04 | loss: 0.1177 | norm: 0.00 | time: 59.07ms | tokens processed: 16,224,256 | tok/sec: 69,343.57
# 3980 | lr: 5.59e-04 | loss: 0.1357 | norm: 0.00 | time: 58.24ms | tokens processed: 16,306,176 | tok/sec: 70,331.47
# 4000 | lr: 5.58e-04 | loss: 0.1250 | norm: 0.00 | time: 56.36ms | tokens processed: 16,388,096 | tok/sec: 72,675.03
# valid loss: 8.8750
# Hello, I'm a language model, less implased with whatever ascone scaredased built Laksh pearl
# Hello, I'm a language model, suffering to Pr packed Money> exre built built lands in
# Hello, I'm a language model, they be- plug-denFains cannot Better felt
# Hello, I'm a language model, separated the insect as itaries angrily angrily worstFas carefully
# Hello, I'm a language model, the va ways should he  pe heartixtraining desiring
# 4020 | lr: 5.58e-04 | loss: 0.1348 | norm: 0.00 | time: 58.80ms | tokens processed: 16,470,016 | tok/sec: 69,656.78
# 4040 | lr: 5.57e-04 | loss: 0.1152 | norm: 0.00 | time: 54.84ms | tokens processed: 16,551,936 | tok/sec: 74,695.08
# 4060 | lr: 5.57e-04 | loss: 0.1152 | norm: 0.00 | time: 54.42ms | tokens processed: 16,633,856 | tok/sec: 75,262.17
# 4080 | lr: 5.56e-04 | loss: 0.1167 | norm: 0.00 | time: 55.15ms | tokens processed: 16,715,776 | tok/sec: 74,276.87
# 4100 | lr: 5.56e-04 | loss: 0.1211 | norm: 0.00 | time: 57.19ms | tokens processed: 16,797,696 | tok/sec: 71,624.27
# 4120 | lr: 5.55e-04 | loss: 0.1001 | norm: 0.00 | time: 56.22ms | tokens processed: 16,879,616 | tok/sec: 72,853.47
# 4140 | lr: 5.55e-04 | loss: 0.1445 | norm: 0.00 | time: 54.39ms | tokens processed: 16,961,536 | tok/sec: 75,301.42
# 4160 | lr: 5.54e-04 | loss: 0.1201 | norm: 0.00 | time: 55.58ms | tokens processed: 17,043,456 | tok/sec: 73,692.86
# 4180 | lr: 5.54e-04 | loss: 0.1260 | norm: 0.00 | time: 57.67ms | tokens processed: 17,125,376 | tok/sec: 71,021.13
# 4200 | lr: 5.53e-04 | loss: 0.1035 | norm: 0.00 | time: 53.83ms | tokens processed: 17,207,296 | tok/sec: 76,087.15
# 4220 | lr: 5.53e-04 | loss: 0.1064 | norm: 0.00 | time: 54.53ms | tokens processed: 17,289,216 | tok/sec: 75,115.07
# 4240 | lr: 5.52e-04 | loss: 0.1123 | norm: 0.00 | time: 54.73ms | tokens processed: 17,371,136 | tok/sec: 74,840.21
# valid loss: 8.8125
# Hello, I'm a language model, was Constrated within is thief, ( for sport..
# Hello, I'm a language model, enjoying water the lack al's gazed; abject diet revenue
# Hello, I'm a language model, ponds hostilities, monkeys with you.' great bird  sureide
# Hello, I'm a language model, conjizzard come." And WINMER prev Regane lesson ask
# Hello, I'm a language model, said sharp increasing bees ten of sport books and kiss three counselors
# 4260 | lr: 5.52e-04 | loss: 0.0684 | norm: 0.00 | time: 55.14ms | tokens processed: 17,453,056 | tok/sec: 74,283.62
# 4280 | lr: 5.51e-04 | loss: 0.1196 | norm: 0.00 | time: 55.78ms | tokens processed: 17,534,976 | tok/sec: 73,426.72
# 4300 | lr: 5.51e-04 | loss: 0.1211 | norm: 0.00 | time: 60.28ms | tokens processed: 17,616,896 | tok/sec: 67,949.20
# 4320 | lr: 5.50e-04 | loss: 0.1060 | norm: 0.00 | time: 56.45ms | tokens processed: 17,698,816 | tok/sec: 72,564.53
# 4340 | lr: 5.50e-04 | loss: 0.1187 | norm: 0.00 | time: 54.86ms | tokens processed: 17,780,736 | tok/sec: 74,661.00
# 4360 | lr: 5.49e-04 | loss: 0.1040 | norm: 0.00 | time: 53.31ms | tokens processed: 17,862,656 | tok/sec: 76,832.02
# 4380 | lr: 5.49e-04 | loss: 0.1289 | norm: 0.00 | time: 54.77ms | tokens processed: 17,944,576 | tok/sec: 74,785.80
# 4400 | lr: 5.48e-04 | loss: 0.1016 | norm: 0.00 | time: 56.21ms | tokens processed: 18,026,496 | tok/sec: 72,868.62
# 4420 | lr: 5.48e-04 | loss: 0.1133 | norm: 0.00 | time: 55.95ms | tokens processed: 18,108,416 | tok/sec: 73,202.70
# 4440 | lr: 5.47e-04 | loss: 0.0957 | norm: 0.00 | time: 54.40ms | tokens processed: 18,190,336 | tok/sec: 75,295.81
# 4460 | lr: 5.46e-04 | loss: 0.0923 | norm: 0.00 | time: 55.05ms | tokens processed: 18,272,256 | tok/sec: 74,400.07
# 4480 | lr: 5.46e-04 | loss: 0.0991 | norm: 0.00 | time: 58.72ms | tokens processed: 18,354,176 | tok/sec: 69,749.82
# 4500 | lr: 5.45e-04 | loss: 0.1030 | norm: 0.00 | time: 56.08ms | tokens processed: 18,436,096 | tok/sec: 73,032.79
# valid loss: 8.9375
# Hello, I'm a language model, left by Gayre interatt touchingity he men of tears
# Hello, I'm a language model, though is Death Shiva made palace but set from al an
# Hello, I'm a language model, r foretoldants will their nail' means or their cap
# Hello, I'm a language model, soat ( try toother Swift! And he should de
# Hello, I'm a language model, or weaponisonMaster must be something intrigue draws only sin even
# 4520 | lr: 5.45e-04 | loss: 0.1050 | norm: 0.00 | time: 55.28ms | tokens processed: 18,518,016 | tok/sec: 74,092.36
# 4540 | lr: 5.44e-04 | loss: 0.1035 | norm: 0.00 | time: 57.38ms | tokens processed: 18,599,936 | tok/sec: 71,387.07
# 4560 | lr: 5.44e-04 | loss: 0.1157 | norm: 0.00 | time: 54.80ms | tokens processed: 18,681,856 | tok/sec: 74,742.20
# 4580 | lr: 5.43e-04 | loss: 0.0859 | norm: 0.00 | time: 59.01ms | tokens processed: 18,763,776 | tok/sec: 69,412.77
# 4600 | lr: 5.42e-04 | loss: 0.0947 | norm: 0.00 | time: 55.75ms | tokens processed: 18,845,696 | tok/sec: 73,470.99
# 4620 | lr: 5.42e-04 | loss: 0.1021 | norm: 0.00 | time: 53.10ms | tokens processed: 18,927,616 | tok/sec: 77,131.78
# 4640 | lr: 5.41e-04 | loss: 0.0859 | norm: 0.00 | time: 53.98ms | tokens processed: 19,009,536 | tok/sec: 75,883.48
# 4660 | lr: 5.41e-04 | loss: 0.0854 | norm: 0.00 | time: 56.55ms | tokens processed: 19,091,456 | tok/sec: 72,428.70
# 4680 | lr: 5.40e-04 | loss: 0.0981 | norm: 0.00 | time: 53.73ms | tokens processed: 19,173,376 | tok/sec: 76,238.41
# 4700 | lr: 5.40e-04 | loss: 0.0732 | norm: 0.00 | time: 327.74ms | tokens processed: 19,255,296 | tok/sec: 12,497.85
# 4720 | lr: 5.39e-04 | loss: 0.1104 | norm: 0.00 | time: 54.38ms | tokens processed: 19,337,216 | tok/sec: 75,321.23
# 4740 | lr: 5.38e-04 | loss: 0.0947 | norm: 0.00 | time: 55.72ms | tokens processed: 19,419,136 | tok/sec: 73,510.92
# valid loss: 9.3125
# Hello, I'm a language model, play bed word they faint not is cut as the pres remained
# Hello, I'm a language model, namely guest — therefore anger bit him if this conclusion monkey ate
# Hello, I'm a language model, if she64 meal and prosperity are quickly interbrear such
# Hello, I'm a language model, one isIE you are abise had stillacing more on
# Hello, I'm a language model, disease will speak of three other is At again water." In
# 4760 | lr: 5.38e-04 | loss: 0.0952 | norm: 0.00 | time: 329.37ms | tokens processed: 19,501,056 | tok/sec: 12,435.88
# 4780 | lr: 5.37e-04 | loss: 0.0850 | norm: 0.00 | time: 54.00ms | tokens processed: 19,582,976 | tok/sec: 75,851.66
# 4800 | lr: 5.37e-04 | loss: 0.0889 | norm: 0.00 | time: 55.85ms | tokens processed: 19,664,896 | tok/sec: 73,335.51
# 4820 | lr: 5.36e-04 | loss: 0.0938 | norm: 0.00 | time: 56.26ms | tokens processed: 19,746,816 | tok/sec: 72,802.23
# 4840 | lr: 5.35e-04 | loss: 0.0967 | norm: 0.00 | time: 353.93ms | tokens processed: 19,828,736 | tok/sec: 11,573.06
# 4860 | lr: 5.35e-04 | loss: 0.0869 | norm: 0.00 | time: 57.08ms | tokens processed: 19,910,656 | tok/sec: 71,757.70
# 4880 | lr: 5.34e-04 | loss: 0.1309 | norm: 0.00 | time: 58.25ms | tokens processed: 19,992,576 | tok/sec: 70,318.23
# Exception ignored in: <function _xla_gc_callback at 0x7e756c611940>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
#
# KeyboardInterrupt:
# 4900 | lr: 5.34e-04 | loss: 0.0947 | norm: 0.00 | time: 55.66ms | tokens processed: 20,074,496 | tok/sec: 73,585.86
# 4920 | lr: 5.33e-04 | loss: 0.0923 | norm: 0.00 | time: 53.95ms | tokens processed: 20,156,416 | tok/sec: 75,925.07
# 4940 | lr: 5.32e-04 | loss: 0.0898 | norm: 0.00 | time: 54.39ms | tokens processed: 20,238,336 | tok/sec: 75,308.36
# 4960 | lr: 5.32e-04 | loss: 0.1167 | norm: 0.00 | time: 326.33ms | tokens processed: 20,320,256 | tok/sec: 12,551.77
# 4980 | lr: 5.31e-04 | loss: 0.0840 | norm: 0.00 | time: 325.82ms | tokens processed: 20,402,176 | tok/sec: 12,571.17
# 5000 | lr: 5.31e-04 | loss: 0.1021 | norm: 0.00 | time: 55.89ms | tokens processed: 20,484,096 | tok/sec: 73,282.64
# Received KeyboardInterrupt. Exiting...
# valid loss: 9.0000
# completions: ["Hello, I'm a language model, thisaka mayBOOK beg of another pl oil and I If", 'Hello, I\'m a language model, ent nib speakerary beast force remote heat filling." Late ', "Hello, I'm a language model, ocean arm away away) anxiety and more slayer THE PAN", "Hello, I'm a language model, anxiety Hiscorlands its orders spinolved Brah speak of", "Hello, I'm a language model, to 23 blood exception of His gal bent did hold flight"]
# Hello, I'm a language model, thisaka mayBOOK beg of another pl oil and I If
# Hello, I'm a language model, ent nib speakerary beast force remote heat filling." Late
# Hello, I'm a language model, ocean arm away away) anxiety and more slayer THE PAN
# Hello, I'm a language model, anxiety Hiscorlands its orders spinolved Brah speak of
# Hello, I'm a language model, to 23 blood exception of His gal bent did hold flight

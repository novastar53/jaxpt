# %% [markdown]
# # NoPE GPT Experiment
#
# This experiment trains a GPT model without any positional embeddings. According to Kazemnejad et al. (2024), this should still work due to the causal attention map inducing positional information.

# %% [markdown]
# ### Configure the machine and install packages

# %%
from typing import Literal
import sys

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# Cloning into 'jaxpt'...
# remote: Enumerating objects: 619, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 619 (delta 209), reused 178 (delta 116), pack-reused 297 (from 1)
# Receiving objects: 100% (619/619), 17.48 MiB | 36.08 MiB/s, done.
# Resolving deltas: 100% (359/359), done.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.7 MB/s eta 0:00:00
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import jax.numpy as jnp
import numpy as np

os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
    '--xla_gpu_enable_latency_hiding_scheduler=true '
)

os.environ.update({
  "NCCL_LL128_BUFFSIZE": "-2",
  "NCCL_LL_BUFFSIZE": "-2",
  "NCCL_PROTO": "SIMPLE,LL,LL128",
 })


# Hardware setup
print("JAX version:", jax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

REQUESTED_DEVICE = "gpu"

jax.config.update("jax_platform_name", REQUESTED_DEVICE) # Make sure we're using the GPU

device = jax.default_backend()
if device != REQUESTED_DEVICE:
    warnings.warn(f"not using {REQUESTED_DEVICE}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Available devices: 1
# using gpu
# 784 µs ± 14.9 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize the baseline and candidate models and perform a sanity check

# %%
from functools import partial

from flax import nnx

from jaxpt.infer import generate_completions
from jaxpt.models import RoPE_GPT, NoPE_GPT, RoPE_GPTConfig, NoPE_GPTConfig

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
baseline_config = NoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
candidate_config = RoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(baseline_config)
nnx.display(candidate_config)
baseline = NoPE_GPT(baseline_config, rngs)
candidate = RoPE_GPT(candidate_config, rngs)

#m = load_checkpoint("run_20250311_uqdwjq", 5600)
graphdef, rngstate, state = nnx.split(baseline, nnx.RngState, ...)
nnx.display(state)
graphdef, rngstate, state = nnx.split(candidate, nnx.RngState, ...)
nnx.display(state)

#completions = generate_completions()
#for completion in completions:
#print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_b3322a684ee44826a58d494128ae277e" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_b3322a684ee44826a58d494128ae277e")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_b3322a684ee44826a58d494128ae277e")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_d866d670685a4959ab701c55db04d1dc" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d866d670685a4959ab701c55db04d1dc")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d866d670685a4959ab701c55db04d1dc")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_4e7fa119a0cd4262a299dd169047c360" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_4e7fa119a0cd4262a299dd169047c360")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_4e7fa119a0cd4262a299dd169047c360")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_4e7fa119a0cd4262a299dd169047c360")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_0e3b8f3cc90b4682827811dae945ac62" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0e3b8f3cc90b4682827811dae945ac62")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0e3b8f3cc90b4682827811dae945ac62")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_0e3b8f3cc90b4682827811dae945ac62")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %% [markdown]
# ### Configure Logging and Checkpointing

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

baseline_run_dirname = f"baseline_run_{timestamp}_{random_code}"
print(f"Baseline Run: {baseline_run_dirname}")
candidate_run_dirname = f"candidate_run_{timestamp}_{random_code}"
print(f"Candidate Run: {candidate_run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Baseline Run: baseline_run_20250426_cfrenm
# Candidate Run: candidate_run_20250426_cfrenm
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %% [markdown]
# ### Configure Training Run

# %%
import dataclasses

############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**19 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 64
  T: int = 1024
  max_steps: int = 19073 # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 20
  eval_interval: int = 250
  checkpoint_interval: int = 250
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T * num_devices) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()

trconf = TrainerConfig(
  num_tokens_per_batch=2**11,
  mB=2,
  T=1024,
  max_steps=9*48*10, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=20,
  eval_interval=250,
  checkpoint_interval=0,

)

trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient


print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# tokens/batch: 2,048
# block size: 1024
# sub-batch size: 2
# no. gradient accumulation steps: 1
# effective batch size per device:  2
# effective batch size: 2
# max steps: 4320

# %% [markdown]
# ### Configure the Baseline and Candidate Optimizer

# %%
import optax

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

# Generate a weight decay mask
_, params, _ = nnx.split(baseline, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
baseline_optimizer = nnx.Optimizer(baseline, tx)

# count the number of weight decay params
def get_size(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)
print(f"baseline weight decay param count: {weight_decay_param_count:,}")


_, params, _ = nnx.split(candidate, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
candidate_optimizer = nnx.Optimizer(candidate, tx)

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)

print(f"candidate weight decay param count: {weight_decay_param_count:,}")
# Out:
# baseline weight decay param count: 123,532,032
# candidate weight decay param count: 123,597,568

# %% [markdown]
# ### Configure DataLoader

# %%
from jaxpt.dataloaders import DataLoader
from jaxpt.eval import calc_validation_loss
from jaxpt.train import loss_fn

dataset = "panchatantra-ryder"

if platform == "colab":
    dataset_path = Path().absolute() / "jaxpt" / "datasets" / dataset / "processed"
else:
    if dataset == "fineweb-edu":
      dataset_path = "/home/ubuntu/gpt2-train/fineweb-edu/processed"
    elif dataset == "panchatantra-ryder":
      dataset_path = Path().absolute().parent /  "datasets" / dataset / "processed"
    else:
      raise ValueError(f"Dataset {dataset} not found")

train_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=num_devices, label="train")
eval_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=1, label="valid", quiet=True)

def evaluate(model):
  model.eval()
  completions = generate_completions(model)
  val_loss = calc_validation_loss(model, loss_fn=loss_fn, dataloader=eval_dl)
  model.train()
  return val_loss, completions
# Out:
# dataloader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     2
# block size:     1024
# device rank:    1
# ------------------------

# %% [markdown]
# ### Setup the Training Loop

# %%
# %matplotlib inline

import time

import matplotlib.pyplot as plt

from jaxpt.utils import append_to_csv
from jaxpt.train import parallel_train_step


baseline_train_losses, candidate_train_losses = [], []
baseline_val_losses, candidate_val_losses = [], []
append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", ["step", "loss"])
append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{candidate_run_dirname}_valid.csv", ["step", "loss"])

baseline.train()
candidate.train()

try:
  for step in range(trconf.max_steps):
    start = time.time()
    batch, target = train_dl()

    # baseline step
    baseline_avg_loss, baseline_avg_grads = parallel_train_step(baseline, baseline_optimizer, batch, target)
    baseline_avg_loss.block_until_ready()

    # candidate step
    candidate_avg_loss, candidate_avg_grads = parallel_train_step(candidate, candidate_optimizer, batch, target)
    candidate_avg_loss.block_until_ready()

    # compute stats
    baseline_avg_loss = jnp.float32(baseline_avg_loss[0])
    candidate_avg_loss = jnp.float32(candidate_avg_loss[0])

    lr = warmup_with_cosine_decay_schedule(step)
    norm = 0 # norm[0]|
    iter_time = time.time() - start
    sub_step_time = iter_time / trconf.grad_accumulation_steps
    tokens_per_sec = num_devices * trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
    tokens_processed = (step+1) * num_devices * trconf.grad_accumulation_steps * trconf.mB * trconf.T

    if step % trconf.print_interval == 0:
      baseline_train_losses.append((step, baseline_avg_loss))
      candidate_train_losses.append((step, candidate_avg_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", [step, lr, baseline_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", [step, lr, candidate_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | baseline loss: {baseline_avg_loss:0.4f} | "
            f"candidate loss: {candidate_avg_loss:0.4f} | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      baseline_valid_loss, baseline_completions = evaluate(baseline)
      baseline_valid_loss = jnp.float32(baseline_valid_loss)
      baseline_val_losses.append((step, baseline_valid_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, baseline_valid_loss])
      candidate_valid_loss, candidate_completions = evaluate(candidate)
      candidate_valid_loss = jnp.float32(candidate_valid_loss)
      candidate_val_losses.append((step, jnp.float32(candidate_valid_loss)))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, candidate_valid_loss])
      print(f"baseline valid loss: {baseline_valid_loss:0.4f} |"
            f"candidate valid loss: {candidate_valid_loss:0.4f} "  )

      print("Baseline completions:")
      for completion in baseline_completions:
        print(completion)
      print("Candidate completions")
      for completion in candidate_completions:
        print(completion)
    #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
      #save_checkpoint(m, step)


except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

baseline_valid_loss, baseline_completions = evaluate(baseline)
baseline_valid_loss = jnp.float32(baseline_valid_loss)
candidate_valid_loss, candidate_completions = evaluate(candidate)
candidate_valid_loss = jnp.float32(candidate_valid_loss)
print(f"baseline valid loss: {baseline_valid_loss:0.4f} | "
      f"candidate valid loss: {candidate_valid_loss:0.4f}")
print(f"baseline completions")
for completion in baseline_completions:
  print(completion)
print(f"candidate completions")
for completion in candidate_completions:
  print(completion)

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].plot([x[0] for x in baseline_train_losses], [x[1] for x in baseline_train_losses], label="baseline")
axes[0].plot([x[0] for x in candidate_train_losses], [x[1] for x in candidate_train_losses], label="candidate")
axes[0].set_title("Train Loss")

axes[1].plot([x[0] for x in baseline_val_losses], [x[1] for x in baseline_val_losses], label="baseline")
axes[1].plot([x[0] for x in candidate_val_losses], [x[1] for x in candidate_val_losses], label="candidate")
axes[1].set_title("Valid Loss")

plt.legend()
plt.savefig(log_dir / f"{baseline_run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# 0 | lr: 6.00e-05 | baseline loss: 11.0000 | candidate loss: 10.8750 | tokens processed: 2,048 | tok/sec: 31.14
# baseline valid loss: 9.5000 |candidate valid loss: 9.5000
# Baseline completions:
# Hello, I'm a language model, November }) EC pinpoint browseXX  BuiltXX ,enough
# Hello, I'm a language model, ess Ult garn intertwined fabby Awesome academ3737 intertwinedorst
# Hello, I'm a language model,making EC  }) usheredutter Hog37 Greatest
# anic Greatest
# Hello, I'm a language model, pinpoint, ExaminationXXensed Satan Debian copies Cance, mitochond Ending
# Hello, I'm a language model, mil garn detainedXXanic
#  Hogisionatuutter,ensed
# Candidate completions
# Hello, I'm a language model,.TopicsAttach 820 Plenty charter They Schultz , appre
# Hello, I'm a language model, wasteland 820 Factoryscale mushrooms lawsuits PlentyWOR.. VER writing
# Hello, I'm a language model,istics lan  Reply ReplysecutionWOR一lock
#  KE Bis
# Hello, I'm a language model, kWh, varied STA descendant Customenser Hobassis, Select Employ
# Hello, I'm a language model, lawsuits Design factions slideshowamic
#  Replytg Ellison Wyatt,assis
# 20 | lr: 6.00e-04 | baseline loss: 6.3125 | candidate loss: 6.4062 | tokens processed: 43,008 | tok/sec: 24,575.46
# 40 | lr: 6.00e-04 | baseline loss: 5.9375 | candidate loss: 6.0312 | tokens processed: 83,968 | tok/sec: 24,842.34
# 60 | lr: 6.00e-04 | baseline loss: 5.8750 | candidate loss: 5.9688 | tokens processed: 124,928 | tok/sec: 25,482.84
# 80 | lr: 6.00e-04 | baseline loss: 5.6250 | candidate loss: 5.6250 | tokens processed: 165,888 | tok/sec: 25,143.82
# 100 | lr: 5.99e-04 | baseline loss: 5.4062 | candidate loss: 5.6250 | tokens processed: 206,848 | tok/sec: 23,172.39
# 120 | lr: 5.99e-04 | baseline loss: 5.2188 | candidate loss: 5.3750 | tokens processed: 247,808 | tok/sec: 24,221.29
# 140 | lr: 5.99e-04 | baseline loss: 5.0625 | candidate loss: 5.1562 | tokens processed: 288,768 | tok/sec: 24,329.20
# 160 | lr: 5.98e-04 | baseline loss: 4.9375 | candidate loss: 5.0938 | tokens processed: 329,728 | tok/sec: 25,539.97
# 180 | lr: 5.98e-04 | baseline loss: 4.9375 | candidate loss: 5.0625 | tokens processed: 370,688 | tok/sec: 25,276.78
# 200 | lr: 5.97e-04 | baseline loss: 4.8125 | candidate loss: 5.0000 | tokens processed: 411,648 | tok/sec: 24,260.35
# 220 | lr: 5.97e-04 | baseline loss: 4.8750 | candidate loss: 4.9375 | tokens processed: 452,608 | tok/sec: 24,836.45
# 240 | lr: 5.96e-04 | baseline loss: 4.6875 | candidate loss: 4.7500 | tokens processed: 493,568 | tok/sec: 25,036.10
# baseline valid loss: 5.5000 |candidate valid loss: 5.3438
# Baseline completions:
# Hello, I'm a language model, when now she have we do prieved  FRI Then
# Hello, I'm a language model, or eyes had been go of evil heard of this set-
# Hello, I'm a language model, so not, no said ' this to. icht
# Hello, I'm a language model, a wife said with you were life I had the more in
# Hello, I'm a language model, who he thought from order, at those have other to was
# Candidate completions
# Hello, I'm a language model, a hunterman," resta. With their sayingANT monkey
# Hello, I'm a language model, why she has take to he should she, the mere house
# Hello, I'm a language model, but said: sir and though and he! A body
# Hello, I'm a language model, they and after LRAbank — Death had a mere story
# Hello, I'm a language model, who must if she are then did found no city of not
# 260 | lr: 5.96e-04 | baseline loss: 4.8125 | candidate loss: 4.9375 | tokens processed: 534,528 | tok/sec: 24,635.58
# 280 | lr: 5.95e-04 | baseline loss: 4.3125 | candidate loss: 4.3750 | tokens processed: 575,488 | tok/sec: 24,550.53
# 300 | lr: 5.94e-04 | baseline loss: 4.9062 | candidate loss: 5.0312 | tokens processed: 616,448 | tok/sec: 25,465.47
# 320 | lr: 5.93e-04 | baseline loss: 4.6250 | candidate loss: 4.6875 | tokens processed: 657,408 | tok/sec: 24,290.05
# 340 | lr: 5.92e-04 | baseline loss: 4.5625 | candidate loss: 4.5938 | tokens processed: 698,368 | tok/sec: 24,741.17
# 360 | lr: 5.91e-04 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 739,328 | tok/sec: 5,386.42
# 380 | lr: 5.90e-04 | baseline loss: 4.5312 | candidate loss: 4.5938 | tokens processed: 780,288 | tok/sec: 24,073.58
# 400 | lr: 5.89e-04 | baseline loss: 4.5000 | candidate loss: 4.5312 | tokens processed: 821,248 | tok/sec: 24,375.32
# 420 | lr: 5.88e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 862,208 | tok/sec: 24,782.14
# 440 | lr: 5.87e-04 | baseline loss: 4.6562 | candidate loss: 4.6875 | tokens processed: 903,168 | tok/sec: 24,845.50
# 460 | lr: 5.86e-04 | baseline loss: 4.3438 | candidate loss: 4.4062 | tokens processed: 944,128 | tok/sec: 23,749.70
# 480 | lr: 5.84e-04 | baseline loss: 4.7188 | candidate loss: 4.7812 | tokens processed: 985,088 | tok/sec: 25,061.22
# 500 | lr: 5.83e-04 | baseline loss: 4.2188 | candidate loss: 4.2500 | tokens processed: 1,026,048 | tok/sec: 24,276.53
# baseline valid loss: 5.5000 |candidate valid loss: 5.3750
# Baseline completions:
# Hello, I'm a language model, for much man and sound from him I all a snake I
# Hello, I'm a language model, yet in friends your part." — so that Hom
# Hello, I'm a language model, what is a brother and king." Then to the frog or
# Hello, I'm a language model, she When they do. Go here my heart were so
# Hello, I'm a language model, you his eyes — who ierceen on any voice him
# Candidate completions
# Hello, I'm a language model, for they all you heard their wife into, ?" At
# Hello, I'm a language model, not that show and then my soul for me with virtue was
# Hello, I'm a language model, too to have going with heaven? He do  "How
# Hello, I'm a language model, what he came me of its feets, there was
# Hello, I'm a language model, my race when they no TO take to be I
# 520 | lr: 5.82e-04 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 1,067,008 | tok/sec: 25,244.17
# 540 | lr: 5.80e-04 | baseline loss: 4.3125 | candidate loss: 4.3750 | tokens processed: 1,107,968 | tok/sec: 23,435.96
# 560 | lr: 5.79e-04 | baseline loss: 4.1250 | candidate loss: 4.1562 | tokens processed: 1,148,928 | tok/sec: 24,658.00
# 580 | lr: 5.77e-04 | baseline loss: 4.3750 | candidate loss: 4.2812 | tokens processed: 1,189,888 | tok/sec: 24,796.37
# 600 | lr: 5.75e-04 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 1,230,848 | tok/sec: 23,623.06
# 620 | lr: 5.74e-04 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 1,271,808 | tok/sec: 22,703.67
# 640 | lr: 5.72e-04 | baseline loss: 4.0625 | candidate loss: 4.0625 | tokens processed: 1,312,768 | tok/sec: 23,420.05
# 660 | lr: 5.70e-04 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 1,353,728 | tok/sec: 24,659.20
# 680 | lr: 5.68e-04 | baseline loss: 4.2188 | candidate loss: 4.2500 | tokens processed: 1,394,688 | tok/sec: 5,510.24
# 700 | lr: 5.67e-04 | baseline loss: 4.3750 | candidate loss: 4.4062 | tokens processed: 1,435,648 | tok/sec: 23,049.21
# 720 | lr: 5.65e-04 | baseline loss: 4.1250 | candidate loss: 4.0625 | tokens processed: 1,476,608 | tok/sec: 5,551.48
# 740 | lr: 5.63e-04 | baseline loss: 4.1562 | candidate loss: 4.2188 | tokens processed: 1,517,568 | tok/sec: 5,831.65
# baseline valid loss: 5.4062 |candidate valid loss: 5.3438
# Baseline completions:
# Hello, I'm a language model, they will look into learning is  not whom the And Const
# Hello, I'm a language model, by another woods this moment by it and his eggs like
# Hello, I'm a language model, when when the right and was him a diet. The stomach
# Hello, I'm a language model, a certain life !" One go; snake is they all
# Hello, I'm a language model, so over good to it on seeing food?" Rak your
# Candidate completions
# Hello, I'm a language model, when why of our cell the forest thought at ?" '
# Hello, I'm a language model, all them all life! For that cut from his story here
# Hello, I'm a language model, as good-born'ump with my two For such
# Hello, I'm a language model, then with you, his home who should in evil in
# Hello, I'm a language model, you set low: asked From Gar pain as I the
# 760 | lr: 5.61e-04 | baseline loss: 4.1562 | candidate loss: 4.2500 | tokens processed: 1,558,528 | tok/sec: 25,019.03
# 780 | lr: 5.59e-04 | baseline loss: 3.6562 | candidate loss: 3.7188 | tokens processed: 1,599,488 | tok/sec: 24,802.96
# 800 | lr: 5.56e-04 | baseline loss: 4.3438 | candidate loss: 4.4062 | tokens processed: 1,640,448 | tok/sec: 23,968.45
# 820 | lr: 5.54e-04 | baseline loss: 4.3125 | candidate loss: 4.3750 | tokens processed: 1,681,408 | tok/sec: 24,920.25
# 840 | lr: 5.52e-04 | baseline loss: 4.1562 | candidate loss: 4.1875 | tokens processed: 1,722,368 | tok/sec: 25,573.35
# 860 | lr: 5.50e-04 | baseline loss: 4.3750 | candidate loss: 4.4688 | tokens processed: 1,763,328 | tok/sec: 24,922.78
# 880 | lr: 5.48e-04 | baseline loss: 4.1250 | candidate loss: 4.1562 | tokens processed: 1,804,288 | tok/sec: 25,066.63
# 900 | lr: 5.45e-04 | baseline loss: 4.0312 | candidate loss: 4.0938 | tokens processed: 1,845,248 | tok/sec: 25,207.65
# 920 | lr: 5.43e-04 | baseline loss: 4.0000 | candidate loss: 4.0625 | tokens processed: 1,886,208 | tok/sec: 23,526.91
# 940 | lr: 5.40e-04 | baseline loss: 4.1875 | candidate loss: 4.1875 | tokens processed: 1,927,168 | tok/sec: 24,627.32
# 960 | lr: 5.38e-04 | baseline loss: 4.0938 | candidate loss: 4.1250 | tokens processed: 1,968,128 | tok/sec: 24,703.81
# 980 | lr: 5.35e-04 | baseline loss: 4.1875 | candidate loss: 4.2500 | tokens processed: 2,009,088 | tok/sec: 24,751.72
# 1000 | lr: 5.33e-04 | baseline loss: 3.8125 | candidate loss: 3.8438 | tokens processed: 2,050,048 | tok/sec: 25,522.97
# baseline valid loss: 5.4375 |candidate valid loss: 5.4375
# Baseline completions:
# Hello, I'm a language model, that," took them your friends. Why should you not made
# Hello, I'm a language model, she thing will keep to his husband who return, out by
# Hello, I'm a language model, a trick, then it at all you some And furthermore
# Hello, I'm a language model, my heart where, to he took such her dear on he
# Hello, I'm a language model, with meat without come away. Come each gods if he sat
# Candidate completions
# Hello, I'm a language model, with each reflected a poor life. "Friend  OFwhich
# Hello, I'm a language model, how we place he rose and found and in your manered
# Hello, I'm a language model, then? I want by way? And where I should?
# Hello, I'm a language model, too!No heart and she may just what, one moment
# Hello, I'm a language model, my plan through an female to soon under how I heard
# 1020 | lr: 5.30e-04 | baseline loss: 4.0000 | candidate loss: 4.0312 | tokens processed: 2,091,008 | tok/sec: 24,853.77
# 1040 | lr: 5.27e-04 | baseline loss: 3.8906 | candidate loss: 4.0000 | tokens processed: 2,131,968 | tok/sec: 24,446.07
# 1060 | lr: 5.25e-04 | baseline loss: 3.8906 | candidate loss: 3.9375 | tokens processed: 2,172,928 | tok/sec: 5,312.64
# 1080 | lr: 5.22e-04 | baseline loss: 3.9375 | candidate loss: 3.9531 | tokens processed: 2,213,888 | tok/sec: 25,543.84
# 1100 | lr: 5.19e-04 | baseline loss: 3.7812 | candidate loss: 3.7969 | tokens processed: 2,254,848 | tok/sec: 5,523.29
# 1120 | lr: 5.16e-04 | baseline loss: 3.9688 | candidate loss: 4.0000 | tokens processed: 2,295,808 | tok/sec: 23,826.05
# 1140 | lr: 5.13e-04 | baseline loss: 3.3125 | candidate loss: 3.2969 | tokens processed: 2,336,768 | tok/sec: 23,949.01
# 1160 | lr: 5.11e-04 | baseline loss: 4.0625 | candidate loss: 4.1250 | tokens processed: 2,377,728 | tok/sec: 24,912.30
# 1180 | lr: 5.08e-04 | baseline loss: 3.8594 | candidate loss: 4.0312 | tokens processed: 2,418,688 | tok/sec: 24,674.22
# 1200 | lr: 5.05e-04 | baseline loss: 3.7500 | candidate loss: 3.7656 | tokens processed: 2,459,648 | tok/sec: 23,536.58
# 1220 | lr: 5.02e-04 | baseline loss: 3.7969 | candidate loss: 3.7656 | tokens processed: 2,500,608 | tok/sec: 23,706.31
# 1240 | lr: 4.99e-04 | baseline loss: 3.8281 | candidate loss: 3.9375 | tokens processed: 2,541,568 | tok/sec: 24,912.15
# baseline valid loss: 5.4062 |candidate valid loss: 5.3125
# Baseline completions:
# Hello, I'm a language model, this understand within her wanderings, Che any, and I
# Hello, I'm a language model, out! proud about how: which not stolen for fools thus
# Hello, I'm a language model,, when the men? What I have going to do now
# Hello, I'm a language model, his own wit into us here what even near, is our
# Hello, I'm a language model, "Why sticks and asked the bargain have that be killed from
# Candidate completions
# Hello, I'm a language model, when if not fail out to the she failed to, though
# Hello, I'm a language model, which did what of learning  was killed." So calench
# Hello, I'm a language model, his head, we friend!" PAN hearing about by personal trouble
# Hello, I'm a language model, so his reters A common first from a went.
# Hello, I'm a language model, with shame up to it, like kings who are in me
# 1260 | lr: 4.95e-04 | baseline loss: 3.7656 | candidate loss: 3.8281 | tokens processed: 2,582,528 | tok/sec: 22,882.15
# 1280 | lr: 4.92e-04 | baseline loss: 3.8125 | candidate loss: 3.8594 | tokens processed: 2,623,488 | tok/sec: 25,193.82
# 1300 | lr: 4.89e-04 | baseline loss: 3.8438 | candidate loss: 3.8906 | tokens processed: 2,664,448 | tok/sec: 24,853.91
# 1320 | lr: 4.86e-04 | baseline loss: 3.6719 | candidate loss: 3.7656 | tokens processed: 2,705,408 | tok/sec: 24,614.40
# 1340 | lr: 4.83e-04 | baseline loss: 3.8594 | candidate loss: 3.8906 | tokens processed: 2,746,368 | tok/sec: 25,228.30
# 1360 | lr: 4.79e-04 | baseline loss: 3.5938 | candidate loss: 3.6406 | tokens processed: 2,787,328 | tok/sec: 24,415.71
# 1380 | lr: 4.76e-04 | baseline loss: 3.7344 | candidate loss: 3.7812 | tokens processed: 2,828,288 | tok/sec: 25,040.11
# 1400 | lr: 4.73e-04 | baseline loss: 3.6406 | candidate loss: 3.7812 | tokens processed: 2,869,248 | tok/sec: 24,016.23
# 1420 | lr: 4.70e-04 | baseline loss: 3.5938 | candidate loss: 3.6562 | tokens processed: 2,910,208 | tok/sec: 24,830.92
# 1440 | lr: 4.66e-04 | baseline loss: 3.6406 | candidate loss: 3.7344 | tokens processed: 2,951,168 | tok/sec: 24,702.46
# 1460 | lr: 4.63e-04 | baseline loss: 3.6875 | candidate loss: 3.7969 | tokens processed: 2,992,128 | tok/sec: 24,749.15
# 1480 | lr: 4.59e-04 | baseline loss: 3.6406 | candidate loss: 3.7031 | tokens processed: 3,033,088 | tok/sec: 23,750.95
# 1500 | lr: 4.56e-04 | baseline loss: 3.5625 | candidate loss: 3.6562 | tokens processed: 3,074,048 | tok/sec: 25,141.76
# baseline valid loss: 5.5625 |candidate valid loss: 5.3438
# Baseline completions:
# Hello, I'm a language model, it quickly come the cave you out on knowing her back was
# Hello, I'm a language model, each day all death with her purpose by my friend gave into
# Hello, I'm a language model, a mouse. Even a tank for you wandering And Fl
# Hello, I'm a language model, you his love with her hand again his purpose THE FR
# Hello, I'm a language model, sir your gods that old He gave itsredible." After
# Candidate completions
# Hello, I'm a language model, his daughters she answered. And what: "But my
# Hello, I'm a language model, or in pride after first — uningly did you must done
# Hello, I'm a language model, a long hearting, do." " the urnle
# Hello, I'm a language model, with a half of food at seeing one ? Whyfore a
# Hello, I'm a language model, in whatever even the two heart like him all any, her
# 1520 | lr: 4.52e-04 | baseline loss: 3.6406 | candidate loss: 3.6719 | tokens processed: 3,115,008 | tok/sec: 23,848.28
# 1540 | lr: 4.49e-04 | baseline loss: 3.5000 | candidate loss: 3.6094 | tokens processed: 3,155,968 | tok/sec: 23,702.39
# 1560 | lr: 4.45e-04 | baseline loss: 3.6562 | candidate loss: 3.6250 | tokens processed: 3,196,928 | tok/sec: 23,053.98
# 1580 | lr: 4.42e-04 | baseline loss: 3.5625 | candidate loss: 3.5625 | tokens processed: 3,237,888 | tok/sec: 24,538.04
# 1600 | lr: 4.38e-04 | baseline loss: 3.6250 | candidate loss: 3.6562 | tokens processed: 3,278,848 | tok/sec: 24,165.82
# 1620 | lr: 4.34e-04 | baseline loss: 3.5625 | candidate loss: 3.6250 | tokens processed: 3,319,808 | tok/sec: 24,420.36
# 1640 | lr: 4.31e-04 | baseline loss: 3.0156 | candidate loss: 3.1562 | tokens processed: 3,360,768 | tok/sec: 24,712.76
# 1660 | lr: 4.27e-04 | baseline loss: 3.7344 | candidate loss: 3.8906 | tokens processed: 3,401,728 | tok/sec: 24,976.26
# 1680 | lr: 4.23e-04 | baseline loss: 3.6719 | candidate loss: 3.6719 | tokens processed: 3,442,688 | tok/sec: 5,693.27
# 1700 | lr: 4.20e-04 | baseline loss: 3.4688 | candidate loss: 3.5312 | tokens processed: 3,483,648 | tok/sec: 24,860.31
# 1720 | lr: 4.16e-04 | baseline loss: 3.5469 | candidate loss: 3.5625 | tokens processed: 3,524,608 | tok/sec: 23,293.92
# 1740 | lr: 4.12e-04 | baseline loss: 3.4844 | candidate loss: 3.5938 | tokens processed: 3,565,568 | tok/sec: 24,879.32
# baseline valid loss: 5.4375 |candidate valid loss: 5.3125
# Baseline completions:
# Hello, I'm a language model, too away-To FRIMy dear the crow, and killed
# Hello, I'm a language model, which a fat be certain others me?" But they pl life
# Hello, I'm a language model,:i  asked with Lover in L
# When beauty
# Hello, I'm a language model, a few alone by most found there through and he perceived this
# Hello, I'm a language model, you she creature through it."d up all poison, their
# Candidate completions
# Hello, I'm a language model, all by men under rely, as day, the bed
# Hello, I'm a language model, found, that every night be listened at her, of fish
# Hello, I'm a language model, "He  tale and took him: son, then remain
# Hello, I'm a language model, but you plan  and you shall went here. Lute
# Hello, I'm a language model, you make not by friends, has-w first-Ne
# 1760 | lr: 4.09e-04 | baseline loss: 3.4375 | candidate loss: 3.4688 | tokens processed: 3,606,528 | tok/sec: 24,637.63
# 1780 | lr: 4.05e-04 | baseline loss: 3.3906 | candidate loss: 3.4531 | tokens processed: 3,647,488 | tok/sec: 24,914.75
# 1800 | lr: 4.01e-04 | baseline loss: 3.4844 | candidate loss: 3.6250 | tokens processed: 3,688,448 | tok/sec: 25,040.04
# 1820 | lr: 3.97e-04 | baseline loss: 3.4531 | candidate loss: 3.4844 | tokens processed: 3,729,408 | tok/sec: 24,360.38
# 1840 | lr: 3.93e-04 | baseline loss: 3.6094 | candidate loss: 3.6406 | tokens processed: 3,770,368 | tok/sec: 24,294.11
# 1860 | lr: 3.90e-04 | baseline loss: 3.2656 | candidate loss: 3.3438 | tokens processed: 3,811,328 | tok/sec: 25,048.36
# 1880 | lr: 3.86e-04 | baseline loss: 3.5312 | candidate loss: 3.6250 | tokens processed: 3,852,288 | tok/sec: 24,651.91
# 1900 | lr: 3.82e-04 | baseline loss: 3.4375 | candidate loss: 3.4531 | tokens processed: 3,893,248 | tok/sec: 23,885.54
# 1920 | lr: 3.78e-04 | baseline loss: 3.4688 | candidate loss: 3.4688 | tokens processed: 3,934,208 | tok/sec: 24,841.33
# 1940 | lr: 3.74e-04 | baseline loss: 3.3438 | candidate loss: 3.3750 | tokens processed: 3,975,168 | tok/sec: 25,450.30
# 1960 | lr: 3.70e-04 | baseline loss: 3.2188 | candidate loss: 3.3281 | tokens processed: 4,016,128 | tok/sec: 24,975.02
# 1980 | lr: 3.66e-04 | baseline loss: 3.4688 | candidate loss: 3.4062 | tokens processed: 4,057,088 | tok/sec: 23,926.73
# 2000 | lr: 3.62e-04 | baseline loss: 2.6719 | candidate loss: 2.8281 | tokens processed: 4,098,048 | tok/sec: 25,082.81
# baseline valid loss: 5.5625 |candidate valid loss: 5.4062
# Baseline completions:
# Hello, I'm a language model, do free like for woman? Indeed proud if it? Since
# Hello, I'm a language model, which will follow against life for home is it is much go
# Hello, I'm a language model, it the monkey unhter." But said Slow-in;
# Hello, I'm a language model, a king with yourself." For others gleavly pond-
# Hello, I'm a language model, is my darling turns your at or!" must you bab
# Candidate completions
# Hello, I'm a language model, to I missed near no father of wags by nile
# Hello, I'm a language model, are quickly a saying about her saw life of water the time
# Hello, I'm a language model, who reas against a prince sleeps the journey, brother used
# Hello, I'm a language model, with no manner of her hands fail in bed, not tell
# Hello, I'm a language model, I and part is true In-blade For there has
# 2020 | lr: 3.58e-04 | baseline loss: 3.5156 | candidate loss: 3.6406 | tokens processed: 4,139,008 | tok/sec: 24,811.05
# 2040 | lr: 3.55e-04 | baseline loss: 3.3281 | candidate loss: 3.3438 | tokens processed: 4,179,968 | tok/sec: 24,535.80
# 2060 | lr: 3.51e-04 | baseline loss: 3.2656 | candidate loss: 3.2812 | tokens processed: 4,220,928 | tok/sec: 5,548.92
# 2080 | lr: 3.47e-04 | baseline loss: 3.1875 | candidate loss: 3.2969 | tokens processed: 4,261,888 | tok/sec: 22,816.63
# 2100 | lr: 3.43e-04 | baseline loss: 3.2656 | candidate loss: 3.3438 | tokens processed: 4,302,848 | tok/sec: 24,528.72
# 2120 | lr: 3.39e-04 | baseline loss: 3.2500 | candidate loss: 3.2344 | tokens processed: 4,343,808 | tok/sec: 23,726.68
# 2140 | lr: 3.35e-04 | baseline loss: 3.2031 | candidate loss: 3.2812 | tokens processed: 4,384,768 | tok/sec: 24,833.58
# 2160 | lr: 3.31e-04 | baseline loss: 3.2656 | candidate loss: 3.3281 | tokens processed: 4,425,728 | tok/sec: 5,300.02
# 2180 | lr: 3.27e-04 | baseline loss: 3.1250 | candidate loss: 3.1719 | tokens processed: 4,466,688 | tok/sec: 25,196.93
# 2200 | lr: 3.23e-04 | baseline loss: 3.3281 | candidate loss: 3.3906 | tokens processed: 4,507,648 | tok/sec: 25,270.31
# 2220 | lr: 3.19e-04 | baseline loss: 3.2188 | candidate loss: 3.3125 | tokens processed: 4,548,608 | tok/sec: 24,478.26
# 2240 | lr: 3.15e-04 | baseline loss: 3.2031 | candidate loss: 3.3281 | tokens processed: 4,589,568 | tok/sec: 24,650.57
# baseline valid loss: 5.5000 |candidate valid loss: 5.3750
# Baseline completions:
# Hello, I'm a language model, with respectfulills at I was  the edge ?" How
# Hello, I'm a language model, each I Victor camel named Shell.": So I Spike my
# Hello, I'm a language model, who of a time in others by killing in the eggs go
# Hello, I'm a language model, "if in that a sn an empty possible. Furthermore
# Hello, I'm a language model, a cage though he seized the right paw was my eggs the
# Candidate completions
# Hello, I'm a language model, I put each made? To be gracious thrilled and the very
# Hello, I'm a language model, it must may feel their ear a fathermen! TakeF
# Hello, I'm a language model, they who, it, so The god. The saying
# Hello, I'm a language model, who time your king's Meated low over one seized here
# Hello, I'm a language model, in inva quoted peace. She drew by learningly but
# 2260 | lr: 3.11e-04 | baseline loss: 3.1406 | candidate loss: 3.1875 | tokens processed: 4,630,528 | tok/sec: 5,731.35
# 2280 | lr: 3.07e-04 | baseline loss: 3.1875 | candidate loss: 3.2188 | tokens processed: 4,671,488 | tok/sec: 24,741.95
# 2300 | lr: 3.03e-04 | baseline loss: 3.1875 | candidate loss: 3.2500 | tokens processed: 4,712,448 | tok/sec: 24,195.23
# 2320 | lr: 3.00e-04 | baseline loss: 3.2656 | candidate loss: 3.3125 | tokens processed: 4,753,408 | tok/sec: 25,030.19
# 2340 | lr: 2.96e-04 | baseline loss: 2.9844 | candidate loss: 2.9844 | tokens processed: 4,794,368 | tok/sec: 23,391.03
# 2360 | lr: 2.92e-04 | baseline loss: 3.0938 | candidate loss: 3.1406 | tokens processed: 4,835,328 | tok/sec: 25,056.03
# 2380 | lr: 2.88e-04 | baseline loss: 3.0000 | candidate loss: 3.1875 | tokens processed: 4,876,288 | tok/sec: 24,412.66
# 2400 | lr: 2.84e-04 | baseline loss: 2.9844 | candidate loss: 3.0312 | tokens processed: 4,917,248 | tok/sec: 23,332.96
# 2420 | lr: 2.80e-04 | baseline loss: 2.9531 | candidate loss: 3.0938 | tokens processed: 4,958,208 | tok/sec: 24,111.08
# 2440 | lr: 2.76e-04 | baseline loss: 3.0781 | candidate loss: 3.1406 | tokens processed: 4,999,168 | tok/sec: 24,835.80
# 2460 | lr: 2.72e-04 | baseline loss: 3.0000 | candidate loss: 3.1719 | tokens processed: 5,040,128 | tok/sec: 5,554.16
# 2480 | lr: 2.69e-04 | baseline loss: 3.0625 | candidate loss: 3.1250 | tokens processed: 5,081,088 | tok/sec: 5,373.54
# 2500 | lr: 2.65e-04 | baseline loss: 2.3594 | candidate loss: 2.4531 | tokens processed: 5,122,048 | tok/sec: 24,262.47
# baseline valid loss: 5.6875 |candidate valid loss: 5.5000
# Baseline completions:
# Hello, I'm a language model, heav friend go wild King : then your ?" After
# Hello, I'm a language model, without grab distress every other ends your nest was a sa B
# Hello, I'm a language model, their counselors Tried-flru came to take house
# Hello, I'm a language model, with ans. If kings more I said hold on
# Hello, I'm a language model, too at our own a upon." A shULL cried
# Candidate completions
# Hello, I'm a language model, my wit every lot make an Is she, a bird
# Hello, I'm a language model, is near each said they and went alone a time this heed
# Hello, I'm a language model, for our kindly own. He go con-p Hell
# Hello, I'm a language model, too! Since not a come that know one set,
# Hello, I'm a language model, but base by father issued the prov in men the rose have
# 2520 | lr: 2.61e-04 | baseline loss: 3.0469 | candidate loss: 3.2188 | tokens processed: 5,163,008 | tok/sec: 24,665.65
# 2540 | lr: 2.57e-04 | baseline loss: 2.9219 | candidate loss: 3.0000 | tokens processed: 5,203,968 | tok/sec: 24,242.41
# 2560 | lr: 2.53e-04 | baseline loss: 2.8906 | candidate loss: 3.0000 | tokens processed: 5,244,928 | tok/sec: 24,489.77
# 2580 | lr: 2.50e-04 | baseline loss: 2.8281 | candidate loss: 2.9531 | tokens processed: 5,285,888 | tok/sec: 5,558.54
# 2600 | lr: 2.46e-04 | baseline loss: 2.8750 | candidate loss: 3.0469 | tokens processed: 5,326,848 | tok/sec: 24,820.59
# 2620 | lr: 2.42e-04 | baseline loss: 2.7188 | candidate loss: 2.7656 | tokens processed: 5,367,808 | tok/sec: 23,809.41
# 2640 | lr: 2.38e-04 | baseline loss: 2.8750 | candidate loss: 2.8750 | tokens processed: 5,408,768 | tok/sec: 24,807.90
# 2660 | lr: 2.35e-04 | baseline loss: 2.9219 | candidate loss: 3.0781 | tokens processed: 5,449,728 | tok/sec: 24,151.55
# 2680 | lr: 2.31e-04 | baseline loss: 2.8906 | candidate loss: 2.9688 | tokens processed: 5,490,688 | tok/sec: 24,755.71
# 2700 | lr: 2.27e-04 | baseline loss: 2.9219 | candidate loss: 3.0312 | tokens processed: 5,531,648 | tok/sec: 24,516.40
# 2720 | lr: 2.24e-04 | baseline loss: 2.8281 | candidate loss: 2.9062 | tokens processed: 5,572,608 | tok/sec: 22,351.58
# 2740 | lr: 2.20e-04 | baseline loss: 2.9531 | candidate loss: 2.9688 | tokens processed: 5,613,568 | tok/sec: 25,164.08
# baseline valid loss: 5.6875 |candidate valid loss: 5.5000
# Baseline completions:
# Hello, I'm a language model, you carry self the mouth into an named Gold that brings
# Hello, I'm a language model, well shade! Where-n double grass by giving I."
# Hello, I'm a language model, his ear and started with more — evils, with eyes
# Hello, I'm a language model, too — his wife and Wrong into Spike sea, learned and
# Hello, I'm a language model, there provide to earth there is I — other night a master
# Candidate completions
# Hello, I'm a language model, his back wandering dead we gave his health will be-conduct
# Hello, I'm a language model, that kill when night passed and so that they had bat intent
# Hello, I'm a language model, like like the whole. L OFers climb  and because
# Hello, I'm a language model, " Lost has not only one." You must heron
# Hello, I'm a language model, with measures on an and fecters but the wood
# 2760 | lr: 2.17e-04 | baseline loss: 2.7344 | candidate loss: 2.8594 | tokens processed: 5,654,528 | tok/sec: 24,544.91
# 2780 | lr: 2.13e-04 | baseline loss: 2.7344 | candidate loss: 2.8281 | tokens processed: 5,695,488 | tok/sec: 24,348.58
# 2800 | lr: 2.09e-04 | baseline loss: 2.7344 | candidate loss: 2.8750 | tokens processed: 5,736,448 | tok/sec: 25,293.82
# 2820 | lr: 2.06e-04 | baseline loss: 2.6562 | candidate loss: 2.7812 | tokens processed: 5,777,408 | tok/sec: 23,866.83
# 2840 | lr: 2.02e-04 | baseline loss: 2.7969 | candidate loss: 2.9219 | tokens processed: 5,818,368 | tok/sec: 24,457.56
# 2860 | lr: 1.99e-04 | baseline loss: 2.0156 | candidate loss: 2.1406 | tokens processed: 5,859,328 | tok/sec: 23,965.24
# 2880 | lr: 1.96e-04 | baseline loss: 2.6875 | candidate loss: 2.8281 | tokens processed: 5,900,288 | tok/sec: 23,803.14
# 2900 | lr: 1.92e-04 | baseline loss: 2.7500 | candidate loss: 2.8125 | tokens processed: 5,941,248 | tok/sec: 24,942.03
# 2920 | lr: 1.89e-04 | baseline loss: 2.7656 | candidate loss: 2.8750 | tokens processed: 5,982,208 | tok/sec: 24,447.26
# 2940 | lr: 1.85e-04 | baseline loss: 2.6094 | candidate loss: 2.7500 | tokens processed: 6,023,168 | tok/sec: 24,822.89
# 2960 | lr: 1.82e-04 | baseline loss: 2.5938 | candidate loss: 2.7031 | tokens processed: 6,064,128 | tok/sec: 5,805.33
# 2980 | lr: 1.79e-04 | baseline loss: 2.6875 | candidate loss: 2.7500 | tokens processed: 6,105,088 | tok/sec: 24,075.54
# 3000 | lr: 1.76e-04 | baseline loss: 2.3281 | candidate loss: 2.5312 | tokens processed: 6,146,048 | tok/sec: 24,347.61
# baseline valid loss: 5.7812 |candidate valid loss: 5.6250
# Baseline completions:
# Hello, I'm a language model, his soul from to harm! With those ?" Well
# Hello, I'm a language model, .... I it; his purpose were hard, I fly be
# Hello, I'm a language model, a proud. Since they go I, since you he became
# Hello, I'm a language model, that he himself, there be king gives one life — I
# Hello, I'm a language model, too in no home and after home- court upon the prov
# Candidate completions
# Hello, I'm a language model, she the girl and poor dull about myself near by ,"
# Hello, I'm a language model, so in time by pouring a moates but character gave among
# Hello, I'm a language model, after cling; myself one-Face. When the prov-
# Hello, I'm a language model, all. "what is dead among him! After your
# Hello, I'm a language model, in genuine fate have said the yellow WHO Hang bit. Therefore
# 3020 | lr: 1.72e-04 | baseline loss: 2.6406 | candidate loss: 2.8125 | tokens processed: 6,187,008 | tok/sec: 5,316.04
# 3040 | lr: 1.69e-04 | baseline loss: 2.6094 | candidate loss: 2.7812 | tokens processed: 6,227,968 | tok/sec: 23,378.04
# 3060 | lr: 1.66e-04 | baseline loss: 2.7344 | candidate loss: 2.7969 | tokens processed: 6,268,928 | tok/sec: 24,678.90
# 3080 | lr: 1.63e-04 | baseline loss: 2.6250 | candidate loss: 2.7812 | tokens processed: 6,309,888 | tok/sec: 24,286.14
# 3100 | lr: 1.60e-04 | baseline loss: 2.5000 | candidate loss: 2.6250 | tokens processed: 6,350,848 | tok/sec: 24,599.95
# 3120 | lr: 1.57e-04 | baseline loss: 2.5625 | candidate loss: 2.6719 | tokens processed: 6,391,808 | tok/sec: 24,612.78
# 3140 | lr: 1.54e-04 | baseline loss: 2.5312 | candidate loss: 2.6562 | tokens processed: 6,432,768 | tok/sec: 24,881.20
# 3160 | lr: 1.51e-04 | baseline loss: 2.6250 | candidate loss: 2.7344 | tokens processed: 6,473,728 | tok/sec: 24,398.58
# 3180 | lr: 1.48e-04 | baseline loss: 2.6562 | candidate loss: 2.8125 | tokens processed: 6,514,688 | tok/sec: 25,504.18
# 3200 | lr: 1.45e-04 | baseline loss: 2.5156 | candidate loss: 2.6094 | tokens processed: 6,555,648 | tok/sec: 24,722.79
# 3220 | lr: 1.42e-04 | baseline loss: 2.5625 | candidate loss: 2.6562 | tokens processed: 6,596,608 | tok/sec: 25,017.94
# 3240 | lr: 1.39e-04 | baseline loss: 2.5312 | candidate loss: 2.7188 | tokens processed: 6,637,568 | tok/sec: 25,094.02
# baseline valid loss: 5.8125 |candidate valid loss: 5.5625
# Baseline completions:
# Hello, I'm a language model, too far was to escape is to beat every plan out be
# Hello, I'm a language model, well blame? From strike, said : To On virtue
# Hello, I'm a language model, re: "Let food look yourself to lose them a heart
# Hello, I'm a language model, with me your father in vain because elephants as they keep her
# Hello, I'm a language model, in command they to an easy means?" We there?" A
# Candidate completions
# Hello, I'm a language model, all had had given?" At this meating the great distinction
# Hello, I'm a language model, felt, w return you. May each is this full he
# Hello, I'm a language model, for her  continued; one, when shouts of food with
# Hello, I'm a language model, his hearts and snake upon windly spuda?" There
# Hello, I'm a language model, with and returned upon us. She use peace this. That
# 3260 | lr: 1.37e-04 | baseline loss: 2.5469 | candidate loss: 2.6719 | tokens processed: 6,678,528 | tok/sec: 24,410.16
# 3280 | lr: 1.34e-04 | baseline loss: 2.4688 | candidate loss: 2.5625 | tokens processed: 6,719,488 | tok/sec: 24,685.21
# 3300 | lr: 1.31e-04 | baseline loss: 2.4531 | candidate loss: 2.5312 | tokens processed: 6,760,448 | tok/sec: 24,825.90
# 3320 | lr: 1.29e-04 | baseline loss: 2.3438 | candidate loss: 2.5000 | tokens processed: 6,801,408 | tok/sec: 24,493.82
# 3340 | lr: 1.26e-04 | baseline loss: 2.5312 | candidate loss: 2.5781 | tokens processed: 6,842,368 | tok/sec: 24,551.72
# 3360 | lr: 1.23e-04 | baseline loss: 1.6406 | candidate loss: 1.7656 | tokens processed: 6,883,328 | tok/sec: 24,975.53
# 3380 | lr: 1.21e-04 | baseline loss: 2.5312 | candidate loss: 2.6719 | tokens processed: 6,924,288 | tok/sec: 24,090.86
# 3400 | lr: 1.18e-04 | baseline loss: 2.4062 | candidate loss: 2.4062 | tokens processed: 6,965,248 | tok/sec: 24,640.81
# 3420 | lr: 1.16e-04 | baseline loss: 2.4531 | candidate loss: 2.4844 | tokens processed: 7,006,208 | tok/sec: 23,177.51
# 3440 | lr: 1.14e-04 | baseline loss: 2.1250 | candidate loss: 2.2656 | tokens processed: 7,047,168 | tok/sec: 24,155.63
# 3460 | lr: 1.11e-04 | baseline loss: 2.3594 | candidate loss: 2.4688 | tokens processed: 7,088,128 | tok/sec: 24,804.11
# 3480 | lr: 1.09e-04 | baseline loss: 2.2969 | candidate loss: 2.4062 | tokens processed: 7,129,088 | tok/sec: 24,841.26
# 3500 | lr: 1.07e-04 | baseline loss: 2.3281 | candidate loss: 2.4375 | tokens processed: 7,170,048 | tok/sec: 23,731.40
# baseline valid loss: 5.9062 |candidate valid loss: 5.6875
# Baseline completions:
# Hello, I'm a language model, or — our present ends at the KingM. And what
# Hello, I'm a language model, your kind yourself expedrat in it with its com were blind
# Hello, I'm a language model, sir with a certain tree time he heard me. He gives
# Hello, I'm a language model, what is likely be-Fights your day you alone is
# Hello, I'm a language model, a holy brow when every me another tricks from a prod
# Candidate completions
# Hello, I'm a language model, but on is better ? What are found no name  he
# Hello, I'm a language model, full made blind and civered be as a bitly die
# Hello, I'm a language model, who see  purpose. Thus if we would  hurriedly
# Hello, I'm a language model, then it it would intent through me through butter. However bit
# Hello, I'm a language model, with bewildlined when the Brah bird sweet rice, it
# 3520 | lr: 1.05e-04 | baseline loss: 2.4531 | candidate loss: 2.6094 | tokens processed: 7,211,008 | tok/sec: 24,194.95
# 3540 | lr: 1.02e-04 | baseline loss: 2.2188 | candidate loss: 2.3594 | tokens processed: 7,251,968 | tok/sec: 24,718.67
# 3560 | lr: 1.00e-04 | baseline loss: 2.3594 | candidate loss: 2.5156 | tokens processed: 7,292,928 | tok/sec: 5,744.29
# 3580 | lr: 9.83e-05 | baseline loss: 2.2500 | candidate loss: 2.4688 | tokens processed: 7,333,888 | tok/sec: 5,729.10
# 3600 | lr: 9.63e-05 | baseline loss: 2.3594 | candidate loss: 2.4688 | tokens processed: 7,374,848 | tok/sec: 5,808.95
# 3620 | lr: 9.44e-05 | baseline loss: 2.3281 | candidate loss: 2.5312 | tokens processed: 7,415,808 | tok/sec: 5,576.20
# 3640 | lr: 9.25e-05 | baseline loss: 2.3281 | candidate loss: 2.5156 | tokens processed: 7,456,768 | tok/sec: 23,876.78
# 3660 | lr: 9.06e-05 | baseline loss: 2.3906 | candidate loss: 2.5000 | tokens processed: 7,497,728 | tok/sec: 24,392.90
# 3680 | lr: 8.89e-05 | baseline loss: 2.1562 | candidate loss: 2.3281 | tokens processed: 7,538,688 | tok/sec: 24,250.01
# 3700 | lr: 8.71e-05 | baseline loss: 2.2656 | candidate loss: 2.4219 | tokens processed: 7,579,648 | tok/sec: 25,012.26
# 3720 | lr: 8.54e-05 | baseline loss: 1.9062 | candidate loss: 2.1094 | tokens processed: 7,620,608 | tok/sec: 24,415.01
# 3740 | lr: 8.38e-05 | baseline loss: 2.3438 | candidate loss: 2.4531 | tokens processed: 7,661,568 | tok/sec: 23,860.13
# baseline valid loss: 5.8750 |candidate valid loss: 5.6250
# Baseline completions:
# Hello, I'm a language model, play said there go quite of So hear this be that
# Hello, I'm a language model, be your purpose which have the quick upon an of light grief
# Hello, I'm a language model, you after re and he, there everyi-Neck
# Hello, I'm a language model, too our name was so told or friends without a riverch
# Hello, I'm a language model, in what re a means No mountain mind whosecker —
# Candidate completions
# Hello, I'm a language model, was secret about his personal forest, like for his heart the
# Hello, I'm a language model, fate may devise delight which in of time the proverb gleors
# Hello, I'm a language model, "You is death." J manner." these For charity
# Hello, I'm a language model, came and drew out." cut them blind into a crab heard
# Hello, I'm a language model, for control cut in star-between peopleies points, after
# 3760 | lr: 8.22e-05 | baseline loss: 2.3281 | candidate loss: 2.3750 | tokens processed: 7,702,528 | tok/sec: 23,758.24
# 3780 | lr: 8.06e-05 | baseline loss: 2.3438 | candidate loss: 2.5781 | tokens processed: 7,743,488 | tok/sec: 23,940.20
# 3800 | lr: 7.92e-05 | baseline loss: 2.3125 | candidate loss: 2.4688 | tokens processed: 7,784,448 | tok/sec: 24,807.40
# 3820 | lr: 7.77e-05 | baseline loss: 2.2500 | candidate loss: 2.3906 | tokens processed: 7,825,408 | tok/sec: 24,912.51
# 3840 | lr: 7.64e-05 | baseline loss: 2.2656 | candidate loss: 2.3438 | tokens processed: 7,866,368 | tok/sec: 23,747.60
# 3860 | lr: 7.50e-05 | baseline loss: 1.6172 | candidate loss: 1.7344 | tokens processed: 7,907,328 | tok/sec: 24,625.34
# 3880 | lr: 7.38e-05 | baseline loss: 2.2344 | candidate loss: 2.4219 | tokens processed: 7,948,288 | tok/sec: 5,266.07
# 3900 | lr: 7.26e-05 | baseline loss: 2.2969 | candidate loss: 2.4375 | tokens processed: 7,989,248 | tok/sec: 25,236.75
# 3920 | lr: 7.14e-05 | baseline loss: 2.4219 | candidate loss: 2.4531 | tokens processed: 8,030,208 | tok/sec: 24,985.48
# 3940 | lr: 7.03e-05 | baseline loss: 2.1719 | candidate loss: 2.4062 | tokens processed: 8,071,168 | tok/sec: 24,867.01
# 3960 | lr: 6.92e-05 | baseline loss: 2.0625 | candidate loss: 2.2344 | tokens processed: 8,112,128 | tok/sec: 23,612.99
# 3980 | lr: 6.82e-05 | baseline loss: 2.2656 | candidate loss: 2.4062 | tokens processed: 8,153,088 | tok/sec: 22,566.79
# 4000 | lr: 6.73e-05 | baseline loss: 2.0781 | candidate loss: 2.3125 | tokens processed: 8,194,048 | tok/sec: 24,348.30
# baseline valid loss: 5.9375 |candidate valid loss: 5.6875
# Baseline completions:
# Hello, I'm a language model, you this lament exped' man un began into the crow took
# Hello, I'm a language model, every com said — we did to show our little little,
# Hello, I'm a language model, their her and returned of ease through." Ah, too!
# Hello, I'm a language model, he goes had him." For before all formidable. Goi
# Hello, I'm a language model, a distance his abif you his d his belly was at
# Candidate completions
# Hello, I'm a language model, from love de soil through you, after and the great rejo
# Hello, I'm a language model, whose acts as at stake — gleist have heard sayingly
# Hello, I'm a language model, with love of rings, called Sug; very And with
# Hello, I'm a language model, but all made in wateras defame would, his ab
# Hello, I'm a language model, then she paid. Indeed, which only good with the crow
# 4020 | lr: 6.64e-05 | baseline loss: 2.1250 | candidate loss: 2.3438 | tokens processed: 8,235,008 | tok/sec: 24,820.16
# 4040 | lr: 6.56e-05 | baseline loss: 2.2031 | candidate loss: 2.3125 | tokens processed: 8,275,968 | tok/sec: 24,212.89
# 4060 | lr: 6.48e-05 | baseline loss: 2.1094 | candidate loss: 2.3438 | tokens processed: 8,316,928 | tok/sec: 24,655.45
# 4080 | lr: 6.41e-05 | baseline loss: 2.1719 | candidate loss: 2.3594 | tokens processed: 8,357,888 | tok/sec: 24,992.97
# 4100 | lr: 6.35e-05 | baseline loss: 2.1250 | candidate loss: 2.3750 | tokens processed: 8,398,848 | tok/sec: 24,577.08
# 4120 | lr: 6.29e-05 | baseline loss: 2.3281 | candidate loss: 2.3594 | tokens processed: 8,439,808 | tok/sec: 24,504.09
# 4140 | lr: 6.23e-05 | baseline loss: 2.2188 | candidate loss: 2.4375 | tokens processed: 8,480,768 | tok/sec: 25,392.15
# 4160 | lr: 6.18e-05 | baseline loss: 2.2031 | candidate loss: 2.3281 | tokens processed: 8,521,728 | tok/sec: 24,481.96
# 4180 | lr: 6.14e-05 | baseline loss: 2.0312 | candidate loss: 2.2344 | tokens processed: 8,562,688 | tok/sec: 25,470.22
# 4200 | lr: 6.10e-05 | baseline loss: 2.2969 | candidate loss: 2.3750 | tokens processed: 8,603,648 | tok/sec: 23,904.42
# 4220 | lr: 6.07e-05 | baseline loss: 1.3750 | candidate loss: 1.5625 | tokens processed: 8,644,608 | tok/sec: 5,626.55
# 4240 | lr: 6.05e-05 | baseline loss: 2.3125 | candidate loss: 2.5156 | tokens processed: 8,685,568 | tok/sec: 24,192.77
# baseline valid loss: 5.9375 |candidate valid loss: 5.7188
# Baseline completions:
# Hello, I'm a language model, he fell helplesster where will the wise path, the saying
# Hello, I'm a language model,, he sought "there be at seeing:i88 shrew
# Hello, I'm a language model, their blocks the Brahatings! The sweet. At to
# Hello, I'm a language model,: at last !" RAMched."jatsomeiliation
# Hello, I'm a language model, his pawsated one personal power grows heart when torn and went
# Candidate completions
# Hello, I'm a language model, while body shall. Some her-^ too! What cannot
# Hello, I'm a language model, alone to our share wateras are in life: a secret
# Hello, I'm a language model, therely being ins worshipc of an owl, they ad
# Hello, I'm a language model, from Nor cause: For now blind like to guard by
# Hello, I'm a language model, then both ent) no court when at king grew the seven
# 4260 | lr: 6.03e-05 | baseline loss: 2.1719 | candidate loss: 2.2812 | tokens processed: 8,726,528 | tok/sec: 24,035.72
# 4280 | lr: 6.01e-05 | baseline loss: 2.2500 | candidate loss: 2.3281 | tokens processed: 8,767,488 | tok/sec: 24,277.15
# 4300 | lr: 6.00e-05 | baseline loss: 1.9766 | candidate loss: 2.1406 | tokens processed: 8,808,448 | tok/sec: 24,050.73
# baseline valid loss: 5.9375 | candidate valid loss: 5.7188
# baseline completions
# Hello, I'm a language model, you without my purpose-d  part was ?" For
# Hello, I'm a language model, then your con him very reason if was how not her a
# Hello, I'm a language model, too to  en himself or en at thunderness or all
# Hello, I'm a language model, so, be, he had as ought here, had gone
# Hello, I'm a language model, a st I by every plan-u.* cut I
# candidate completions
# Hello, I'm a language model, was two; but lacking in the like these be killed."
# Hello, I'm a language model, we go ever comes away." All at seeing him away because
# Hello, I'm a language model, or ill, which you: * to Lively there dwell
# Hello, I'm a language model, came as dead skilled, there as day of his treacher.'
# Hello, I'm a language model, then time when torn: f on: and I may

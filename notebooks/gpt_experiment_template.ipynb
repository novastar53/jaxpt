# %% [markdown]
# # NoPE GPT Experiment
#
# This experiment trains a GPT model without any positional embeddings. According to Kazemnejad et al. (2024), this should still work due to the causal attention map inducing positional information.

# %% [markdown]
# ### Configure the machine and install packages

# %%
from typing import Literal
import sys

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# fatal: destination path 'jaxpt' already exists and is not an empty directory.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# WARNING: Skipping tensorflow as it is not installed.

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import jax.numpy as jnp
import numpy as np

os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
    '--xla_gpu_enable_latency_hiding_scheduler=true '
)

os.environ.update({
  "NCCL_LL128_BUFFSIZE": "-2",
  "NCCL_LL_BUFFSIZE": "-2",
  "NCCL_PROTO": "SIMPLE,LL,LL128",
 })


# Hardware setup
print("JAX version:", jax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

REQUESTED_DEVICE = "gpu"

jax.config.update("jax_platform_name", REQUESTED_DEVICE) # Make sure we're using the GPU

device = jax.default_backend()
if device != REQUESTED_DEVICE:
    warnings.warn(f"not using {REQUESTED_DEVICE}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Available devices: 1
# using gpu
# 785 µs ± 19.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Initialize the baseline and candidate models and perform a sanity check

# %%
from functools import partial

from flax import nnx

from jaxpt.infer import generate_completions
from jaxpt.models import GPT, NoPE_GPT, GPTConfig, NoPE_GPTConfig

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
baseline_config = NoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
candidate_config = GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(baseline_config)
nnx.display(candidate_config)
baseline = NoPE_GPT(baseline_config, rngs)
candidate = GPT(candidate_config, rngs)

#m = load_checkpoint("run_20250311_uqdwjq", 5600)
graphdef, rngstate, state = nnx.split(baseline, nnx.RngState, ...)
nnx.display(state)
graphdef, rngstate, state = nnx.split(candidate, nnx.RngState, ...)
nnx.display(state)

#completions = generate_completions()
#for completion in completions:
#print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_ff179e43341843f081c7701776567f44" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_ff179e43341843f081c7701776567f44")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_ff179e43341843f081c7701776567f44")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_60e75d4e6cc34c03a4fa9e646517cb0a" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_60e75d4e6cc34c03a4fa9e646517cb0a")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_60e75d4e6cc34c03a4fa9e646517cb0a")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_3ba977b35b5e490c83a7ff26db0793cc" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3ba977b35b5e490c83a7ff26db0793cc")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3ba977b35b5e490c83a7ff26db0793cc")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_3ba977b35b5e490c83a7ff26db0793cc")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_411c925a25ff4cf8b85a65ad4aa0a549" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_411c925a25ff4cf8b85a65ad4aa0a549")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_411c925a25ff4cf8b85a65ad4aa0a549")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_411c925a25ff4cf8b85a65ad4aa0a549")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %% [markdown]
# ### Configure Logging and Checkpointing

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

baseline_run_dirname = f"baseline_run_{timestamp}_{random_code}"
print(f"Baseline Run: {baseline_run_dirname}")
candidate_run_dirname = f"candidate_run_{timestamp}_{random_code}"
print(f"Candidate Run: {candidate_run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Baseline Run: baseline_run_20250425_ipmkyf
# Candidate Run: candidate_run_20250425_ipmkyf
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %% [markdown]
# ### Configure Training Run

# %%
import dataclasses

############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**19 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 64
  T: int = 1024
  max_steps: int = 19073 # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 20
  eval_interval: int = 250
  checkpoint_interval: int = 250
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T * num_devices) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()

trconf = TrainerConfig(
  num_tokens_per_batch=2**14,
  mB=4,
  T=1024,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)

trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient


print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# tokens/batch: 16,384
# block size: 1024
# sub-batch size: 4
# no. gradient accumulation steps: 4
# effective batch size per device:  16
# effective batch size: 16
# max steps: 432

# %% [markdown]
# ### Configure the Baseline and Candidate Optimizer

# %%
import optax

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

# Generate a weight decay mask
_, params, _ = nnx.split(baseline, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
baseline_optimizer = nnx.Optimizer(baseline, tx)

# count the number of weight decay params
def get_size(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)
print(f"baseline weight decay param count: {weight_decay_param_count:,}")


_, params, _ = nnx.split(candidate, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
candidate_optimizer = nnx.Optimizer(candidate, tx)

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)

print(f"candidate weight decay param count: {weight_decay_param_count:,}")
# Out:
# baseline weight decay param count: 123,532,032
# candidate weight decay param count: 124,318,464

# %% [markdown]
# ### Configure DataLoader

# %%
from jaxpt.dataloaders import DataLoader
from jaxpt.eval import calc_validation_loss
from jaxpt.train import loss_fn

dataset = "panchatantra-ryder"

if platform == "colab":
    dataset_path = Path().absolute() / "jaxpt" / "datasets" / dataset / "processed"
else:
    if dataset == "fineweb-edu":
      dataset_path = "/home/ubuntu/gpt2-train/fineweb-edu/processed"
    elif dataset == "panchatantra-ryder":
      dataset_path = Path().absolute().parent /  "datasets" / dataset / "processed"
    else:
      raise ValueError(f"Dataset {dataset} not found")

train_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=num_devices, label="train")
eval_dl = DataLoader(dirpath=dataset_path, batch_size=trconf.mB, block_size=trconf.T, device_rank=1, label="valid", quiet=True)

def evaluate(model):
  model.eval()
  completions = generate_completions(model)
  val_loss = calc_validation_loss(model, loss_fn=loss_fn, dataloader=eval_dl)
  model.train()
  return val_loss, completions
# Out:
# dataloader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     4
# block size:     1024
# device rank:    1
# ------------------------

# %% [markdown]
# ### Setup the Training Loop

# %%
# %matplotlib inline

import time

import matplotlib.pyplot as plt

from jaxpt.utils import append_to_csv
from jaxpt.train import parallel_train_step


baseline_train_losses, candidate_train_losses = [], []
baseline_val_losses, candidate_val_losses = [], []
append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", ["step", "loss"])
append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{candidate_run_dirname}_valid.csv", ["step", "loss"])

baseline.train()
candidate.train()

try:
  for step in range(trconf.max_steps):
    start = time.time()
    batch, target = train_dl()

    # baseline step
    baseline_avg_loss, baseline_avg_grads = parallel_train_step(baseline, baseline_optimizer, batch, target)
    baseline_avg_loss.block_until_ready()

    # candidate step
    candidate_avg_loss, candidate_avg_grads = parallel_train_step(candidate, candidate_optimizer, batch, target)
    candidate_avg_loss.block_until_ready()

    # compute stats
    baseline_avg_loss = jnp.float32(baseline_avg_loss[0])
    candidate_avg_loss = jnp.float32(candidate_avg_loss[0])

    lr = warmup_with_cosine_decay_schedule(step)
    norm = 0 # norm[0]|
    iter_time = time.time() - start
    sub_step_time = iter_time / trconf.grad_accumulation_steps
    tokens_per_sec = num_devices * trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
    tokens_processed = (step+1) * num_devices * trconf.grad_accumulation_steps * trconf.mB * trconf.T

    if step % trconf.print_interval == 0:
      baseline_train_losses.append((step, baseline_avg_loss))
      candidate_train_losses.append((step, candidate_avg_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", [step, lr, baseline_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", [step, lr, candidate_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | baseline loss: {baseline_avg_loss:0.4f} | "
            f"candidate loss: {candidate_avg_loss:0.4f} | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      baseline_valid_loss, baseline_completions = evaluate(baseline)
      baseline_valid_loss = jnp.float32(baseline_valid_loss)
      baseline_val_losses.append((step, baseline_valid_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, baseline_valid_loss])
      candidate_valid_loss, candidate_completions = evaluate(candidate)
      candidate_valid_loss = jnp.float32(candidate_valid_loss)
      candidate_val_losses.append((step, jnp.float32(candidate_valid_loss)))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, candidate_valid_loss])
      print(f"baseline valid loss: {baseline_valid_loss:0.4f} |"
            f"candidate valid loss: {candidate_valid_loss:0.4f} "  )

      print("Baseline completions:")
      for completion in baseline_completions:
        print(completion)
      print("Candidate completions")
      for completion in candidate_completions:
        print(completion)
    #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
      #save_checkpoint(m, step)


except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

baseline_valid_loss, baseline_completions = evaluate(baseline)
baseline_valid_loss = jnp.float32(baseline_valid_loss)
candidate_valid_loss, candidate_completions = evaluate(candidate)
candidate_valid_loss = jnp.float32(candidate_valid_loss)
print(f"baseline valid loss: {baseline_valid_loss:0.4f} | "
      f"candidate valid loss: {candidate_valid_loss:0.4f}")
print(f"baseline completions")
for completion in baseline_completions:
  print(completion)
print(f"candidate completions")
for completion in candidate_completions:
  print(completion)

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].plot([x[0] for x in baseline_train_losses], [x[1] for x in baseline_train_losses], label="baseline")
axes[0].plot([x[0] for x in candidate_train_losses], [x[1] for x in candidate_train_losses], label="candidate")
axes[0].set_title("Train Loss")

axes[1].plot([x[0] for x in baseline_val_losses], [x[1] for x in baseline_val_losses], label="baseline")
axes[1].plot([x[0] for x in candidate_val_losses], [x[1] for x in candidate_val_losses], label="candidate")
axes[1].set_title("Valid Loss")

plt.legend()
plt.savefig(log_dir / f"{baseline_run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# 0 | lr: 6.00e-05 | baseline loss: 10.9375 | candidate loss: 10.8750 | tokens processed: 16,384 | tok/sec: 375.44
# baseline valid loss: 9.5000 |candidate valid loss: 9.5000
# Baseline completions:
# Hello, I'm a language model, Novemberical greeting grimXX Biblical  hypocrisy bullied  browse 698
# Hello, I'm a language model,263 pelvicXX usheredanic ushered Debian Satan. ushered quir TB
# Hello, I'm a language model, Ulthaven  Ryan,XX263 grimF
# ,ensed
# Hello, I'm a language model, Conver touches37XXensed academ pelvic Story Greatest Vanceれmaking
# Hello, I'm a language model, Greatest Vance November circles TB
#  devised more Cance repo, 698
# Candidate completions
# Hello, I'm a language model,istics Storm247igger Raise546  profile civilizations do�
# Hello, I'm a language model, NAD247 Technician STA grounds一tg Raise Raisedo Shirley Pablo
# Hello, I'm a language model, apprechest  theology Printing grounds STAistics showcasing
# "]Pen
# Hello, I'm a language model, kWh considerably Matt Mattongs Bis Wyatt thingenser appre546 Schultz
# Hello, I'm a language model,encia EmployVa considerably cooked
#  democratically Schultz MAD546, demise
# 1 | lr: 1.20e-04 | baseline loss: 9.1875 | candidate loss: 9.1875 | tokens processed: 32,768 | tok/sec: 118,748.63
# 2 | lr: 1.80e-04 | baseline loss: 8.9375 | candidate loss: 8.8750 | tokens processed: 49,152 | tok/sec: 134,547.79
# 3 | lr: 2.40e-04 | baseline loss: 9.7500 | candidate loss: 8.5000 | tokens processed: 65,536 | tok/sec: 142,811.23
# 4 | lr: 3.00e-04 | baseline loss: 8.7500 | candidate loss: 10.3750 | tokens processed: 81,920 | tok/sec: 146,791.95
# 5 | lr: 3.60e-04 | baseline loss: 8.2500 | candidate loss: 8.5000 | tokens processed: 98,304 | tok/sec: 146,301.92
# 6 | lr: 4.20e-04 | baseline loss: 8.0625 | candidate loss: 8.1250 | tokens processed: 114,688 | tok/sec: 145,496.24
# 7 | lr: 4.80e-04 | baseline loss: 7.8125 | candidate loss: 7.9375 | tokens processed: 131,072 | tok/sec: 33,416.65
# 8 | lr: 5.40e-04 | baseline loss: 7.4375 | candidate loss: 7.4688 | tokens processed: 147,456 | tok/sec: 140,117.72
# 9 | lr: 6.00e-04 | baseline loss: 7.1562 | candidate loss: 7.3750 | tokens processed: 163,840 | tok/sec: 144,124.91
# 10 | lr: 6.00e-04 | baseline loss: 6.8750 | candidate loss: 7.0312 | tokens processed: 180,224 | tok/sec: 142,596.97
# 11 | lr: 6.00e-04 | baseline loss: 6.6250 | candidate loss: 6.8125 | tokens processed: 196,608 | tok/sec: 146,269.54
# 12 | lr: 6.00e-04 | baseline loss: 6.3750 | candidate loss: 6.5312 | tokens processed: 212,992 | tok/sec: 142,892.00
# 13 | lr: 6.00e-04 | baseline loss: 6.3125 | candidate loss: 6.4375 | tokens processed: 229,376 | tok/sec: 143,344.76
# 14 | lr: 6.00e-04 | baseline loss: 6.3125 | candidate loss: 6.4062 | tokens processed: 245,760 | tok/sec: 142,768.50
# 15 | lr: 6.00e-04 | baseline loss: 6.2188 | candidate loss: 6.2812 | tokens processed: 262,144 | tok/sec: 138,219.62
# 16 | lr: 6.00e-04 | baseline loss: 6.0312 | candidate loss: 6.1250 | tokens processed: 278,528 | tok/sec: 138,289.16
# 17 | lr: 6.00e-04 | baseline loss: 6.0625 | candidate loss: 6.1250 | tokens processed: 294,912 | tok/sec: 139,154.73
# 18 | lr: 6.00e-04 | baseline loss: 6.1562 | candidate loss: 6.2188 | tokens processed: 311,296 | tok/sec: 140,596.18
# 19 | lr: 5.99e-04 | baseline loss: 6.0312 | candidate loss: 6.1250 | tokens processed: 327,680 | tok/sec: 141,190.67
# 20 | lr: 5.99e-04 | baseline loss: 6.0000 | candidate loss: 6.0938 | tokens processed: 344,064 | tok/sec: 139,197.29
# 21 | lr: 5.99e-04 | baseline loss: 6.5000 | candidate loss: 5.9688 | tokens processed: 360,448 | tok/sec: 141,276.01
# 22 | lr: 5.99e-04 | baseline loss: 6.0625 | candidate loss: 6.0625 | tokens processed: 376,832 | tok/sec: 140,490.12
# 23 | lr: 5.99e-04 | baseline loss: 6.0000 | candidate loss: 6.0312 | tokens processed: 393,216 | tok/sec: 144,611.69
# 24 | lr: 5.99e-04 | baseline loss: 6.0625 | candidate loss: 6.1250 | tokens processed: 409,600 | tok/sec: 34,845.64
# 25 | lr: 5.98e-04 | baseline loss: 6.1562 | candidate loss: 6.2500 | tokens processed: 425,984 | tok/sec: 138,299.73
# 26 | lr: 5.98e-04 | baseline loss: 6.0312 | candidate loss: 6.0625 | tokens processed: 442,368 | tok/sec: 145,437.74
# 27 | lr: 5.98e-04 | baseline loss: 5.9062 | candidate loss: 5.9688 | tokens processed: 458,752 | tok/sec: 138,720.17
# 28 | lr: 5.98e-04 | baseline loss: 6.0000 | candidate loss: 6.0312 | tokens processed: 475,136 | tok/sec: 139,341.24
# 29 | lr: 5.97e-04 | baseline loss: 5.7812 | candidate loss: 5.8750 | tokens processed: 491,520 | tok/sec: 140,281.33
# 30 | lr: 5.97e-04 | baseline loss: 6.0312 | candidate loss: 6.0938 | tokens processed: 507,904 | tok/sec: 138,478.65
# 31 | lr: 5.97e-04 | baseline loss: 5.8125 | candidate loss: 5.8750 | tokens processed: 524,288 | tok/sec: 138,606.02
# 32 | lr: 5.96e-04 | baseline loss: 5.6250 | candidate loss: 5.7188 | tokens processed: 540,672 | tok/sec: 141,442.63
# 33 | lr: 5.96e-04 | baseline loss: 5.6875 | candidate loss: 5.8125 | tokens processed: 557,056 | tok/sec: 136,485.74
# 34 | lr: 5.96e-04 | baseline loss: 5.8125 | candidate loss: 5.8750 | tokens processed: 573,440 | tok/sec: 137,729.01
# 35 | lr: 5.95e-04 | baseline loss: 5.7812 | candidate loss: 5.9375 | tokens processed: 589,824 | tok/sec: 140,464.27
# 36 | lr: 5.95e-04 | baseline loss: 6.0000 | candidate loss: 6.0938 | tokens processed: 606,208 | tok/sec: 142,397.52
# 37 | lr: 5.95e-04 | baseline loss: 5.6562 | candidate loss: 5.7188 | tokens processed: 622,592 | tok/sec: 132,886.78
# 38 | lr: 5.94e-04 | baseline loss: 5.7188 | candidate loss: 5.8438 | tokens processed: 638,976 | tok/sec: 134,730.60
# 39 | lr: 5.94e-04 | baseline loss: 5.7188 | candidate loss: 5.8125 | tokens processed: 655,360 | tok/sec: 138,595.39
# 40 | lr: 5.93e-04 | baseline loss: 5.9062 | candidate loss: 6.0625 | tokens processed: 671,744 | tok/sec: 139,735.93
# 41 | lr: 5.93e-04 | baseline loss: 5.6875 | candidate loss: 5.8125 | tokens processed: 688,128 | tok/sec: 136,803.91
# 42 | lr: 5.92e-04 | baseline loss: 5.8438 | candidate loss: 5.9688 | tokens processed: 704,512 | tok/sec: 138,174.87
# 43 | lr: 5.92e-04 | baseline loss: 5.7812 | candidate loss: 5.8750 | tokens processed: 720,896 | tok/sec: 32,761.42
# 44 | lr: 5.91e-04 | baseline loss: 5.6562 | candidate loss: 5.7812 | tokens processed: 737,280 | tok/sec: 139,446.71
# 45 | lr: 5.91e-04 | baseline loss: 5.5938 | candidate loss: 5.7188 | tokens processed: 753,664 | tok/sec: 140,728.63
# 46 | lr: 5.90e-04 | baseline loss: 5.5625 | candidate loss: 5.6875 | tokens processed: 770,048 | tok/sec: 135,570.52
# 47 | lr: 5.90e-04 | baseline loss: 5.6250 | candidate loss: 5.7500 | tokens processed: 786,432 | tok/sec: 135,175.04
# 48 | lr: 5.89e-04 | baseline loss: 5.5625 | candidate loss: 5.6562 | tokens processed: 802,816 | tok/sec: 141,336.16
# 49 | lr: 5.89e-04 | baseline loss: 5.6250 | candidate loss: 5.7188 | tokens processed: 819,200 | tok/sec: 137,741.16
# 50 | lr: 5.88e-04 | baseline loss: 5.6562 | candidate loss: 5.7188 | tokens processed: 835,584 | tok/sec: 141,771.78
# baseline valid loss: 5.8438 |candidate valid loss: 5.8750
# Baseline completions:
# Hello, I'm a language model, all was was FRI that that the it man  he
# Hello, I'm a language model, was lion with not whenENhis lion that and as who
# Hello, I'm a language model, said is the had and not king ICHAT the you who
# Hello, I'm a language model, his he great this you master FRI man will a day this
# Hello, I'm a language model, you it saying that when No How are saying. PAN
# Candidate completions
# Hello, I'm a language model,." king? thisEN you the my will the and him
# Hello, I'm a language model, we to it's as is their. he: good?"
# Hello, I'm a language model, is "
#  "and's is that who theEN
# Hello, I'm a language model, I S a a L not their's andOSS that
# Hello, I'm a language model, that as have is's king we for have from and-
# 51 | lr: 5.88e-04 | baseline loss: 5.5938 | candidate loss: 5.6250 | tokens processed: 851,968 | tok/sec: 121,709.90
# 52 | lr: 5.87e-04 | baseline loss: 5.4688 | candidate loss: 5.5312 | tokens processed: 868,352 | tok/sec: 122,663.19
# 53 | lr: 5.86e-04 | baseline loss: 5.5312 | candidate loss: 5.5938 | tokens processed: 884,736 | tok/sec: 140,957.82
# 54 | lr: 5.86e-04 | baseline loss: 5.5938 | candidate loss: 5.6562 | tokens processed: 901,120 | tok/sec: 144,738.10
# 55 | lr: 5.85e-04 | baseline loss: 5.5312 | candidate loss: 5.5938 | tokens processed: 917,504 | tok/sec: 139,707.52
# 56 | lr: 5.84e-04 | baseline loss: 5.5000 | candidate loss: 5.5625 | tokens processed: 933,888 | tok/sec: 32,990.15
# 57 | lr: 5.84e-04 | baseline loss: 5.5000 | candidate loss: 5.5312 | tokens processed: 950,272 | tok/sec: 138,524.15
# 58 | lr: 5.83e-04 | baseline loss: 5.5938 | candidate loss: 5.6562 | tokens processed: 966,656 | tok/sec: 141,296.92
# 59 | lr: 5.82e-04 | baseline loss: 5.5000 | candidate loss: 5.5938 | tokens processed: 983,040 | tok/sec: 141,447.58
# 60 | lr: 5.82e-04 | baseline loss: 5.5938 | candidate loss: 5.6562 | tokens processed: 999,424 | tok/sec: 137,999.51
# 61 | lr: 5.81e-04 | baseline loss: 5.6562 | candidate loss: 5.7188 | tokens processed: 1,015,808 | tok/sec: 142,662.10
# 62 | lr: 5.80e-04 | baseline loss: 5.5000 | candidate loss: 5.5625 | tokens processed: 1,032,192 | tok/sec: 138,996.83
# 63 | lr: 5.79e-04 | baseline loss: 5.4688 | candidate loss: 5.5625 | tokens processed: 1,048,576 | tok/sec: 136,367.65
# 64 | lr: 5.78e-04 | baseline loss: 5.5000 | candidate loss: 5.5625 | tokens processed: 1,064,960 | tok/sec: 139,768.33
# 65 | lr: 5.78e-04 | baseline loss: 5.2812 | candidate loss: 5.3438 | tokens processed: 1,081,344 | tok/sec: 139,424.07
# 66 | lr: 5.77e-04 | baseline loss: 5.5000 | candidate loss: 5.5625 | tokens processed: 1,097,728 | tok/sec: 137,732.32
# 67 | lr: 5.76e-04 | baseline loss: 5.3125 | candidate loss: 5.3750 | tokens processed: 1,114,112 | tok/sec: 140,325.16
# 68 | lr: 5.75e-04 | baseline loss: 5.1562 | candidate loss: 5.1875 | tokens processed: 1,130,496 | tok/sec: 140,187.75
# 69 | lr: 5.74e-04 | baseline loss: 5.3125 | candidate loss: 5.4062 | tokens processed: 1,146,880 | tok/sec: 139,074.19
# 70 | lr: 5.74e-04 | baseline loss: 5.2812 | candidate loss: 5.3438 | tokens processed: 1,163,264 | tok/sec: 136,274.89
# 71 | lr: 5.73e-04 | baseline loss: 5.5312 | candidate loss: 5.5938 | tokens processed: 1,179,648 | tok/sec: 134,760.19
# 72 | lr: 5.72e-04 | baseline loss: 5.4688 | candidate loss: 5.5000 | tokens processed: 1,196,032 | tok/sec: 134,966.10
# 73 | lr: 5.71e-04 | baseline loss: 5.2500 | candidate loss: 5.3438 | tokens processed: 1,212,416 | tok/sec: 34,474.88
# 74 | lr: 5.70e-04 | baseline loss: 5.4062 | candidate loss: 5.5000 | tokens processed: 1,228,800 | tok/sec: 135,316.38
# 75 | lr: 5.69e-04 | baseline loss: 5.4062 | candidate loss: 5.5000 | tokens processed: 1,245,184 | tok/sec: 139,139.52
# 76 | lr: 5.68e-04 | baseline loss: 5.5625 | candidate loss: 5.6562 | tokens processed: 1,261,568 | tok/sec: 134,913.90
# 77 | lr: 5.67e-04 | baseline loss: 5.4375 | candidate loss: 5.5000 | tokens processed: 1,277,952 | tok/sec: 142,325.26
# 78 | lr: 5.66e-04 | baseline loss: 5.5000 | candidate loss: 5.5625 | tokens processed: 1,294,336 | tok/sec: 142,364.77
# 79 | lr: 5.65e-04 | baseline loss: 5.4375 | candidate loss: 5.4688 | tokens processed: 1,310,720 | tok/sec: 137,542.39
# 80 | lr: 5.64e-04 | baseline loss: 5.4062 | candidate loss: 5.4062 | tokens processed: 1,327,104 | tok/sec: 141,473.49
# 81 | lr: 5.63e-04 | baseline loss: 5.4062 | candidate loss: 5.4062 | tokens processed: 1,343,488 | tok/sec: 133,744.40
# 82 | lr: 5.62e-04 | baseline loss: 5.3125 | candidate loss: 5.3438 | tokens processed: 1,359,872 | tok/sec: 135,567.31
# 83 | lr: 5.61e-04 | baseline loss: 5.4375 | candidate loss: 5.4062 | tokens processed: 1,376,256 | tok/sec: 140,012.95
# 84 | lr: 5.60e-04 | baseline loss: 5.3125 | candidate loss: 5.3125 | tokens processed: 1,392,640 | tok/sec: 138,412.55
# 85 | lr: 5.59e-04 | baseline loss: 5.4375 | candidate loss: 5.4688 | tokens processed: 1,409,024 | tok/sec: 138,143.49
# 86 | lr: 5.58e-04 | baseline loss: 5.3750 | candidate loss: 5.4062 | tokens processed: 1,425,408 | tok/sec: 138,894.29
# 87 | lr: 5.57e-04 | baseline loss: 5.3750 | candidate loss: 5.4062 | tokens processed: 1,441,792 | tok/sec: 132,607.02
# 88 | lr: 5.56e-04 | baseline loss: 5.2812 | candidate loss: 5.3125 | tokens processed: 1,458,176 | tok/sec: 132,303.21
# 89 | lr: 5.55e-04 | baseline loss: 5.2188 | candidate loss: 5.2500 | tokens processed: 1,474,560 | tok/sec: 32,338.26
# 90 | lr: 5.54e-04 | baseline loss: 5.3125 | candidate loss: 5.2812 | tokens processed: 1,490,944 | tok/sec: 138,954.67
# 91 | lr: 5.52e-04 | baseline loss: 5.2812 | candidate loss: 5.2500 | tokens processed: 1,507,328 | tok/sec: 135,060.27
# 92 | lr: 5.51e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 1,523,712 | tok/sec: 135,484.99
# 93 | lr: 5.50e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 1,540,096 | tok/sec: 139,547.80
# 94 | lr: 5.49e-04 | baseline loss: 5.3438 | candidate loss: 5.3125 | tokens processed: 1,556,480 | tok/sec: 137,240.78
# 95 | lr: 5.48e-04 | baseline loss: 5.2188 | candidate loss: 5.2188 | tokens processed: 1,572,864 | tok/sec: 137,560.01
# 96 | lr: 5.47e-04 | baseline loss: 5.4688 | candidate loss: 5.4688 | tokens processed: 1,589,248 | tok/sec: 137,871.32
# 97 | lr: 5.45e-04 | baseline loss: 5.4375 | candidate loss: 5.4062 | tokens processed: 1,605,632 | tok/sec: 139,712.92
# 98 | lr: 5.44e-04 | baseline loss: 5.2500 | candidate loss: 5.2188 | tokens processed: 1,622,016 | tok/sec: 135,783.48
# 99 | lr: 5.43e-04 | baseline loss: 5.2500 | candidate loss: 5.2500 | tokens processed: 1,638,400 | tok/sec: 134,550.42
# 100 | lr: 5.42e-04 | baseline loss: 5.2188 | candidate loss: 5.2188 | tokens processed: 1,654,784 | tok/sec: 136,845.32
# baseline valid loss: 5.5625 |candidate valid loss: 5.5312
# Baseline completions:
# Hello, I'm a language model, to these once I she be, was there  PAN part
# Hello, I'm a language model, saw in they again to you who be- his what saw
# Hello, I'm a language model, not in a money aoe to he of  In their
# Hello, I'm a language model, this, one is his will if so him, what you
# Hello, I'm a language model, is againNow this my  of home not one, me
# Candidate completions
# Hello, I'm a language model, that so? How: When On, " and
# Hello, I'm a language model, .... Then your then as I her with this a do have
# Hello, I'm a language model, there you the in you are this and with the this their
# Hello, I'm a language model, my an own you and all had who him, too of
# Hello, I'm a language model, his be their dear as the partRA They be a all
# 101 | lr: 5.40e-04 | baseline loss: 5.1562 | candidate loss: 5.1562 | tokens processed: 1,671,168 | tok/sec: 119,875.72
# 102 | lr: 5.39e-04 | baseline loss: 5.3125 | candidate loss: 5.2812 | tokens processed: 1,687,552 | tok/sec: 129,612.44
# 103 | lr: 5.38e-04 | baseline loss: 5.0000 | candidate loss: 4.9688 | tokens processed: 1,703,936 | tok/sec: 134,014.35
# 104 | lr: 5.37e-04 | baseline loss: 4.9062 | candidate loss: 4.8438 | tokens processed: 1,720,320 | tok/sec: 136,883.21
# 105 | lr: 5.35e-04 | baseline loss: 5.1875 | candidate loss: 5.1562 | tokens processed: 1,736,704 | tok/sec: 34,559.84
# 106 | lr: 5.34e-04 | baseline loss: 5.0625 | candidate loss: 5.0000 | tokens processed: 1,753,088 | tok/sec: 140,441.59
# 107 | lr: 5.33e-04 | baseline loss: 5.4688 | candidate loss: 5.4688 | tokens processed: 1,769,472 | tok/sec: 135,425.98
# 108 | lr: 5.31e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 1,785,856 | tok/sec: 130,723.18
# 109 | lr: 5.30e-04 | baseline loss: 5.0938 | candidate loss: 5.0625 | tokens processed: 1,802,240 | tok/sec: 138,807.04
# 110 | lr: 5.29e-04 | baseline loss: 5.1875 | candidate loss: 5.2188 | tokens processed: 1,818,624 | tok/sec: 142,496.14
# 111 | lr: 5.27e-04 | baseline loss: 5.2188 | candidate loss: 5.2188 | tokens processed: 1,835,008 | tok/sec: 140,576.05
# 112 | lr: 5.26e-04 | baseline loss: 5.3438 | candidate loss: 5.3125 | tokens processed: 1,851,392 | tok/sec: 135,912.65
# 113 | lr: 5.24e-04 | baseline loss: 5.2188 | candidate loss: 5.2188 | tokens processed: 1,867,776 | tok/sec: 133,864.76
# 114 | lr: 5.23e-04 | baseline loss: 5.3750 | candidate loss: 5.3750 | tokens processed: 1,884,160 | tok/sec: 137,547.07
# 115 | lr: 5.22e-04 | baseline loss: 5.1562 | candidate loss: 5.1562 | tokens processed: 1,900,544 | tok/sec: 136,283.54
# 116 | lr: 5.20e-04 | baseline loss: 5.1875 | candidate loss: 5.1562 | tokens processed: 1,916,928 | tok/sec: 137,443.63
# 117 | lr: 5.19e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 1,933,312 | tok/sec: 135,963.75
# 118 | lr: 5.17e-04 | baseline loss: 5.0938 | candidate loss: 5.0938 | tokens processed: 1,949,696 | tok/sec: 137,709.97
# 119 | lr: 5.16e-04 | baseline loss: 5.1562 | candidate loss: 5.1250 | tokens processed: 1,966,080 | tok/sec: 134,106.15
# 120 | lr: 5.14e-04 | baseline loss: 5.1250 | candidate loss: 5.0625 | tokens processed: 1,982,464 | tok/sec: 132,499.63
# 121 | lr: 5.13e-04 | baseline loss: 5.2500 | candidate loss: 5.1875 | tokens processed: 1,998,848 | tok/sec: 132,642.09
# 122 | lr: 5.11e-04 | baseline loss: 5.1562 | candidate loss: 5.1250 | tokens processed: 2,015,232 | tok/sec: 131,569.13
# 123 | lr: 5.10e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 2,031,616 | tok/sec: 138,030.28
# 124 | lr: 5.08e-04 | baseline loss: 5.0938 | candidate loss: 5.0625 | tokens processed: 2,048,000 | tok/sec: 33,069.82
# 125 | lr: 5.07e-04 | baseline loss: 5.0625 | candidate loss: 5.0000 | tokens processed: 2,064,384 | tok/sec: 136,057.97
# 126 | lr: 5.05e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 2,080,768 | tok/sec: 137,242.70
# 127 | lr: 5.04e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 2,097,152 | tok/sec: 136,555.71
# 128 | lr: 5.02e-04 | baseline loss: 5.0000 | candidate loss: 5.0000 | tokens processed: 2,113,536 | tok/sec: 138,909.45
# 129 | lr: 5.01e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 2,129,920 | tok/sec: 136,923.85
# 130 | lr: 4.99e-04 | baseline loss: 5.1250 | candidate loss: 5.0938 | tokens processed: 2,146,304 | tok/sec: 138,928.83
# 131 | lr: 4.98e-04 | baseline loss: 5.0312 | candidate loss: 5.0312 | tokens processed: 2,162,688 | tok/sec: 138,958.89
# 132 | lr: 4.96e-04 | baseline loss: 5.2812 | candidate loss: 5.2500 | tokens processed: 2,179,072 | tok/sec: 138,123.77
# 133 | lr: 4.94e-04 | baseline loss: 5.1250 | candidate loss: 5.0938 | tokens processed: 2,195,456 | tok/sec: 137,894.83
# 134 | lr: 4.93e-04 | baseline loss: 5.0312 | candidate loss: 5.0000 | tokens processed: 2,211,840 | tok/sec: 142,719.87
# 135 | lr: 4.91e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 2,228,224 | tok/sec: 142,866.75
# 136 | lr: 4.90e-04 | baseline loss: 4.9688 | candidate loss: 4.9062 | tokens processed: 2,244,608 | tok/sec: 143,547.47
# 137 | lr: 4.88e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 2,260,992 | tok/sec: 140,092.87
# 138 | lr: 4.86e-04 | baseline loss: 5.0938 | candidate loss: 5.0312 | tokens processed: 2,277,376 | tok/sec: 32,552.13
# 139 | lr: 4.85e-04 | baseline loss: 4.7500 | candidate loss: 4.6875 | tokens processed: 2,293,760 | tok/sec: 137,068.59
# 140 | lr: 4.83e-04 | baseline loss: 4.7188 | candidate loss: 4.6250 | tokens processed: 2,310,144 | tok/sec: 145,514.42
# 141 | lr: 4.81e-04 | baseline loss: 5.0000 | candidate loss: 4.9375 | tokens processed: 2,326,528 | tok/sec: 143,543.87
# 142 | lr: 4.80e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 2,342,912 | tok/sec: 143,115.19
# 143 | lr: 4.78e-04 | baseline loss: 5.3438 | candidate loss: 5.2500 | tokens processed: 2,359,296 | tok/sec: 143,156.63
# 144 | lr: 4.76e-04 | baseline loss: 4.9688 | candidate loss: 4.8750 | tokens processed: 2,375,680 | tok/sec: 137,147.38
# 145 | lr: 4.75e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 2,392,064 | tok/sec: 137,069.14
# 146 | lr: 4.73e-04 | baseline loss: 5.0312 | candidate loss: 5.0000 | tokens processed: 2,408,448 | tok/sec: 141,903.23
# 147 | lr: 4.71e-04 | baseline loss: 5.0000 | candidate loss: 4.9375 | tokens processed: 2,424,832 | tok/sec: 140,576.62
# 148 | lr: 4.70e-04 | baseline loss: 5.1250 | candidate loss: 5.0625 | tokens processed: 2,441,216 | tok/sec: 138,861.73
# 149 | lr: 4.68e-04 | baseline loss: 5.0312 | candidate loss: 5.0312 | tokens processed: 2,457,600 | tok/sec: 137,735.36
# 150 | lr: 4.66e-04 | baseline loss: 5.2500 | candidate loss: 5.1875 | tokens processed: 2,473,984 | tok/sec: 140,870.85
# baseline valid loss: 5.5000 |candidate valid loss: 5.4062
# Baseline completions:
# Hello, I'm a language model, it when why me." Then  As an king. At
# Hello, I'm a language model, too a lifeed have, againCome withCHATWho for
# Hello, I'm a language model, "The king be saidWhat be are no "For
# Hello, I'm a language model, his wife," as he on water him be. My king
# Hello, I'm a language model, my body made his words: Give why will him, then
# Candidate completions
# Hello, I'm a language model, they and for your Brah by Of life "Oh
# Hello, I'm a language model, being it had they," is dear his master of night be
# Hello, I'm a language model, then this After he- The L Brah, his crow
# Hello, I'm a language model, you the You his lion by their crow by a feet is
# Hello, I'm a language model, his crow or be did the he as an who is your
# 151 | lr: 4.64e-04 | baseline loss: 4.8438 | candidate loss: 4.8750 | tokens processed: 2,490,368 | tok/sec: 116,663.91
# 152 | lr: 4.63e-04 | baseline loss: 5.0312 | candidate loss: 5.0000 | tokens processed: 2,506,752 | tok/sec: 127,250.51
# 153 | lr: 4.61e-04 | baseline loss: 5.0312 | candidate loss: 5.0000 | tokens processed: 2,523,136 | tok/sec: 132,169.87
# 154 | lr: 4.59e-04 | baseline loss: 4.9375 | candidate loss: 4.9375 | tokens processed: 2,539,520 | tok/sec: 134,215.89
# 155 | lr: 4.57e-04 | baseline loss: 4.9062 | candidate loss: 4.9062 | tokens processed: 2,555,904 | tok/sec: 137,267.10
# 156 | lr: 4.56e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 2,572,288 | tok/sec: 137,687.62
# 157 | lr: 4.54e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 2,588,672 | tok/sec: 32,590.25
# 158 | lr: 4.52e-04 | baseline loss: 4.9062 | candidate loss: 4.9062 | tokens processed: 2,605,056 | tok/sec: 137,259.69
# 159 | lr: 4.50e-04 | baseline loss: 5.0000 | candidate loss: 4.9688 | tokens processed: 2,621,440 | tok/sec: 139,070.25
# 160 | lr: 4.48e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 2,637,824 | tok/sec: 135,999.53
# 161 | lr: 4.47e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 2,654,208 | tok/sec: 141,675.91
# 162 | lr: 4.45e-04 | baseline loss: 5.0000 | candidate loss: 4.9375 | tokens processed: 2,670,592 | tok/sec: 143,679.23
# 163 | lr: 4.43e-04 | baseline loss: 4.9062 | candidate loss: 4.8750 | tokens processed: 2,686,976 | tok/sec: 142,961.56
# 164 | lr: 4.41e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 2,703,360 | tok/sec: 138,200.16
# 165 | lr: 4.39e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 2,719,744 | tok/sec: 144,433.58
# 166 | lr: 4.37e-04 | baseline loss: 4.9375 | candidate loss: 4.8750 | tokens processed: 2,736,128 | tok/sec: 142,854.87
# 167 | lr: 4.36e-04 | baseline loss: 4.9375 | candidate loss: 4.8750 | tokens processed: 2,752,512 | tok/sec: 141,918.47
# 168 | lr: 4.34e-04 | baseline loss: 5.1250 | candidate loss: 5.0938 | tokens processed: 2,768,896 | tok/sec: 141,225.49
# 169 | lr: 4.32e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 2,785,280 | tok/sec: 139,652.73
# 170 | lr: 4.30e-04 | baseline loss: 4.8438 | candidate loss: 4.7812 | tokens processed: 2,801,664 | tok/sec: 141,258.88
# 171 | lr: 4.28e-04 | baseline loss: 4.9062 | candidate loss: 4.8438 | tokens processed: 2,818,048 | tok/sec: 137,708.86
# 172 | lr: 4.26e-04 | baseline loss: 4.7812 | candidate loss: 4.7500 | tokens processed: 2,834,432 | tok/sec: 137,772.09
# 173 | lr: 4.24e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 2,850,816 | tok/sec: 33,380.49
# 174 | lr: 4.23e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 2,867,200 | tok/sec: 138,226.57
# 175 | lr: 4.21e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 2,883,584 | tok/sec: 135,587.37
# 176 | lr: 4.19e-04 | baseline loss: 4.5312 | candidate loss: 4.4688 | tokens processed: 2,899,968 | tok/sec: 139,523.43
# 177 | lr: 4.17e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 2,916,352 | tok/sec: 141,242.91
# 178 | lr: 4.15e-04 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 2,932,736 | tok/sec: 140,094.87
# 179 | lr: 4.13e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 2,949,120 | tok/sec: 140,841.69
# 180 | lr: 4.11e-04 | baseline loss: 4.7812 | candidate loss: 4.7188 | tokens processed: 2,965,504 | tok/sec: 138,862.29
# 181 | lr: 4.09e-04 | baseline loss: 4.7500 | candidate loss: 4.7812 | tokens processed: 2,981,888 | tok/sec: 140,047.19
# 182 | lr: 4.07e-04 | baseline loss: 4.7812 | candidate loss: 4.7812 | tokens processed: 2,998,272 | tok/sec: 137,130.96
# 183 | lr: 4.05e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 3,014,656 | tok/sec: 138,246.31
# 184 | lr: 4.03e-04 | baseline loss: 4.8750 | candidate loss: 4.8750 | tokens processed: 3,031,040 | tok/sec: 139,325.42
# 185 | lr: 4.01e-04 | baseline loss: 4.9062 | candidate loss: 4.9062 | tokens processed: 3,047,424 | tok/sec: 142,563.54
# 186 | lr: 4.00e-04 | baseline loss: 5.0312 | candidate loss: 5.0312 | tokens processed: 3,063,808 | tok/sec: 138,686.02
# 187 | lr: 3.98e-04 | baseline loss: 4.6562 | candidate loss: 4.7188 | tokens processed: 3,080,192 | tok/sec: 139,123.74
# 188 | lr: 3.96e-04 | baseline loss: 4.9062 | candidate loss: 4.8750 | tokens processed: 3,096,576 | tok/sec: 140,889.62
# 189 | lr: 3.94e-04 | baseline loss: 4.7812 | candidate loss: 4.8125 | tokens processed: 3,112,960 | tok/sec: 137,253.11
# 190 | lr: 3.92e-04 | baseline loss: 4.8125 | candidate loss: 4.7812 | tokens processed: 3,129,344 | tok/sec: 142,864.67
# 191 | lr: 3.90e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 3,145,728 | tok/sec: 35,361.60
# 192 | lr: 3.88e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 3,162,112 | tok/sec: 140,269.02
# 193 | lr: 3.86e-04 | baseline loss: 4.8750 | candidate loss: 4.8438 | tokens processed: 3,178,496 | tok/sec: 141,900.59
# 194 | lr: 3.84e-04 | baseline loss: 4.7500 | candidate loss: 4.7500 | tokens processed: 3,194,880 | tok/sec: 138,133.49
# 195 | lr: 3.82e-04 | baseline loss: 4.7812 | candidate loss: 4.7812 | tokens processed: 3,211,264 | tok/sec: 140,613.15
# 196 | lr: 3.80e-04 | baseline loss: 4.7812 | candidate loss: 4.7500 | tokens processed: 3,227,648 | tok/sec: 140,732.95
# 197 | lr: 3.78e-04 | baseline loss: 4.7500 | candidate loss: 4.6875 | tokens processed: 3,244,032 | tok/sec: 135,633.40
# 198 | lr: 3.76e-04 | baseline loss: 4.7812 | candidate loss: 4.7500 | tokens processed: 3,260,416 | tok/sec: 138,033.05
# 199 | lr: 3.74e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 3,276,800 | tok/sec: 139,022.98
# 200 | lr: 3.72e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 3,293,184 | tok/sec: 139,006.67
# baseline valid loss: 5.4375 |candidate valid loss: 5.4375
# Baseline completions:
# Hello, I'm a language model, who more were men should life. Yet her saidman am
# Hello, I'm a language model, O son or birds no heart his name is other wise from
# Hello, I'm a language model, theyives. Yes; On her a friends THEEye
# Hello, I'm a language model, but a hundred do his certain way when food ers are
# Hello, I'm a language model, the very birds I why When them come after a Brah
# Candidate completions
# Hello, I'm a language model, who repliedin I started?" AndEar said OF story-
# Hello, I'm a language model, your life had Liveers and when one and he as her
# Hello, I'm a language model, so of the master in there and youNINGCHAT thought me
# Hello, I'm a language model, sayingEN friends; AsFriend your rest into a holy men
# Hello, I'm a language model, in do as it! There; Pr took a part
# 201 | lr: 3.70e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 3,309,568 | tok/sec: 118,893.27
# 202 | lr: 3.68e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 3,325,952 | tok/sec: 123,292.83
# 203 | lr: 3.66e-04 | baseline loss: 4.8438 | candidate loss: 4.7812 | tokens processed: 3,342,336 | tok/sec: 137,925.00
# 204 | lr: 3.64e-04 | baseline loss: 4.9375 | candidate loss: 4.9062 | tokens processed: 3,358,720 | tok/sec: 138,094.35
# 205 | lr: 3.62e-04 | baseline loss: 4.7812 | candidate loss: 4.7188 | tokens processed: 3,375,104 | tok/sec: 139,149.66
# 206 | lr: 3.60e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 3,391,488 | tok/sec: 138,658.87
# 207 | lr: 3.58e-04 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 3,407,872 | tok/sec: 135,335.83
# 208 | lr: 3.56e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,424,256 | tok/sec: 138,235.74
# 209 | lr: 3.54e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,440,640 | tok/sec: 136,987.17
# 210 | lr: 3.52e-04 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 3,457,024 | tok/sec: 32,386.46
# 211 | lr: 3.50e-04 | baseline loss: 4.3438 | candidate loss: 4.3125 | tokens processed: 3,473,408 | tok/sec: 138,003.94
# 212 | lr: 3.48e-04 | baseline loss: 4.4062 | candidate loss: 4.3750 | tokens processed: 3,489,792 | tok/sec: 142,684.31
# 213 | lr: 3.46e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,506,176 | tok/sec: 137,918.36
# 214 | lr: 3.44e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 3,522,560 | tok/sec: 137,340.34
# 215 | lr: 3.42e-04 | baseline loss: 4.9688 | candidate loss: 4.9688 | tokens processed: 3,538,944 | tok/sec: 136,981.16
# 216 | lr: 3.40e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 3,555,328 | tok/sec: 133,857.20
# 217 | lr: 3.38e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,571,712 | tok/sec: 135,449.74
# 218 | lr: 3.36e-04 | baseline loss: 4.6562 | candidate loss: 4.6562 | tokens processed: 3,588,096 | tok/sec: 134,077.89
# 219 | lr: 3.34e-04 | baseline loss: 4.8125 | candidate loss: 4.7812 | tokens processed: 3,604,480 | tok/sec: 140,334.04
# 220 | lr: 3.32e-04 | baseline loss: 4.7812 | candidate loss: 4.7188 | tokens processed: 3,620,864 | tok/sec: 141,535.27
# 221 | lr: 3.30e-04 | baseline loss: 4.8438 | candidate loss: 4.8438 | tokens processed: 3,637,248 | tok/sec: 139,040.42
# 222 | lr: 3.28e-04 | baseline loss: 4.8750 | candidate loss: 4.8750 | tokens processed: 3,653,632 | tok/sec: 144,704.87
# 223 | lr: 3.26e-04 | baseline loss: 4.6250 | candidate loss: 4.6562 | tokens processed: 3,670,016 | tok/sec: 143,271.24
# 224 | lr: 3.24e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,686,400 | tok/sec: 33,948.57
# 225 | lr: 3.22e-04 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 3,702,784 | tok/sec: 139,455.76
# 226 | lr: 3.20e-04 | baseline loss: 4.6562 | candidate loss: 4.6562 | tokens processed: 3,719,168 | tok/sec: 143,550.47
# 227 | lr: 3.18e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,735,552 | tok/sec: 142,795.50
# 228 | lr: 3.16e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,751,936 | tok/sec: 139,767.76
# 229 | lr: 3.14e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,768,320 | tok/sec: 145,643.33
# 230 | lr: 3.12e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 3,784,704 | tok/sec: 135,364.36
# 231 | lr: 3.10e-04 | baseline loss: 4.6875 | candidate loss: 4.6562 | tokens processed: 3,801,088 | tok/sec: 141,219.98
# 232 | lr: 3.08e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 3,817,472 | tok/sec: 140,530.05
# 233 | lr: 3.06e-04 | baseline loss: 4.6250 | candidate loss: 4.6562 | tokens processed: 3,833,856 | tok/sec: 137,669.96
# 234 | lr: 3.04e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 3,850,240 | tok/sec: 138,735.30
# 235 | lr: 3.02e-04 | baseline loss: 4.6562 | candidate loss: 4.6562 | tokens processed: 3,866,624 | tok/sec: 139,802.45
# 236 | lr: 3.00e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,883,008 | tok/sec: 138,088.52
# 237 | lr: 2.98e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,899,392 | tok/sec: 140,420.07
# 238 | lr: 2.96e-04 | baseline loss: 4.6250 | candidate loss: 4.6562 | tokens processed: 3,915,776 | tok/sec: 133,554.13
# 239 | lr: 2.94e-04 | baseline loss: 4.7188 | candidate loss: 4.7188 | tokens processed: 3,932,160 | tok/sec: 135,366.23
# 240 | lr: 2.92e-04 | baseline loss: 4.8125 | candidate loss: 4.8125 | tokens processed: 3,948,544 | tok/sec: 33,428.81
# 241 | lr: 2.90e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 3,964,928 | tok/sec: 135,425.71
# 242 | lr: 2.88e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 3,981,312 | tok/sec: 139,454.06
# 243 | lr: 2.86e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 3,997,696 | tok/sec: 134,488.81
# 244 | lr: 2.84e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 4,014,080 | tok/sec: 138,910.85
# 245 | lr: 2.82e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 4,030,464 | tok/sec: 133,331.80
# 246 | lr: 2.80e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 4,046,848 | tok/sec: 139,069.97
# 247 | lr: 2.78e-04 | baseline loss: 4.1875 | candidate loss: 4.1875 | tokens processed: 4,063,232 | tok/sec: 139,889.82
# 248 | lr: 2.76e-04 | baseline loss: 4.3750 | candidate loss: 4.3438 | tokens processed: 4,079,616 | tok/sec: 143,253.62
# 249 | lr: 2.74e-04 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 4,096,000 | tok/sec: 141,351.27
# 250 | lr: 2.72e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 4,112,384 | tok/sec: 142,016.13
# baseline valid loss: 5.4375 |candidate valid loss: 5.3438
# Baseline completions:
# Hello, I'm a language model, if hearing nothing by heart with dear me not not a life
# Hello, I'm a language model, her man! Yet then in man?" Then you she have
# Hello, I'm a language model, so?" And even you must you the we  For to
# Hello, I'm a language model, a wife by your crocodentle." His brother the rogue in
# Hello, I'm a language model, she gave wasile named (over should thought was eat
# Candidate completions
# Hello, I'm a language model, she does yet with Theodore with a forest! And I do
# Hello, I'm a language model, since there do they give him no home in his forest said
# Hello, I'm a language model, my heart. Indeed." His home in Live
# A name
# Hello, I'm a language model, but the One life and for by Live told he in you
# Hello, I'm a language model, a wife were well from so whenCr?" Who said in
# 251 | lr: 2.70e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 4,128,768 | tok/sec: 120,886.03
# 252 | lr: 2.68e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 4,145,152 | tok/sec: 129,307.09
# 253 | lr: 2.66e-04 | baseline loss: 4.5312 | candidate loss: 4.5625 | tokens processed: 4,161,536 | tok/sec: 136,744.29
# 254 | lr: 2.64e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 4,177,920 | tok/sec: 33,462.74
# 255 | lr: 2.62e-04 | baseline loss: 4.7500 | candidate loss: 4.7500 | tokens processed: 4,194,304 | tok/sec: 142,690.24
# 256 | lr: 2.60e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 4,210,688 | tok/sec: 138,191.54
# 257 | lr: 2.59e-04 | baseline loss: 4.7812 | candidate loss: 4.7812 | tokens processed: 4,227,072 | tok/sec: 145,633.46
# 258 | lr: 2.57e-04 | baseline loss: 4.6875 | candidate loss: 4.7188 | tokens processed: 4,243,456 | tok/sec: 142,941.63
# 259 | lr: 2.55e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 4,259,840 | tok/sec: 145,519.66
# 260 | lr: 2.53e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,276,224 | tok/sec: 140,334.90
# 261 | lr: 2.51e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 4,292,608 | tok/sec: 136,667.87
# 262 | lr: 2.49e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 4,308,992 | tok/sec: 139,781.98
# 263 | lr: 2.47e-04 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 4,325,376 | tok/sec: 138,540.63
# 264 | lr: 2.45e-04 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 4,341,760 | tok/sec: 139,531.93
# 265 | lr: 2.43e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 4,358,144 | tok/sec: 140,521.72
# 266 | lr: 2.41e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 4,374,528 | tok/sec: 140,370.74
# 267 | lr: 2.39e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 4,390,912 | tok/sec: 137,179.41
# 268 | lr: 2.37e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 4,407,296 | tok/sec: 133,182.44
# 269 | lr: 2.36e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 4,423,680 | tok/sec: 134,181.04
# 270 | lr: 2.34e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 4,440,064 | tok/sec: 131,406.85
# 271 | lr: 2.32e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 4,456,448 | tok/sec: 134,898.28
# 272 | lr: 2.30e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 4,472,832 | tok/sec: 33,522.38
# 273 | lr: 2.28e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 4,489,216 | tok/sec: 138,417.57
# 274 | lr: 2.26e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,505,600 | tok/sec: 136,519.09
# 275 | lr: 2.24e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 4,521,984 | tok/sec: 136,449.69
# 276 | lr: 2.23e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 4,538,368 | tok/sec: 136,924.66
# 277 | lr: 2.21e-04 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 4,554,752 | tok/sec: 141,359.12
# 278 | lr: 2.19e-04 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 4,571,136 | tok/sec: 140,842.84
# 279 | lr: 2.17e-04 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 4,587,520 | tok/sec: 138,150.98
# 280 | lr: 2.15e-04 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 4,603,904 | tok/sec: 140,027.79
# 281 | lr: 2.13e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,620,288 | tok/sec: 142,044.31
# 282 | lr: 2.12e-04 | baseline loss: 4.2812 | candidate loss: 4.2500 | tokens processed: 4,636,672 | tok/sec: 138,019.46
# 283 | lr: 2.10e-04 | baseline loss: 4.0938 | candidate loss: 4.0625 | tokens processed: 4,653,056 | tok/sec: 138,430.39
# 284 | lr: 2.08e-04 | baseline loss: 4.3438 | candidate loss: 4.3125 | tokens processed: 4,669,440 | tok/sec: 139,368.09
# 285 | lr: 2.06e-04 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 4,685,824 | tok/sec: 126,419.47
# 286 | lr: 2.04e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 4,702,208 | tok/sec: 134,377.83
# 287 | lr: 2.03e-04 | baseline loss: 4.5938 | candidate loss: 4.5312 | tokens processed: 4,718,592 | tok/sec: 130,032.81
# 288 | lr: 2.01e-04 | baseline loss: 4.4062 | candidate loss: 4.3750 | tokens processed: 4,734,976 | tok/sec: 139,209.42
# 289 | lr: 1.99e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 4,751,360 | tok/sec: 31,457.72
# 290 | lr: 1.97e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 4,767,744 | tok/sec: 136,262.19
# 291 | lr: 1.96e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 4,784,128 | tok/sec: 133,297.40
# 292 | lr: 1.94e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,800,512 | tok/sec: 134,942.25
# 293 | lr: 1.92e-04 | baseline loss: 4.7188 | candidate loss: 4.6875 | tokens processed: 4,816,896 | tok/sec: 138,063.00
# 294 | lr: 1.90e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,833,280 | tok/sec: 134,886.36
# 295 | lr: 1.89e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 4,849,664 | tok/sec: 141,091.82
# 296 | lr: 1.87e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 4,866,048 | tok/sec: 137,248.18
# 297 | lr: 1.85e-04 | baseline loss: 4.4688 | candidate loss: 4.4375 | tokens processed: 4,882,432 | tok/sec: 138,252.99
# 298 | lr: 1.84e-04 | baseline loss: 4.5312 | candidate loss: 4.4688 | tokens processed: 4,898,816 | tok/sec: 135,152.18
# 299 | lr: 1.82e-04 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 4,915,200 | tok/sec: 141,045.20
# 300 | lr: 1.80e-04 | baseline loss: 4.5938 | candidate loss: 4.6250 | tokens processed: 4,931,584 | tok/sec: 139,418.98
# baseline valid loss: 5.3438 |candidate valid loss: 5.3438
# Baseline completions:
# Hello, I'm a language model, when heaven up all your day the city — king saidc
# Hello, I'm a language model, one day like our gods and againlrou. Tell no
# Hello, I'm a language model, if one the waterorings for good heardDS The fish
# Hello, I'm a language model, they while home the otherings two l My the same FRI
# Hello, I'm a language model, then all great great we by last for them I are
# Candidate completions
# Hello, I'm a language model, so friends replied? BrahAnd so for mind. For what
# Hello, I'm a language model, indeed! Indeed or to you take." As this for love
# Hello, I'm a language model, in him. These he- You must eat To master
# Hello, I'm a language model, you, asked it was we went here I will, I
# Hello, I'm a language model, then like? There does is some do — since the This
# 301 | lr: 1.79e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 4,947,968 | tok/sec: 115,869.79
# 302 | lr: 1.77e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 4,964,352 | tok/sec: 124,599.93
# 303 | lr: 1.75e-04 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 4,980,736 | tok/sec: 35,131.72
# 304 | lr: 1.74e-04 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 4,997,120 | tok/sec: 136,923.30
# 305 | lr: 1.72e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 5,013,504 | tok/sec: 138,286.65
# 306 | lr: 1.70e-04 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 5,029,888 | tok/sec: 134,850.10
# 307 | lr: 1.69e-04 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 5,046,272 | tok/sec: 133,068.71
# 308 | lr: 1.67e-04 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 5,062,656 | tok/sec: 138,456.89
# 309 | lr: 1.66e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 5,079,040 | tok/sec: 140,056.61
# 310 | lr: 1.64e-04 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 5,095,424 | tok/sec: 133,730.86
# 311 | lr: 1.62e-04 | baseline loss: 4.6875 | candidate loss: 4.6562 | tokens processed: 5,111,808 | tok/sec: 141,396.06
# 312 | lr: 1.61e-04 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 5,128,192 | tok/sec: 136,991.27
# 313 | lr: 1.59e-04 | baseline loss: 4.4062 | candidate loss: 4.4062 | tokens processed: 5,144,576 | tok/sec: 138,895.13
# 314 | lr: 1.58e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 5,160,960 | tok/sec: 137,577.91
# 315 | lr: 1.56e-04 | baseline loss: 4.4375 | candidate loss: 4.4375 | tokens processed: 5,177,344 | tok/sec: 141,647.59
# 316 | lr: 1.55e-04 | baseline loss: 4.4375 | candidate loss: 4.4375 | tokens processed: 5,193,728 | tok/sec: 137,758.28
# 317 | lr: 1.53e-04 | baseline loss: 4.5625 | candidate loss: 4.5625 | tokens processed: 5,210,112 | tok/sec: 137,886.81
# 318 | lr: 1.52e-04 | baseline loss: 4.1562 | candidate loss: 4.1562 | tokens processed: 5,226,496 | tok/sec: 136,848.59
# 319 | lr: 1.50e-04 | baseline loss: 4.0938 | candidate loss: 4.1250 | tokens processed: 5,242,880 | tok/sec: 131,221.42
# 320 | lr: 1.49e-04 | baseline loss: 4.4062 | candidate loss: 4.4062 | tokens processed: 5,259,264 | tok/sec: 134,407.53
# 321 | lr: 1.47e-04 | baseline loss: 4.3125 | candidate loss: 4.3438 | tokens processed: 5,275,648 | tok/sec: 138,915.06
# 322 | lr: 1.46e-04 | baseline loss: 4.6562 | candidate loss: 4.7188 | tokens processed: 5,292,032 | tok/sec: 137,699.48
# 323 | lr: 1.44e-04 | baseline loss: 4.4375 | candidate loss: 4.5000 | tokens processed: 5,308,416 | tok/sec: 32,512.34
# 324 | lr: 1.43e-04 | baseline loss: 4.3438 | candidate loss: 4.4375 | tokens processed: 5,324,800 | tok/sec: 132,796.90
# 325 | lr: 1.41e-04 | baseline loss: 4.4375 | candidate loss: 4.5312 | tokens processed: 5,341,184 | tok/sec: 132,064.20
# 326 | lr: 1.40e-04 | baseline loss: 4.4375 | candidate loss: 4.5312 | tokens processed: 5,357,568 | tok/sec: 134,349.19
# 327 | lr: 1.38e-04 | baseline loss: 4.5625 | candidate loss: 4.6562 | tokens processed: 5,373,952 | tok/sec: 135,744.86
# 328 | lr: 1.37e-04 | baseline loss: 4.5312 | candidate loss: 4.6562 | tokens processed: 5,390,336 | tok/sec: 130,453.68
# 329 | lr: 1.36e-04 | baseline loss: 4.6562 | candidate loss: 4.8125 | tokens processed: 5,406,720 | tok/sec: 142,616.80
# 330 | lr: 1.34e-04 | baseline loss: 4.4062 | candidate loss: 4.5000 | tokens processed: 5,423,104 | tok/sec: 131,720.44
# 331 | lr: 1.33e-04 | baseline loss: 4.4688 | candidate loss: 4.5625 | tokens processed: 5,439,488 | tok/sec: 136,675.76
# 332 | lr: 1.31e-04 | baseline loss: 4.5000 | candidate loss: 4.5938 | tokens processed: 5,455,872 | tok/sec: 136,078.98
# 333 | lr: 1.30e-04 | baseline loss: 4.4062 | candidate loss: 4.5000 | tokens processed: 5,472,256 | tok/sec: 134,671.19
# 334 | lr: 1.29e-04 | baseline loss: 4.4062 | candidate loss: 4.5000 | tokens processed: 5,488,640 | tok/sec: 133,665.57
# 335 | lr: 1.27e-04 | baseline loss: 4.3750 | candidate loss: 4.4688 | tokens processed: 5,505,024 | tok/sec: 137,568.54
# 336 | lr: 1.26e-04 | baseline loss: 4.5312 | candidate loss: 4.6250 | tokens processed: 5,521,408 | tok/sec: 137,159.97
# 337 | lr: 1.25e-04 | baseline loss: 4.4062 | candidate loss: 4.5000 | tokens processed: 5,537,792 | tok/sec: 134,122.11
# 338 | lr: 1.23e-04 | baseline loss: 4.5625 | candidate loss: 4.6562 | tokens processed: 5,554,176 | tok/sec: 135,365.16
# 339 | lr: 1.22e-04 | baseline loss: 4.4375 | candidate loss: 4.5000 | tokens processed: 5,570,560 | tok/sec: 135,410.50
# 340 | lr: 1.21e-04 | baseline loss: 4.3125 | candidate loss: 4.4062 | tokens processed: 5,586,944 | tok/sec: 33,382.39
# 341 | lr: 1.20e-04 | baseline loss: 4.4688 | candidate loss: 4.5625 | tokens processed: 5,603,328 | tok/sec: 140,320.29
# 342 | lr: 1.18e-04 | baseline loss: 4.4375 | candidate loss: 4.5312 | tokens processed: 5,619,712 | tok/sec: 136,875.85
# 343 | lr: 1.17e-04 | baseline loss: 4.4062 | candidate loss: 4.5000 | tokens processed: 5,636,096 | tok/sec: 137,848.36
# 344 | lr: 1.16e-04 | baseline loss: 4.4688 | candidate loss: 4.5312 | tokens processed: 5,652,480 | tok/sec: 140,705.57
# 345 | lr: 1.15e-04 | baseline loss: 4.5000 | candidate loss: 4.5938 | tokens processed: 5,668,864 | tok/sec: 140,224.08
# 346 | lr: 1.13e-04 | baseline loss: 4.4375 | candidate loss: 4.5312 | tokens processed: 5,685,248 | tok/sec: 134,084.95
# 347 | lr: 1.12e-04 | baseline loss: 4.6875 | candidate loss: 4.7500 | tokens processed: 5,701,632 | tok/sec: 130,289.20
# 348 | lr: 1.11e-04 | baseline loss: 4.5312 | candidate loss: 4.5938 | tokens processed: 5,718,016 | tok/sec: 138,379.38
# 349 | lr: 1.10e-04 | baseline loss: 4.3438 | candidate loss: 4.4375 | tokens processed: 5,734,400 | tok/sec: 136,933.40
# 350 | lr: 1.09e-04 | baseline loss: 4.4375 | candidate loss: 4.5312 | tokens processed: 5,750,784 | tok/sec: 138,448.24
# baseline valid loss: 5.3125 |candidate valid loss: 5.3125
# Baseline completions:
# Hello, I'm a language model, for mind by him wife heard this — he said the forest
# Hello, I'm a language model, no your eyes byT this have Live," thoughtsings
# Hello, I'm a language model, so it the rabbit-F repliedin mind. The turtle
# Hello, I'm a language model, my good time and so? "Then there this! He
# Hello, I'm a language model, in fire should to love. Come here so — king replied
# Candidate completions
# Hello, I'm a language model, who set they did; "I went Victor saidEN house
# Hello, I'm a language model, like-sl THE Itupon these good to his forest time
# Hello, I'm a language model, but no dear in this an man said." upon what
# Hello, I'm a language model, his friend lived he had, is her:
# That are
# Hello, I'm a language model, my home a monkey." By friend answered tellsis their
# 351 | lr: 1.08e-04 | baseline loss: 4.3438 | candidate loss: 4.4062 | tokens processed: 5,767,168 | tok/sec: 122,783.95
# 352 | lr: 1.06e-04 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 5,783,552 | tok/sec: 116,557.85
# 353 | lr: 1.05e-04 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 5,799,936 | tok/sec: 130,548.35
# 354 | lr: 1.04e-04 | baseline loss: 4.0625 | candidate loss: 4.1250 | tokens processed: 5,816,320 | tok/sec: 32,156.88
# 355 | lr: 1.03e-04 | baseline loss: 4.0000 | candidate loss: 4.0625 | tokens processed: 5,832,704 | tok/sec: 135,814.88
# 356 | lr: 1.02e-04 | baseline loss: 4.3750 | candidate loss: 4.3750 | tokens processed: 5,849,088 | tok/sec: 134,100.65
# 357 | lr: 1.01e-04 | baseline loss: 4.2812 | candidate loss: 4.3125 | tokens processed: 5,865,472 | tok/sec: 134,300.09
# 358 | lr: 9.99e-05 | baseline loss: 4.6875 | candidate loss: 4.6875 | tokens processed: 5,881,856 | tok/sec: 133,324.30
# 359 | lr: 9.89e-05 | baseline loss: 4.3750 | candidate loss: 4.3750 | tokens processed: 5,898,240 | tok/sec: 126,361.59
# 360 | lr: 9.79e-05 | baseline loss: 4.3438 | candidate loss: 4.3750 | tokens processed: 5,914,624 | tok/sec: 135,450.81
# 361 | lr: 9.68e-05 | baseline loss: 4.4375 | candidate loss: 4.4688 | tokens processed: 5,931,008 | tok/sec: 136,990.45
# 362 | lr: 9.58e-05 | baseline loss: 4.4375 | candidate loss: 4.5000 | tokens processed: 5,947,392 | tok/sec: 136,951.95
# 363 | lr: 9.48e-05 | baseline loss: 4.5000 | candidate loss: 4.5312 | tokens processed: 5,963,776 | tok/sec: 137,898.98
# 364 | lr: 9.39e-05 | baseline loss: 4.5312 | candidate loss: 4.5625 | tokens processed: 5,980,160 | tok/sec: 135,030.81
# 365 | lr: 9.29e-05 | baseline loss: 4.6562 | candidate loss: 4.7188 | tokens processed: 5,996,544 | tok/sec: 138,099.34
# 366 | lr: 9.19e-05 | baseline loss: 4.3125 | candidate loss: 4.3750 | tokens processed: 6,012,928 | tok/sec: 134,867.57
# 367 | lr: 9.10e-05 | baseline loss: 4.4688 | candidate loss: 4.5312 | tokens processed: 6,029,312 | tok/sec: 138,479.49
# 368 | lr: 9.01e-05 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 6,045,696 | tok/sec: 137,961.27
# 369 | lr: 8.92e-05 | baseline loss: 4.4062 | candidate loss: 4.4062 | tokens processed: 6,062,080 | tok/sec: 135,934.43
# 370 | lr: 8.83e-05 | baseline loss: 4.3438 | candidate loss: 4.4062 | tokens processed: 6,078,464 | tok/sec: 34,493.59
# 371 | lr: 8.74e-05 | baseline loss: 4.3750 | candidate loss: 4.4375 | tokens processed: 6,094,848 | tok/sec: 135,452.94
# 372 | lr: 8.65e-05 | baseline loss: 4.5000 | candidate loss: 4.5625 | tokens processed: 6,111,232 | tok/sec: 139,918.59
# 373 | lr: 8.56e-05 | baseline loss: 4.3438 | candidate loss: 4.4062 | tokens processed: 6,127,616 | tok/sec: 137,121.65
# 374 | lr: 8.48e-05 | baseline loss: 4.5000 | candidate loss: 4.5312 | tokens processed: 6,144,000 | tok/sec: 140,168.88
# 375 | lr: 8.39e-05 | baseline loss: 4.3750 | candidate loss: 4.4375 | tokens processed: 6,160,384 | tok/sec: 134,641.64
# 376 | lr: 8.31e-05 | baseline loss: 4.3125 | candidate loss: 4.3438 | tokens processed: 6,176,768 | tok/sec: 134,771.29
# 377 | lr: 8.23e-05 | baseline loss: 4.4375 | candidate loss: 4.4688 | tokens processed: 6,193,152 | tok/sec: 134,674.09
# 378 | lr: 8.15e-05 | baseline loss: 4.4062 | candidate loss: 4.4688 | tokens processed: 6,209,536 | tok/sec: 134,035.00
# 379 | lr: 8.07e-05 | baseline loss: 4.3750 | candidate loss: 4.4062 | tokens processed: 6,225,920 | tok/sec: 138,113.50
# 380 | lr: 8.00e-05 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 6,242,304 | tok/sec: 137,094.30
# 381 | lr: 7.92e-05 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 6,258,688 | tok/sec: 136,112.40
# 382 | lr: 7.85e-05 | baseline loss: 4.4375 | candidate loss: 4.4688 | tokens processed: 6,275,072 | tok/sec: 136,811.54
# 383 | lr: 7.78e-05 | baseline loss: 4.6250 | candidate loss: 4.6250 | tokens processed: 6,291,456 | tok/sec: 139,618.68
# 384 | lr: 7.71e-05 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 6,307,840 | tok/sec: 136,088.41
# 385 | lr: 7.64e-05 | baseline loss: 4.3125 | candidate loss: 4.3750 | tokens processed: 6,324,224 | tok/sec: 140,639.92
# 386 | lr: 7.57e-05 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 6,340,608 | tok/sec: 138,435.13
# 387 | lr: 7.50e-05 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 6,356,992 | tok/sec: 139,596.27
# 388 | lr: 7.44e-05 | baseline loss: 4.4375 | candidate loss: 4.4375 | tokens processed: 6,373,376 | tok/sec: 140,681.38
# 389 | lr: 7.37e-05 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 6,389,760 | tok/sec: 135,045.94
# 390 | lr: 7.31e-05 | baseline loss: 4.0000 | candidate loss: 4.0000 | tokens processed: 6,406,144 | tok/sec: 32,995.79
# 391 | lr: 7.25e-05 | baseline loss: 4.0625 | candidate loss: 4.0938 | tokens processed: 6,422,528 | tok/sec: 139,385.05
# 392 | lr: 7.19e-05 | baseline loss: 4.3125 | candidate loss: 4.3125 | tokens processed: 6,438,912 | tok/sec: 138,118.22
# 393 | lr: 7.13e-05 | baseline loss: 4.2812 | candidate loss: 4.2812 | tokens processed: 6,455,296 | tok/sec: 138,064.94
# 394 | lr: 7.07e-05 | baseline loss: 4.7188 | candidate loss: 4.6875 | tokens processed: 6,471,680 | tok/sec: 137,083.36
# 395 | lr: 7.02e-05 | baseline loss: 4.3125 | candidate loss: 4.3125 | tokens processed: 6,488,064 | tok/sec: 134,023.50
# 396 | lr: 6.96e-05 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 6,504,448 | tok/sec: 135,284.95
# 397 | lr: 6.91e-05 | baseline loss: 4.4062 | candidate loss: 4.3750 | tokens processed: 6,520,832 | tok/sec: 140,305.68
# 398 | lr: 6.86e-05 | baseline loss: 4.5312 | candidate loss: 4.5312 | tokens processed: 6,537,216 | tok/sec: 138,074.65
# 399 | lr: 6.81e-05 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 6,553,600 | tok/sec: 140,565.12
# 400 | lr: 6.76e-05 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 6,569,984 | tok/sec: 142,937.17
# baseline valid loss: 5.3125 |candidate valid loss: 5.2500
# Baseline completions:
# Hello, I'm a language model, they at kings has forest! And why of dear the and
# Hello, I'm a language model, since if with WIN (or) you no a elephantling
# Hello, I'm a language model, then a king went a heart," went an  You were
# Hello, I'm a language model, if a day to her; FRI carered, well?
# Hello, I'm a language model, you as there is in A old two quite a crow
# Candidate completions
# Hello, I'm a language model, in men I went or you, it with ?" To
# Hello, I'm a language model, though all friends are wANT shrewm of a very business
# Hello, I'm a language model, for an king be. When it: not  'Who
# Hello, I'm a language model, his old mind and said home on Slow — dear power;
# Hello, I'm a language model, you shall eat your forest. Here they would once, as
# 401 | lr: 6.72e-05 | baseline loss: 4.6562 | candidate loss: 4.6562 | tokens processed: 6,586,368 | tok/sec: 120,725.69
# 402 | lr: 6.67e-05 | baseline loss: 4.3125 | candidate loss: 4.3125 | tokens processed: 6,602,752 | tok/sec: 119,229.09
# 403 | lr: 6.63e-05 | baseline loss: 4.5000 | candidate loss: 4.5000 | tokens processed: 6,619,136 | tok/sec: 140,706.15
# 404 | lr: 6.58e-05 | baseline loss: 4.4375 | candidate loss: 4.4375 | tokens processed: 6,635,520 | tok/sec: 31,806.75
# 405 | lr: 6.54e-05 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 6,651,904 | tok/sec: 138,419.52
# 406 | lr: 6.50e-05 | baseline loss: 4.3438 | candidate loss: 4.3438 | tokens processed: 6,668,288 | tok/sec: 137,974.57
# 407 | lr: 6.47e-05 | baseline loss: 4.4375 | candidate loss: 4.4375 | tokens processed: 6,684,672 | tok/sec: 137,166.54
# 408 | lr: 6.43e-05 | baseline loss: 4.4688 | candidate loss: 4.5000 | tokens processed: 6,701,056 | tok/sec: 140,688.29
# 409 | lr: 6.39e-05 | baseline loss: 4.3438 | candidate loss: 4.3750 | tokens processed: 6,717,440 | tok/sec: 131,852.62
# 410 | lr: 6.36e-05 | baseline loss: 4.4375 | candidate loss: 4.4688 | tokens processed: 6,733,824 | tok/sec: 134,821.53
# 411 | lr: 6.33e-05 | baseline loss: 4.4062 | candidate loss: 4.4062 | tokens processed: 6,750,208 | tok/sec: 135,585.77
# 412 | lr: 6.30e-05 | baseline loss: 4.3750 | candidate loss: 4.3750 | tokens processed: 6,766,592 | tok/sec: 135,098.77
# 413 | lr: 6.27e-05 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 6,782,976 | tok/sec: 135,057.88
# 414 | lr: 6.24e-05 | baseline loss: 4.4062 | candidate loss: 4.4375 | tokens processed: 6,799,360 | tok/sec: 136,654.83
# 415 | lr: 6.22e-05 | baseline loss: 4.3750 | candidate loss: 4.3438 | tokens processed: 6,815,744 | tok/sec: 134,694.95
# 416 | lr: 6.19e-05 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 6,832,128 | tok/sec: 136,411.23
# 417 | lr: 6.17e-05 | baseline loss: 4.4688 | candidate loss: 4.4688 | tokens processed: 6,848,512 | tok/sec: 131,008.28
# 418 | lr: 6.15e-05 | baseline loss: 4.5938 | candidate loss: 4.5312 | tokens processed: 6,864,896 | tok/sec: 137,576.81
# 419 | lr: 6.13e-05 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 6,881,280 | tok/sec: 141,345.46
# 420 | lr: 6.11e-05 | baseline loss: 4.4688 | candidate loss: 4.4375 | tokens processed: 6,897,664 | tok/sec: 135,518.65
# 421 | lr: 6.09e-05 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 6,914,048 | tok/sec: 140,517.41
# 422 | lr: 6.07e-05 | baseline loss: 4.4062 | candidate loss: 4.3750 | tokens processed: 6,930,432 | tok/sec: 137,145.74
# 423 | lr: 6.06e-05 | baseline loss: 4.3125 | candidate loss: 4.2812 | tokens processed: 6,946,816 | tok/sec: 34,701.72
# 424 | lr: 6.05e-05 | baseline loss: 4.4688 | candidate loss: 4.4062 | tokens processed: 6,963,200 | tok/sec: 133,560.62
# 425 | lr: 6.04e-05 | baseline loss: 4.4062 | candidate loss: 4.3750 | tokens processed: 6,979,584 | tok/sec: 138,111.83
# 426 | lr: 6.03e-05 | baseline loss: 4.0000 | candidate loss: 3.9844 | tokens processed: 6,995,968 | tok/sec: 137,004.38
# 427 | lr: 6.02e-05 | baseline loss: 4.1250 | candidate loss: 4.1250 | tokens processed: 7,012,352 | tok/sec: 139,235.93
# 428 | lr: 6.01e-05 | baseline loss: 4.3125 | candidate loss: 4.2812 | tokens processed: 7,028,736 | tok/sec: 140,287.92
# 429 | lr: 6.01e-05 | baseline loss: 4.3125 | candidate loss: 4.3125 | tokens processed: 7,045,120 | tok/sec: 140,191.76
# 430 | lr: 6.00e-05 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 7,061,504 | tok/sec: 138,644.89
# 431 | lr: 6.00e-05 | baseline loss: 4.2500 | candidate loss: 4.2812 | tokens processed: 7,077,888 | tok/sec: 136,702.40
# baseline valid loss: 5.3125 | candidate valid loss: 5.3125
# baseline completions
# Hello, I'm a language model, they thereman named maned the part I said: for
# Hello, I'm a language model, that no long?" rabbit saidAnd I do you will me
# Hello, I'm a language model, for their wife asked his jack him it on the other do
# Hello, I'm a language model, with- proverbed your rest are their words  ELEress
# Hello, I'm a language model, I lost all my death, is love it us the good
# candidate completions
# Hello, I'm a language model, so — great familying her. When Rusty was a frog
# Hello, I'm a language model, your familying him my dear things?" What, of w
# Hello, I'm a language model, for one, at his jackoed I
# THE edge
# Hello, I'm a language model, his good body: 'So home when Live' in my
# Hello, I'm a language model, you go at my water-esteemfully named What to

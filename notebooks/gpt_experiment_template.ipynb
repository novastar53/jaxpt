# %% [markdown]
# # NoPE GPT Experiment
#
# This experiment trains a GPT model without any positional embeddings. According to Kazemnejad et al. (2024), this should still work due to the causal attention map inducing positional information.

# %% [markdown]
# ### Configure the machine and install packages

# %%
from typing import Literal
import sys

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# fatal: destination path 'jaxpt' already exists and is not an empty directory.
# M	src/jaxpt/dataloaders.py
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# WARNING: Skipping tensorflow as it is not installed.

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )

sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import jax.numpy as jnp
import numpy as np

os.environ['XLA_FLAGS'] = (
    '--xla_gpu_triton_gemm_any=True '
    '--xla_gpu_enable_latency_hiding_scheduler=true '
)

os.environ.update({
  "NCCL_LL128_BUFFSIZE": "-2",
  "NCCL_LL_BUFFSIZE": "-2",
  "NCCL_PROTO": "SIMPLE,LL,LL128",
 })


# Hardware setup
print("JAX version:", jax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

REQUESTED_DEVICE = "gpu"

jax.config.update("jax_platform_name", REQUESTED_DEVICE) # Make sure we're using the GPU

device = jax.default_backend()
if device != REQUESTED_DEVICE:
    warnings.warn(f"not using {REQUESTED_DEVICE}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Makes sure the matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Available devices: 1
# using gpu
# 786 µs ± 26.1 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize the baseline and candidate models and perform a sanity check

# %%
from functools import partial

from flax import nnx

from jaxpt.infer import generate_completions
from jaxpt.models import RoPE_GPT, NoPE_GPT, RoPE_GPTConfig, NoPE_GPTConfig

"""
+--------------+---------+--------+------+
| Model        | Layers  | Heads  | Embd |
+--------------+---------+--------+------+
| gpt2-medium  | 24      | 16     | 1024 |
| gpt2-large   | 36      | 20     | 1280 |
| gpt2-xl      | 48      | 25     | 1600 |
+--------------+---------+--------+------+
"""

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
baseline_config = NoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
candidate_config = RoPE_GPTConfig(dtype=jnp.bfloat16, \
                   vocab_size=50257, \
                   sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(baseline_config)
nnx.display(candidate_config)
baseline = NoPE_GPT(baseline_config, rngs)
candidate = RoPE_GPT(candidate_config, rngs)

#m = load_checkpoint("run_20250311_uqdwjq", 5600)
graphdef, rngstate, state = nnx.split(baseline, nnx.RngState, ...)
nnx.display(state)
graphdef, rngstate, state = nnx.split(candidate, nnx.RngState, ...)
nnx.display(state)

#completions = generate_completions()
#for completion in completions:
#print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_379d7765728b44478fb2ecf0d0a4cab9" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_379d7765728b44478fb2ecf0d0a4cab9")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_379d7765728b44478fb2ecf0d0a4cab9")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_425b722aa54a46f089456b58dc26169c" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_425b722aa54a46f089456b58dc26169c")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_425b722aa54a46f089456b58dc26169c")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_cf47a1421a3f4527b6e93e23f945320a" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cf47a1421a3f4527b6e93e23f945320a")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cf47a1421a3f4527b6e93e23f945320a")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cf47a1421a3f4527b6e93e23f945320a")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_d6bab5168da44593ae54ea71d3343069" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d6bab5168da44593ae54ea71d3343069")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d6bab5168da44593ae54ea71d3343069")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d6bab5168da44593ae54ea71d3343069")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %% [markdown]
# ### Configure Logging and Checkpointing

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

baseline_run_dirname = f"baseline_run_{timestamp}_{random_code}"
print(f"Baseline Run: {baseline_run_dirname}")
candidate_run_dirname = f"candidate_run_{timestamp}_{random_code}"
print(f"Candidate Run: {candidate_run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Baseline Run: baseline_run_20250426_rlgxwo
# Candidate Run: candidate_run_20250426_rlgxwo
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %% [markdown]
# ### Configure Training Run

# %%
import dataclasses

############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**14 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 16
  T: int = 1024
  max_steps: int = 19073 # 1 epoch (99 shards of the dataset should be around 18883, but Karpathy used 19073 for some reason)
  max_lr: float = 6e-4
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 715
  print_interval: int = 20
  eval_interval: int = 250
  checkpoint_interval: int = 250
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T * num_devices) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()

'''trconf = TrainerConfig(
  num_tokens_per_batch=2**11,
  mB=2,
  T=1024,
  max_steps=9*48*10, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=20,
  eval_interval=250,
  checkpoint_interval=0,

)

trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient
'''

print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"sub-batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB)
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB * num_devices}")
print(f"max steps: {trconf.max_steps}")
# Out:
# tokens/batch: 16,384
# block size: 1024
# sub-batch size: 16
# no. gradient accumulation steps: 1
# effective batch size per device:  16
# effective batch size: 16
# max steps: 19073

# %% [markdown]
# ### Configure the Baseline and Candidate Optimizer

# %%
import optax

# Set up the optimizer
def warmup_with_cosine_decay_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    coeff = 0.5 * (1 + jnp.cos(jnp.pi * (step - trconf.warmup_steps) / (trconf.max_steps - trconf.warmup_steps)))
    cosine_lr =  trconf.min_lr + coeff * (trconf.max_lr - trconf.min_lr)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < trconf.max_steps, cosine_lr, trconf.min_lr))

# Generate a weight decay mask
_, params, _ = nnx.split(baseline, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
baseline_optimizer = nnx.Optimizer(baseline, tx)

# count the number of weight decay params
def get_size(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)
print(f"baseline weight decay param count: {weight_decay_param_count:,}")


_, params, _ = nnx.split(candidate, nnx.Param, nnx.Variable)
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)
tx = optax.chain(
    optax.clip_by_global_norm(trconf.max_grad_norm),
    optax.adamw(warmup_with_cosine_decay_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask)
)
candidate_optimizer = nnx.Optimizer(candidate, tx)

weight_decay_params = jax.tree_util.tree_map(get_size, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)

print(f"candidate weight decay param count: {weight_decay_param_count:,}")
# Out:
# baseline weight decay param count: 123,532,032
# candidate weight decay param count: 123,597,568

# %% [markdown]
# ### Configure DataLoader

# %%
import os
from google.cloud import storage

def is_folder_empty_or_missing(folder_path):
    """Check if the folder is missing or empty."""
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} does not exist.")
        return True
    if not os.path.isdir(folder_path):
        raise ValueError(f"{folder_path} exists but is not a folder!")
    if not any(os.scandir(folder_path)):
        print(f"Folder {folder_path} is empty.")
        return True
    return False

def download_gcs_bucket(bucket_name, destination_folder, folder_prefix=""):
    """Download all files from the GCS bucket to the destination folder."""
    # Initialize GCS client
    client = storage.Client()
    bucket = client.bucket(bucket_name)

    # List and download all blobs
    blobs = bucket.list_blobs(prefix=folder_prefix)
    for blob in blobs:
        dest_path = os.path.join(destination_folder, blob.name)
        if blob.name.endswith(".npz"):
            # Create destination directory if needed
            #os.makedirs(os.path.dirname(dest_path), exist_ok=True)
            # Download blob
            print(f"Downloading {blob.name} to {dest_path}")
            blob.download_to_filename(dest_path)

# %%
from jaxpt.dataloaders import DataLoader
from jaxpt.eval import calc_validation_loss
from jaxpt.train import loss_fn

import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "alpha-448101-282bc1b884cd.json"

dataset = "fineweb-edu"
gcs_bucket = "jaxpt_datasets"
gcs_folder_prefix = "fineweb-edu/processed"

if platform == "colab":
    datasets_folder = Path().absolute() / "jaxpt" / "datasets"
elif platform == "cuda":
    datasets_folder = Path("/home/ubuntu/gpt2-train/")
else:
    datasets_folder = Path().absolute().parent / "datasets"

dataset_path = datasets_folder / dataset / "processed"

if is_folder_empty_or_missing(dataset_path):
    print("Folder is missing or empty. Downloading files from GCS...")
    os.makedirs(dataset_path, exist_ok=True)  # Create the folder if it didn't exist
    download_gcs_bucket(gcs_bucket, datasets_folder, folder_prefix=gcs_folder_prefix)

# %%
train_dl = DataLoader(dirpath=dataset_path,
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=num_devices,
                      label="train")
eval_dl = DataLoader(dirpath=dataset_path,
                     batch_size=trconf.mB,
                     block_size=trconf.T,
                     device_rank=1,
                     label="valid",
                     quiet=True)

def evaluate(model):
  model.eval()
  completions = generate_completions(model)
  val_loss = calc_validation_loss(model, loss_fn=loss_fn, dataloader=eval_dl)
  model.train()
  return val_loss, completions
# Out:
# dataloader initialized:
# ------------------------
# label:          train
# shards:         99
# shard size:     100,000,000
# batch size:     16
# block size:     1024
# device rank:    1
# ------------------------

# %% [markdown]
# ### Setup the Training Loop

# %%
# %matplotlib inline

import time

import matplotlib.pyplot as plt

from jaxpt.utils import append_to_csv
from jaxpt.train import parallel_train_step


baseline_train_losses, candidate_train_losses = [], []
baseline_val_losses, candidate_val_losses = [], []
append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", ["step", "loss"])
append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", ["step", "lr", "loss", "norm", "time", "tokens_processed", "tokens_per_sec"])
append_to_csv(log_dir / f"{candidate_run_dirname}_valid.csv", ["step", "loss"])

baseline.train()
candidate.train()

try:
  for step in range(trconf.max_steps):
    start = time.time()
    batch, target = train_dl()

    # baseline step
    baseline_avg_loss, baseline_avg_grads = parallel_train_step(baseline, baseline_optimizer, batch, target)
    baseline_avg_loss.block_until_ready()

    # candidate step
    candidate_avg_loss, candidate_avg_grads = parallel_train_step(candidate, candidate_optimizer, batch, target)
    candidate_avg_loss.block_until_ready()

    # compute stats
    baseline_avg_loss = jnp.float32(baseline_avg_loss[0])
    candidate_avg_loss = jnp.float32(candidate_avg_loss[0])

    lr = warmup_with_cosine_decay_schedule(step)
    norm = 0 # norm[0]|
    iter_time = time.time() - start
    sub_step_time = iter_time / trconf.grad_accumulation_steps
    tokens_per_sec = num_devices * trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
    tokens_processed = (step+1) * num_devices * trconf.grad_accumulation_steps * trconf.mB * trconf.T

    if step % trconf.print_interval == 0:
      baseline_train_losses.append((step, baseline_avg_loss))
      candidate_train_losses.append((step, candidate_avg_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_train.csv", [step, lr, baseline_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      append_to_csv(log_dir / f"{candidate_run_dirname}_train.csv", [step, lr, candidate_avg_loss, norm, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | baseline loss: {baseline_avg_loss:0.4f} | "
            f"candidate loss: {candidate_avg_loss:0.4f} | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      baseline_valid_loss, baseline_completions = evaluate(baseline)
      baseline_valid_loss = jnp.float32(baseline_valid_loss)
      baseline_val_losses.append((step, baseline_valid_loss))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, baseline_valid_loss])
      candidate_valid_loss, candidate_completions = evaluate(candidate)
      candidate_valid_loss = jnp.float32(candidate_valid_loss)
      candidate_val_losses.append((step, jnp.float32(candidate_valid_loss)))
      append_to_csv(log_dir / f"{baseline_run_dirname}_valid.csv", [step, candidate_valid_loss])
      print(f"baseline valid loss: {baseline_valid_loss:0.4f} |"
            f"candidate valid loss: {candidate_valid_loss:0.4f} "  )

      print("Baseline completions:")
      for completion in baseline_completions:
        print(completion)
      print("Candidate completions")
      for completion in candidate_completions:
        print(completion)
    #if step > 0 and trconf.checkpoint_interval > 0 and step % trconf.checkpoint_interval == 0:
      #save_checkpoint(m, step)


except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

baseline_valid_loss, baseline_completions = evaluate(baseline)
baseline_valid_loss = jnp.float32(baseline_valid_loss)
candidate_valid_loss, candidate_completions = evaluate(candidate)
candidate_valid_loss = jnp.float32(candidate_valid_loss)
print(f"baseline valid loss: {baseline_valid_loss:0.4f} | "
      f"candidate valid loss: {candidate_valid_loss:0.4f}")
print(f"baseline completions")
for completion in baseline_completions:
  print(completion)
print(f"candidate completions")
for completion in candidate_completions:
  print(completion)

fig, axes = plt.subplots(2, 1, figsize=(10, 8))

axes[0].plot([x[0] for x in baseline_train_losses], [x[1] for x in baseline_train_losses], label="baseline")
axes[0].plot([x[0] for x in candidate_train_losses], [x[1] for x in candidate_train_losses], label="candidate")
axes[0].set_title("Train Loss")

axes[1].plot([x[0] for x in baseline_val_losses], [x[1] for x in baseline_val_losses], label="baseline")
axes[1].plot([x[0] for x in candidate_val_losses], [x[1] for x in candidate_val_losses], label="candidate")
axes[1].set_title("Valid Loss")

plt.legend()
plt.savefig(log_dir / f"{baseline_run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# 0 | lr: 8.39e-07 | baseline loss: 6.9375 | candidate loss: 6.9375 | tokens processed: 16,384 | tok/sec: 212.60
# baseline valid loss: 7.1875 |candidate valid loss: 7.3125
# Baseline completions:
# Hello, I'm a language model, but had all you he will the different has a first and
# Hello, I'm a language model, your small with well it, also can you in being when
# Hello, I'm a language model, for its time like that. However is other to their variety
# Hello, I'm a language model,, a largest is have other person: 6 of only these
# Hello, I'm a language model, that he could it-and when than one could the work
# Candidate completions
# Hello, I'm a language model, is only your same years or be, � the first;
# Hello, I'm a language model, this UnitedWhy's many. That were to have only how
# Hello, I'm a language model, which you are there was, we be only to an organization
# Hello, I'm a language model, in us not you� Is example into more if we
# Hello, I'm a language model, but at what� that for us like threeation and one
# 20 | lr: 1.76e-05 | baseline loss: 6.7188 | candidate loss: 6.6562 | tokens processed: 344,064 | tok/sec: 27,728.41
# 40 | lr: 3.44e-05 | baseline loss: 6.9375 | candidate loss: 6.9062 | tokens processed: 671,744 | tok/sec: 59,029.49
# 60 | lr: 5.12e-05 | baseline loss: 6.8438 | candidate loss: 6.8125 | tokens processed: 999,424 | tok/sec: 60,084.13
# 80 | lr: 6.80e-05 | baseline loss: 7.4062 | candidate loss: 7.4062 | tokens processed: 1,327,104 | tok/sec: 59,988.25
# 100 | lr: 8.48e-05 | baseline loss: 6.8125 | candidate loss: 6.7812 | tokens processed: 1,654,784 | tok/sec: 59,478.84
# 120 | lr: 1.02e-04 | baseline loss: 6.9688 | candidate loss: 6.9375 | tokens processed: 1,982,464 | tok/sec: 58,418.54
# 140 | lr: 1.18e-04 | baseline loss: 6.9062 | candidate loss: 6.9062 | tokens processed: 2,310,144 | tok/sec: 57,944.62
# 160 | lr: 1.35e-04 | baseline loss: 6.9688 | candidate loss: 6.9688 | tokens processed: 2,637,824 | tok/sec: 58,501.24
# 180 | lr: 1.52e-04 | baseline loss: 6.7500 | candidate loss: 6.7500 | tokens processed: 2,965,504 | tok/sec: 59,582.09
# 200 | lr: 1.69e-04 | baseline loss: 6.8125 | candidate loss: 6.8125 | tokens processed: 3,293,184 | tok/sec: 57,644.14
# 220 | lr: 1.85e-04 | baseline loss: 6.8438 | candidate loss: 6.8125 | tokens processed: 3,620,864 | tok/sec: 58,873.78
# 240 | lr: 2.02e-04 | baseline loss: 6.7812 | candidate loss: 6.7812 | tokens processed: 3,948,544 | tok/sec: 59,288.56
# baseline valid loss: 6.7500 |candidate valid loss: 6.8125
# Baseline completions:
# Hello, I'm a language model, with so had you more from a lot will have be an
# Hello, I'm a language model, especially from order-like of 1's of this could put
# Hello, I'm a language model, we were the average to know with their two,
# B
# Hello, I'm a language model, he can no other in many � use about an significant-
# Hello, I'm a language model,
# How more a most found also they's high. However
# Candidate completions
# Hello, I'm a language model, he takes time at both their other life will have a number
# Hello, I'm a language model, even as some their study for my study is in. With
# Hello, I'm a language model,
# 2, one in many time as with the time:
# Hello, I'm a language model, a other types on an averageing we want, one that
# Hello, I'm a language model, it from both for "S may produce us he was.
# 260 | lr: 2.19e-04 | baseline loss: 6.8125 | candidate loss: 6.7812 | tokens processed: 4,276,224 | tok/sec: 24,243.75
# 280 | lr: 2.36e-04 | baseline loss: 6.5625 | candidate loss: 6.5625 | tokens processed: 4,603,904 | tok/sec: 59,162.74
# 300 | lr: 2.53e-04 | baseline loss: 7.0000 | candidate loss: 7.0000 | tokens processed: 4,931,584 | tok/sec: 57,939.19
# 320 | lr: 2.69e-04 | baseline loss: 6.9375 | candidate loss: 6.9375 | tokens processed: 5,259,264 | tok/sec: 57,617.07
# 340 | lr: 2.86e-04 | baseline loss: 6.6250 | candidate loss: 6.6250 | tokens processed: 5,586,944 | tok/sec: 58,016.63
# 360 | lr: 3.03e-04 | baseline loss: 6.8750 | candidate loss: 6.8750 | tokens processed: 5,914,624 | tok/sec: 57,790.10
# 380 | lr: 3.20e-04 | baseline loss: 6.7500 | candidate loss: 6.7500 | tokens processed: 6,242,304 | tok/sec: 58,739.11
# 400 | lr: 3.37e-04 | baseline loss: 6.7188 | candidate loss: 6.7188 | tokens processed: 6,569,984 | tok/sec: 58,209.02
# 420 | lr: 3.53e-04 | baseline loss: 6.6875 | candidate loss: 6.6875 | tokens processed: 6,897,664 | tok/sec: 58,625.81
# 440 | lr: 3.70e-04 | baseline loss: 6.7500 | candidate loss: 6.7500 | tokens processed: 7,225,344 | tok/sec: 24,349.60
# 460 | lr: 3.87e-04 | baseline loss: 6.6562 | candidate loss: 6.6250 | tokens processed: 7,553,024 | tok/sec: 58,134.57
# 480 | lr: 4.04e-04 | baseline loss: 6.4688 | candidate loss: 6.4688 | tokens processed: 7,880,704 | tok/sec: 59,395.82
# 500 | lr: 4.20e-04 | baseline loss: 6.9688 | candidate loss: 7.0625 | tokens processed: 8,208,384 | tok/sec: 24,509.68
# baseline valid loss: 6.6562 |candidate valid loss: 6.7500
# Baseline completions:
# Hello, I'm a language model, he lived upon what so if the car which is not more
# Hello, I'm a language model, what was they think an health – there was to write all
# Hello, I'm a language model, as more.org
# *, it started to help its
# Hello, I'm a language model, they can reach in order-MHE-�ll
# Hello, I'm a language model,
# • 3 in E. E+44<|endoftext|>In general
# Candidate completions
# Hello, I'm a language model,000 from time the state (The brain by a child who
# Hello, I'm a language model, some way but just like more or also been more one during
# Hello, I'm a language model, they be the soil to see that was sure the best level
# Hello, I'm a language model, you. All or you like different weeks“At least
# Hello, I'm a language model, we see over it also be true back through every new knowledge
# 520 | lr: 4.37e-04 | baseline loss: 6.3438 | candidate loss: 6.3125 | tokens processed: 8,536,064 | tok/sec: 24,110.91
# 540 | lr: 4.54e-04 | baseline loss: 6.5625 | candidate loss: 6.5625 | tokens processed: 8,863,744 | tok/sec: 59,261.57
# 560 | lr: 4.71e-04 | baseline loss: 6.5938 | candidate loss: 6.5938 | tokens processed: 9,191,424 | tok/sec: 58,579.83
# 580 | lr: 4.88e-04 | baseline loss: 6.4062 | candidate loss: 6.4062 | tokens processed: 9,519,104 | tok/sec: 29,070.90
# 600 | lr: 5.04e-04 | baseline loss: 6.3438 | candidate loss: 6.3438 | tokens processed: 9,846,784 | tok/sec: 58,217.46
# 620 | lr: 5.21e-04 | baseline loss: 6.3750 | candidate loss: 6.3750 | tokens processed: 10,174,464 | tok/sec: 58,361.63
# 640 | lr: 5.38e-04 | baseline loss: 6.4062 | candidate loss: 6.4062 | tokens processed: 10,502,144 | tok/sec: 23,368.08
# 660 | lr: 5.55e-04 | baseline loss: 6.2812 | candidate loss: 6.2812 | tokens processed: 10,829,824 | tok/sec: 59,474.42
# 680 | lr: 5.71e-04 | baseline loss: 6.4375 | candidate loss: 6.4375 | tokens processed: 11,157,504 | tok/sec: 58,063.93
# 700 | lr: 5.88e-04 | baseline loss: 6.4375 | candidate loss: 6.4375 | tokens processed: 11,485,184 | tok/sec: 58,723.75
# 720 | lr: 6.00e-04 | baseline loss: 6.8750 | candidate loss: 6.8438 | tokens processed: 11,812,864 | tok/sec: 59,766.30
# 740 | lr: 6.00e-04 | baseline loss: 6.6250 | candidate loss: 6.6250 | tokens processed: 12,140,544 | tok/sec: 59,156.17
# baseline valid loss: 6.5000 |candidate valid loss: 6.5000
# Baseline completions:
# Hello, I'm a language model, this does their body" from a major things, or to
# Hello, I'm a language model,
# What make our image for instance�s the part about
# Hello, I'm a language model, we is the second, your one or her. If her
# Hello, I'm a language model, such, especially for any longer an area by an open or
# Hello, I'm a language model, which I
# (0. While much way's a result
# Candidate completions
# Hello, I'm a language model, that use two children by any of those old-based development
# Hello, I'm a language model, one as those food you to say this means a set her
# Hello, I'm a language model, such an care are to prevent it may tell the problem –
# Hello, I'm a language model, with your big time with what people might to your friend that
# Hello, I'm a language model, which do is also get around other countries the study and if
# 760 | lr: 6.00e-04 | baseline loss: 6.4062 | candidate loss: 6.4062 | tokens processed: 12,468,224 | tok/sec: 58,070.16
# 780 | lr: 6.00e-04 | baseline loss: 6.3750 | candidate loss: 6.3438 | tokens processed: 12,795,904 | tok/sec: 59,260.03
# 800 | lr: 6.00e-04 | baseline loss: 6.7500 | candidate loss: 6.7500 | tokens processed: 13,123,584 | tok/sec: 58,186.70
# 820 | lr: 6.00e-04 | baseline loss: 6.5625 | candidate loss: 6.5312 | tokens processed: 13,451,264 | tok/sec: 59,023.51
# 840 | lr: 6.00e-04 | baseline loss: 6.5000 | candidate loss: 6.5000 | tokens processed: 13,778,944 | tok/sec: 58,199.80
# 860 | lr: 6.00e-04 | baseline loss: 6.4375 | candidate loss: 6.4375 | tokens processed: 14,106,624 | tok/sec: 23,858.65
# 880 | lr: 6.00e-04 | baseline loss: 6.0938 | candidate loss: 6.0625 | tokens processed: 14,434,304 | tok/sec: 57,502.57
# 900 | lr: 6.00e-04 | baseline loss: 6.5312 | candidate loss: 6.5000 | tokens processed: 14,761,984 | tok/sec: 58,313.20
# 920 | lr: 6.00e-04 | baseline loss: 6.1875 | candidate loss: 6.1875 | tokens processed: 15,089,664 | tok/sec: 57,299.56
# 940 | lr: 6.00e-04 | baseline loss: 6.1562 | candidate loss: 6.1250 | tokens processed: 15,417,344 | tok/sec: 59,093.25
# 960 | lr: 6.00e-04 | baseline loss: 6.0625 | candidate loss: 6.0625 | tokens processed: 15,745,024 | tok/sec: 58,810.09
# 980 | lr: 6.00e-04 | baseline loss: 6.3438 | candidate loss: 6.3125 | tokens processed: 16,072,704 | tok/sec: 28,714.19
# 1000 | lr: 6.00e-04 | baseline loss: 6.2812 | candidate loss: 6.2812 | tokens processed: 16,400,384 | tok/sec: 58,248.15
# baseline valid loss: 6.3438 |candidate valid loss: 6.3438
# Baseline completions:
# Hello, I'm a language model, not on being known? (1 the day, but she
# Hello, I'm a language model, these way would is when a healthy is so to all problems
# Hello, I'm a language model, when so in home in any to you take a child
#
# Hello, I'm a language model, he was first known, I find at such in addition in
# Hello, I'm a language model, a short system� our people think all an first-out
# Candidate completions
# Hello, I'm a language model, when on
# Sphil. Although let us, then
# Hello, I'm a language model, such time which of two of human lives on your hand"
# Hello, I'm a language model, he, the water-12 and they shall be at what
# Hello, I'm a language model, as the process is in each or your book and may go
# Hello, I'm a language model, I also ask,
# - Why think so was the more
# 1020 | lr: 6.00e-04 | baseline loss: 6.0625 | candidate loss: 6.0312 | tokens processed: 16,728,064 | tok/sec: 58,792.08
# 1040 | lr: 6.00e-04 | baseline loss: 6.2188 | candidate loss: 6.1875 | tokens processed: 17,055,744 | tok/sec: 58,508.06
# 1060 | lr: 6.00e-04 | baseline loss: 6.4062 | candidate loss: 6.4062 | tokens processed: 17,383,424 | tok/sec: 28,394.07
# 1080 | lr: 5.99e-04 | baseline loss: 6.0625 | candidate loss: 6.0625 | tokens processed: 17,711,104 | tok/sec: 59,017.83
# 1100 | lr: 5.99e-04 | baseline loss: 6.0938 | candidate loss: 6.0938 | tokens processed: 18,038,784 | tok/sec: 58,399.12
# 1120 | lr: 5.99e-04 | baseline loss: 6.0938 | candidate loss: 6.0625 | tokens processed: 18,366,464 | tok/sec: 58,044.02
# 1140 | lr: 5.99e-04 | baseline loss: 6.1875 | candidate loss: 6.1875 | tokens processed: 18,694,144 | tok/sec: 58,304.14
# 1160 | lr: 5.99e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 19,021,824 | tok/sec: 57,389.43
# 1180 | lr: 5.99e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 19,349,504 | tok/sec: 58,832.30
# 1200 | lr: 5.99e-04 | baseline loss: 6.0312 | candidate loss: 6.0000 | tokens processed: 19,677,184 | tok/sec: 57,651.58
# 1220 | lr: 5.99e-04 | baseline loss: 5.9688 | candidate loss: 5.9375 | tokens processed: 20,004,864 | tok/sec: 58,437.46
# 1240 | lr: 5.99e-04 | baseline loss: 6.0625 | candidate loss: 6.0000 | tokens processed: 20,332,544 | tok/sec: 28,452.02
# baseline valid loss: 6.2812 |candidate valid loss: 6.2500
# Baseline completions:
# Hello, I'm a language model, so soon do he used it can't an essential for these
# Hello, I'm a language model, when you often one you should serve by one, how will
# Hello, I'm a language model, you could have something. At your life without the next range
# Hello, I'm a language model, to a better-up at order will the process might can
# Hello, I'm a language model, which their peers from how to others often they be used beyond
# Candidate completions
# Hello, I'm a language model, to identify out it means for a very new, the past
# Hello, I'm a language model, even we all is true for better life to have known they
# Hello, I'm a language model, including social, personal journey's commitment in home, you a
# Hello, I'm a language model, I� author for an ongoing actions – both, both an
# Hello, I'm a language model, or support can create clear we seek people around every time is
# 1260 | lr: 5.99e-04 | baseline loss: 6.0938 | candidate loss: 6.0938 | tokens processed: 20,660,224 | tok/sec: 57,739.79
# 1280 | lr: 5.99e-04 | baseline loss: 5.7500 | candidate loss: 5.7500 | tokens processed: 20,987,904 | tok/sec: 58,666.45
# 1300 | lr: 5.99e-04 | baseline loss: 6.1250 | candidate loss: 6.1250 | tokens processed: 21,315,584 | tok/sec: 58,683.49
# 1320 | lr: 5.99e-04 | baseline loss: 6.1875 | candidate loss: 6.1562 | tokens processed: 21,643,264 | tok/sec: 58,579.49
# 1340 | lr: 5.98e-04 | baseline loss: 5.9688 | candidate loss: 5.9375 | tokens processed: 21,970,944 | tok/sec: 59,020.87
# 1360 | lr: 5.98e-04 | baseline loss: 5.8750 | candidate loss: 5.8750 | tokens processed: 22,298,624 | tok/sec: 58,959.80
# 1380 | lr: 5.98e-04 | baseline loss: 5.9688 | candidate loss: 5.9375 | tokens processed: 22,626,304 | tok/sec: 57,646.41
# 1400 | lr: 5.98e-04 | baseline loss: 6.2188 | candidate loss: 6.1562 | tokens processed: 22,953,984 | tok/sec: 59,527.64
# 1420 | lr: 5.98e-04 | baseline loss: 6.1562 | candidate loss: 6.1562 | tokens processed: 23,281,664 | tok/sec: 58,747.25
# 1440 | lr: 5.98e-04 | baseline loss: 5.9062 | candidate loss: 5.8750 | tokens processed: 23,609,344 | tok/sec: 58,055.30
# 1460 | lr: 5.98e-04 | baseline loss: 5.8125 | candidate loss: 5.7812 | tokens processed: 23,937,024 | tok/sec: 58,295.24
# 1480 | lr: 5.98e-04 | baseline loss: 6.0625 | candidate loss: 6.0625 | tokens processed: 24,264,704 | tok/sec: 23,744.56
# 1500 | lr: 5.98e-04 | baseline loss: 5.7812 | candidate loss: 5.7500 | tokens processed: 24,592,384 | tok/sec: 58,098.64
# baseline valid loss: 6.0938 |candidate valid loss: 6.0625
# Baseline completions:
# Hello, I'm a language model, for real scale from public systems, their behavior, including,
# Hello, I'm a language model, their time but only with your job are some person today!
# Hello, I'm a language model, there would not never. And what the last few things may
# Hello, I'm a language model, or more as not be to which there does the results in
# Hello, I'm a language model, including. To take sense of any goal (that do.
# Candidate completions
# Hello, I'm a language model, while talking: How want: I like our work and make
# Hello, I'm a language model, on it all from just that most. But we've enough
# Hello, I'm a language model, including how you also have enough! You
# � � When
# Hello, I'm a language model, which it said by all is all for something like just that
# Hello, I'm a language model, or by many to it. All skills we start. With
# 1520 | lr: 5.97e-04 | baseline loss: 5.7188 | candidate loss: 5.7188 | tokens processed: 24,920,064 | tok/sec: 58,624.71
# 1540 | lr: 5.97e-04 | baseline loss: 6.0938 | candidate loss: 6.0625 | tokens processed: 25,247,744 | tok/sec: 58,185.12
# 1560 | lr: 5.97e-04 | baseline loss: 5.9375 | candidate loss: 5.9375 | tokens processed: 25,575,424 | tok/sec: 28,527.01
# 1580 | lr: 5.97e-04 | baseline loss: 6.0312 | candidate loss: 6.0000 | tokens processed: 25,903,104 | tok/sec: 59,326.80
# 1600 | lr: 5.97e-04 | baseline loss: 5.8438 | candidate loss: 5.8125 | tokens processed: 26,230,784 | tok/sec: 58,621.36
# 1620 | lr: 5.97e-04 | baseline loss: 6.0312 | candidate loss: 6.0000 | tokens processed: 26,558,464 | tok/sec: 58,776.64
# 1640 | lr: 5.97e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 26,886,144 | tok/sec: 57,862.45
# 1660 | lr: 5.96e-04 | baseline loss: 6.1875 | candidate loss: 6.1562 | tokens processed: 27,213,824 | tok/sec: 23,890.71
# 1680 | lr: 5.96e-04 | baseline loss: 5.9688 | candidate loss: 5.9688 | tokens processed: 27,541,504 | tok/sec: 58,101.98
# 1700 | lr: 5.96e-04 | baseline loss: 6.0312 | candidate loss: 6.0312 | tokens processed: 27,869,184 | tok/sec: 56,938.17
# 1720 | lr: 5.96e-04 | baseline loss: 5.9375 | candidate loss: 5.9062 | tokens processed: 28,196,864 | tok/sec: 23,997.91
# 1740 | lr: 5.96e-04 | baseline loss: 6.3750 | candidate loss: 6.3750 | tokens processed: 28,524,544 | tok/sec: 58,866.47
# baseline valid loss: 6.0625 |candidate valid loss: 6.0625
# Baseline completions:
# Hello, I'm a language model, that his second student a single-assra's not so
# Hello, I'm a language model, how can add into either by giving and what they work which
# Hello, I'm a language model, for each time where we use and it with the fact are
# Hello, I'm a language model, then to it would take more quickly it with this post to
# Hello, I'm a language model, as opposed together; "bomeer: not only is
# Candidate completions
# Hello, I'm a language model, in.e's scientific science. On some cases. His
# Hello, I'm a language model,
# You's how these questions more detail the world being asked
# Hello, I'm a language model, including students. With all those a very children, it the
# Hello, I'm a language model, a new lesson as that might set together without that then it
# Hello, I'm a language model, he then of my childhood, such or student she said on
# 1760 | lr: 5.96e-04 | baseline loss: 6.3125 | candidate loss: 6.3125 | tokens processed: 28,852,224 | tok/sec: 57,781.11
# 1780 | lr: 5.96e-04 | baseline loss: 5.9375 | candidate loss: 5.9062 | tokens processed: 29,179,904 | tok/sec: 59,005.36
# 1800 | lr: 5.95e-04 | baseline loss: 5.8438 | candidate loss: 5.8125 | tokens processed: 29,507,584 | tok/sec: 58,374.42
# 1820 | lr: 5.95e-04 | baseline loss: 5.6875 | candidate loss: 5.6562 | tokens processed: 29,835,264 | tok/sec: 57,679.07
# 1840 | lr: 5.95e-04 | baseline loss: 5.7812 | candidate loss: 5.7500 | tokens processed: 30,162,944 | tok/sec: 58,082.63
# 1860 | lr: 5.95e-04 | baseline loss: 5.9062 | candidate loss: 5.8750 | tokens processed: 30,490,624 | tok/sec: 29,271.43
# 1880 | lr: 5.95e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 30,818,304 | tok/sec: 57,847.31
# 1900 | lr: 5.94e-04 | baseline loss: 6.0312 | candidate loss: 6.0000 | tokens processed: 31,145,984 | tok/sec: 58,194.63
# 1920 | lr: 5.94e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 31,473,664 | tok/sec: 58,281.94
# 1940 | lr: 5.94e-04 | baseline loss: 6.0000 | candidate loss: 5.9688 | tokens processed: 31,801,344 | tok/sec: 58,696.72
# 1960 | lr: 5.94e-04 | baseline loss: 5.9062 | candidate loss: 5.8750 | tokens processed: 32,129,024 | tok/sec: 57,786.50
# 1980 | lr: 5.94e-04 | baseline loss: 5.7812 | candidate loss: 5.7500 | tokens processed: 32,456,704 | tok/sec: 57,765.32
# 2000 | lr: 5.93e-04 | baseline loss: 5.5312 | candidate loss: 5.5000 | tokens processed: 32,784,384 | tok/sec: 56,406.36
# baseline valid loss: 6.0625 |candidate valid loss: 5.8438
# Baseline completions:
# Hello, I'm a language model, he must bring on more in his body before he could to
# Hello, I'm a language model, particularly a series."1 (V2 (4 3 the
# Hello, I'm a language model, or by a text (E.)) we have had received
# Hello, I'm a language model, so, especially when I were all by your life since we
# Hello, I'm a language model, not taken under this, how and if students say, that
# Candidate completions
# Hello, I'm a language model, to get at every form them to one side. This point
# Hello, I'm a language model, including you with others have an intellectual thinking with their view over
# Hello, I'm a language model, we cannot have only, they would do an idea and when
# Hello, I'm a language model, that he and, as not for life? He feels this
# Hello, I'm a language model, it-group or by the actual art style would be called
# 2020 | lr: 5.93e-04 | baseline loss: 5.9688 | candidate loss: 5.9062 | tokens processed: 33,112,064 | tok/sec: 58,399.22
# 2040 | lr: 5.93e-04 | baseline loss: 5.9062 | candidate loss: 5.8750 | tokens processed: 33,439,744 | tok/sec: 59,376.01
# 2060 | lr: 5.93e-04 | baseline loss: 5.8750 | candidate loss: 5.8438 | tokens processed: 33,767,424 | tok/sec: 57,541.04
# 2080 | lr: 5.93e-04 | baseline loss: 5.8438 | candidate loss: 5.8438 | tokens processed: 34,095,104 | tok/sec: 58,239.02
# 2100 | lr: 5.92e-04 | baseline loss: 5.8438 | candidate loss: 5.8125 | tokens processed: 34,422,784 | tok/sec: 57,301.66
# 2120 | lr: 5.92e-04 | baseline loss: 5.8438 | candidate loss: 5.7812 | tokens processed: 34,750,464 | tok/sec: 57,819.86
# 2140 | lr: 5.92e-04 | baseline loss: 5.6250 | candidate loss: 5.5938 | tokens processed: 35,078,144 | tok/sec: 57,806.77
# 2160 | lr: 5.92e-04 | baseline loss: 6.0000 | candidate loss: 5.9062 | tokens processed: 35,405,824 | tok/sec: 57,626.01
# 2180 | lr: 5.92e-04 | baseline loss: 5.7812 | candidate loss: 5.7812 | tokens processed: 35,733,504 | tok/sec: 57,427.07
# 2200 | lr: 5.91e-04 | baseline loss: 5.8750 | candidate loss: 5.8750 | tokens processed: 36,061,184 | tok/sec: 58,153.21
# 2220 | lr: 5.91e-04 | baseline loss: 6.0938 | candidate loss: 6.0625 | tokens processed: 36,388,864 | tok/sec: 58,075.91
# 2240 | lr: 5.91e-04 | baseline loss: 5.7188 | candidate loss: 5.6875 | tokens processed: 36,716,544 | tok/sec: 58,801.04
# baseline valid loss: 5.8750 |candidate valid loss: 5.7500
# Baseline completions:
# Hello, I'm a language model, for everyone out with people's own learning can help us who
# Hello, I'm a language model, who should choose through being on those working at their social practice
# Hello, I'm a language model, so-based structure that all that they used to have it
# Hello, I'm a language model, we are: "You do
# After these questions it't
# Hello, I'm a language model, in every way is done more relevant text when students are interested
# Candidate completions
# Hello, I'm a language model, like: An English text
# The "m.
# H
# Hello, I'm a language model, particularly in such two in which one day after being too with
# Hello, I'm a language model, the same way there and there have an alternative to go without
# Hello, I'm a language model, so to play with this video so there also an act that
# Hello, I'm a language model, as he lived the term of each grade I is the music
# 2260 | lr: 5.91e-04 | baseline loss: 5.6562 | candidate loss: 5.6250 | tokens processed: 37,044,224 | tok/sec: 58,592.97
# 2280 | lr: 5.90e-04 | baseline loss: 5.8125 | candidate loss: 5.7812 | tokens processed: 37,371,904 | tok/sec: 57,648.44
# 2300 | lr: 5.90e-04 | baseline loss: 5.7188 | candidate loss: 5.6875 | tokens processed: 37,699,584 | tok/sec: 59,245.17
# 2320 | lr: 5.90e-04 | baseline loss: 5.5625 | candidate loss: 5.5625 | tokens processed: 38,027,264 | tok/sec: 57,613.54
# 2340 | lr: 5.90e-04 | baseline loss: 5.4375 | candidate loss: 5.4062 | tokens processed: 38,354,944 | tok/sec: 28,361.64
# 2360 | lr: 5.89e-04 | baseline loss: 5.6875 | candidate loss: 5.6250 | tokens processed: 38,682,624 | tok/sec: 58,499.80
# 2380 | lr: 5.89e-04 | baseline loss: 5.5938 | candidate loss: 5.5625 | tokens processed: 39,010,304 | tok/sec: 57,678.39
# 2400 | lr: 5.89e-04 | baseline loss: 5.6875 | candidate loss: 5.6562 | tokens processed: 39,337,984 | tok/sec: 58,352.51
# 2420 | lr: 5.89e-04 | baseline loss: 5.4688 | candidate loss: 5.4375 | tokens processed: 39,665,664 | tok/sec: 57,849.79
# 2440 | lr: 5.88e-04 | baseline loss: 5.5938 | candidate loss: 5.5625 | tokens processed: 39,993,344 | tok/sec: 57,186.93
# 2460 | lr: 5.88e-04 | baseline loss: 5.6562 | candidate loss: 5.6250 | tokens processed: 40,321,024 | tok/sec: 58,006.64
# 2480 | lr: 5.88e-04 | baseline loss: 5.7812 | candidate loss: 5.7500 | tokens processed: 40,648,704 | tok/sec: 58,311.76
# 2500 | lr: 5.88e-04 | baseline loss: 5.5000 | candidate loss: 5.4375 | tokens processed: 40,976,384 | tok/sec: 57,720.54
# baseline valid loss: 5.7812 |candidate valid loss: 5.7188
# Baseline completions:
# Hello, I'm a language model, how she and in English that they really become the word (
# Hello, I'm a language model, because she took care a little lower education for them an activity
# Hello, I'm a language model, to give the skills for other students�naires and get from
# Hello, I'm a language model, I can just help him how any human emotions and remember what
# Hello, I'm a language model, which must start them by the material around for my life!
# Candidate completions
# Hello, I'm a language model, you or experience-mher-for my mind-h
# Hello, I'm a language model, said she doesn understand any answer which would always get free at
# Hello, I'm a language model, who lived, told them his experience the family. When something
# Hello, I'm a language model, we� talk with it out at his personal. Maybe he
# Hello, I'm a language model, a long; she never come him some person his family-
# 2520 | lr: 5.87e-04 | baseline loss: 5.6562 | candidate loss: 5.6562 | tokens processed: 41,304,064 | tok/sec: 57,561.71
# 2540 | lr: 5.87e-04 | baseline loss: 5.4688 | candidate loss: 5.4375 | tokens processed: 41,631,744 | tok/sec: 28,209.04
# 2560 | lr: 5.87e-04 | baseline loss: 5.4688 | candidate loss: 5.4062 | tokens processed: 41,959,424 | tok/sec: 58,432.94
# 2580 | lr: 5.86e-04 | baseline loss: 5.5312 | candidate loss: 5.5000 | tokens processed: 42,287,104 | tok/sec: 57,561.33
# 2600 | lr: 5.86e-04 | baseline loss: 5.6250 | candidate loss: 5.5938 | tokens processed: 42,614,784 | tok/sec: 59,054.55
# 2620 | lr: 5.86e-04 | baseline loss: 5.4688 | candidate loss: 5.4062 | tokens processed: 42,942,464 | tok/sec: 59,587.77
# 2640 | lr: 5.85e-04 | baseline loss: 5.7188 | candidate loss: 5.6562 | tokens processed: 43,270,144 | tok/sec: 57,128.69
# 2660 | lr: 5.85e-04 | baseline loss: 5.4375 | candidate loss: 5.3750 | tokens processed: 43,597,824 | tok/sec: 58,927.85
# 2680 | lr: 5.85e-04 | baseline loss: 5.7188 | candidate loss: 5.6875 | tokens processed: 43,925,504 | tok/sec: 58,381.71
# 2700 | lr: 5.85e-04 | baseline loss: 5.5625 | candidate loss: 5.5312 | tokens processed: 44,253,184 | tok/sec: 57,830.95
# 2720 | lr: 5.84e-04 | baseline loss: 5.1250 | candidate loss: 5.0938 | tokens processed: 44,580,864 | tok/sec: 58,640.92
# 2740 | lr: 5.84e-04 | baseline loss: 5.3438 | candidate loss: 5.3125 | tokens processed: 44,908,544 | tok/sec: 23,826.95
# baseline valid loss: 5.5938 |candidate valid loss: 5.7188
# Baseline completions:
# Hello, I'm a language model, for it science at present science, there for students and school
# Hello, I'm a language model, while teaching; my project that needs that we need us!
# Hello, I'm a language model, using some examples throughout our study on each week. Our name
# Hello, I'm a language model, we are that they will know these insights you are reading that
# Hello, I'm a language model, a special topic (d.). you provide examples out and understand
# Candidate completions
# Hello, I'm a language model, to practice one sentence/e/the 'D' in
# Hello, I'm a language model, what a story should, it goes about, so of science
# Hello, I'm a language model, we're a brief tool you need it just like we ask
# Hello, I'm a language model, it's even in this point like when reading, an editor
# Hello, I'm a language model, which's words a writing? Yes students the question of all
# 2760 | lr: 5.84e-04 | baseline loss: 5.3750 | candidate loss: 5.3125 | tokens processed: 45,236,224 | tok/sec: 59,046.84
# 2780 | lr: 5.83e-04 | baseline loss: 5.3125 | candidate loss: 5.2500 | tokens processed: 45,563,904 | tok/sec: 58,143.03
# 2800 | lr: 5.83e-04 | baseline loss: 5.3750 | candidate loss: 5.3125 | tokens processed: 45,891,584 | tok/sec: 23,242.94
# 2820 | lr: 5.83e-04 | baseline loss: 5.6250 | candidate loss: 5.5312 | tokens processed: 46,219,264 | tok/sec: 59,239.24
# 2840 | lr: 5.82e-04 | baseline loss: 5.2500 | candidate loss: 5.2188 | tokens processed: 46,546,944 | tok/sec: 59,489.40
# 2860 | lr: 5.82e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 46,874,624 | tok/sec: 58,289.16
# 2880 | lr: 5.82e-04 | baseline loss: 5.1875 | candidate loss: 5.1250 | tokens processed: 47,202,304 | tok/sec: 57,952.04
# 2900 | lr: 5.81e-04 | baseline loss: 5.5938 | candidate loss: 5.5625 | tokens processed: 47,529,984 | tok/sec: 59,481.57
# 2920 | lr: 5.81e-04 | baseline loss: 5.2812 | candidate loss: 5.2188 | tokens processed: 47,857,664 | tok/sec: 59,095.89
# 2940 | lr: 5.81e-04 | baseline loss: 5.5312 | candidate loss: 5.5000 | tokens processed: 48,185,344 | tok/sec: 58,926.53
# 2960 | lr: 5.80e-04 | baseline loss: 5.3750 | candidate loss: 5.3125 | tokens processed: 48,513,024 | tok/sec: 58,760.61
# 2980 | lr: 5.80e-04 | baseline loss: 5.5000 | candidate loss: 5.4375 | tokens processed: 48,840,704 | tok/sec: 57,407.26
# 3000 | lr: 5.80e-04 | baseline loss: 5.3438 | candidate loss: 5.2812 | tokens processed: 49,168,384 | tok/sec: 58,039.71
# baseline valid loss: 5.5625 |candidate valid loss: 5.5938
# Baseline completions:
# Hello, I'm a language model, so often making, especially challenging and that was a few thousand
# Hello, I'm a language model, at different social challenges through physical interactions which the physical intelligence used
# Hello, I'm a language model, in that has started a team and researchers developed a lot of
# Hello, I'm a language model, they will delve more efficient measures – by them, particularly important
# Hello, I'm a language model, we explore you have many hours we offer about time, it
# Candidate completions
# Hello, I'm a language model, that if teaching your individual makes them together it. It all
# Hello, I'm a language model, writing is done or have my classifications for me since
#
# Hello, I'm a language model, as to see more information it a very small, it you
# Hello, I'm a language model, or a speech can create in several important methods that require learning
# Hello, I'm a language model, the author provides some, if teachers of different amounts and those
# 3020 | lr: 5.79e-04 | baseline loss: 5.1875 | candidate loss: 5.1562 | tokens processed: 49,496,064 | tok/sec: 58,971.39
# 3040 | lr: 5.79e-04 | baseline loss: 5.4688 | candidate loss: 5.4062 | tokens processed: 49,823,744 | tok/sec: 58,355.14
# 3060 | lr: 5.79e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 50,151,424 | tok/sec: 57,825.16
# 3080 | lr: 5.78e-04 | baseline loss: 5.5938 | candidate loss: 5.5312 | tokens processed: 50,479,104 | tok/sec: 23,767.62
# 3100 | lr: 5.78e-04 | baseline loss: 5.6562 | candidate loss: 5.5938 | tokens processed: 50,806,784 | tok/sec: 56,858.23
# 3120 | lr: 5.77e-04 | baseline loss: 5.6562 | candidate loss: 5.6250 | tokens processed: 51,134,464 | tok/sec: 58,672.16
# 3140 | lr: 5.77e-04 | baseline loss: 5.4375 | candidate loss: 5.3438 | tokens processed: 51,462,144 | tok/sec: 58,682.83
# 3160 | lr: 5.77e-04 | baseline loss: 5.6875 | candidate loss: 5.6562 | tokens processed: 51,789,824 | tok/sec: 58,709.61
# 3180 | lr: 5.76e-04 | baseline loss: 5.5312 | candidate loss: 5.4688 | tokens processed: 52,117,504 | tok/sec: 58,575.99
# 3200 | lr: 5.76e-04 | baseline loss: 5.6250 | candidate loss: 5.5938 | tokens processed: 52,445,184 | tok/sec: 57,473.71
# 3220 | lr: 5.76e-04 | baseline loss: 5.5312 | candidate loss: 5.5000 | tokens processed: 52,772,864 | tok/sec: 58,462.62
# 3240 | lr: 5.75e-04 | baseline loss: 5.5938 | candidate loss: 5.5625 | tokens processed: 53,100,544 | tok/sec: 28,378.13
# baseline valid loss: 5.6562 |candidate valid loss: 5.6875
# Baseline completions:
# Hello, I'm a language model, it as they had only more. After now it is what
# Hello, I'm a language model, just about that if in all three people would like ten children
# Hello, I'm a language model, an anti. Also this point in some hours, there appears
# Hello, I'm a language model, in this community of an effective time must work for food purposes
# Hello, I'm a language model, I had on their environment. � an enormous project� system
# Candidate completions
# Hello, I'm a language model, or another that does these findings, be discussed, but other
# Hello, I'm a language model, � trying each subject/day at www/tosis –
# Hello, I'm a language model, you were to them and give an individual characters. You's
# Hello, I'm a language model, using, not on my use such material sources of using to
# Hello, I'm a language model, as
# PAMOYIN OFISUSERAL
# 3260 | lr: 5.75e-04 | baseline loss: 5.7500 | candidate loss: 5.6562 | tokens processed: 53,428,224 | tok/sec: 58,789.67
# 3280 | lr: 5.74e-04 | baseline loss: 5.5938 | candidate loss: 5.5625 | tokens processed: 53,755,904 | tok/sec: 58,935.93
# 3300 | lr: 5.74e-04 | baseline loss: 5.3438 | candidate loss: 5.2812 | tokens processed: 54,083,584 | tok/sec: 57,898.63
# 3320 | lr: 5.74e-04 | baseline loss: 5.4062 | candidate loss: 5.3750 | tokens processed: 54,411,264 | tok/sec: 57,938.17
# 3340 | lr: 5.73e-04 | baseline loss: 5.4062 | candidate loss: 5.3125 | tokens processed: 54,738,944 | tok/sec: 57,924.49
# 3360 | lr: 5.73e-04 | baseline loss: 5.4062 | candidate loss: 5.3438 | tokens processed: 55,066,624 | tok/sec: 58,323.94
# 3380 | lr: 5.72e-04 | baseline loss: 5.5625 | candidate loss: 5.5000 | tokens processed: 55,394,304 | tok/sec: 58,754.03
# 3400 | lr: 5.72e-04 | baseline loss: 5.4375 | candidate loss: 5.4062 | tokens processed: 55,721,984 | tok/sec: 58,589.02
# 3420 | lr: 5.72e-04 | baseline loss: 5.6250 | candidate loss: 5.5938 | tokens processed: 56,049,664 | tok/sec: 57,277.73
# 3440 | lr: 5.71e-04 | baseline loss: 5.3750 | candidate loss: 5.3125 | tokens processed: 56,377,344 | tok/sec: 58,172.66
# 3460 | lr: 5.71e-04 | baseline loss: 5.3438 | candidate loss: 5.2500 | tokens processed: 56,705,024 | tok/sec: 57,937.14
# 3480 | lr: 5.70e-04 | baseline loss: 5.4375 | candidate loss: 5.3750 | tokens processed: 57,032,704 | tok/sec: 58,994.02
# 3500 | lr: 5.70e-04 | baseline loss: 5.3750 | candidate loss: 5.3438 | tokens processed: 57,360,384 | tok/sec: 58,488.34
# baseline valid loss: 5.3750 |candidate valid loss: 5.3750
# Baseline completions:
# Hello, I'm a language model, so scientists just hope was more likely before there were more info
# Hello, I'm a language model, they don cell you'd. Not one's most famous when
# Hello, I'm a language model, not always the real, all. But just, a key
# Hello, I'm a language model, for the two other four more five two ways, when there
# Hello, I'm a language model, it comes about an actual step being put about 150.�
# Candidate completions
# Hello, I'm a language model, to consider at first importance; I was writing a good deal
# Hello, I'm a language model, writing by taking many animals for any way in my sense would
# Hello, I'm a language model, like our own attention of reading that will discuss the way there
# Hello, I'm a language model, so that "s not very painfully you're". We
# Hello, I'm a language model, as is. If no one looks are they only are so
# 3520 | lr: 5.69e-04 | baseline loss: 5.5312 | candidate loss: 5.4688 | tokens processed: 57,688,064 | tok/sec: 57,797.34
# 3540 | lr: 5.69e-04 | baseline loss: 5.4375 | candidate loss: 5.3750 | tokens processed: 58,015,744 | tok/sec: 57,785.43
# 3560 | lr: 5.69e-04 | baseline loss: 5.3125 | candidate loss: 5.2500 | tokens processed: 58,343,424 | tok/sec: 58,975.59
# 3580 | lr: 5.68e-04 | baseline loss: 5.2812 | candidate loss: 5.2500 | tokens processed: 58,671,104 | tok/sec: 58,448.10
# 3600 | lr: 5.68e-04 | baseline loss: 5.4062 | candidate loss: 5.3438 | tokens processed: 58,998,784 | tok/sec: 58,236.45
# 3620 | lr: 5.67e-04 | baseline loss: 5.6250 | candidate loss: 5.5625 | tokens processed: 59,326,464 | tok/sec: 58,992.95
# 3640 | lr: 5.67e-04 | baseline loss: 4.9688 | candidate loss: 4.9062 | tokens processed: 59,654,144 | tok/sec: 57,662.08
# 3660 | lr: 5.66e-04 | baseline loss: 5.4062 | candidate loss: 5.3438 | tokens processed: 59,981,824 | tok/sec: 56,937.42
# 3680 | lr: 5.66e-04 | baseline loss: 5.4062 | candidate loss: 5.3438 | tokens processed: 60,309,504 | tok/sec: 58,861.02
# 3700 | lr: 5.66e-04 | baseline loss: 5.0312 | candidate loss: 4.9688 | tokens processed: 60,637,184 | tok/sec: 57,994.84
# 3720 | lr: 5.65e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 60,964,864 | tok/sec: 58,336.56
# 3740 | lr: 5.65e-04 | baseline loss: 5.5312 | candidate loss: 5.5000 | tokens processed: 61,292,544 | tok/sec: 59,529.54
# baseline valid loss: 5.3438 |candidate valid loss: 5.2188
# Baseline completions:
# Hello, I'm a language model, my understanding we had with you, then look at my school
# Hello, I'm a language model, something may provide better clarity of meaning on what to look when
# Hello, I'm a language model, how are a topic and their meaning, their own way might
# Hello, I'm a language model, for the idea and a more
# My idea to I can
# Hello, I'm a language model, or by any form was originally accepted here! How do's
# Candidate completions
# Hello, I'm a language model, �.I thought many I think like each word is my
# Hello, I'm a language model, where there did their stories to solve your beliefs about different strategies
# Hello, I'm a language model, to write the point in you with. Or, then go
# Hello, I'm a language model, my language which are in that most when your body seems the
# Hello, I'm a language model, it I are able each other means working only an individual problem
# 3760 | lr: 5.64e-04 | baseline loss: 5.3125 | candidate loss: 5.2500 | tokens processed: 61,620,224 | tok/sec: 58,869.64
# 3780 | lr: 5.64e-04 | baseline loss: 5.4688 | candidate loss: 5.4062 | tokens processed: 61,947,904 | tok/sec: 58,661.89
# 3800 | lr: 5.63e-04 | baseline loss: 5.1875 | candidate loss: 5.1250 | tokens processed: 62,275,584 | tok/sec: 57,804.29
# 3820 | lr: 5.63e-04 | baseline loss: 5.1250 | candidate loss: 5.0625 | tokens processed: 62,603,264 | tok/sec: 24,127.62
# 3840 | lr: 5.62e-04 | baseline loss: 5.3750 | candidate loss: 5.3125 | tokens processed: 62,930,944 | tok/sec: 28,067.99
# 3860 | lr: 5.62e-04 | baseline loss: 5.2188 | candidate loss: 5.1875 | tokens processed: 63,258,624 | tok/sec: 56,673.71
# 3880 | lr: 5.61e-04 | baseline loss: 5.1875 | candidate loss: 5.1250 | tokens processed: 63,586,304 | tok/sec: 57,407.26
# 3900 | lr: 5.61e-04 | baseline loss: 5.2812 | candidate loss: 5.2188 | tokens processed: 63,913,984 | tok/sec: 58,497.75
# 3920 | lr: 5.60e-04 | baseline loss: 5.0625 | candidate loss: 5.0312 | tokens processed: 64,241,664 | tok/sec: 58,316.56
# 3940 | lr: 5.60e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 64,569,344 | tok/sec: 58,661.39
# 3960 | lr: 5.59e-04 | baseline loss: 5.2500 | candidate loss: 5.1875 | tokens processed: 64,897,024 | tok/sec: 58,216.32
# 3980 | lr: 5.59e-04 | baseline loss: 5.1250 | candidate loss: 5.0625 | tokens processed: 65,224,704 | tok/sec: 58,813.62
# 4000 | lr: 5.58e-04 | baseline loss: 5.2812 | candidate loss: 5.2188 | tokens processed: 65,552,384 | tok/sec: 58,677.82
# baseline valid loss: 5.3125 |candidate valid loss: 5.1875
# Baseline completions:
# Hello, I'm a language model, is so pretty great with all. Let are a great part
# Hello, I'm a language model, too will try your idea and more on it than my idea
# Hello, I'm a language model, you must have information from which it� same thing are intended
# Hello, I'm a language model, they can gain many students into teaching which he has all been
# Hello, I'm a language model, we take everything through each other! With something and we all
# Candidate completions
# Hello, I'm a language model, as being applied at its computer, such is the language-
# Hello, I'm a language model, however (4 minutes)? This term you want the development style
# Hello, I'm a language model, then he is confident that not in language knowledge. So only
# Hello, I'm a language model, or you (1-14 cm range more) up with
# Hello, I'm a language model, in our previous book?
# He and went not in all
# 4020 | lr: 5.58e-04 | baseline loss: 5.0625 | candidate loss: 5.0000 | tokens processed: 65,880,064 | tok/sec: 58,895.93
# 4040 | lr: 5.57e-04 | baseline loss: 5.3125 | candidate loss: 5.2812 | tokens processed: 66,207,744 | tok/sec: 25,478.91
# 4060 | lr: 5.57e-04 | baseline loss: 5.5938 | candidate loss: 5.5312 | tokens processed: 66,535,424 | tok/sec: 60,232.43
# 4080 | lr: 5.56e-04 | baseline loss: 5.2188 | candidate loss: 5.1562 | tokens processed: 66,863,104 | tok/sec: 59,598.31
# 4100 | lr: 5.56e-04 | baseline loss: 5.3125 | candidate loss: 5.2500 | tokens processed: 67,190,784 | tok/sec: 58,937.60
# 4120 | lr: 5.55e-04 | baseline loss: 5.0312 | candidate loss: 4.9688 | tokens processed: 67,518,464 | tok/sec: 58,361.63
# 4140 | lr: 5.55e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 67,846,144 | tok/sec: 59,141.66
# 4160 | lr: 5.54e-04 | baseline loss: 5.0938 | candidate loss: 5.0312 | tokens processed: 68,173,824 | tok/sec: 30,761.85
# 4180 | lr: 5.54e-04 | baseline loss: 4.9062 | candidate loss: 4.8438 | tokens processed: 68,501,504 | tok/sec: 59,704.93
# 4200 | lr: 5.53e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 68,829,184 | tok/sec: 58,796.21
# 4220 | lr: 5.53e-04 | baseline loss: 5.1562 | candidate loss: 5.0938 | tokens processed: 69,156,864 | tok/sec: 58,082.09
# 4240 | lr: 5.52e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 69,484,544 | tok/sec: 58,633.42
# baseline valid loss: 5.2500 |candidate valid loss: 5.2188
# Baseline completions:
# Hello, I'm a language model, in every layer we assume I� N+ (e (
# Hello, I'm a language model, i3 years from both parties – but this technology should we
# Hello, I'm a language model, for I, especially, rather it would later be done because
# Hello, I'm a language model, as I could help the word method better fit, using my
# Hello, I'm a language model, so not by learning on the original business which used the original
# Candidate completions
# Hello, I'm a language model, not very strongly! With their own of some people. Yet
# Hello, I'm a language model, from many months I did in mind; it� seemed my
# Hello, I'm a language model, we find the differences, then that you live in, �
# Hello, I'm a language model, is not alone by no such class — which means or no
# Hello, I'm a language model, but only two? Maybe you should� get? I mean
# 4260 | lr: 5.52e-04 | baseline loss: 4.9688 | candidate loss: 4.9062 | tokens processed: 69,812,224 | tok/sec: 57,880.44
# 4280 | lr: 5.51e-04 | baseline loss: 5.1250 | candidate loss: 5.0625 | tokens processed: 70,139,904 | tok/sec: 57,787.08
# 4300 | lr: 5.51e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 70,467,584 | tok/sec: 58,976.25
# 4320 | lr: 5.50e-04 | baseline loss: 5.1875 | candidate loss: 5.0938 | tokens processed: 70,795,264 | tok/sec: 56,123.97
# 4340 | lr: 5.50e-04 | baseline loss: 4.9375 | candidate loss: 4.8438 | tokens processed: 71,122,944 | tok/sec: 24,511.37
# 4360 | lr: 5.49e-04 | baseline loss: 4.8438 | candidate loss: 4.7812 | tokens processed: 71,450,624 | tok/sec: 28,781.38
# 4380 | lr: 5.49e-04 | baseline loss: 4.9688 | candidate loss: 4.9062 | tokens processed: 71,778,304 | tok/sec: 58,236.01
# 4400 | lr: 5.48e-04 | baseline loss: 5.0938 | candidate loss: 5.0625 | tokens processed: 72,105,984 | tok/sec: 58,153.90
# 4420 | lr: 5.48e-04 | baseline loss: 5.5000 | candidate loss: 5.4375 | tokens processed: 72,433,664 | tok/sec: 59,240.06
# 4440 | lr: 5.47e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 72,761,344 | tok/sec: 57,903.80
# 4460 | lr: 5.46e-04 | baseline loss: 4.8125 | candidate loss: 4.7500 | tokens processed: 73,089,024 | tok/sec: 57,693.55
# 4480 | lr: 5.46e-04 | baseline loss: 5.1250 | candidate loss: 5.0312 | tokens processed: 73,416,704 | tok/sec: 58,658.19
# 4500 | lr: 5.45e-04 | baseline loss: 4.8438 | candidate loss: 4.7812 | tokens processed: 73,744,384 | tok/sec: 58,364.90
# baseline valid loss: 5.1250 |candidate valid loss: 5.3125
# Baseline completions:
# Hello, I'm a language model, then that holds for him by a certain network, but its
# Hello, I'm a language model, rather to communicate how technology works into our future of intelligence processes
# Hello, I'm a language model, so he was based. After his life would be in many
# Hello, I'm a language model, in a game with my skills we started so to our company
# Hello, I'm a language model, a particular scenario would bring on when thinking over many other concepts
# Candidate completions
# Hello, I'm a language model, or who made my students more. Now at least, at
# Hello, I'm a language model, such it are two categories and of those used by friends working
# Hello, I'm a language model, to take the form and get an entire topic.”
# Hello, I'm a language model, that was well to go beyond (n, the group and
# Hello, I'm a language model, it did almost no effect. By analyzing more it is an
# 4520 | lr: 5.45e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 74,072,064 | tok/sec: 28,575.33
# 4540 | lr: 5.44e-04 | baseline loss: 5.3125 | candidate loss: 5.1875 | tokens processed: 74,399,744 | tok/sec: 57,728.98
# 4560 | lr: 5.44e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 74,727,424 | tok/sec: 58,925.63
# 4580 | lr: 5.43e-04 | baseline loss: 5.2812 | candidate loss: 5.2188 | tokens processed: 75,055,104 | tok/sec: 58,024.91
# 4600 | lr: 5.42e-04 | baseline loss: 5.0938 | candidate loss: 5.0625 | tokens processed: 75,382,784 | tok/sec: 59,205.86
# 4620 | lr: 5.42e-04 | baseline loss: 4.9688 | candidate loss: 4.8750 | tokens processed: 75,710,464 | tok/sec: 58,801.94
# 4640 | lr: 5.41e-04 | baseline loss: 4.7812 | candidate loss: 4.6875 | tokens processed: 76,038,144 | tok/sec: 58,108.22
# 4660 | lr: 5.41e-04 | baseline loss: 5.0625 | candidate loss: 4.9688 | tokens processed: 76,365,824 | tok/sec: 58,365.74
# 4680 | lr: 5.40e-04 | baseline loss: 5.0938 | candidate loss: 5.0312 | tokens processed: 76,693,504 | tok/sec: 58,246.91
# 4700 | lr: 5.40e-04 | baseline loss: 5.1875 | candidate loss: 5.0938 | tokens processed: 77,021,184 | tok/sec: 57,579.27
# 4720 | lr: 5.39e-04 | baseline loss: 5.2188 | candidate loss: 5.1562 | tokens processed: 77,348,864 | tok/sec: 57,286.47
# 4740 | lr: 5.38e-04 | baseline loss: 5.1250 | candidate loss: 5.0312 | tokens processed: 77,676,544 | tok/sec: 58,137.22
# baseline valid loss: 5.0625 |candidate valid loss: 5.0000
# Baseline completions:
# Hello, I'm a language model, for such much attention," writes Drhlin.<|endoftext|>By
# Hello, I'm a language model, from all about in both a game is in fact." How
# Hello, I'm a language model, like science-toxicing and culture I have the knowledge
# Hello, I'm a language model, which means and can use with good value by using less and
# Hello, I'm a language model, that cannot, so he can become his world before him that
# Candidate completions
# Hello, I'm a language model, it allows You: A new book? That's what really
# Hello, I'm a language model, however: It helps others understand of you as much is how
# Hello, I'm a language model, which could have happened with in his speech the world with those
# Hello, I'm a language model, in my present-classes who work again in fronts
# Hello, I'm a language model, you just ask. Here are hundreds free times all of their
# 4760 | lr: 5.38e-04 | baseline loss: 4.9375 | candidate loss: 4.8750 | tokens processed: 78,004,224 | tok/sec: 57,981.24
# 4780 | lr: 5.37e-04 | baseline loss: 5.0625 | candidate loss: 5.0000 | tokens processed: 78,331,904 | tok/sec: 58,316.02
# 4800 | lr: 5.37e-04 | baseline loss: 5.5000 | candidate loss: 5.4062 | tokens processed: 78,659,584 | tok/sec: 58,875.65
# 4820 | lr: 5.36e-04 | baseline loss: 5.0312 | candidate loss: 4.9375 | tokens processed: 78,987,264 | tok/sec: 58,478.69
# 4840 | lr: 5.35e-04 | baseline loss: 5.0000 | candidate loss: 4.9062 | tokens processed: 79,314,944 | tok/sec: 57,520.95
# ...
# 6680 | lr: 4.71e-04 | baseline loss: 4.5938 | candidate loss: 4.5312 | tokens processed: 109,461,504 | tok/sec: 59,180.93
# 6700 | lr: 4.70e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 109,789,184 | tok/sec: 58,384.93
# 6720 | lr: 4.70e-04 | baseline loss: 4.7188 | candidate loss: 4.6875 | tokens processed: 110,116,864 | tok/sec: 58,513.99
# 6740 | lr: 4.69e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 110,444,544 | tok/sec: 57,135.96
# baseline valid loss: 4.6875 |candidate valid loss: 4.6562
# Baseline completions:
# Hello, I'm a language model,
# Lillo A.; (1985 that I�)
# Hello, I'm a language model, not my site has already used much detail for me of using
# Hello, I'm a language model, this method will keep reading my next. One of her learning
# Hello, I'm a language model, there�m much better as anyone looking them, more easily
# Hello, I'm a language model, my school model can apply to math this question through a course
# Candidate completions
# Hello, I'm a language model, which uses both an intermediate English word by following a second phrase
# Hello, I'm a language model, here; Now why then the lesson does. And one would
# Hello, I'm a language model, how does the mind be from learning how one of our individual
# Hello, I'm a language model, because you decide on how do English pronunciation get? But I
# Hello, I'm a language model, you and each individual’ area within 30 words and on
# 6760 | lr: 4.68e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 110,772,224 | tok/sec: 24,877.83
# 6780 | lr: 4.67e-04 | baseline loss: 4.7500 | candidate loss: 4.6875 | tokens processed: 111,099,904 | tok/sec: 58,561.01
# 6800 | lr: 4.66e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 111,427,584 | tok/sec: 58,826.40
# 6820 | lr: 4.66e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 111,755,264 | tok/sec: 59,285.85
# 6840 | lr: 4.65e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 112,082,944 | tok/sec: 58,556.27
# 6860 | lr: 4.64e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 112,410,624 | tok/sec: 56,977.97
# 6880 | lr: 4.63e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 112,738,304 | tok/sec: 58,155.72
# 6900 | lr: 4.62e-04 | baseline loss: 5.0625 | candidate loss: 5.0000 | tokens processed: 113,065,984 | tok/sec: 58,357.86
# 6920 | lr: 4.62e-04 | baseline loss: 4.6562 | candidate loss: 4.5625 | tokens processed: 113,393,664 | tok/sec: 58,402.60
# 6940 | lr: 4.61e-04 | baseline loss: 4.6875 | candidate loss: 4.6562 | tokens processed: 113,721,344 | tok/sec: 58,636.07
# 6960 | lr: 4.60e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 114,049,024 | tok/sec: 57,634.61
# 6980 | lr: 4.59e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 114,376,704 | tok/sec: 58,200.74
# 7000 | lr: 4.58e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 114,704,384 | tok/sec: 58,352.31
# baseline valid loss: 4.6875 |candidate valid loss: 4.6562
# Baseline completions:
# Hello, I'm a language model, or more – from
# M. Vib.
# H
# Hello, I'm a language model, like some photos-hay of which have evolved throughout Asia
# Hello, I'm a language model, in one way our knowledge base to our audience. In general
# Hello, I'm a language model, for the application for an email I is on my my site
# Hello, I'm a language model, my teacher (who often seem!) The child here are actually
# Candidate completions
# Hello, I'm a language model, as will as they may use. Some English words will begin
# Hello, I'm a language model, maybe one being part as to life (which we�so
# Hello, I'm a language model, if one of life's thoughts about, so I would appreciate
# Hello, I'm a language model, not the speaker's action was applied through discussion of these sentences
# Hello, I'm a language model, so long what, no, on other computer issues is being
# 7020 | lr: 4.58e-04 | baseline loss: 4.5312 | candidate loss: 4.4688 | tokens processed: 115,032,064 | tok/sec: 58,313.99
# 7040 | lr: 4.57e-04 | baseline loss: 4.5938 | candidate loss: 4.5312 | tokens processed: 115,359,744 | tok/sec: 24,001.63
# 7060 | lr: 4.56e-04 | baseline loss: 4.6250 | candidate loss: 4.5625 | tokens processed: 115,687,424 | tok/sec: 59,419.55
# 7080 | lr: 4.55e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 116,015,104 | tok/sec: 57,128.17
# 7100 | lr: 4.54e-04 | baseline loss: 4.2812 | candidate loss: 4.2188 | tokens processed: 116,342,784 | tok/sec: 58,589.77
# 7120 | lr: 4.53e-04 | baseline loss: 4.9688 | candidate loss: 4.9062 | tokens processed: 116,670,464 | tok/sec: 24,165.57
# 7140 | lr: 4.53e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 116,998,144 | tok/sec: 58,166.26
# 7160 | lr: 4.52e-04 | baseline loss: 4.5000 | candidate loss: 4.4375 | tokens processed: 117,325,824 | tok/sec: 58,677.67
# 7180 | lr: 4.51e-04 | baseline loss: 4.3438 | candidate loss: 4.3125 | tokens processed: 117,653,504 | tok/sec: 57,262.03
# 7200 | lr: 4.50e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 117,981,184 | tok/sec: 58,924.06
# 7220 | lr: 4.49e-04 | baseline loss: 4.6250 | candidate loss: 4.5625 | tokens processed: 118,308,864 | tok/sec: 58,428.62
# 7240 | lr: 4.48e-04 | baseline loss: 4.4375 | candidate loss: 4.3750 | tokens processed: 118,636,544 | tok/sec: 58,970.83
# baseline valid loss: 4.5938 |candidate valid loss: 4.6250
# Baseline completions:
# Hello, I'm a language model, as though only that for one of three characters is still much
# Hello, I'm a language model,� sense my focus might lead something better off my readers so
# Hello, I'm a language model, you need a word of living your dog up to learn exactly
# Hello, I'm a language model, we are used a method we'll only available in programming the
# Hello, I'm a language model, that still will come right as most recently started all of an
# Candidate completions
# Hello, I'm a language model, is sometimes going up right or you say I am I just
# Hello, I'm a language model, whether there does and a number where this was done right without
# Hello, I'm a language model, in other language people that exist for us during the long first
# Hello, I'm a language model, as I might know the power within others when it rains them
# Hello, I'm a language model, not of communication as children." Most social. At a more
# 7260 | lr: 4.48e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 118,964,224 | tok/sec: 59,021.53
# 7280 | lr: 4.47e-04 | baseline loss: 4.4688 | candidate loss: 4.4062 | tokens processed: 119,291,904 | tok/sec: 56,677.68
# 7300 | lr: 4.46e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 119,619,584 | tok/sec: 24,228.79
# 7320 | lr: 4.45e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 119,947,264 | tok/sec: 58,403.15
# 7340 | lr: 4.44e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 120,274,944 | tok/sec: 58,026.33
# 7360 | lr: 4.43e-04 | baseline loss: 4.4062 | candidate loss: 4.3438 | tokens processed: 120,602,624 | tok/sec: 57,984.71
# 7380 | lr: 4.43e-04 | baseline loss: 4.6250 | candidate loss: 4.5938 | tokens processed: 120,930,304 | tok/sec: 28,495.88
# 7400 | lr: 4.42e-04 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 121,257,984 | tok/sec: 58,638.07
# 7420 | lr: 4.41e-04 | baseline loss: 4.5312 | candidate loss: 4.4688 | tokens processed: 121,585,664 | tok/sec: 58,562.26
# 7440 | lr: 4.40e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 121,913,344 | tok/sec: 58,034.51
# 7460 | lr: 4.39e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 122,241,024 | tok/sec: 57,841.07
# 7480 | lr: 4.38e-04 | baseline loss: 4.8750 | candidate loss: 4.8125 | tokens processed: 122,568,704 | tok/sec: 57,346.85
# 7500 | lr: 4.38e-04 | baseline loss: 4.7500 | candidate loss: 4.6875 | tokens processed: 122,896,384 | tok/sec: 57,493.76
# baseline valid loss: 4.6875 |candidate valid loss: 4.5625
# Baseline completions:
# Hello, I'm a language model, one about using and selecting on a layer which I've already
# Hello, I'm a language model, we must give readers such about his world; it shows clear
# Hello, I'm a language model,
# which I discuss in many other contexts where I want to
# Hello, I'm a language model, it sounds just like ‽us' The Great English:
# Hello, I'm a language model, in his context (E.A rather powerful philosophy of mathematics
# Candidate completions
# Hello, I'm a language model, an object will. With reading and making visual images of space
# Hello, I'm a language model, even like The Family Association: LABH
# And maybe
# Hello, I'm a language model, "Do me an act if a child works?" What has
# Hello, I'm a language model, for a given level and my way the text, text is
# Hello, I'm a language model, not too from that class. Children could teach through language by
# 7520 | lr: 4.37e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 123,224,064 | tok/sec: 58,136.88
# 7540 | lr: 4.36e-04 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 123,551,744 | tok/sec: 57,212.64
# 7560 | lr: 4.35e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 123,879,424 | tok/sec: 58,729.63
# 7580 | lr: 4.34e-04 | baseline loss: 4.7812 | candidate loss: 4.7188 | tokens processed: 124,207,104 | tok/sec: 58,094.41
# 7600 | lr: 4.33e-04 | baseline loss: 4.5312 | candidate loss: 4.5000 | tokens processed: 124,534,784 | tok/sec: 58,285.05
# 7620 | lr: 4.32e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 124,862,464 | tok/sec: 57,577.15
# 7640 | lr: 4.32e-04 | baseline loss: 4.6562 | candidate loss: 4.6250 | tokens processed: 125,190,144 | tok/sec: 57,775.28
# 7660 | lr: 4.31e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 125,517,824 | tok/sec: 58,304.69
# 7680 | lr: 4.30e-04 | baseline loss: 4.4688 | candidate loss: 4.4375 | tokens processed: 125,845,504 | tok/sec: 58,356.67
# 7700 | lr: 4.29e-04 | baseline loss: 4.7812 | candidate loss: 4.7500 | tokens processed: 126,173,184 | tok/sec: 58,788.41
# 7720 | lr: 4.28e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 126,500,864 | tok/sec: 57,774.60
# 7740 | lr: 4.27e-04 | baseline loss: 4.7500 | candidate loss: 4.7188 | tokens processed: 126,828,544 | tok/sec: 58,229.99
# baseline valid loss: 4.5625 |candidate valid loss: 4.5625
# Baseline completions:
# Hello, I'm a language model, one kind way from multiple characters. When and where the program
# Hello, I'm a language model, this can explain everything inside and possibly all a little computer (
# Hello, I'm a language model, to have the words, like it would tell you a problem
# Hello, I'm a language model, that has given my experience using machine data over time because there
# Hello, I'm a language model, so look here as part of whether all new developments were now
# Candidate completions
# Hello, I'm a language model, the question itself with people you're, at least you do
# Hello, I'm a language model,
# the job will. In it can mean the "no
# Hello, I'm a language model, not what to define your situation as it exists. But most
# Hello, I'm a language model, because the concepts can do very very independently can do quite accurately
# Hello, I'm a language model, a list comes into "the state power grid -- the word
# 7760 | lr: 4.26e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 127,156,224 | tok/sec: 58,172.90
# 7780 | lr: 4.26e-04 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 127,483,904 | tok/sec: 57,202.97
# 7800 | lr: 4.25e-04 | baseline loss: 4.5000 | candidate loss: 4.4688 | tokens processed: 127,811,584 | tok/sec: 23,681.79
# 7820 | lr: 4.24e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 128,139,264 | tok/sec: 57,216.79
# 7840 | lr: 4.23e-04 | baseline loss: 4.5000 | candidate loss: 4.4375 | tokens processed: 128,466,944 | tok/sec: 57,695.44
# 7860 | lr: 4.22e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 128,794,624 | tok/sec: 57,063.28
# 7880 | lr: 4.21e-04 | baseline loss: 4.5938 | candidate loss: 4.5625 | tokens processed: 129,122,304 | tok/sec: 56,614.32
# 7900 | lr: 4.20e-04 | baseline loss: 4.7188 | candidate loss: 4.6562 | tokens processed: 129,449,984 | tok/sec: 56,696.10
# 7920 | lr: 4.19e-04 | baseline loss: 4.6875 | candidate loss: 4.6250 | tokens processed: 129,777,664 | tok/sec: 58,418.73
# 7940 | lr: 4.19e-04 | baseline loss: 4.5938 | candidate loss: 4.5938 | tokens processed: 130,105,344 | tok/sec: 54,791.44
# 7960 | lr: 4.18e-04 | baseline loss: 4.7812 | candidate loss: 4.7500 | tokens processed: 130,433,024 | tok/sec: 23,458.24
# 7980 | lr: 4.17e-04 | baseline loss: 4.5625 | candidate loss: 4.5000 | tokens processed: 130,760,704 | tok/sec: 57,354.41
# 8000 | lr: 4.16e-04 | baseline loss: 4.4375 | candidate loss: 4.4062 | tokens processed: 131,088,384 | tok/sec: 58,078.16
# baseline valid loss: 4.5000 |candidate valid loss: 4.4375
# Baseline completions:
# Hello, I'm a language model, it just holds you out by a class which you have read
# Hello, I'm a language model, this example by students - it requires one and a school students
# Hello, I'm a language model, in general. Many languages offer more complete explanation.<|endoftext|>D
# Hello, I'm a language model, to describe you a different design so different techniques, knowledge in
# Hello, I'm a language model, the fact a method here. Students' choice through their choice
# Candidate completions
# Hello, I'm a language model, as people take. Some groups, one has a lot experience
# Hello, I'm a language model, however with his/M is often in fact that both occurs
# Hello, I'm a language model, to use a voice that includes being "learned as normal
# Hello, I'm a language model, you will love you when learning new examples as you did and
# Hello, I'm a language model, which focuses largely with being a leader person responsible out to do
# 8020 | lr: 4.15e-04 | baseline loss: 4.5312 | candidate loss: 4.4688 | tokens processed: 131,416,064 | tok/sec: 57,587.47
# 8040 | lr: 4.14e-04 | baseline loss: 4.4688 | candidate loss: 4.4062 | tokens processed: 131,743,744 | tok/sec: 57,775.91
# 8060 | lr: 4.13e-04 | baseline loss: 4.5625 | candidate loss: 4.5312 | tokens processed: 132,071,424 | tok/sec: 57,734.46
# 8080 | lr: 4.12e-04 | baseline loss: 4.5000 | candidate loss: 4.4375 | tokens processed: 132,399,104 | tok/sec: 58,431.15
# 8100 | lr: 4.12e-04 | baseline loss: 4.8438 | candidate loss: 4.8125 | tokens processed: 132,726,784 | tok/sec: 56,839.37
# 8120 | lr: 4.11e-04 | baseline loss: 4.5625 | candidate loss: 4.5000 | tokens processed: 133,054,464 | tok/sec: 57,421.94
# 8140 | lr: 4.10e-04 | baseline loss: 4.5000 | candidate loss: 4.4375 | tokens processed: 133,382,144 | tok/sec: 57,336.61
# 8160 | lr: 4.09e-04 | baseline loss: 4.0938 | candidate loss: 4.0625 | tokens processed: 133,709,824 | tok/sec: 58,917.29
# Received KeyboardInterrupt. Exiting...
# baseline valid loss: 4.6562 | candidate valid loss: 4.5000
# baseline completions
# Hello, I'm a language model, as these technologies would later turn out across and then be applied
# Hello, I'm a language model, they doni because at all kinds one and two sets as
# Hello, I'm a language model, with more information… I see what is clear about our most
# Hello, I'm a language model, where we get that of something it came through the study process
# Hello, I'm a language model, for teaching him/stq1's ideas or works out
# candidate completions
# Hello, I'm a language model, or your knowledge for learning something that takes long. And because
# Hello, I'm a language model, my name isn'll end the cycle from "a tree planted
# Hello, I'm a language model, because some people start reading language learning as people, you feel
# Hello, I'm a language model, we dons, it all looks too small to try with
# Hello, I'm a language model, which helps form it is a reality – just someone, maybe

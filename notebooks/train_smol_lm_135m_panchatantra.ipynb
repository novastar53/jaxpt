# %% [markdown]
# # Let's Train SmolLM 135M

# %% [markdown]
# ### Configure the machine and install packages

# %%
import os

#os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=8'

from typing import Literal

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken datasets --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# fatal: destination path 'jaxpt' already exists and is not an empty directory.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# WARNING: Skipping tensorflow as it is not installed.

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )


sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import flax
import jax.numpy as jnp
import numpy as np

from jax.sharding import Mesh, PartitionSpec, NamedSharding

# Hardware setup
print("JAX version:", jax.__version__)
print("Flax version", flax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

requested_device = "gpu"

jax.config.update("jax_platform_name", requested_device) # Make sure we're using the GPU

mesh = Mesh(devices, ("devices",))
spec = PartitionSpec("devices",)
sharding = NamedSharding(mesh, spec)

device = jax.default_backend()
if device != requested_device:
    warnings.warn(f"not using {requested_device}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Make sure matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Flax version 0.10.6
# Available devices: 1
# using gpu
# 794 µs ± 9.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Initialize SmolLLM model and perform a sanity check

# %%
from flax import nnx

from jaxpt.infer import generate_completions, generate
from jaxpt.models import SmolLM, SmolLM_Config
from jaxpt.models.smol_lm import from_hf_pretrained
from jaxpt.utils import count_params, create_sharded_model

from transformers import AutoTokenizer

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = SmolLM_Config(dtype=jnp.bfloat16, \
                    #vocab_size=49152,
                    block_size=128,
                    n_layer=4,
                    n_embed=128,
                    n_head=4,
                    n_kv_head=2,
                    n_mlp_hidden=384,
                    use_cache=False,
                    mesh=mesh,
                    sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)
with mesh:
    m = create_sharded_model(SmolLM, config, rngs)
    #m = SmolLM(config, rngs)
    #graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
    #nnx.display(state)
    #m = load_checkpoint("run_20250311_uqdwjq", 5600)
    #m = from_hf_pretrained(config, rngs)

    graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
    total_params = count_params(m)

    print(f"Parameter Count: {total_params:,}")
    nnx.display(state)

    tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-135M")
    #completions = generate_completions(m, enc=tokenizer, num_completions=5, max_length=21, prefix="Ducks quack, donkeys bray, cats mew, horses")
    #for completion in completions:
    #    print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_5916696c5d214ae697f164d41066f26f" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_5916696c5d214ae697f164d41066f26f")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_5916696c5d214ae697f164d41066f26f")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Parameter Count: 7,220,480
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_251dcf5e16fb46b8bdcc5071712445ae" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_251dcf5e16fb46b8bdcc5071712445ae")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_251dcf5e16fb46b8bdcc5071712445ae")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_251dcf5e16fb46b8bdcc5071712445ae")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %%
jax.debug.visualize_array_sharding(state.wte.embedding.value)
# Out:
#
#
#
#
#
#   GPU 0

# %% [markdown]
# ### Configure Training Run

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

run_dirname = f"run_{timestamp}_{random_code}"
print(f"Run: {run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Run: run_20250718_cmxakz
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %%
import dataclasses

import optax


############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**12 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 32 * num_devices
  T: int = 128
  max_steps: int = int((2000*146776) // (2**12))
  max_lr: float = 1e-2
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 3
  print_interval: int = 5
  eval_interval: int = 5000
  checkpoint_interval: int = 10000
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()
'''
trconf = TrainerConfig(
  num_tokens_per_batch=2**9,
  mB=2**4,
  T=2**5,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)

trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient
'''

# Set up the optimizer
cool_down_period = 0.3
def trapezoidal_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    cooldown_lr = trconf.max_lr * (trconf.max_steps - step) / (trconf.max_steps - (1 - cool_down_period) * trconf.max_steps)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < (1 - cool_down_period) * trconf.max_steps, trconf.max_lr, cooldown_lr))

steps = range(0, trconf.max_steps, 1000)
total_schedule = [ trapezoidal_schedule(step) for step in steps ]
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.plot(steps, total_schedule)
plt.title("LR Schedule")
plt.show()

# Generate a weight decay mask
# First split the model into params and variables
graphdef, params, variables = nnx.split(m, nnx.Param, nnx.Variable)
# Then create a mask for the weight decay params
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)

tx = optax.chain(
    #optax.clip_by_global_norm(trconf.max_grad_norm),
    #optax.adamw(trapezoidal_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask),
    optax.adam(trapezoidal_schedule)
)
optimizer = nnx.Optimizer(m, tx)

# count the number of weight decay params
def f(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(f, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)


print(f"weight decay param count: {weight_decay_param_count:,}")
print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB // num_devices)
print(f"max steps: {trconf.max_steps:,}")
# Out:
# weight decay param count: 7,219,328
# tokens/batch: 4,096
# block size: 128
# batch size: 32
# no. gradient accumulation steps: 1
# effective batch size: 32
# effective batch size per device:  32
# max steps: 71,667

# %% [markdown]
# ### DataLoader and Validation Setup

# %%
from jaxpt.dataloaders import DataLoader, HuggingfaceDataLoader, CloudDataLoader

batch_size = trconf.T * trconf.mB * trconf.grad_accumulation_steps
batch_memory = batch_size*2
print(f"Batch Size (Tokens): {batch_size:,} | Batch Memory: {batch_memory/1024} MB")

'''
train_dl = HuggingfaceDataLoader(batch_size=trconf.mB * DATA_DIMS,
                                 block_size=trconf.T,
                                 device_rank=1,
                                 tokenizer="HuggingFaceTB/SmolLM-135M",
                                 dataset_paths=["HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus"],
                                 dataset_names=["cosmopedia-v2",
                                                "python-edu",
                                                "fineweb-edu-dedup"],
                                 probabilities=[0.111, 0.016 , 0.873],
                                 label="train",
                                 random_seed=1337,
                                 buffer_size=10_000,
                                 streaming=True)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./alpha-448101-282bc1b884cd.json"

train_dl = CloudDataLoader(bucket_name="jaxpt_datasets",
                      bucket_prefix="fineweb-edu-100b/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")

'''
train_dl = DataLoader(dirpath="/content/jaxpt/datasets/panchatantra-ryder/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
# Out:
# Batch Size (Tokens): 4,096 | Batch Memory: 8.0 MB
# DataLoader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     32
# block size:     128
# device rank:    1
# ------------------------

# %%
from jaxpt.utils import append_to_csv

train_losses = []
append_to_csv(log_dir / f"{run_dirname}_train.csv", ["step", "lr", "loss", "time", "tokens_processed", "tokens_per_sec"])
step = 0

# %%
# %matplotlib inline

import time

import matplotlib.pyplot as plt


def loss_fn(model, batch, targets):
    logits = model(batch)
    loss = optax.softmax_cross_entropy_with_integer_labels(logits, targets)
    return loss.mean(), logits


@nnx.jit
def train_step(model, optimizer, batch, targets):
    (loss, logits), grads = nnx.value_and_grad(loss_fn, has_aux=True)(model, batch, targets)
    optimizer.update(grads)
    return loss, grads, logits


m.train()
try:
  while step < trconf.max_steps:
    start = time.time()
    batch, target = train_dl()
    batch = jax.device_put(batch.squeeze(), sharding)
    target = jax.device_put(target.squeeze(), sharding)
    loss, grads, logits = train_step(m, optimizer, batch, target)

    if step % trconf.print_interval == 0:
      # compute stats
      loss.block_until_ready()
      lr = trapezoidal_schedule(step)
      iter_time = time.time() - start
      sub_step_time = iter_time / trconf.grad_accumulation_steps
      tokens_per_sec = trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
      tokens_processed = (step+1) * trconf.grad_accumulation_steps * trconf.mB * trconf.T

      train_losses.append((step, loss))
      append_to_csv(log_dir / f"{run_dirname}_train.csv", [step, lr, loss, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | "
            f"loss: {loss:0.4f} | "
            f"time: {iter_time*1000:0.2f}ms | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      print("Evaluation TBD")
      #save_checkpoint(m, run_dirname, step)
    step += 1

except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

plt.figure(figsize=(5, 3))
plt.plot([x[0] for x in train_losses], [x[1] for x in train_losses], label="train loss")
plt.legend()
plt.savefig(log_dir / f"{run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# 46695 | lr: 1.00e-02 | loss: 0.1702 | time: 13.88ms | tokens processed: 191,266,816 | tok/sec: 295,024.54
# 46700 | lr: 1.00e-02 | loss: 0.1857 | time: 13.11ms | tokens processed: 191,287,296 | tok/sec: 312,412.38
# 46705 | lr: 1.00e-02 | loss: 0.1695 | time: 13.35ms | tokens processed: 191,307,776 | tok/sec: 306,810.77
# 46710 | lr: 1.00e-02 | loss: 0.1753 | time: 14.11ms | tokens processed: 191,328,256 | tok/sec: 290,332.91
# 46715 | lr: 1.00e-02 | loss: 0.1740 | time: 14.02ms | tokens processed: 191,348,736 | tok/sec: 292,095.16
# 46720 | lr: 1.00e-02 | loss: 0.1837 | time: 13.86ms | tokens processed: 191,369,216 | tok/sec: 295,521.88
# 46725 | lr: 1.00e-02 | loss: 0.2093 | time: 14.31ms | tokens processed: 191,389,696 | tok/sec: 286,183.29
# 46730 | lr: 1.00e-02 | loss: 0.1806 | time: 14.73ms | tokens processed: 191,410,176 | tok/sec: 278,121.92
# 46735 | lr: 1.00e-02 | loss: 0.1749 | time: 14.60ms | tokens processed: 191,430,656 | tok/sec: 280,460.19
# 46740 | lr: 1.00e-02 | loss: 0.1863 | time: 14.77ms | tokens processed: 191,451,136 | tok/sec: 277,358.60
# 46745 | lr: 1.00e-02 | loss: 0.1903 | time: 14.67ms | tokens processed: 191,471,616 | tok/sec: 279,138.68
# 46750 | lr: 1.00e-02 | loss: 0.1893 | time: 13.51ms | tokens processed: 191,492,096 | tok/sec: 303,183.08
# 46755 | lr: 1.00e-02 | loss: 0.1604 | time: 14.96ms | tokens processed: 191,512,576 | tok/sec: 273,795.87
# 46760 | lr: 1.00e-02 | loss: 0.1841 | time: 14.75ms | tokens processed: 191,533,056 | tok/sec: 277,667.91
# 46765 | lr: 1.00e-02 | loss: 0.1740 | time: 14.77ms | tokens processed: 191,553,536 | tok/sec: 277,242.23
# 46770 | lr: 1.00e-02 | loss: 0.2088 | time: 14.65ms | tokens processed: 191,574,016 | tok/sec: 279,579.31
# 46775 | lr: 1.00e-02 | loss: 0.2068 | time: 14.86ms | tokens processed: 191,594,496 | tok/sec: 275,583.40
# 46780 | lr: 1.00e-02 | loss: 0.1729 | time: 13.48ms | tokens processed: 191,614,976 | tok/sec: 303,955.51
# 46785 | lr: 1.00e-02 | loss: 0.1579 | time: 14.86ms | tokens processed: 191,635,456 | tok/sec: 275,578.98
# 46790 | lr: 1.00e-02 | loss: 0.1613 | time: 14.57ms | tokens processed: 191,655,936 | tok/sec: 281,093.45
# 46795 | lr: 1.00e-02 | loss: 0.1760 | time: 15.08ms | tokens processed: 191,676,416 | tok/sec: 271,566.96
# 46800 | lr: 1.00e-02 | loss: 0.1782 | time: 14.83ms | tokens processed: 191,696,896 | tok/sec: 276,234.77
# 46805 | lr: 1.00e-02 | loss: 0.1611 | time: 14.46ms | tokens processed: 191,717,376 | tok/sec: 283,178.43
# 46810 | lr: 1.00e-02 | loss: 0.1898 | time: 14.14ms | tokens processed: 191,737,856 | tok/sec: 289,618.32
# 46815 | lr: 1.00e-02 | loss: 0.2223 | time: 14.58ms | tokens processed: 191,758,336 | tok/sec: 280,978.51
# 46820 | lr: 1.00e-02 | loss: 0.1384 | time: 14.83ms | tokens processed: 191,778,816 | tok/sec: 276,239.21
# 46825 | lr: 1.00e-02 | loss: 0.1836 | time: 14.37ms | tokens processed: 191,799,296 | tok/sec: 285,114.66
# 46830 | lr: 1.00e-02 | loss: 0.1803 | time: 14.60ms | tokens processed: 191,819,776 | tok/sec: 280,634.28
# 46835 | lr: 1.00e-02 | loss: 0.1857 | time: 14.52ms | tokens processed: 191,840,256 | tok/sec: 282,155.26
# 46840 | lr: 1.00e-02 | loss: 0.1794 | time: 13.94ms | tokens processed: 191,860,736 | tok/sec: 293,914.14
# 46845 | lr: 1.00e-02 | loss: 0.1867 | time: 14.67ms | tokens processed: 191,881,216 | tok/sec: 279,220.34
# 46850 | lr: 1.00e-02 | loss: 0.1808 | time: 13.06ms | tokens processed: 191,901,696 | tok/sec: 313,598.55
# 46855 | lr: 1.00e-02 | loss: 0.1711 | time: 13.28ms | tokens processed: 191,922,176 | tok/sec: 308,374.81
# 46860 | lr: 1.00e-02 | loss: 0.1687 | time: 12.87ms | tokens processed: 191,942,656 | tok/sec: 318,375.66
# 46865 | lr: 1.00e-02 | loss: 0.1956 | time: 14.64ms | tokens processed: 191,963,136 | tok/sec: 279,738.65
# 46870 | lr: 1.00e-02 | loss: 0.1937 | time: 12.87ms | tokens processed: 191,983,616 | tok/sec: 318,228.23
# 46875 | lr: 1.00e-02 | loss: 0.1706 | time: 14.67ms | tokens processed: 192,004,096 | tok/sec: 279,197.65
# 46880 | lr: 1.00e-02 | loss: 0.1744 | time: 13.96ms | tokens processed: 192,024,576 | tok/sec: 293,327.00
# 46885 | lr: 1.00e-02 | loss: 0.1678 | time: 14.90ms | tokens processed: 192,045,056 | tok/sec: 274,943.89
# 46890 | lr: 1.00e-02 | loss: 0.1577 | time: 14.76ms | tokens processed: 192,065,536 | tok/sec: 277,578.19
# 46895 | lr: 1.00e-02 | loss: 0.1861 | time: 14.95ms | tokens processed: 192,086,016 | tok/sec: 273,944.30
# 46900 | lr: 1.00e-02 | loss: 0.1489 | time: 13.53ms | tokens processed: 192,106,496 | tok/sec: 302,686.30
# 46905 | lr: 1.00e-02 | loss: 0.1738 | time: 13.89ms | tokens processed: 192,126,976 | tok/sec: 294,806.85
# 46910 | lr: 1.00e-02 | loss: 0.1525 | time: 14.57ms | tokens processed: 192,147,456 | tok/sec: 281,134.84
# 46915 | lr: 1.00e-02 | loss: 0.1763 | time: 14.90ms | tokens processed: 192,167,936 | tok/sec: 274,855.92
# 46920 | lr: 1.00e-02 | loss: 0.1783 | time: 13.02ms | tokens processed: 192,188,416 | tok/sec: 314,713.02
# 46925 | lr: 1.00e-02 | loss: 0.2053 | time: 14.27ms | tokens processed: 192,208,896 | tok/sec: 287,082.35
# 46930 | lr: 1.00e-02 | loss: 0.1928 | time: 12.77ms | tokens processed: 192,229,376 | tok/sec: 320,717.40
# 46935 | lr: 1.00e-02 | loss: 0.1865 | time: 13.85ms | tokens processed: 192,249,856 | tok/sec: 295,745.73
# 46940 | lr: 1.00e-02 | loss: 0.1724 | time: 14.24ms | tokens processed: 192,270,336 | tok/sec: 287,611.02
# 46945 | lr: 1.00e-02 | loss: 0.1843 | time: 14.33ms | tokens processed: 192,290,816 | tok/sec: 285,845.22
# 46950 | lr: 1.00e-02 | loss: 0.1716 | time: 14.30ms | tokens processed: 192,311,296 | tok/sec: 286,345.47
# 46955 | lr: 1.00e-02 | loss: 0.1711 | time: 14.56ms | tokens processed: 192,331,776 | tok/sec: 281,351.24
# 46960 | lr: 1.00e-02 | loss: 0.1870 | time: 13.10ms | tokens processed: 192,352,256 | tok/sec: 312,628.41
# 46965 | lr: 1.00e-02 | loss: 0.1616 | time: 14.47ms | tokens processed: 192,372,736 | tok/sec: 282,977.87
# 46970 | lr: 1.00e-02 | loss: 0.1636 | time: 14.63ms | tokens processed: 192,393,216 | tok/sec: 279,980.27
# 46975 | lr: 1.00e-02 | loss: 0.1661 | time: 14.53ms | tokens processed: 192,413,696 | tok/sec: 281,905.24
# 46980 | lr: 1.00e-02 | loss: 0.1808 | time: 14.53ms | tokens processed: 192,434,176 | tok/sec: 281,863.61
# 46985 | lr: 1.00e-02 | loss: 0.1751 | time: 14.08ms | tokens processed: 192,454,656 | tok/sec: 290,962.30
# 46990 | lr: 1.00e-02 | loss: 0.1820 | time: 13.51ms | tokens processed: 192,475,136 | tok/sec: 303,252.65
# 46995 | lr: 1.00e-02 | loss: 0.1828 | time: 14.46ms | tokens processed: 192,495,616 | tok/sec: 283,178.43
# 47000 | lr: 1.00e-02 | loss: 0.1783 | time: 14.57ms | tokens processed: 192,516,096 | tok/sec: 281,111.84
# 47005 | lr: 1.00e-02 | loss: 0.1706 | time: 13.83ms | tokens processed: 192,536,576 | tok/sec: 296,071.92
# 47010 | lr: 1.00e-02 | loss: 0.1748 | time: 14.03ms | tokens processed: 192,557,056 | tok/sec: 292,000.84
# 47015 | lr: 1.00e-02 | loss: 0.1629 | time: 14.51ms | tokens processed: 192,577,536 | tok/sec: 282,215.51
# 47020 | lr: 1.00e-02 | loss: 0.1789 | time: 13.40ms | tokens processed: 192,598,016 | tok/sec: 305,767.79
# 47025 | lr: 1.00e-02 | loss: 0.1742 | time: 14.50ms | tokens processed: 192,618,496 | tok/sec: 282,535.76
# 47030 | lr: 1.00e-02 | loss: 0.2026 | time: 13.34ms | tokens processed: 192,638,976 | tok/sec: 306,980.72
# 47035 | lr: 1.00e-02 | loss: 0.1392 | time: 13.70ms | tokens processed: 192,659,456 | tok/sec: 299,040.37
# 47040 | lr: 1.00e-02 | loss: 0.1551 | time: 13.85ms | tokens processed: 192,679,936 | tok/sec: 295,811.93
# 47045 | lr: 1.00e-02 | loss: 0.1776 | time: 14.02ms | tokens processed: 192,700,416 | tok/sec: 292,209.43
# 47050 | lr: 1.00e-02 | loss: 0.1604 | time: 13.75ms | tokens processed: 192,720,896 | tok/sec: 297,930.58
# 47055 | lr: 1.00e-02 | loss: 0.1769 | time: 14.03ms | tokens processed: 192,741,376 | tok/sec: 291,842.10
# 47060 | lr: 1.00e-02 | loss: 0.1607 | time: 13.05ms | tokens processed: 192,761,856 | tok/sec: 313,953.86
# 47065 | lr: 1.00e-02 | loss: 0.1454 | time: 14.59ms | tokens processed: 192,782,336 | tok/sec: 280,771.87
# 47070 | lr: 1.00e-02 | loss: 0.1512 | time: 14.49ms | tokens processed: 192,802,816 | tok/sec: 282,661.27
# 47075 | lr: 1.00e-02 | loss: 0.1616 | time: 14.08ms | tokens processed: 192,823,296 | tok/sec: 290,834.24
# 47080 | lr: 1.00e-02 | loss: 0.1608 | time: 13.91ms | tokens processed: 192,843,776 | tok/sec: 294,392.60
# 47085 | lr: 1.00e-02 | loss: 0.1935 | time: 13.66ms | tokens processed: 192,864,256 | tok/sec: 299,812.73
# 47090 | lr: 1.00e-02 | loss: 0.2078 | time: 14.14ms | tokens processed: 192,884,736 | tok/sec: 289,623.20
# 47095 | lr: 1.00e-02 | loss: 0.1686 | time: 14.40ms | tokens processed: 192,905,216 | tok/sec: 284,439.63
# 47100 | lr: 1.00e-02 | loss: 0.1867 | time: 14.51ms | tokens processed: 192,925,696 | tok/sec: 282,363.94
# 47105 | lr: 1.00e-02 | loss: 0.1641 | time: 14.65ms | tokens processed: 192,946,176 | tok/sec: 279,633.92
# 47110 | lr: 1.00e-02 | loss: 0.1489 | time: 13.58ms | tokens processed: 192,966,656 | tok/sec: 301,512.30
# 47115 | lr: 1.00e-02 | loss: 0.1609 | time: 14.83ms | tokens processed: 192,987,136 | tok/sec: 276,265.87
# 47120 | lr: 1.00e-02 | loss: 0.1731 | time: 14.92ms | tokens processed: 193,007,616 | tok/sec: 274,618.67
# 47125 | lr: 1.00e-02 | loss: 0.1877 | time: 14.96ms | tokens processed: 193,028,096 | tok/sec: 273,861.33
# 47130 | lr: 1.00e-02 | loss: 0.1675 | time: 14.73ms | tokens processed: 193,048,576 | tok/sec: 278,139.93
# 47135 | lr: 1.00e-02 | loss: 0.1625 | time: 14.43ms | tokens processed: 193,069,056 | tok/sec: 283,866.25
# 47140 | lr: 1.00e-02 | loss: 0.1492 | time: 13.32ms | tokens processed: 193,089,536 | tok/sec: 307,480.70
# 47145 | lr: 1.00e-02 | loss: 0.1726 | time: 432.92ms | tokens processed: 193,110,016 | tok/sec: 9,461.37
# 47150 | lr: 1.00e-02 | loss: 0.1556 | time: 14.08ms | tokens processed: 193,130,496 | tok/sec: 290,996.80
# 47155 | lr: 1.00e-02 | loss: 0.1774 | time: 14.55ms | tokens processed: 193,150,976 | tok/sec: 281,448.03
# 47160 | lr: 1.00e-02 | loss: 0.1908 | time: 14.07ms | tokens processed: 193,171,456 | tok/sec: 291,110.21
# 47165 | lr: 1.00e-02 | loss: 0.1578 | time: 14.54ms | tokens processed: 193,191,936 | tok/sec: 281,669.52
# 47170 | lr: 1.00e-02 | loss: 0.1745 | time: 14.24ms | tokens processed: 193,212,416 | tok/sec: 287,692.90
# 47175 | lr: 1.00e-02 | loss: 0.1883 | time: 13.41ms | tokens processed: 193,232,896 | tok/sec: 305,474.20
# 47180 | lr: 1.00e-02 | loss: 0.2006 | time: 14.50ms | tokens processed: 193,253,376 | tok/sec: 282,531.11
# 47185 | lr: 1.00e-02 | loss: 0.1818 | time: 13.76ms | tokens processed: 193,273,856 | tok/sec: 297,610.59
# 47190 | lr: 1.00e-02 | loss: 0.1697 | time: 14.41ms | tokens processed: 193,294,336 | tok/sec: 284,298.42
# 47195 | lr: 1.00e-02 | loss: 0.1908 | time: 14.42ms | tokens processed: 193,314,816 | tok/sec: 284,025.81
# 47200 | lr: 1.00e-02 | loss: 0.1727 | time: 14.08ms | tokens processed: 193,335,296 | tok/sec: 290,819.47
# 47205 | lr: 1.00e-02 | loss: 0.1648 | time: 13.20ms | tokens processed: 193,355,776 | tok/sec: 310,408.51
# 47210 | lr: 1.00e-02 | loss: 0.1931 | time: 14.76ms | tokens processed: 193,376,256 | tok/sec: 277,493.00
# 47215 | lr: 1.00e-02 | loss: 0.1870 | time: 13.90ms | tokens processed: 193,396,736 | tok/sec: 294,736.04
# 47220 | lr: 1.00e-02 | loss: 0.1917 | time: 13.86ms | tokens processed: 193,417,216 | tok/sec: 295,547.30
# 47225 | lr: 1.00e-02 | loss: 0.1792 | time: 14.06ms | tokens processed: 193,437,696 | tok/sec: 291,357.06
# 47230 | lr: 1.00e-02 | loss: 0.1718 | time: 14.81ms | tokens processed: 193,458,176 | tok/sec: 276,523.78
# 47235 | lr: 1.00e-02 | loss: 0.1737 | time: 13.69ms | tokens processed: 193,478,656 | tok/sec: 299,160.14
# 47240 | lr: 1.00e-02 | loss: 0.1765 | time: 14.65ms | tokens processed: 193,499,136 | tok/sec: 279,652.13
# 47245 | lr: 1.00e-02 | loss: 0.1999 | time: 14.26ms | tokens processed: 193,519,616 | tok/sec: 287,240.75
# 47250 | lr: 1.00e-02 | loss: 0.1314 | time: 13.93ms | tokens processed: 193,540,096 | tok/sec: 294,075.13
# 47255 | lr: 1.00e-02 | loss: 0.2066 | time: 13.67ms | tokens processed: 193,560,576 | tok/sec: 299,702.90
# 47260 | lr: 1.00e-02 | loss: 0.1906 | time: 14.51ms | tokens processed: 193,581,056 | tok/sec: 282,243.33
# 47265 | lr: 1.00e-02 | loss: 0.1863 | time: 13.34ms | tokens processed: 193,601,536 | tok/sec: 306,947.81
# 47270 | lr: 1.00e-02 | loss: 0.1872 | time: 13.98ms | tokens processed: 193,622,016 | tok/sec: 292,986.84
# 47275 | lr: 1.00e-02 | loss: 0.2055 | time: 13.62ms | tokens processed: 193,642,496 | tok/sec: 300,636.44
# 47280 | lr: 1.00e-02 | loss: 0.1500 | time: 14.39ms | tokens processed: 193,662,976 | tok/sec: 284,632.84
# 47285 | lr: 1.00e-02 | loss: 0.1572 | time: 14.16ms | tokens processed: 193,683,456 | tok/sec: 289,354.91
# 47290 | lr: 1.00e-02 | loss: 0.1905 | time: 14.03ms | tokens processed: 193,703,936 | tok/sec: 291,966.10
# 47295 | lr: 1.00e-02 | loss: 0.1881 | time: 13.47ms | tokens processed: 193,724,416 | tok/sec: 303,993.16
# 47300 | lr: 1.00e-02 | loss: 0.1932 | time: 14.53ms | tokens processed: 193,744,896 | tok/sec: 281,928.37
# 47305 | lr: 1.00e-02 | loss: 0.1996 | time: 13.78ms | tokens processed: 193,765,376 | tok/sec: 297,157.59
# 47310 | lr: 1.00e-02 | loss: 0.1720 | time: 14.21ms | tokens processed: 193,785,856 | tok/sec: 288,218.99
# 47315 | lr: 1.00e-02 | loss: 0.1704 | time: 14.73ms | tokens processed: 193,806,336 | tok/sec: 278,004.91
# 47320 | lr: 1.00e-02 | loss: 0.1648 | time: 14.80ms | tokens processed: 193,826,816 | tok/sec: 276,822.31
# 47325 | lr: 1.00e-02 | loss: 0.1750 | time: 13.59ms | tokens processed: 193,847,296 | tok/sec: 301,507.01
# 47330 | lr: 1.00e-02 | loss: 0.1902 | time: 14.01ms | tokens processed: 193,867,776 | tok/sec: 292,288.98
# 47335 | lr: 1.00e-02 | loss: 0.1679 | time: 14.55ms | tokens processed: 193,888,256 | tok/sec: 281,535.66
# 47340 | lr: 1.00e-02 | loss: 0.1684 | time: 13.98ms | tokens processed: 193,908,736 | tok/sec: 292,981.84
# 47345 | lr: 1.00e-02 | loss: 0.1924 | time: 14.48ms | tokens processed: 193,929,216 | tok/sec: 282,889.33
# 47350 | lr: 1.00e-02 | loss: 0.1854 | time: 14.54ms | tokens processed: 193,949,696 | tok/sec: 281,789.64
# 47355 | lr: 1.00e-02 | loss: 0.1654 | time: 12.69ms | tokens processed: 193,970,176 | tok/sec: 322,711.50
# 47360 | lr: 1.00e-02 | loss: 0.1692 | time: 14.15ms | tokens processed: 193,990,656 | tok/sec: 289,369.53
# 47365 | lr: 1.00e-02 | loss: 0.1689 | time: 13.99ms | tokens processed: 194,011,136 | tok/sec: 292,702.31
# 47370 | lr: 1.00e-02 | loss: 0.1740 | time: 14.33ms | tokens processed: 194,031,616 | tok/sec: 285,778.65
# 47375 | lr: 1.00e-02 | loss: 0.2060 | time: 14.55ms | tokens processed: 194,052,096 | tok/sec: 281,475.70
# 47380 | lr: 1.00e-02 | loss: 0.1815 | time: 14.57ms | tokens processed: 194,072,576 | tok/sec: 281,111.84
# 47385 | lr: 1.00e-02 | loss: 0.1773 | time: 13.58ms | tokens processed: 194,093,056 | tok/sec: 301,634.05
# 47390 | lr: 1.00e-02 | loss: 0.1856 | time: 13.86ms | tokens processed: 194,113,536 | tok/sec: 295,511.72
# 47395 | lr: 1.00e-02 | loss: 0.1435 | time: 14.57ms | tokens processed: 194,134,016 | tok/sec: 281,121.04
# 47400 | lr: 1.00e-02 | loss: 0.1739 | time: 14.69ms | tokens processed: 194,154,496 | tok/sec: 278,821.56
# 47405 | lr: 1.00e-02 | loss: 0.1836 | time: 14.21ms | tokens processed: 194,174,976 | tok/sec: 288,189.98
# 47410 | lr: 1.00e-02 | loss: 0.1771 | time: 14.41ms | tokens processed: 194,195,456 | tok/sec: 284,157.35
# 47415 | lr: 1.00e-02 | loss: 0.1859 | time: 12.95ms | tokens processed: 194,215,936 | tok/sec: 316,353.06
# 47420 | lr: 1.00e-02 | loss: 0.1700 | time: 14.52ms | tokens processed: 194,236,416 | tok/sec: 282,169.16
# 47425 | lr: 1.00e-02 | loss: 0.1864 | time: 14.59ms | tokens processed: 194,256,896 | tok/sec: 280,781.05
# 47430 | lr: 1.00e-02 | loss: 0.1437 | time: 13.70ms | tokens processed: 194,277,376 | tok/sec: 298,962.31
# 47435 | lr: 1.00e-02 | loss: 0.1664 | time: 13.79ms | tokens processed: 194,297,856 | tok/sec: 297,095.93
# 47440 | lr: 1.00e-02 | loss: 0.1646 | time: 13.88ms | tokens processed: 194,318,336 | tok/sec: 295,156.33
# 47445 | lr: 1.00e-02 | loss: 0.1707 | time: 13.55ms | tokens processed: 194,338,816 | tok/sec: 302,361.34
# 47450 | lr: 1.00e-02 | loss: 0.1792 | time: 14.37ms | tokens processed: 194,359,296 | tok/sec: 284,944.42
# 47455 | lr: 1.00e-02 | loss: 0.1674 | time: 14.35ms | tokens processed: 194,379,776 | tok/sec: 285,360.93
# 47460 | lr: 1.00e-02 | loss: 0.1803 | time: 14.32ms | tokens processed: 194,400,256 | tok/sec: 286,111.80
# 47465 | lr: 1.00e-02 | loss: 0.1281 | time: 14.22ms | tokens processed: 194,420,736 | tok/sec: 287,962.94
# 47470 | lr: 1.00e-02 | loss: 0.1564 | time: 13.85ms | tokens processed: 194,441,216 | tok/sec: 295,755.91
# 47475 | lr: 1.00e-02 | loss: 0.1484 | time: 13.18ms | tokens processed: 194,461,696 | tok/sec: 310,762.24
# 47480 | lr: 1.00e-02 | loss: 0.2016 | time: 14.06ms | tokens processed: 194,482,176 | tok/sec: 291,401.54
# 47485 | lr: 1.00e-02 | loss: 0.2068 | time: 14.51ms | tokens processed: 194,502,656 | tok/sec: 282,243.33
# 47490 | lr: 1.00e-02 | loss: 0.1808 | time: 14.63ms | tokens processed: 194,523,136 | tok/sec: 280,044.16
# 47495 | lr: 1.00e-02 | loss: 0.1887 | time: 14.70ms | tokens processed: 194,543,616 | tok/sec: 278,568.38
# 47500 | lr: 1.00e-02 | loss: 0.1367 | time: 14.58ms | tokens processed: 194,564,096 | tok/sec: 280,840.72
# 47505 | lr: 1.00e-02 | loss: 0.1784 | time: 13.04ms | tokens processed: 194,584,576 | tok/sec: 314,045.68
# 47510 | lr: 1.00e-02 | loss: 0.1779 | time: 14.42ms | tokens processed: 194,605,056 | tok/sec: 284,068.08
# 47515 | lr: 1.00e-02 | loss: 0.1591 | time: 14.55ms | tokens processed: 194,625,536 | tok/sec: 281,503.37
# 47520 | lr: 1.00e-02 | loss: 0.1597 | time: 14.33ms | tokens processed: 194,646,016 | tok/sec: 285,830.95
# 47525 | lr: 1.00e-02 | loss: 0.1798 | time: 14.75ms | tokens processed: 194,666,496 | tok/sec: 277,730.76
# 47530 | lr: 1.00e-02 | loss: 0.1643 | time: 13.38ms | tokens processed: 194,686,976 | tok/sec: 306,121.94
# 47535 | lr: 1.00e-02 | loss: 0.1800 | time: 13.13ms | tokens processed: 194,707,456 | tok/sec: 312,003.87
# 47540 | lr: 1.00e-02 | loss: 0.1492 | time: 14.77ms | tokens processed: 194,727,936 | tok/sec: 277,246.70
# 47545 | lr: 1.00e-02 | loss: 0.1888 | time: 14.70ms | tokens processed: 194,748,416 | tok/sec: 278,554.83
# 47550 | lr: 1.00e-02 | loss: 0.1603 | time: 14.80ms | tokens processed: 194,768,896 | tok/sec: 276,755.42
# 47555 | lr: 1.00e-02 | loss: 0.1845 | time: 14.64ms | tokens processed: 194,789,376 | tok/sec: 279,866.24
# 47560 | lr: 1.00e-02 | loss: 0.1818 | time: 14.20ms | tokens processed: 194,809,856 | tok/sec: 288,407.69
# 47565 | lr: 1.00e-02 | loss: 0.1754 | time: 13.49ms | tokens processed: 194,830,336 | tok/sec: 303,665.39
# 47570 | lr: 1.00e-02 | loss: 0.1960 | time: 14.67ms | tokens processed: 194,850,816 | tok/sec: 279,233.96
# 47575 | lr: 1.00e-02 | loss: 0.1758 | time: 14.56ms | tokens processed: 194,871,296 | tok/sec: 281,342.02
# 47580 | lr: 1.00e-02 | loss: 0.1636 | time: 14.43ms | tokens processed: 194,891,776 | tok/sec: 283,894.39
# 47585 | lr: 1.00e-02 | loss: 0.1773 | time: 13.93ms | tokens processed: 194,912,256 | tok/sec: 294,039.90
# 47590 | lr: 1.00e-02 | loss: 0.1892 | time: 14.74ms | tokens processed: 194,932,736 | tok/sec: 277,834.06
# 47595 | lr: 1.00e-02 | loss: 0.1716 | time: 12.88ms | tokens processed: 194,953,216 | tok/sec: 317,945.54
# 47600 | lr: 1.00e-02 | loss: 0.1628 | time: 14.74ms | tokens processed: 194,973,696 | tok/sec: 277,798.12
# 47605 | lr: 1.00e-02 | loss: 0.1917 | time: 14.43ms | tokens processed: 194,994,176 | tok/sec: 283,833.42
# 47610 | lr: 1.00e-02 | loss: 0.1933 | time: 13.42ms | tokens processed: 195,014,656 | tok/sec: 305,300.49
# 47615 | lr: 1.00e-02 | loss: 0.2030 | time: 14.47ms | tokens processed: 195,035,136 | tok/sec: 283,122.43
# 47620 | lr: 1.00e-02 | loss: 0.1733 | time: 14.11ms | tokens processed: 195,055,616 | tok/sec: 290,323.10
# 47625 | lr: 1.00e-02 | loss: 0.1841 | time: 13.61ms | tokens processed: 195,076,096 | tok/sec: 300,889.17
# 47630 | lr: 1.00e-02 | loss: 0.1700 | time: 14.63ms | tokens processed: 195,096,576 | tok/sec: 280,066.99
# 47635 | lr: 1.00e-02 | loss: 0.1931 | time: 13.74ms | tokens processed: 195,117,056 | tok/sec: 298,008.10
# 47640 | lr: 1.00e-02 | loss: 0.1730 | time: 14.65ms | tokens processed: 195,137,536 | tok/sec: 279,629.37
# 47645 | lr: 1.00e-02 | loss: 0.1491 | time: 14.20ms | tokens processed: 195,158,016 | tok/sec: 288,543.32
# 47650 | lr: 1.00e-02 | loss: 0.1796 | time: 14.37ms | tokens processed: 195,178,496 | tok/sec: 284,944.42
# 47655 | lr: 1.00e-02 | loss: 0.1794 | time: 13.89ms | tokens processed: 195,198,976 | tok/sec: 294,827.09
# 47660 | lr: 1.00e-02 | loss: 0.1762 | time: 14.56ms | tokens processed: 195,219,456 | tok/sec: 281,240.70
# 47665 | lr: 1.00e-02 | loss: 0.1580 | time: 14.33ms | tokens processed: 195,239,936 | tok/sec: 285,750.13
# 47670 | lr: 1.00e-02 | loss: 0.1793 | time: 14.29ms | tokens processed: 195,260,416 | tok/sec: 286,555.62
# 47675 | lr: 1.00e-02 | loss: 0.1827 | time: 13.56ms | tokens processed: 195,280,896 | tok/sec: 302,116.75
# 47680 | lr: 1.00e-02 | loss: 0.1359 | time: 13.99ms | tokens processed: 195,301,376 | tok/sec: 292,747.20
# 47685 | lr: 1.00e-02 | loss: 0.1749 | time: 12.45ms | tokens processed: 195,321,856 | tok/sec: 328,920.93
# 47690 | lr: 1.00e-02 | loss: 0.1665 | time: 13.67ms | tokens processed: 195,342,336 | tok/sec: 299,561.80
# 47695 | lr: 1.00e-02 | loss: 0.1467 | time: 13.62ms | tokens processed: 195,362,816 | tok/sec: 300,636.44
# 47700 | lr: 1.00e-02 | loss: 0.1863 | time: 14.35ms | tokens processed: 195,383,296 | tok/sec: 285,507.94
# 47705 | lr: 1.00e-02 | loss: 0.1634 | time: 14.39ms | tokens processed: 195,403,776 | tok/sec: 284,552.70
# 47710 | lr: 1.00e-02 | loss: 0.1769 | time: 14.53ms | tokens processed: 195,424,256 | tok/sec: 281,928.37
# 47715 | lr: 1.00e-02 | loss: 0.1463 | time: 12.95ms | tokens processed: 195,444,736 | tok/sec: 316,312.29
# 47720 | lr: 1.00e-02 | loss: 0.1816 | time: 13.79ms | tokens processed: 195,465,216 | tok/sec: 296,998.34
# 47725 | lr: 1.00e-02 | loss: 0.1954 | time: 13.99ms | tokens processed: 195,485,696 | tok/sec: 292,837.02
# 47730 | lr: 1.00e-02 | loss: 0.1800 | time: 14.49ms | tokens processed: 195,506,176 | tok/sec: 282,698.48
# 47735 | lr: 1.00e-02 | loss: 0.1655 | time: 14.42ms | tokens processed: 195,526,656 | tok/sec: 284,143.25
# 47740 | lr: 1.00e-02 | loss: 0.1851 | time: 13.94ms | tokens processed: 195,547,136 | tok/sec: 293,788.48
# 47745 | lr: 1.00e-02 | loss: 0.1763 | time: 13.32ms | tokens processed: 195,567,616 | tok/sec: 307,464.19
# 47750 | lr: 1.00e-02 | loss: 0.1592 | time: 14.52ms | tokens processed: 195,588,096 | tok/sec: 282,020.93
# 47755 | lr: 1.00e-02 | loss: 0.1652 | time: 14.55ms | tokens processed: 195,608,576 | tok/sec: 281,567.96
# 47760 | lr: 1.00e-02 | loss: 0.1864 | time: 14.39ms | tokens processed: 195,629,056 | tok/sec: 284,623.41
# 47765 | lr: 1.00e-02 | loss: 0.1619 | time: 12.89ms | tokens processed: 195,649,536 | tok/sec: 317,851.42
# 47770 | lr: 1.00e-02 | loss: 0.1782 | time: 14.58ms | tokens processed: 195,670,016 | tok/sec: 281,010.68
# 47775 | lr: 1.00e-02 | loss: 0.1568 | time: 13.17ms | tokens processed: 195,690,496 | tok/sec: 311,099.89
# 47780 | lr: 1.00e-02 | loss: 0.2036 | time: 14.28ms | tokens processed: 195,710,976 | tok/sec: 286,766.08
# 47785 | lr: 1.00e-02 | loss: 0.1678 | time: 14.26ms | tokens processed: 195,731,456 | tok/sec: 287,139.93
# 47790 | lr: 1.00e-02 | loss: 0.1584 | time: 14.00ms | tokens processed: 195,751,936 | tok/sec: 292,657.43
# 47795 | lr: 1.00e-02 | loss: 0.1757 | time: 14.63ms | tokens processed: 195,772,416 | tok/sec: 279,930.09
# 47800 | lr: 1.00e-02 | loss: 0.1752 | time: 14.31ms | tokens processed: 195,792,896 | tok/sec: 286,240.51
# 47805 | lr: 1.00e-02 | loss: 0.1673 | time: 13.71ms | tokens processed: 195,813,376 | tok/sec: 298,811.51
# 47810 | lr: 1.00e-02 | loss: 0.1714 | time: 14.71ms | tokens processed: 195,833,856 | tok/sec: 278,473.56
# 47815 | lr: 1.00e-02 | loss: 0.1754 | time: 14.63ms | tokens processed: 195,854,336 | tok/sec: 280,048.73
# 47820 | lr: 1.00e-02 | loss: 0.1822 | time: 14.76ms | tokens processed: 195,874,816 | tok/sec: 277,448.19
# 47825 | lr: 1.00e-02 | loss: 0.1818 | time: 12.47ms | tokens processed: 195,895,296 | tok/sec: 328,436.74
# 47830 | lr: 1.00e-02 | loss: 0.1919 | time: 14.40ms | tokens processed: 195,915,776 | tok/sec: 284,467.89
# 47835 | lr: 1.00e-02 | loss: 0.1885 | time: 14.55ms | tokens processed: 195,936,256 | tok/sec: 281,457.25
# 47840 | lr: 1.00e-02 | loss: 0.1653 | time: 14.60ms | tokens processed: 195,956,736 | tok/sec: 280,615.94
# 47845 | lr: 1.00e-02 | loss: 0.1679 | time: 14.43ms | tokens processed: 195,977,216 | tok/sec: 283,885.01
# 47850 | lr: 1.00e-02 | loss: 0.1707 | time: 14.24ms | tokens processed: 195,997,696 | tok/sec: 287,668.81
# 47855 | lr: 1.00e-02 | loss: 0.1598 | time: 13.54ms | tokens processed: 196,018,176 | tok/sec: 302,526.40
# 47860 | lr: 1.00e-02 | loss: 0.1499 | time: 14.15ms | tokens processed: 196,038,656 | tok/sec: 289,384.16
# 47865 | lr: 1.00e-02 | loss: 0.1980 | time: 13.74ms | tokens processed: 196,059,136 | tok/sec: 298,121.87
# 47870 | lr: 1.00e-02 | loss: 0.1839 | time: 13.99ms | tokens processed: 196,079,616 | tok/sec: 292,782.12
# 47875 | lr: 1.00e-02 | loss: 0.1664 | time: 13.92ms | tokens processed: 196,100,096 | tok/sec: 294,291.74
# 47880 | lr: 1.00e-02 | loss: 0.1653 | time: 14.61ms | tokens processed: 196,120,576 | tok/sec: 280,396.10
# 47885 | lr: 1.00e-02 | loss: 0.1733 | time: 12.67ms | tokens processed: 196,141,056 | tok/sec: 323,294.49
# 47890 | lr: 1.00e-02 | loss: 0.1942 | time: 14.44ms | tokens processed: 196,161,536 | tok/sec: 283,683.44
# 47895 | lr: 1.00e-02 | loss: 0.1492 | time: 14.36ms | tokens processed: 196,182,016 | tok/sec: 285,256.69
# 47900 | lr: 1.00e-02 | loss: 0.1725 | time: 13.01ms | tokens processed: 196,202,496 | tok/sec: 314,897.62
# 47905 | lr: 1.00e-02 | loss: 0.1776 | time: 14.24ms | tokens processed: 196,222,976 | tok/sec: 287,611.02
# 47910 | lr: 1.00e-02 | loss: 0.1630 | time: 14.54ms | tokens processed: 196,243,456 | tok/sec: 281,697.23
# 47915 | lr: 1.00e-02 | loss: 0.1536 | time: 13.22ms | tokens processed: 196,263,936 | tok/sec: 309,809.55
# 47920 | lr: 1.00e-02 | loss: 0.2004 | time: 14.42ms | tokens processed: 196,284,416 | tok/sec: 284,044.59
# 47925 | lr: 1.00e-02 | loss: 0.1897 | time: 14.02ms | tokens processed: 196,304,896 | tok/sec: 292,234.29
# 47930 | lr: 1.00e-02 | loss: 0.1418 | time: 14.73ms | tokens processed: 196,325,376 | tok/sec: 277,982.41
# 47935 | lr: 1.00e-02 | loss: 0.1623 | time: 14.24ms | tokens processed: 196,345,856 | tok/sec: 287,731.45
# 47940 | lr: 1.00e-02 | loss: 0.1755 | time: 13.89ms | tokens processed: 196,366,336 | tok/sec: 294,948.57
# 47945 | lr: 1.00e-02 | loss: 0.1713 | time: 13.14ms | tokens processed: 196,386,816 | tok/sec: 311,771.73
# 47950 | lr: 1.00e-02 | loss: 0.2016 | time: 14.15ms | tokens processed: 196,407,296 | tok/sec: 289,506.07
# 47955 | lr: 1.00e-02 | loss: 0.1885 | time: 14.74ms | tokens processed: 196,427,776 | tok/sec: 277,838.55
# 47960 | lr: 1.00e-02 | loss: 0.1529 | time: 14.48ms | tokens processed: 196,448,256 | tok/sec: 282,866.04
# 47965 | lr: 1.00e-02 | loss: 0.1883 | time: 14.64ms | tokens processed: 196,468,736 | tok/sec: 279,724.98
# 47970 | lr: 1.00e-02 | loss: 0.1740 | time: 14.00ms | tokens processed: 196,489,216 | tok/sec: 292,562.74
# 47975 | lr: 1.00e-02 | loss: 0.1696 | time: 12.86ms | tokens processed: 196,509,696 | tok/sec: 318,405.17
# 47980 | lr: 1.00e-02 | loss: 0.1862 | time: 13.98ms | tokens processed: 196,530,176 | tok/sec: 293,046.81
# 47985 | lr: 1.00e-02 | loss: 0.1621 | time: 14.83ms | tokens processed: 196,550,656 | tok/sec: 276,181.48
# 47990 | lr: 1.00e-02 | loss: 0.1807 | time: 14.75ms | tokens processed: 196,571,136 | tok/sec: 277,771.17
# 47995 | lr: 1.00e-02 | loss: 0.1403 | time: 14.30ms | tokens processed: 196,591,616 | tok/sec: 286,493.50
# 48000 | lr: 1.00e-02 | loss: 0.1635 | time: 14.52ms | tokens processed: 196,612,096 | tok/sec: 282,113.56
# 48005 | lr: 1.00e-02 | loss: 0.1829 | time: 12.94ms | tokens processed: 196,632,576 | tok/sec: 316,557.08
# 48010 | lr: 1.00e-02 | loss: 0.1576 | time: 14.60ms | tokens processed: 196,653,056 | tok/sec: 280,492.24
# 48015 | lr: 1.00e-02 | loss: 0.1721 | time: 14.14ms | tokens processed: 196,673,536 | tok/sec: 289,623.20
# 48020 | lr: 1.00e-02 | loss: 0.1844 | time: 14.64ms | tokens processed: 196,694,016 | tok/sec: 279,852.57
# 48025 | lr: 1.00e-02 | loss: 0.1663 | time: 14.18ms | tokens processed: 196,714,496 | tok/sec: 288,897.53
# 48030 | lr: 1.00e-02 | loss: 0.1688 | time: 14.41ms | tokens processed: 196,734,976 | tok/sec: 284,270.19
# 48035 | lr: 1.00e-02 | loss: 0.1599 | time: 13.40ms | tokens processed: 196,755,456 | tok/sec: 305,746.03
# 48040 | lr: 1.00e-02 | loss: 0.1659 | time: 14.86ms | tokens processed: 196,775,936 | tok/sec: 275,618.77
# 48045 | lr: 1.00e-02 | loss: 0.1680 | time: 12.82ms | tokens processed: 196,796,416 | tok/sec: 319,447.18
# 48050 | lr: 1.00e-02 | loss: 0.1647 | time: 12.78ms | tokens processed: 196,816,896 | tok/sec: 320,549.85
# 48055 | lr: 1.00e-02 | loss: 0.1676 | time: 13.32ms | tokens processed: 196,837,376 | tok/sec: 307,502.71
# 48060 | lr: 1.00e-02 | loss: 0.1742 | time: 13.63ms | tokens processed: 196,857,856 | tok/sec: 300,568.06
# 48065 | lr: 1.00e-02 | loss: 0.1476 | time: 13.34ms | tokens processed: 196,878,336 | tok/sec: 307,013.64
# 48070 | lr: 1.00e-02 | loss: 0.1627 | time: 13.65ms | tokens processed: 196,898,816 | tok/sec: 300,037.88
# 48075 | lr: 1.00e-02 | loss: 0.1727 | time: 13.97ms | tokens processed: 196,919,296 | tok/sec: 293,121.81
# 48080 | lr: 1.00e-02 | loss: 0.1445 | time: 13.07ms | tokens processed: 196,939,776 | tok/sec: 313,284.02
# 48085 | lr: 1.00e-02 | loss: 0.1660 | time: 13.78ms | tokens processed: 196,960,256 | tok/sec: 297,152.45
# 48090 | lr: 1.00e-02 | loss: 0.1672 | time: 12.78ms | tokens processed: 196,980,736 | tok/sec: 320,615.65
# 48095 | lr: 1.00e-02 | loss: 0.1854 | time: 12.67ms | tokens processed: 197,001,216 | tok/sec: 323,300.57
# 48100 | lr: 1.00e-02 | loss: 0.1811 | time: 14.44ms | tokens processed: 197,021,696 | tok/sec: 283,571.06
# 48105 | lr: 1.00e-02 | loss: 0.1477 | time: 13.23ms | tokens processed: 197,042,176 | tok/sec: 309,597.40
# 48110 | lr: 1.00e-02 | loss: 0.1285 | time: 13.73ms | tokens processed: 197,062,656 | tok/sec: 298,308.23
# 48115 | lr: 1.00e-02 | loss: 0.1560 | time: 13.43ms | tokens processed: 197,083,136 | tok/sec: 304,953.66
# 48120 | lr: 1.00e-02 | loss: 0.1567 | time: 14.07ms | tokens processed: 197,103,616 | tok/sec: 291,031.31
# 48125 | lr: 1.00e-02 | loss: 0.1678 | time: 13.10ms | tokens processed: 197,124,096 | tok/sec: 312,742.23
# 48130 | lr: 1.00e-02 | loss: 0.1818 | time: 13.81ms | tokens processed: 197,144,576 | tok/sec: 296,644.49
# 48135 | lr: 1.00e-02 | loss: 0.1569 | time: 13.69ms | tokens processed: 197,165,056 | tok/sec: 299,170.56
# 48140 | lr: 1.00e-02 | loss: 0.1636 | time: 13.86ms | tokens processed: 197,185,536 | tok/sec: 295,481.22
# 48145 | lr: 1.00e-02 | loss: 0.1447 | time: 13.71ms | tokens processed: 197,206,016 | tok/sec: 298,853.10
# 48150 | lr: 1.00e-02 | loss: 0.1724 | time: 13.37ms | tokens processed: 197,226,496 | tok/sec: 306,340.28
# 48155 | lr: 1.00e-02 | loss: 0.1776 | time: 13.23ms | tokens processed: 197,246,976 | tok/sec: 309,513.73
# 48160 | lr: 1.00e-02 | loss: 0.1895 | time: 13.35ms | tokens processed: 197,267,456 | tok/sec: 306,772.42
# 48165 | lr: 1.00e-02 | loss: 0.1673 | time: 14.00ms | tokens processed: 197,287,936 | tok/sec: 292,537.83
# 48170 | lr: 1.00e-02 | loss: 0.1489 | time: 13.57ms | tokens processed: 197,308,416 | tok/sec: 301,915.00
# 48175 | lr: 1.00e-02 | loss: 0.1504 | time: 13.92ms | tokens processed: 197,328,896 | tok/sec: 294,266.54
# 48180 | lr: 1.00e-02 | loss: 0.1635 | time: 14.06ms | tokens processed: 197,349,376 | tok/sec: 291,406.48
# 48185 | lr: 1.00e-02 | loss: 0.1701 | time: 12.71ms | tokens processed: 197,369,856 | tok/sec: 322,305.86
# 48190 | lr: 1.00e-02 | loss: 0.1535 | time: 13.62ms | tokens processed: 197,390,336 | tok/sec: 300,652.22
# 48195 | lr: 1.00e-02 | loss: 0.1560 | time: 14.21ms | tokens processed: 197,410,816 | tok/sec: 288,277.02
# 48200 | lr: 1.00e-02 | loss: 0.1610 | time: 13.89ms | tokens processed: 197,431,296 | tok/sec: 294,923.25
# 48205 | lr: 1.00e-02 | loss: 0.1758 | time: 13.90ms | tokens processed: 197,451,776 | tok/sec: 294,766.38
# 48210 | lr: 1.00e-02 | loss: 0.1986 | time: 14.14ms | tokens processed: 197,472,256 | tok/sec: 289,681.81
# 48215 | lr: 1.00e-02 | loss: 0.1596 | time: 12.97ms | tokens processed: 197,492,736 | tok/sec: 315,690.36
# 48220 | lr: 1.00e-02 | loss: 0.1658 | time: 13.71ms | tokens processed: 197,513,216 | tok/sec: 298,686.83
# 48225 | lr: 1.00e-02 | loss: 0.1896 | time: 14.29ms | tokens processed: 197,533,696 | tok/sec: 286,703.87
# 48230 | lr: 1.00e-02 | loss: 0.1713 | time: 14.15ms | tokens processed: 197,554,176 | tok/sec: 289,413.41
# 48235 | lr: 1.00e-02 | loss: 0.1841 | time: 13.37ms | tokens processed: 197,574,656 | tok/sec: 306,465.97
# 48240 | lr: 1.00e-02 | loss: 0.1589 | time: 14.60ms | tokens processed: 197,595,136 | tok/sec: 280,473.92
# 48245 | lr: 1.00e-02 | loss: 0.1645 | time: 12.78ms | tokens processed: 197,615,616 | tok/sec: 320,573.78
# 48250 | lr: 1.00e-02 | loss: 0.1606 | time: 13.79ms | tokens processed: 197,636,096 | tok/sec: 297,013.75
# 48255 | lr: 1.00e-02 | loss: 0.1969 | time: 13.76ms | tokens processed: 197,656,576 | tok/sec: 297,595.13
# 48260 | lr: 1.00e-02 | loss: 0.1766 | time: 13.45ms | tokens processed: 197,677,056 | tok/sec: 304,591.41
# 48265 | lr: 1.00e-02 | loss: 0.1535 | time: 14.00ms | tokens processed: 197,697,536 | tok/sec: 292,557.76
# 48270 | lr: 1.00e-02 | loss: 0.1483 | time: 14.17ms | tokens processed: 197,718,016 | tok/sec: 289,053.07
# 48275 | lr: 1.00e-02 | loss: 0.1776 | time: 13.11ms | tokens processed: 197,738,496 | tok/sec: 312,440.79
# 48280 | lr: 1.00e-02 | loss: 0.1645 | time: 14.27ms | tokens processed: 197,758,976 | tok/sec: 286,986.44
# 48285 | lr: 1.00e-02 | loss: 0.1560 | time: 14.11ms | tokens processed: 197,779,456 | tok/sec: 290,200.49
# 48290 | lr: 1.00e-02 | loss: 0.1913 | time: 14.36ms | tokens processed: 197,799,936 | tok/sec: 285,171.46
# 48295 | lr: 1.00e-02 | loss: 0.1602 | time: 13.82ms | tokens processed: 197,820,416 | tok/sec: 296,383.49
# 48300 | lr: 1.00e-02 | loss: 0.1781 | time: 13.79ms | tokens processed: 197,840,896 | tok/sec: 297,111.34
# 48305 | lr: 1.00e-02 | loss: 0.1659 | time: 13.27ms | tokens processed: 197,861,376 | tok/sec: 308,590.84
# 48310 | lr: 1.00e-02 | loss: 0.1767 | time: 14.03ms | tokens processed: 197,881,856 | tok/sec: 292,005.80
# 48315 | lr: 1.00e-02 | loss: 0.1758 | time: 14.22ms | tokens processed: 197,902,336 | tok/sec: 288,045.02
# 48320 | lr: 1.00e-02 | loss: 0.1574 | time: 14.61ms | tokens processed: 197,922,816 | tok/sec: 280,272.59
# 48325 | lr: 1.00e-02 | loss: 0.1512 | time: 14.49ms | tokens processed: 197,943,296 | tok/sec: 282,763.62
# 48330 | lr: 1.00e-02 | loss: 0.1897 | time: 13.96ms | tokens processed: 197,963,776 | tok/sec: 293,512.42
# 48335 | lr: 1.00e-02 | loss: 0.1696 | time: 12.34ms | tokens processed: 197,984,256 | tok/sec: 332,010.23
# 48340 | lr: 1.00e-02 | loss: 0.1806 | time: 13.76ms | tokens processed: 198,004,736 | tok/sec: 297,755.02
# 48345 | lr: 1.00e-02 | loss: 0.1845 | time: 14.46ms | tokens processed: 198,025,216 | tok/sec: 283,309.19
# 48350 | lr: 1.00e-02 | loss: 0.1777 | time: 14.71ms | tokens processed: 198,045,696 | tok/sec: 278,469.04
# 48355 | lr: 1.00e-02 | loss: 0.1907 | time: 14.25ms | tokens processed: 198,066,176 | tok/sec: 287,360.86
# 48360 | lr: 1.00e-02 | loss: 0.1421 | time: 12.95ms | tokens processed: 198,086,656 | tok/sec: 316,318.11
# 48365 | lr: 1.00e-02 | loss: 0.1779 | time: 12.68ms | tokens processed: 198,107,136 | tok/sec: 322,917.73
# 48370 | lr: 1.00e-02 | loss: 0.1629 | time: 14.07ms | tokens processed: 198,127,616 | tok/sec: 291,120.08
# 48375 | lr: 1.00e-02 | loss: 0.1775 | time: 14.58ms | tokens processed: 198,148,096 | tok/sec: 280,932.57
# 48380 | lr: 1.00e-02 | loss: 0.1808 | time: 14.16ms | tokens processed: 198,168,576 | tok/sec: 289,354.91
# 48385 | lr: 1.00e-02 | loss: 0.1733 | time: 14.60ms | tokens processed: 198,189,056 | tok/sec: 280,565.53
# 48390 | lr: 1.00e-02 | loss: 0.1572 | time: 14.21ms | tokens processed: 198,209,536 | tok/sec: 288,306.05
# 48395 | lr: 1.00e-02 | loss: 0.1728 | time: 12.88ms | tokens processed: 198,230,016 | tok/sec: 318,086.82
# 48400 | lr: 1.00e-02 | loss: 0.1500 | time: 13.93ms | tokens processed: 198,250,496 | tok/sec: 294,065.06
# 48405 | lr: 1.00e-02 | loss: 0.1704 | time: 13.76ms | tokens processed: 198,270,976 | tok/sec: 297,589.97
# 48410 | lr: 1.00e-02 | loss: 0.1828 | time: 14.71ms | tokens processed: 198,291,456 | tok/sec: 278,419.40
# 48415 | lr: 1.00e-02 | loss: 0.1506 | time: 14.60ms | tokens processed: 198,311,936 | tok/sec: 280,460.19
# 48420 | lr: 1.00e-02 | loss: 0.1567 | time: 14.23ms | tokens processed: 198,332,416 | tok/sec: 287,794.11
# 48425 | lr: 1.00e-02 | loss: 0.1599 | time: 11.96ms | tokens processed: 198,352,896 | tok/sec: 342,549.18
# 48430 | lr: 1.00e-02 | loss: 0.1799 | time: 13.99ms | tokens processed: 198,373,376 | tok/sec: 292,837.02
# 48435 | lr: 1.00e-02 | loss: 0.1595 | time: 13.89ms | tokens processed: 198,393,856 | tok/sec: 294,938.44
# 48440 | lr: 1.00e-02 | loss: 0.1844 | time: 13.82ms | tokens processed: 198,414,336 | tok/sec: 296,322.15
# 48445 | lr: 1.00e-02 | loss: 0.1833 | time: 13.91ms | tokens processed: 198,434,816 | tok/sec: 294,463.25
# 48450 | lr: 1.00e-02 | loss: 0.1391 | time: 14.27ms | tokens processed: 198,455,296 | tok/sec: 286,972.06
# 48455 | lr: 1.00e-02 | loss: 0.1705 | time: 13.44ms | tokens processed: 198,475,776 | tok/sec: 304,845.43
# 48460 | lr: 1.00e-02 | loss: 0.1670 | time: 14.69ms | tokens processed: 198,496,256 | tok/sec: 278,857.76
# 48465 | lr: 1.00e-02 | loss: 0.1907 | time: 14.47ms | tokens processed: 198,516,736 | tok/sec: 283,047.80
# 48470 | lr: 1.00e-02 | loss: 0.1913 | time: 14.13ms | tokens processed: 198,537,216 | tok/sec: 289,960.49
# 48475 | lr: 1.00e-02 | loss: 0.1822 | time: 14.55ms | tokens processed: 198,557,696 | tok/sec: 281,595.65
# 48480 | lr: 1.00e-02 | loss: 0.1820 | time: 14.72ms | tokens processed: 198,578,176 | tok/sec: 278,338.21
# 48485 | lr: 1.00e-02 | loss: 0.2016 | time: 13.86ms | tokens processed: 198,598,656 | tok/sec: 295,450.73
# 48490 | lr: 1.00e-02 | loss: 0.1644 | time: 14.58ms | tokens processed: 198,619,136 | tok/sec: 280,960.13
# 48495 | lr: 1.00e-02 | loss: 0.1747 | time: 14.75ms | tokens processed: 198,639,616 | tok/sec: 277,703.82
# 48500 | lr: 1.00e-02 | loss: 0.1914 | time: 14.94ms | tokens processed: 198,660,096 | tok/sec: 274,145.39
# 48505 | lr: 1.00e-02 | loss: 0.1583 | time: 13.80ms | tokens processed: 198,680,576 | tok/sec: 296,875.17
# 48510 | lr: 1.00e-02 | loss: 0.1838 | time: 12.83ms | tokens processed: 198,701,056 | tok/sec: 319,358.10
# 48515 | lr: 1.00e-02 | loss: 0.1549 | time: 12.36ms | tokens processed: 198,721,536 | tok/sec: 331,491.32
# 48520 | lr: 1.00e-02 | loss: 0.2117 | time: 14.37ms | tokens processed: 198,742,016 | tok/sec: 285,076.82
# 48525 | lr: 1.00e-02 | loss: 0.1717 | time: 14.64ms | tokens processed: 198,762,496 | tok/sec: 279,797.87
# 48530 | lr: 1.00e-02 | loss: 0.1826 | time: 14.49ms | tokens processed: 198,782,976 | tok/sec: 282,772.93
# 48535 | lr: 1.00e-02 | loss: 0.1714 | time: 14.56ms | tokens processed: 198,803,456 | tok/sec: 281,300.56
# 48540 | lr: 1.00e-02 | loss: 0.1274 | time: 14.66ms | tokens processed: 198,823,936 | tok/sec: 279,442.89
# 48545 | lr: 1.00e-02 | loss: 0.1610 | time: 13.17ms | tokens processed: 198,844,416 | tok/sec: 311,082.99
# 48550 | lr: 1.00e-02 | loss: 0.1568 | time: 14.81ms | tokens processed: 198,864,896 | tok/sec: 276,581.65
# 48555 | lr: 1.00e-02 | loss: 0.1776 | time: 14.84ms | tokens processed: 198,885,376 | tok/sec: 276,012.87
# 48560 | lr: 1.00e-02 | loss: 0.1830 | time: 14.68ms | tokens processed: 198,905,856 | tok/sec: 279,066.13
# 48565 | lr: 1.00e-02 | loss: 0.1680 | time: 14.87ms | tokens processed: 198,926,336 | tok/sec: 275,415.52
# 48570 | lr: 1.00e-02 | loss: 0.1896 | time: 14.38ms | tokens processed: 198,946,816 | tok/sec: 284,911.34
# 48575 | lr: 1.00e-02 | loss: 0.1424 | time: 12.63ms | tokens processed: 198,967,296 | tok/sec: 324,325.94
# 48580 | lr: 1.00e-02 | loss: 0.1771 | time: 14.48ms | tokens processed: 198,987,776 | tok/sec: 282,777.58
# 48585 | lr: 1.00e-02 | loss: 0.2136 | time: 14.89ms | tokens processed: 199,008,256 | tok/sec: 275,128.82
# 48590 | lr: 1.00e-02 | loss: 0.1808 | time: 14.79ms | tokens processed: 199,028,736 | tok/sec: 276,916.01
# 48595 | lr: 1.00e-02 | loss: 0.1676 | time: 13.75ms | tokens processed: 199,049,216 | tok/sec: 297,791.15
# 48600 | lr: 1.00e-02 | loss: 0.1976 | time: 14.63ms | tokens processed: 199,069,696 | tok/sec: 279,920.96
# 48605 | lr: 1.00e-02 | loss: 0.1855 | time: 13.80ms | tokens processed: 199,090,176 | tok/sec: 296,731.60
# 48610 | lr: 1.00e-02 | loss: 0.1817 | time: 14.29ms | tokens processed: 199,110,656 | tok/sec: 286,699.08
# 48615 | lr: 1.00e-02 | loss: 0.1749 | time: 14.27ms | tokens processed: 199,131,136 | tok/sec: 287,082.35
# 48620 | lr: 1.00e-02 | loss: 0.1754 | time: 14.09ms | tokens processed: 199,151,616 | tok/sec: 290,662.02
# 48625 | lr: 1.00e-02 | loss: 0.1705 | time: 14.60ms | tokens processed: 199,172,096 | tok/sec: 280,597.61
# 48630 | lr: 1.00e-02 | loss: 0.1792 | time: 14.71ms | tokens processed: 199,192,576 | tok/sec: 278,505.16
# 48635 | lr: 1.00e-02 | loss: 0.1891 | time: 13.98ms | tokens processed: 199,213,056 | tok/sec: 292,886.94
# 48640 | lr: 1.00e-02 | loss: 0.1758 | time: 14.76ms | tokens processed: 199,233,536 | tok/sec: 277,555.76
# 48645 | lr: 1.00e-02 | loss: 0.1929 | time: 14.76ms | tokens processed: 199,254,016 | tok/sec: 277,439.23
# 48650 | lr: 1.00e-02 | loss: 0.1699 | time: 14.51ms | tokens processed: 199,274,496 | tok/sec: 282,196.97
# 48655 | lr: 1.00e-02 | loss: 0.1594 | time: 14.67ms | tokens processed: 199,294,976 | tok/sec: 279,233.96
# 48660 | lr: 1.00e-02 | loss: 0.2044 | time: 14.37ms | tokens processed: 199,315,456 | tok/sec: 285,133.59
# 48665 | lr: 1.00e-02 | loss: 0.1632 | time: 12.25ms | tokens processed: 199,335,936 | tok/sec: 334,401.35
# 48670 | lr: 1.00e-02 | loss: 0.1714 | time: 14.66ms | tokens processed: 199,356,416 | tok/sec: 279,415.62
# 48675 | lr: 1.00e-02 | loss: 0.1706 | time: 14.23ms | tokens processed: 199,376,896 | tok/sec: 287,900.21
# 48680 | lr: 1.00e-02 | loss: 0.1841 | time: 14.27ms | tokens processed: 199,397,376 | tok/sec: 286,962.47
# 48685 | lr: 1.00e-02 | loss: 0.1703 | time: 14.68ms | tokens processed: 199,417,856 | tok/sec: 279,106.94
# 48690 | lr: 1.00e-02 | loss: 0.1526 | time: 14.50ms | tokens processed: 199,438,336 | tok/sec: 282,507.88
# 48695 | lr: 1.00e-02 | loss: 0.1682 | time: 14.17ms | tokens processed: 199,458,816 | tok/sec: 288,970.42
# 48700 | lr: 1.00e-02 | loss: 0.1868 | time: 14.32ms | tokens processed: 199,479,296 | tok/sec: 286,016.53
# 48705 | lr: 1.00e-02 | loss: 0.1820 | time: 14.34ms | tokens processed: 199,499,776 | tok/sec: 285,579.13
# 48710 | lr: 1.00e-02 | loss: 0.1886 | time: 13.54ms | tokens processed: 199,520,256 | tok/sec: 302,595.67
# 48715 | lr: 1.00e-02 | loss: 0.1635 | time: 14.30ms | tokens processed: 199,540,736 | tok/sec: 286,364.56
# 48720 | lr: 1.00e-02 | loss: 0.1599 | time: 14.02ms | tokens processed: 199,561,216 | tok/sec: 292,189.55
# 48725 | lr: 1.00e-02 | loss: 0.1719 | time: 13.80ms | tokens processed: 199,581,696 | tok/sec: 296,808.49
# 48730 | lr: 1.00e-02 | loss: 0.1773 | time: 14.38ms | tokens processed: 199,602,176 | tok/sec: 284,911.34
# 48735 | lr: 1.00e-02 | loss: 0.1794 | time: 14.65ms | tokens processed: 199,622,656 | tok/sec: 279,624.82
# 48740 | lr: 1.00e-02 | loss: 0.1952 | time: 14.24ms | tokens processed: 199,643,136 | tok/sec: 287,620.65
# 48745 | lr: 1.00e-02 | loss: 0.1814 | time: 14.76ms | tokens processed: 199,663,616 | tok/sec: 277,591.64
# 48750 | lr: 1.00e-02 | loss: 0.1903 | time: 14.19ms | tokens processed: 199,684,096 | tok/sec: 288,679.08
# 48755 | lr: 1.00e-02 | loss: 0.1564 | time: 12.21ms | tokens processed: 199,704,576 | tok/sec: 335,459.14
# 48760 | lr: 1.00e-02 | loss: 0.1793 | time: 14.02ms | tokens processed: 199,725,056 | tok/sec: 292,095.16
# 48765 | lr: 1.00e-02 | loss: 0.1783 | time: 14.78ms | tokens processed: 199,745,536 | tok/sec: 277,067.85
# 48770 | lr: 1.00e-02 | loss: 0.1509 | time: 14.79ms | tokens processed: 199,766,016 | tok/sec: 276,996.38
# 48775 | lr: 1.00e-02 | loss: 0.1893 | time: 14.45ms | tokens processed: 199,786,496 | tok/sec: 283,505.55
# 48780 | lr: 1.00e-02 | loss: 0.1507 | time: 15.00ms | tokens processed: 199,806,976 | tok/sec: 273,142.90
# 48785 | lr: 1.00e-02 | loss: 0.1890 | time: 12.69ms | tokens processed: 199,827,456 | tok/sec: 322,881.32
# 48790 | lr: 1.00e-02 | loss: 0.1504 | time: 14.62ms | tokens processed: 199,847,936 | tok/sec: 280,153.76
# 48795 | lr: 1.00e-02 | loss: 0.1669 | time: 14.13ms | tokens processed: 199,868,416 | tok/sec: 289,828.42
# 48800 | lr: 1.00e-02 | loss: 0.1852 | time: 13.80ms | tokens processed: 199,888,896 | tok/sec: 296,870.04
# 48805 | lr: 1.00e-02 | loss: 0.1855 | time: 14.49ms | tokens processed: 199,909,376 | tok/sec: 282,679.87
# 48810 | lr: 1.00e-02 | loss: 0.1671 | time: 14.65ms | tokens processed: 199,929,856 | tok/sec: 279,679.44
# 48815 | lr: 1.00e-02 | loss: 0.1650 | time: 13.93ms | tokens processed: 199,950,336 | tok/sec: 293,994.61
# 48820 | lr: 1.00e-02 | loss: 0.1500 | time: 14.40ms | tokens processed: 199,970,816 | tok/sec: 284,449.05
# 48825 | lr: 1.00e-02 | loss: 0.1781 | time: 14.33ms | tokens processed: 199,991,296 | tok/sec: 285,735.87
# 48830 | lr: 1.00e-02 | loss: 0.1610 | time: 13.65ms | tokens processed: 200,011,776 | tok/sec: 300,064.09
# 48835 | lr: 1.00e-02 | loss: 0.1616 | time: 14.42ms | tokens processed: 200,032,256 | tok/sec: 283,964.78
# 48840 | lr: 1.00e-02 | loss: 0.1906 | time: 14.85ms | tokens processed: 200,052,736 | tok/sec: 275,778.05
# 48845 | lr: 1.00e-02 | loss: 0.1575 | time: 13.70ms | tokens processed: 200,073,216 | tok/sec: 299,087.22
# 48850 | lr: 1.00e-02 | loss: 0.1651 | time: 14.54ms | tokens processed: 200,093,696 | tok/sec: 281,794.27
# 48855 | lr: 1.00e-02 | loss: 0.1961 | time: 14.29ms | tokens processed: 200,114,176 | tok/sec: 286,675.16
# 48860 | lr: 1.00e-02 | loss: 0.1793 | time: 14.47ms | tokens processed: 200,134,656 | tok/sec: 283,019.82
# 48865 | lr: 1.00e-02 | loss: 0.1738 | time: 14.34ms | tokens processed: 200,155,136 | tok/sec: 285,636.11
# 48870 | lr: 1.00e-02 | loss: 0.1628 | time: 14.56ms | tokens processed: 200,175,616 | tok/sec: 281,259.11
# 48875 | lr: 1.00e-02 | loss: 0.1860 | time: 14.39ms | tokens processed: 200,196,096 | tok/sec: 284,736.63
# 48880 | lr: 1.00e-02 | loss: 0.1907 | time: 14.27ms | tokens processed: 200,216,576 | tok/sec: 287,067.96
# 48885 | lr: 1.00e-02 | loss: 0.1755 | time: 14.51ms | tokens processed: 200,237,056 | tok/sec: 282,326.82
# 48890 | lr: 1.00e-02 | loss: 0.1703 | time: 14.49ms | tokens processed: 200,257,536 | tok/sec: 282,689.17
# 48895 | lr: 1.00e-02 | loss: 0.1786 | time: 14.69ms | tokens processed: 200,278,016 | tok/sec: 278,785.36
# 48900 | lr: 1.00e-02 | loss: 0.1703 | time: 14.85ms | tokens processed: 200,298,496 | tok/sec: 275,786.90
# 48905 | lr: 1.00e-02 | loss: 0.1718 | time: 13.38ms | tokens processed: 200,318,976 | tok/sec: 306,094.67
# 48910 | lr: 1.00e-02 | loss: 0.1573 | time: 14.81ms | tokens processed: 200,339,456 | tok/sec: 276,621.73
# 48915 | lr: 1.00e-02 | loss: 0.1817 | time: 14.70ms | tokens processed: 200,359,936 | tok/sec: 278,554.83
# 48920 | lr: 1.00e-02 | loss: 0.1658 | time: 14.75ms | tokens processed: 200,380,416 | tok/sec: 277,726.27
# 48925 | lr: 1.00e-02 | loss: 0.1485 | time: 14.49ms | tokens processed: 200,400,896 | tok/sec: 282,591.53
# 48930 | lr: 1.00e-02 | loss: 0.1931 | time: 13.97ms | tokens processed: 200,421,376 | tok/sec: 293,296.96
# 48935 | lr: 1.00e-02 | loss: 0.1786 | time: 13.60ms | tokens processed: 200,441,856 | tok/sec: 301,152.89
# 48940 | lr: 1.00e-02 | loss: 0.1793 | time: 14.21ms | tokens processed: 200,462,336 | tok/sec: 288,151.31
# 48945 | lr: 1.00e-02 | loss: 0.1614 | time: 13.94ms | tokens processed: 200,482,816 | tok/sec: 293,858.84
# 48950 | lr: 1.00e-02 | loss: 0.1680 | time: 14.54ms | tokens processed: 200,503,296 | tok/sec: 281,711.09
# ...
# 70920 | lr: 3.47e-04 | loss: 0.1139 | time: 14.81ms | tokens processed: 290,492,416 | tok/sec: 276,479.27
# 70925 | lr: 3.45e-04 | loss: 0.1024 | time: 14.83ms | tokens processed: 290,512,896 | tok/sec: 276,270.31
# 70930 | lr: 3.43e-04 | loss: 0.0756 | time: 14.66ms | tokens processed: 290,533,376 | tok/sec: 279,379.27
# 70935 | lr: 3.40e-04 | loss: 0.1062 | time: 14.23ms | tokens processed: 290,553,856 | tok/sec: 287,914.68
# 70940 | lr: 3.38e-04 | loss: 0.1223 | time: 12.75ms | tokens processed: 290,574,336 | tok/sec: 321,239.14
# 70945 | lr: 3.36e-04 | loss: 0.1160 | time: 14.57ms | tokens processed: 290,594,816 | tok/sec: 281,065.85
# 70950 | lr: 3.33e-04 | loss: 0.1332 | time: 15.24ms | tokens processed: 290,615,296 | tok/sec: 268,775.63
# 70955 | lr: 3.31e-04 | loss: 0.1186 | time: 14.73ms | tokens processed: 290,635,776 | tok/sec: 278,139.93
# 70960 | lr: 3.29e-04 | loss: 0.1259 | time: 14.83ms | tokens processed: 290,656,256 | tok/sec: 276,168.16
# 70965 | lr: 3.27e-04 | loss: 0.1121 | time: 14.33ms | tokens processed: 290,676,736 | tok/sec: 285,773.89
# 70970 | lr: 3.24e-04 | loss: 0.1101 | time: 14.24ms | tokens processed: 290,697,216 | tok/sec: 287,712.17
# 70975 | lr: 3.22e-04 | loss: 0.1145 | time: 14.62ms | tokens processed: 290,717,696 | tok/sec: 280,153.76
# 70980 | lr: 3.20e-04 | loss: 0.1184 | time: 14.41ms | tokens processed: 290,738,176 | tok/sec: 284,284.31
# 70985 | lr: 3.17e-04 | loss: 0.1096 | time: 14.39ms | tokens processed: 290,758,656 | tok/sec: 284,661.14
# 70990 | lr: 3.15e-04 | loss: 0.1247 | time: 13.89ms | tokens processed: 290,779,136 | tok/sec: 294,786.62
# 70995 | lr: 3.13e-04 | loss: 0.1041 | time: 14.49ms | tokens processed: 290,799,616 | tok/sec: 282,735.70
# 71000 | lr: 3.10e-04 | loss: 0.1106 | time: 13.67ms | tokens processed: 290,820,096 | tok/sec: 299,530.46
# 71005 | lr: 3.08e-04 | loss: 0.0946 | time: 13.96ms | tokens processed: 290,840,576 | tok/sec: 293,432.21
# 71010 | lr: 3.06e-04 | loss: 0.1265 | time: 14.67ms | tokens processed: 290,861,056 | tok/sec: 279,138.68
# 71015 | lr: 3.03e-04 | loss: 0.1142 | time: 14.06ms | tokens processed: 290,881,536 | tok/sec: 291,401.54
# 71020 | lr: 3.01e-04 | loss: 0.1103 | time: 14.56ms | tokens processed: 290,902,016 | tok/sec: 281,300.56
# 71025 | lr: 2.99e-04 | loss: 0.1132 | time: 14.72ms | tokens processed: 290,922,496 | tok/sec: 278,351.74
# 71030 | lr: 2.96e-04 | loss: 0.1157 | time: 13.93ms | tokens processed: 290,942,976 | tok/sec: 294,130.51
# 71035 | lr: 2.94e-04 | loss: 0.0993 | time: 14.06ms | tokens processed: 290,963,456 | tok/sec: 291,263.21
# 71040 | lr: 2.92e-04 | loss: 0.1025 | time: 14.34ms | tokens processed: 290,983,936 | tok/sec: 285,731.12
# 71045 | lr: 2.89e-04 | loss: 0.1113 | time: 15.16ms | tokens processed: 291,004,416 | tok/sec: 270,263.96
# 71050 | lr: 2.87e-04 | loss: 0.1109 | time: 15.17ms | tokens processed: 291,024,896 | tok/sec: 269,966.67
# 71055 | lr: 2.85e-04 | loss: 0.1281 | time: 15.31ms | tokens processed: 291,045,376 | tok/sec: 267,620.05
# 71060 | lr: 2.82e-04 | loss: 0.1189 | time: 13.96ms | tokens processed: 291,065,856 | tok/sec: 293,321.99
# 71065 | lr: 2.80e-04 | loss: 0.1075 | time: 14.96ms | tokens processed: 291,086,336 | tok/sec: 273,835.14
# 71070 | lr: 2.78e-04 | loss: 0.1227 | time: 15.03ms | tokens processed: 291,106,816 | tok/sec: 272,549.25
# 71075 | lr: 2.75e-04 | loss: 0.1033 | time: 14.68ms | tokens processed: 291,127,296 | tok/sec: 278,989.09
# 71080 | lr: 2.73e-04 | loss: 0.1066 | time: 14.24ms | tokens processed: 291,147,776 | tok/sec: 287,582.14
# 71085 | lr: 2.71e-04 | loss: 0.1002 | time: 15.12ms | tokens processed: 291,168,256 | tok/sec: 270,950.21
# 71090 | lr: 2.68e-04 | loss: 0.1205 | time: 15.04ms | tokens processed: 291,188,736 | tok/sec: 272,264.17
# 71095 | lr: 2.66e-04 | loss: 0.1180 | time: 14.81ms | tokens processed: 291,209,216 | tok/sec: 276,510.42
# 71100 | lr: 2.64e-04 | loss: 0.1087 | time: 15.05ms | tokens processed: 291,229,696 | tok/sec: 272,246.91
# 71105 | lr: 2.61e-04 | loss: 0.1051 | time: 15.10ms | tokens processed: 291,250,176 | tok/sec: 271,339.64
# 71110 | lr: 2.59e-04 | loss: 0.0890 | time: 14.92ms | tokens processed: 291,270,656 | tok/sec: 274,500.19
# 71115 | lr: 2.57e-04 | loss: 0.1075 | time: 14.69ms | tokens processed: 291,291,136 | tok/sec: 278,807.98
# 71120 | lr: 2.54e-04 | loss: 0.1047 | time: 14.50ms | tokens processed: 291,311,616 | tok/sec: 282,540.40
# 71125 | lr: 2.52e-04 | loss: 0.1267 | time: 15.21ms | tokens processed: 291,332,096 | tok/sec: 269,247.41
# 71130 | lr: 2.50e-04 | loss: 0.1193 | time: 15.16ms | tokens processed: 291,352,576 | tok/sec: 270,132.22
# 71135 | lr: 2.47e-04 | loss: 0.1004 | time: 15.03ms | tokens processed: 291,373,056 | tok/sec: 272,540.60
# 71140 | lr: 2.45e-04 | loss: 0.1131 | time: 14.34ms | tokens processed: 291,393,536 | tok/sec: 285,588.62
# 71145 | lr: 2.43e-04 | loss: 0.0842 | time: 14.43ms | tokens processed: 291,414,016 | tok/sec: 283,927.24
# 71150 | lr: 2.40e-04 | loss: 0.1091 | time: 13.34ms | tokens processed: 291,434,496 | tok/sec: 307,084.98
# 71155 | lr: 2.38e-04 | loss: 0.1190 | time: 14.70ms | tokens processed: 291,454,976 | tok/sec: 278,572.90
# 71160 | lr: 2.36e-04 | loss: 0.0933 | time: 13.95ms | tokens processed: 291,475,456 | tok/sec: 293,723.19
# 71165 | lr: 2.33e-04 | loss: 0.1063 | time: 13.97ms | tokens processed: 291,495,936 | tok/sec: 293,266.92
# 71170 | lr: 2.31e-04 | loss: 0.0928 | time: 14.12ms | tokens processed: 291,516,416 | tok/sec: 290,004.54
# 71175 | lr: 2.29e-04 | loss: 0.1061 | time: 14.71ms | tokens processed: 291,536,896 | tok/sec: 278,374.29
# 71180 | lr: 2.27e-04 | loss: 0.1101 | time: 13.91ms | tokens processed: 291,557,376 | tok/sec: 294,432.97
# 71185 | lr: 2.24e-04 | loss: 0.1141 | time: 14.13ms | tokens processed: 291,577,856 | tok/sec: 289,794.19
# 71190 | lr: 2.22e-04 | loss: 0.1148 | time: 15.02ms | tokens processed: 291,598,336 | tok/sec: 272,739.63
# 71195 | lr: 2.20e-04 | loss: 0.1101 | time: 14.74ms | tokens processed: 291,618,816 | tok/sec: 277,807.11
# 71200 | lr: 2.17e-04 | loss: 0.1153 | time: 14.96ms | tokens processed: 291,639,296 | tok/sec: 273,856.97
# 71205 | lr: 2.15e-04 | loss: 0.1036 | time: 15.13ms | tokens processed: 291,659,776 | tok/sec: 270,745.25
# 71210 | lr: 2.13e-04 | loss: 0.1097 | time: 13.61ms | tokens processed: 291,680,256 | tok/sec: 300,968.24
# 71215 | lr: 2.10e-04 | loss: 0.0923 | time: 14.25ms | tokens processed: 291,700,736 | tok/sec: 287,490.70
# 71220 | lr: 2.08e-04 | loss: 0.1131 | time: 14.65ms | tokens processed: 291,721,216 | tok/sec: 279,670.34
# 71225 | lr: 2.06e-04 | loss: 0.1287 | time: 14.81ms | tokens processed: 291,741,696 | tok/sec: 276,541.58
# 71230 | lr: 2.03e-04 | loss: 0.1087 | time: 14.52ms | tokens processed: 291,762,176 | tok/sec: 282,155.26
# 71235 | lr: 2.01e-04 | loss: 0.1016 | time: 15.07ms | tokens processed: 291,782,656 | tok/sec: 271,708.70
# 71240 | lr: 1.99e-04 | loss: 0.1235 | time: 13.75ms | tokens processed: 291,803,136 | tok/sec: 297,925.42
# 71245 | lr: 1.96e-04 | loss: 0.1180 | time: 14.87ms | tokens processed: 291,823,616 | tok/sec: 275,521.53
# 71250 | lr: 1.94e-04 | loss: 0.1186 | time: 14.52ms | tokens processed: 291,844,096 | tok/sec: 282,178.43
# 71255 | lr: 1.92e-04 | loss: 0.1126 | time: 14.98ms | tokens processed: 291,864,576 | tok/sec: 273,408.07
# 71260 | lr: 1.89e-04 | loss: 0.1133 | time: 15.07ms | tokens processed: 291,885,056 | tok/sec: 271,781.77
# 71265 | lr: 1.87e-04 | loss: 0.1357 | time: 15.02ms | tokens processed: 291,905,536 | tok/sec: 272,670.37
# 71270 | lr: 1.85e-04 | loss: 0.1150 | time: 13.82ms | tokens processed: 291,926,016 | tok/sec: 296,296.60
# 71275 | lr: 1.82e-04 | loss: 0.0936 | time: 14.72ms | tokens processed: 291,946,496 | tok/sec: 278,193.98
# 71280 | lr: 1.80e-04 | loss: 0.1120 | time: 14.70ms | tokens processed: 291,966,976 | tok/sec: 278,672.31
# 71285 | lr: 1.78e-04 | loss: 0.1114 | time: 15.04ms | tokens processed: 291,987,456 | tok/sec: 272,393.68
# 71290 | lr: 1.75e-04 | loss: 0.1454 | time: 15.17ms | tokens processed: 292,007,936 | tok/sec: 270,030.32
# 71295 | lr: 1.73e-04 | loss: 0.1091 | time: 14.56ms | tokens processed: 292,028,416 | tok/sec: 281,286.74
# 71300 | lr: 1.71e-04 | loss: 0.1231 | time: 13.31ms | tokens processed: 292,048,896 | tok/sec: 307,734.06
# 71305 | lr: 1.68e-04 | loss: 0.1052 | time: 14.49ms | tokens processed: 292,069,376 | tok/sec: 282,610.12
# 71310 | lr: 1.66e-04 | loss: 0.1205 | time: 15.06ms | tokens processed: 292,089,856 | tok/sec: 271,897.91
# 71315 | lr: 1.64e-04 | loss: 0.1067 | time: 14.38ms | tokens processed: 292,110,336 | tok/sec: 284,831.04
# 71320 | lr: 1.61e-04 | loss: 0.0998 | time: 14.89ms | tokens processed: 292,130,816 | tok/sec: 275,093.58
# 71325 | lr: 1.59e-04 | loss: 0.0960 | time: 14.91ms | tokens processed: 292,151,296 | tok/sec: 274,759.21
# 71330 | lr: 1.57e-04 | loss: 0.1198 | time: 13.28ms | tokens processed: 292,171,776 | tok/sec: 308,457.86
# 71335 | lr: 1.54e-04 | loss: 0.1220 | time: 14.40ms | tokens processed: 292,192,256 | tok/sec: 284,491.44
# 71340 | lr: 1.52e-04 | loss: 0.1057 | time: 14.66ms | tokens processed: 292,212,736 | tok/sec: 279,465.61
# 71345 | lr: 1.50e-04 | loss: 0.1152 | time: 14.80ms | tokens processed: 292,233,216 | tok/sec: 276,733.13
# 71350 | lr: 1.47e-04 | loss: 0.1214 | time: 14.81ms | tokens processed: 292,253,696 | tok/sec: 276,639.55
# 71355 | lr: 1.45e-04 | loss: 0.1201 | time: 12.53ms | tokens processed: 292,274,176 | tok/sec: 326,936.69
# 71360 | lr: 1.43e-04 | loss: 0.0834 | time: 14.23ms | tokens processed: 292,294,656 | tok/sec: 287,933.99
# 71365 | lr: 1.40e-04 | loss: 0.1093 | time: 13.83ms | tokens processed: 292,315,136 | tok/sec: 296,061.71
# 71370 | lr: 1.38e-04 | loss: 0.1256 | time: 14.43ms | tokens processed: 292,335,616 | tok/sec: 283,781.85
# 71375 | lr: 1.36e-04 | loss: 0.1125 | time: 14.35ms | tokens processed: 292,356,096 | tok/sec: 285,507.94
# 71380 | lr: 1.33e-04 | loss: 0.0967 | time: 13.84ms | tokens processed: 292,376,576 | tok/sec: 295,918.93
# 71385 | lr: 1.31e-04 | loss: 0.1233 | time: 13.95ms | tokens processed: 292,397,056 | tok/sec: 293,657.92
# 71390 | lr: 1.29e-04 | loss: 0.1173 | time: 14.42ms | tokens processed: 292,417,536 | tok/sec: 284,021.11
# 71395 | lr: 1.27e-04 | loss: 0.0983 | time: 13.46ms | tokens processed: 292,438,016 | tok/sec: 304,208.47
# 71400 | lr: 1.24e-04 | loss: 0.1065 | time: 13.73ms | tokens processed: 292,458,496 | tok/sec: 298,354.85
# 71405 | lr: 1.22e-04 | loss: 0.1280 | time: 14.23ms | tokens processed: 292,478,976 | tok/sec: 287,818.21
# 71410 | lr: 1.20e-04 | loss: 0.1045 | time: 13.45ms | tokens processed: 292,499,456 | tok/sec: 304,472.65
# 71415 | lr: 1.17e-04 | loss: 0.1051 | time: 14.07ms | tokens processed: 292,519,936 | tok/sec: 291,041.17
# 71420 | lr: 1.15e-04 | loss: 0.1227 | time: 15.04ms | tokens processed: 292,540,416 | tok/sec: 272,385.04
# 71425 | lr: 1.13e-04 | loss: 0.1210 | time: 14.94ms | tokens processed: 292,560,896 | tok/sec: 274,254.80
# 71430 | lr: 1.10e-04 | loss: 0.1050 | time: 14.94ms | tokens processed: 292,581,376 | tok/sec: 274,176.02
# 71435 | lr: 1.08e-04 | loss: 0.1149 | time: 15.04ms | tokens processed: 292,601,856 | tok/sec: 272,315.96
# 71440 | lr: 1.06e-04 | loss: 0.1136 | time: 15.20ms | tokens processed: 292,622,336 | tok/sec: 269,500.83
# 71445 | lr: 1.03e-04 | loss: 0.1232 | time: 14.26ms | tokens processed: 292,642,816 | tok/sec: 287,279.17
# 71450 | lr: 1.01e-04 | loss: 0.1120 | time: 14.92ms | tokens processed: 292,663,296 | tok/sec: 274,443.19
# 71455 | lr: 9.86e-05 | loss: 0.1046 | time: 14.97ms | tokens processed: 292,683,776 | tok/sec: 273,638.87
# 71460 | lr: 9.63e-05 | loss: 0.0989 | time: 14.63ms | tokens processed: 292,704,256 | tok/sec: 280,016.77
# 71465 | lr: 9.40e-05 | loss: 0.1241 | time: 15.07ms | tokens processed: 292,724,736 | tok/sec: 271,777.47
# 71470 | lr: 9.16e-05 | loss: 0.1165 | time: 15.08ms | tokens processed: 292,745,216 | tok/sec: 271,584.13
# 71475 | lr: 8.93e-05 | loss: 0.1198 | time: 13.78ms | tokens processed: 292,765,696 | tok/sec: 297,152.45
# 71480 | lr: 8.70e-05 | loss: 0.0988 | time: 15.00ms | tokens processed: 292,786,176 | tok/sec: 272,982.32
# 71485 | lr: 8.47e-05 | loss: 0.1064 | time: 14.96ms | tokens processed: 292,806,656 | tok/sec: 273,726.07
# 71490 | lr: 8.23e-05 | loss: 0.1114 | time: 15.24ms | tokens processed: 292,827,136 | tok/sec: 268,729.38
# 71495 | lr: 8.00e-05 | loss: 0.1126 | time: 14.77ms | tokens processed: 292,847,616 | tok/sec: 277,278.03
# 71500 | lr: 7.77e-05 | loss: 0.1125 | time: 14.89ms | tokens processed: 292,868,096 | tok/sec: 275,159.67
# 71505 | lr: 7.53e-05 | loss: 0.1167 | time: 13.65ms | tokens processed: 292,888,576 | tok/sec: 300,011.69
# 71510 | lr: 7.30e-05 | loss: 0.1110 | time: 13.59ms | tokens processed: 292,909,056 | tok/sec: 301,475.26
# 71515 | lr: 7.07e-05 | loss: 0.1158 | time: 14.86ms | tokens processed: 292,929,536 | tok/sec: 275,649.73
# 71520 | lr: 6.84e-05 | loss: 0.1211 | time: 15.17ms | tokens processed: 292,950,016 | tok/sec: 269,924.26
# 71525 | lr: 6.60e-05 | loss: 0.1041 | time: 14.60ms | tokens processed: 292,970,496 | tok/sec: 280,574.70
# 71530 | lr: 6.37e-05 | loss: 0.1047 | time: 15.13ms | tokens processed: 292,990,976 | tok/sec: 270,749.52
# 71535 | lr: 6.14e-05 | loss: 0.1006 | time: 12.11ms | tokens processed: 293,011,456 | tok/sec: 338,292.95
# 71540 | lr: 5.91e-05 | loss: 0.1058 | time: 15.19ms | tokens processed: 293,031,936 | tok/sec: 269,568.49
# 71545 | lr: 5.67e-05 | loss: 0.1097 | time: 14.71ms | tokens processed: 293,052,416 | tok/sec: 278,374.29
# 71550 | lr: 5.44e-05 | loss: 0.1037 | time: 14.90ms | tokens processed: 293,072,896 | tok/sec: 274,983.50
# 71555 | lr: 5.21e-05 | loss: 0.1277 | time: 15.24ms | tokens processed: 293,093,376 | tok/sec: 268,851.34
# 71560 | lr: 4.98e-05 | loss: 0.1033 | time: 15.25ms | tokens processed: 293,113,856 | tok/sec: 268,519.37
# 71565 | lr: 4.74e-05 | loss: 0.1282 | time: 14.77ms | tokens processed: 293,134,336 | tok/sec: 277,407.87
# 71570 | lr: 4.51e-05 | loss: 0.1217 | time: 14.38ms | tokens processed: 293,154,816 | tok/sec: 284,831.04
# 71575 | lr: 4.28e-05 | loss: 0.0861 | time: 15.09ms | tokens processed: 293,175,296 | tok/sec: 271,348.21
# 71580 | lr: 4.05e-05 | loss: 0.1037 | time: 14.79ms | tokens processed: 293,195,776 | tok/sec: 276,947.26
# 71585 | lr: 3.81e-05 | loss: 0.1066 | time: 15.10ms | tokens processed: 293,216,256 | tok/sec: 271,211.13
# 71590 | lr: 3.58e-05 | loss: 0.1065 | time: 14.79ms | tokens processed: 293,236,736 | tok/sec: 276,880.31
# 71595 | lr: 3.35e-05 | loss: 0.1169 | time: 12.36ms | tokens processed: 293,257,216 | tok/sec: 331,484.92
# 71600 | lr: 3.12e-05 | loss: 0.1041 | time: 14.77ms | tokens processed: 293,277,696 | tok/sec: 277,403.39
# 71605 | lr: 2.88e-05 | loss: 0.1109 | time: 15.23ms | tokens processed: 293,298,176 | tok/sec: 268,885.00
# 71610 | lr: 2.65e-05 | loss: 0.1023 | time: 15.21ms | tokens processed: 293,318,656 | tok/sec: 269,209.43
# 71615 | lr: 2.42e-05 | loss: 0.1072 | time: 13.92ms | tokens processed: 293,339,136 | tok/sec: 294,155.69
# 71620 | lr: 2.19e-05 | loss: 0.1134 | time: 14.86ms | tokens processed: 293,359,616 | tok/sec: 275,707.23
# 71625 | lr: 1.95e-05 | loss: 0.1111 | time: 13.47ms | tokens processed: 293,380,096 | tok/sec: 304,138.46
# 71630 | lr: 1.72e-05 | loss: 0.1103 | time: 14.84ms | tokens processed: 293,400,576 | tok/sec: 276,048.35
# 71635 | lr: 1.49e-05 | loss: 0.0997 | time: 13.96ms | tokens processed: 293,421,056 | tok/sec: 293,402.14
# 71640 | lr: 1.26e-05 | loss: 0.0978 | time: 13.28ms | tokens processed: 293,441,536 | tok/sec: 308,463.40
# 71645 | lr: 1.02e-05 | loss: 0.1018 | time: 15.12ms | tokens processed: 293,462,016 | tok/sec: 270,984.40
# 71650 | lr: 7.91e-06 | loss: 0.1084 | time: 15.14ms | tokens processed: 293,482,496 | tok/sec: 270,540.60
# 71655 | lr: 5.58e-06 | loss: 0.1048 | time: 14.93ms | tokens processed: 293,502,976 | tok/sec: 274,430.04
# 71660 | lr: 3.26e-06 | loss: 0.1046 | time: 15.06ms | tokens processed: 293,523,456 | tok/sec: 271,958.16
# 71665 | lr: 9.30e-07 | loss: 0.1046 | time: 14.56ms | tokens processed: 293,543,936 | tok/sec: 281,240.70

# %%
completions = generate_completions(m, enc=tokenizer, max_length=40)
for completion in completions:
    print(completion)
# Out:
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  journal or I Quarterly<jupyter_text>�
#  bre dimensional<jupyter_text> fertilizersAs thatode� under
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  journal or I Quarterly<jupyter_text>�
#  bre dimensional<jupyter_start>le s [-icre one
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  percent s remark thatargs Include colonialOKomeseome�
# imesleual<jupyter_code>
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  percent s remark thatargs Include colonialOKomeseome�
# imesleual<jupyter_code>
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  journal or I Quarterly<jupyter_text>�
#  bre dimensionalle s remark smow*�
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  journal or I Quarterly<jupyter_text>�
#  bre dimensional<jupyter_start>le s [-icre one
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  percent s remark thatargs Include colonialOKomeseome�
# imesleual<jupyter_code>
# Hello, I'm a language model,<jupyter_code>�
#
#  percent<jupyter_start> d change dre remark<jupyter_code>�
#
#  journal or I Quarterly<jupyter_text>�
#  bre dimensional<jupyter_start>le s [-icre one

# %% [markdown]
# # Let's Train SmolLM 135M

# %% [markdown]
# ### Configure the machine and install packages

# %%
import os

#os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=8'

from typing import Literal

import jax

platform : Literal["darwin", "colab", "cuda"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken datasets --quiet
    # !pip uninstall -y tensorflow
# Out:
# Running on colab
# fatal: destination path 'jaxpt' already exists and is not an empty directory.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Already up to date.
# WARNING: Skipping tensorflow as it is not installed.

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )


sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /content/jaxpt/src

# %%
import os
import warnings

import jax
import flax
import jax.numpy as jnp
import numpy as np

from jax.sharding import Mesh, PartitionSpec, NamedSharding

# Hardware setup
print("JAX version:", jax.__version__)
print("Flax version", flax.__version__)
devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

requested_device = "gpu"

jax.config.update("jax_platform_name", requested_device) # Make sure we're using the GPU

mesh = Mesh(devices, ("devices",))
spec = PartitionSpec("devices",)
sharding = NamedSharding(mesh, spec)

device = jax.default_backend()
if device != requested_device:
    warnings.warn(f"not using {requested_device}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Make sure matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.5.2
# Flax version 0.10.6
# Available devices: 1
# using gpu
# 869 µs ± 47.3 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Initialize SmolLLM model and perform a sanity check

# %%
from flax import nnx

from jaxpt.infer import generate_completions, generate
from jaxpt.models import SmolLM, SmolLM_Config
from jaxpt.models.smol_lm import from_hf_pretrained
from jaxpt.utils import count_params, create_sharded_model

from transformers import AutoTokenizer

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = SmolLM_Config(dtype=jnp.bfloat16, \
                    #vocab_size=49152,
                    block_size=128,
                    n_layer=4,
                    n_embed=128,
                    n_head=4,
                    n_kv_head=2,
                    n_mlp_hidden=384,
                    use_cache=False,
                    mesh=mesh,
                    sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)
with mesh:
    m = create_sharded_model(SmolLM, config, rngs)
    #m = SmolLM(config, rngs)
    #graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
    #nnx.display(state)
    #m = load_checkpoint("run_20250311_uqdwjq", 5600)
    #m = from_hf_pretrained(config, rngs)

    graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
    total_params = count_params(m)

    print(f"Parameter Count: {total_params:,}")
    nnx.display(state)

    tokenizer = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-135M")
    #completions = generate_completions(m, enc=tokenizer, num_completions=5, max_length=21, prefix="Ducks quack, donkeys bray, cats mew, horses")
    #for completion in completions:
    #    print(completion)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_cef53e7439d9428f8bf2ff3a28ea2482" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cef53e7439d9428f8bf2ff3a28ea2482")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_cef53e7439d9428f8bf2ff3a28ea2482")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Parameter Count: 7,220,480
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_32e6a9b16059445d9613879b25a12888" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_32e6a9b16059445d9613879b25a12888")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_32e6a9b16059445d9613879b25a12888")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_32e6a9b16059445d9613879b25a12888")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
jax.debug.visualize_array_sharding(state.wte.embedding.value)
# Out:
#
#
#
#
#
#   GPU 0

# %% [markdown]
# ### Configure Training Run

# %%
from datetime import datetime
import random
import string


def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

run_dirname = f"run_{timestamp}_{random_code}"
print(f"Run: {run_dirname}")

if platform == "colab":
  output_dir = Path().absolute().parent
elif platform == "cuda":
  output_dir = Path("/home/ubuntu/gpt2-train") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent # Local setup

# Create checkpoint dir
checkpoint_dir = output_dir / "checkpoints"
checkpoint_dir.mkdir(parents=True, exist_ok=True)
print(f"Checkpoint directory: {checkpoint_dir}")

# Create log dir
log_dir = output_dir / "logs"
log_dir.mkdir(parents=True, exist_ok=True)
print(f"Log directory: {log_dir}")

def save_checkpoint(m, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m.save_checkpoint(checkpoint_path)

def load_checkpoint(model, run_dirname, step):
  checkpoint_path = checkpoint_dir / run_dirname / f"checkpoint-{step}.pt"
  m = model.load_checkpoint(checkpoint_path, rngs)
  return m
# Out:
# Run: run_20250718_kooifa
# Checkpoint directory: /checkpoints
# Log directory: /logs

# %%
import dataclasses

import optax


############################
# Nvidia A100 (x 8) Config #
############################

@dataclasses.dataclass
class TrainerConfig:
  num_tokens_per_batch: int = 2**12 # 2**19, 0.5 million as per the GPT 3.5 paper
  mB: int = 32 * num_devices
  T: int = 128
  max_steps: int = int((2000*146776) // (2**12))
  max_lr: float = 1e-2
  min_lr: float = max_lr * 0.1
  max_grad_norm: float = 1.0  # Clip gradients to this norm
  warmup_steps: int = 3
  print_interval: int = 500
  eval_interval: int = 5000
  checkpoint_interval: int = 10000
  grad_accumulation_steps: int = num_tokens_per_batch // (mB * T) # Number of steps over which to average the gradient


##############
# CPU Config #
##############

trconf = TrainerConfig()
'''
trconf = TrainerConfig(
  num_tokens_per_batch=2**9,
  mB=2**4,
  T=2**5,
  max_steps=9*48, # 6 epoch(s)
  max_lr=6e-4,
  min_lr=6e-5,
  max_grad_norm=1.0,
  warmup_steps=10,
  print_interval=1,
  eval_interval=50,
  checkpoint_interval=0,

)

trconf.grad_accumulation_steps =  trconf.num_tokens_per_batch // (trconf.mB * trconf.T * num_devices) # Number of steps over which to average the gradient
'''

# Set up the optimizer
cool_down_period = 0.3
def trapezoidal_schedule(step):

    warmup_lr = trconf.max_lr * (step + 1) / trconf.warmup_steps
    cooldown_lr = trconf.max_lr * (trconf.max_steps - step) / (trconf.max_steps - (1 - cool_down_period) * trconf.max_steps)

    return jnp.where(step < trconf.warmup_steps,
                     warmup_lr,
                     jnp.where(step < (1 - cool_down_period) * trconf.max_steps, trconf.max_lr, cooldown_lr))

steps = range(0, trconf.max_steps, 1000)
total_schedule = [ trapezoidal_schedule(step) for step in steps ]
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.plot(steps, total_schedule)
plt.title("LR Schedule")
plt.show()

# Generate a weight decay mask
# First split the model into params and variables
graphdef, params, variables = nnx.split(m, nnx.Param, nnx.Variable)
# Then create a mask for the weight decay params
weight_decay_mask = jax.tree_util.tree_map(lambda x: len(x.shape) > 1, params)

tx = optax.chain(
    #optax.clip_by_global_norm(trconf.max_grad_norm),
    #optax.adamw(trapezoidal_schedule, b1=0.9, b2=0.95, weight_decay=0.1, mask=weight_decay_mask),
    optax.adafactor(trapezoidal_schedule)
)
optimizer = nnx.Optimizer(m, tx)

# count the number of weight decay params
def f(x, y):
    if x:
        return y.size
    return 0

weight_decay_params = jax.tree_util.tree_map(f, weight_decay_mask, params)
weight_decay_param_count = jax.tree_util.tree_reduce(lambda x, y: x + y, weight_decay_params, 0)


print(f"weight decay param count: {weight_decay_param_count:,}")
print(f"tokens/batch: {trconf.num_tokens_per_batch:,}")
print(f"block size: {trconf.T}")
print(f"batch size: {trconf.mB}")
print(f"no. gradient accumulation steps: {trconf.grad_accumulation_steps}")
print(f"effective batch size: {trconf.grad_accumulation_steps * trconf.mB}")
print(f"effective batch size per device: ", trconf.grad_accumulation_steps * trconf.mB // num_devices)
print(f"max steps: {trconf.max_steps:,}")
# Out:
# weight decay param count: 7,219,328
# tokens/batch: 4,096
# block size: 128
# batch size: 32
# no. gradient accumulation steps: 1
# effective batch size: 32
# effective batch size per device:  32
# max steps: 71,667

# %% [markdown]
# ### DataLoader and Validation Setup

# %%
from jaxpt.dataloaders import DataLoader, HuggingfaceDataLoader, CloudDataLoader

batch_size = trconf.T * trconf.mB * trconf.grad_accumulation_steps
batch_memory = batch_size*2
print(f"Batch Size (Tokens): {batch_size:,} | Batch Memory: {batch_memory/1024} MB")

'''
train_dl = HuggingfaceDataLoader(batch_size=trconf.mB * DATA_DIMS,
                                 block_size=trconf.T,
                                 device_rank=1,
                                 tokenizer="HuggingFaceTB/SmolLM-135M",
                                 dataset_paths=["HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus"],
                                 dataset_names=["cosmopedia-v2",
                                                "python-edu",
                                                "fineweb-edu-dedup"],
                                 probabilities=[0.111, 0.016 , 0.873],
                                 label="train",
                                 random_seed=1337,
                                 buffer_size=10_000,
                                 streaming=True)
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./alpha-448101-282bc1b884cd.json"

train_dl = CloudDataLoader(bucket_name="jaxpt_datasets",
                      bucket_prefix="fineweb-edu-100b/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")

'''
train_dl = DataLoader(dirpath="/content/jaxpt/datasets/panchatantra-ryder/processed",
                      batch_size=trconf.mB,
                      block_size=trconf.T,
                      device_rank=1,
                      label="train")
# Out:
# Batch Size (Tokens): 4,096 | Batch Memory: 8.0 MB
# DataLoader initialized:
# ------------------------
# label:          train
# shards:         1
# shard size:     146,776
# batch size:     32
# block size:     128
# device rank:    1
# ------------------------

# %%
from jaxpt.utils import append_to_csv

train_losses = []
append_to_csv(log_dir / f"{run_dirname}_train.csv", ["step", "lr", "loss", "time", "tokens_processed", "tokens_per_sec"])
step = 0

# %%
# %matplotlib inline

import time

import matplotlib.pyplot as plt


def loss_fn(model, batch, targets):
    logits = model(batch)
    loss = optax.softmax_cross_entropy_with_integer_labels(logits, targets)
    return loss.mean(), logits


@nnx.jit
def train_step(model, optimizer, batch, targets):
    (loss, logits), grads = nnx.value_and_grad(loss_fn, has_aux=True)(model, batch, targets)
    optimizer.update(grads)
    return loss, grads, logits


m.train()
try:
  while step < trconf.max_steps:
    start = time.time()
    batch, target = train_dl()
    batch = jax.device_put(batch.squeeze(), sharding)
    target = jax.device_put(target.squeeze(), sharding)
    loss, grads, logits = train_step(m, optimizer, batch, target)

    if step % trconf.print_interval == 0:
      # compute stats
      loss.block_until_ready()
      lr = trapezoidal_schedule(step)
      iter_time = time.time() - start
      sub_step_time = iter_time / trconf.grad_accumulation_steps
      tokens_per_sec = trconf.mB * trconf.T * trconf.grad_accumulation_steps / iter_time
      tokens_processed = (step+1) * trconf.grad_accumulation_steps * trconf.mB * trconf.T

      train_losses.append((step, loss))
      append_to_csv(log_dir / f"{run_dirname}_train.csv", [step, lr, loss, iter_time*1000, tokens_processed, tokens_per_sec])
      print(f"{step} | lr: {lr:0.2e} | "
            f"loss: {loss:0.4f} | "
            f"time: {iter_time*1000:0.2f}ms | "
            f"tokens processed: {tokens_processed:,} | "
            f"tok/sec: {tokens_per_sec:,.2f}")#, end="\r")
    if step % trconf.eval_interval == 0:
      print("Evaluation TBD")
      #save_checkpoint(m, run_dirname, step)
    step += 1

except KeyboardInterrupt:
    print("Received KeyboardInterrupt. Exiting...")

plt.figure(figsize=(5, 3))
plt.plot([x[0] for x in train_losses], [x[1] for x in train_losses], label="train loss")
plt.legend()
plt.savefig(log_dir / f"{run_dirname}.png", dpi=300, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# 0 | lr: 3.33e-03 | loss: 10.7683 | time: 29927.33ms | tokens processed: 4,096 | tok/sec: 136.86
# Evaluation TBD
# 500 | lr: 1.00e-02 | loss: 4.3713 | time: 86.55ms | tokens processed: 2,052,096 | tok/sec: 47,323.29
# 1000 | lr: 1.00e-02 | loss: 3.8888 | time: 175.46ms | tokens processed: 4,100,096 | tok/sec: 23,344.50
# 1500 | lr: 1.00e-02 | loss: 3.4659 | time: 77.51ms | tokens processed: 6,148,096 | tok/sec: 52,845.69
# 2000 | lr: 1.00e-02 | loss: 3.2856 | time: 172.92ms | tokens processed: 8,196,096 | tok/sec: 23,686.90
# 2500 | lr: 1.00e-02 | loss: 3.0913 | time: 62.37ms | tokens processed: 10,244,096 | tok/sec: 65,667.76
# 3000 | lr: 1.00e-02 | loss: 2.9233 | time: 131.87ms | tokens processed: 12,292,096 | tok/sec: 31,060.66
# 3500 | lr: 1.00e-02 | loss: 2.6979 | time: 45.75ms | tokens processed: 14,340,096 | tok/sec: 89,522.78
# 4000 | lr: 1.00e-02 | loss: 2.3449 | time: 130.28ms | tokens processed: 16,388,096 | tok/sec: 31,439.68
# 4500 | lr: 1.00e-02 | loss: 1.8417 | time: 18.70ms | tokens processed: 18,436,096 | tok/sec: 219,030.41
# 5000 | lr: 1.00e-02 | loss: 1.3656 | time: 27.52ms | tokens processed: 20,484,096 | tok/sec: 148,837.53
# Evaluation TBD
# 5500 | lr: 1.00e-02 | loss: 0.9639 | time: 107.69ms | tokens processed: 22,532,096 | tok/sec: 38,035.91
# 6000 | lr: 1.00e-02 | loss: 0.7383 | time: 69.47ms | tokens processed: 24,580,096 | tok/sec: 58,957.53
# 6500 | lr: 1.00e-02 | loss: 0.4966 | time: 58.72ms | tokens processed: 26,628,096 | tok/sec: 69,758.03
# 7000 | lr: 1.00e-02 | loss: 0.4300 | time: 97.59ms | tokens processed: 28,676,096 | tok/sec: 41,970.19
# 7500 | lr: 1.00e-02 | loss: 0.3624 | time: 77.85ms | tokens processed: 30,724,096 | tok/sec: 52,611.51
# 8000 | lr: 1.00e-02 | loss: 0.4164 | time: 83.98ms | tokens processed: 32,772,096 | tok/sec: 48,775.13
# 8500 | lr: 1.00e-02 | loss: 0.3135 | time: 165.52ms | tokens processed: 34,820,096 | tok/sec: 24,745.94
# 9000 | lr: 1.00e-02 | loss: 0.2947 | time: 58.78ms | tokens processed: 36,868,096 | tok/sec: 69,687.86
# 9500 | lr: 1.00e-02 | loss: 0.3046 | time: 150.19ms | tokens processed: 38,916,096 | tok/sec: 27,271.58
# 10000 | lr: 1.00e-02 | loss: 0.3458 | time: 46.61ms | tokens processed: 40,964,096 | tok/sec: 87,882.86
# Evaluation TBD
# 10500 | lr: 1.00e-02 | loss: 0.2792 | time: 26.78ms | tokens processed: 43,012,096 | tok/sec: 152,943.78
# 11000 | lr: 1.00e-02 | loss: 0.2770 | time: 143.50ms | tokens processed: 45,060,096 | tok/sec: 28,542.78
# 11500 | lr: 1.00e-02 | loss: 0.3062 | time: 23.66ms | tokens processed: 47,108,096 | tok/sec: 173,142.28
# 12000 | lr: 1.00e-02 | loss: 0.2510 | time: 218.10ms | tokens processed: 49,156,096 | tok/sec: 18,780.33
# 12500 | lr: 1.00e-02 | loss: 0.2404 | time: 73.42ms | tokens processed: 51,204,096 | tok/sec: 55,787.67
# 13000 | lr: 1.00e-02 | loss: 0.2235 | time: 147.71ms | tokens processed: 53,252,096 | tok/sec: 27,730.40
# 13500 | lr: 1.00e-02 | loss: 0.2285 | time: 51.01ms | tokens processed: 55,300,096 | tok/sec: 80,304.15
# 14000 | lr: 1.00e-02 | loss: 0.2383 | time: 62.48ms | tokens processed: 57,348,096 | tok/sec: 65,556.01
# 14500 | lr: 1.00e-02 | loss: 0.2785 | time: 123.62ms | tokens processed: 59,396,096 | tok/sec: 33,132.96
# 15000 | lr: 1.00e-02 | loss: 0.2124 | time: 67.06ms | tokens processed: 61,444,096 | tok/sec: 61,083.33
# Evaluation TBD
# 15500 | lr: 1.00e-02 | loss: 0.2520 | time: 62.63ms | tokens processed: 63,492,096 | tok/sec: 65,398.29
# 16000 | lr: 1.00e-02 | loss: 0.2474 | time: 38.02ms | tokens processed: 65,540,096 | tok/sec: 107,722.26
# 16500 | lr: 1.00e-02 | loss: 0.2213 | time: 114.96ms | tokens processed: 67,588,096 | tok/sec: 35,630.54
# 17000 | lr: 1.00e-02 | loss: 0.2275 | time: 26.61ms | tokens processed: 69,636,096 | tok/sec: 153,948.38
# 17500 | lr: 1.00e-02 | loss: 0.2379 | time: 112.71ms | tokens processed: 71,684,096 | tok/sec: 36,341.51
# 18000 | lr: 1.00e-02 | loss: 0.2357 | time: 207.18ms | tokens processed: 73,732,096 | tok/sec: 19,769.97
# 18500 | lr: 1.00e-02 | loss: 0.2320 | time: 67.19ms | tokens processed: 75,780,096 | tok/sec: 60,963.89
# 19000 | lr: 1.00e-02 | loss: 0.2124 | time: 172.94ms | tokens processed: 77,828,096 | tok/sec: 23,684.87
# 19500 | lr: 1.00e-02 | loss: 0.2124 | time: 217.57ms | tokens processed: 79,876,096 | tok/sec: 18,826.55
# 20000 | lr: 1.00e-02 | loss: 0.1960 | time: 64.76ms | tokens processed: 81,924,096 | tok/sec: 63,249.65
# Evaluation TBD
# 20500 | lr: 1.00e-02 | loss: 0.2374 | time: 180.50ms | tokens processed: 83,972,096 | tok/sec: 22,692.07
# 21000 | lr: 1.00e-02 | loss: 0.2166 | time: 151.23ms | tokens processed: 86,020,096 | tok/sec: 27,084.13
# 21500 | lr: 1.00e-02 | loss: 0.1669 | time: 33.28ms | tokens processed: 88,068,096 | tok/sec: 123,064.97
# 22000 | lr: 1.00e-02 | loss: 0.1913 | time: 106.36ms | tokens processed: 90,116,096 | tok/sec: 38,511.60
# 22500 | lr: 1.00e-02 | loss: 0.1916 | time: 18.21ms | tokens processed: 92,164,096 | tok/sec: 224,932.17
# 23000 | lr: 1.00e-02 | loss: 0.1839 | time: 33.72ms | tokens processed: 94,212,096 | tok/sec: 121,486.34
# 23500 | lr: 1.00e-02 | loss: 0.1936 | time: 173.66ms | tokens processed: 96,260,096 | tok/sec: 23,585.99
# 24000 | lr: 1.00e-02 | loss: 0.1508 | time: 71.07ms | tokens processed: 98,308,096 | tok/sec: 57,630.46
# 24500 | lr: 1.00e-02 | loss: 0.2011 | time: 105.18ms | tokens processed: 100,356,096 | tok/sec: 38,943.11
# 25000 | lr: 1.00e-02 | loss: 0.1828 | time: 196.49ms | tokens processed: 102,404,096 | tok/sec: 20,846.07
# Evaluation TBD
# 25500 | lr: 1.00e-02 | loss: 0.1854 | time: 96.42ms | tokens processed: 104,452,096 | tok/sec: 42,482.58
# 26000 | lr: 1.00e-02 | loss: 0.2031 | time: 142.05ms | tokens processed: 106,500,096 | tok/sec: 28,835.78
# 26500 | lr: 1.00e-02 | loss: 0.2294 | time: 68.34ms | tokens processed: 108,548,096 | tok/sec: 59,932.84
# 27000 | lr: 1.00e-02 | loss: 0.1930 | time: 157.43ms | tokens processed: 110,596,096 | tok/sec: 26,018.48
# 27500 | lr: 1.00e-02 | loss: 0.2158 | time: 39.16ms | tokens processed: 112,644,096 | tok/sec: 104,594.58
# 28000 | lr: 1.00e-02 | loss: 0.1715 | time: 120.47ms | tokens processed: 114,692,096 | tok/sec: 33,999.14
# 28500 | lr: 1.00e-02 | loss: 0.2012 | time: 22.05ms | tokens processed: 116,740,096 | tok/sec: 185,750.40
# 29000 | lr: 1.00e-02 | loss: 0.1724 | time: 116.23ms | tokens processed: 118,788,096 | tok/sec: 35,240.90
# 29500 | lr: 1.00e-02 | loss: 0.2137 | time: 183.46ms | tokens processed: 120,836,096 | tok/sec: 22,326.10
# 30000 | lr: 1.00e-02 | loss: 0.1737 | time: 69.67ms | tokens processed: 122,884,096 | tok/sec: 58,791.88
# Evaluation TBD
# 30500 | lr: 1.00e-02 | loss: 0.1608 | time: 171.22ms | tokens processed: 124,932,096 | tok/sec: 23,923.00
# 31000 | lr: 1.00e-02 | loss: 0.1657 | time: 62.61ms | tokens processed: 126,980,096 | tok/sec: 65,420.70
# 31500 | lr: 1.00e-02 | loss: 0.1577 | time: 78.38ms | tokens processed: 129,028,096 | tok/sec: 52,259.59
# 32000 | lr: 1.00e-02 | loss: 0.1664 | time: 173.04ms | tokens processed: 131,076,096 | tok/sec: 23,670.71
# 32500 | lr: 1.00e-02 | loss: 0.1657 | time: 57.78ms | tokens processed: 133,124,096 | tok/sec: 70,885.45
# 33000 | lr: 1.00e-02 | loss: 0.1632 | time: 126.26ms | tokens processed: 135,172,096 | tok/sec: 32,441.05
# 33500 | lr: 1.00e-02 | loss: 0.1609 | time: 31.82ms | tokens processed: 137,220,096 | tok/sec: 128,724.80
# 34000 | lr: 1.00e-02 | loss: 0.1538 | time: 116.28ms | tokens processed: 139,268,096 | tok/sec: 35,226.45
# 34500 | lr: 1.00e-02 | loss: 0.1657 | time: 156.22ms | tokens processed: 141,316,096 | tok/sec: 26,219.40
# 35000 | lr: 1.00e-02 | loss: 0.1553 | time: 54.12ms | tokens processed: 143,364,096 | tok/sec: 75,678.24
# Evaluation TBD
# 35500 | lr: 1.00e-02 | loss: 0.1301 | time: 116.00ms | tokens processed: 145,412,096 | tok/sec: 35,310.87
# 36000 | lr: 1.00e-02 | loss: 0.1595 | time: 206.00ms | tokens processed: 147,460,096 | tok/sec: 19,883.21
# 36500 | lr: 1.00e-02 | loss: 0.1840 | time: 93.38ms | tokens processed: 149,508,096 | tok/sec: 43,863.35
# 37000 | lr: 1.00e-02 | loss: 0.1718 | time: 191.23ms | tokens processed: 151,556,096 | tok/sec: 21,419.39
# 37500 | lr: 1.00e-02 | loss: 0.1741 | time: 195.56ms | tokens processed: 153,604,096 | tok/sec: 20,945.21
# 38000 | lr: 1.00e-02 | loss: 0.1705 | time: 97.30ms | tokens processed: 155,652,096 | tok/sec: 42,097.10
# 38500 | lr: 1.00e-02 | loss: 0.1336 | time: 177.97ms | tokens processed: 157,700,096 | tok/sec: 23,015.22
# 39000 | lr: 1.00e-02 | loss: 0.1918 | time: 64.76ms | tokens processed: 159,748,096 | tok/sec: 63,244.76
# 39500 | lr: 1.00e-02 | loss: 0.1722 | time: 152.70ms | tokens processed: 161,796,096 | tok/sec: 26,824.60
# 40000 | lr: 1.00e-02 | loss: 0.1644 | time: 31.49ms | tokens processed: 163,844,096 | tok/sec: 130,075.63
# Evaluation TBD
# 40500 | lr: 1.00e-02 | loss: 0.1637 | time: 111.16ms | tokens processed: 165,892,096 | tok/sec: 36,849.35
# 41000 | lr: 1.00e-02 | loss: 0.1777 | time: 209.41ms | tokens processed: 167,940,096 | tok/sec: 19,559.96
# 41500 | lr: 1.00e-02 | loss: 0.1539 | time: 103.79ms | tokens processed: 169,988,096 | tok/sec: 39,463.29
# 42000 | lr: 1.00e-02 | loss: 0.1834 | time: 164.69ms | tokens processed: 172,036,096 | tok/sec: 24,871.58
# 42500 | lr: 1.00e-02 | loss: 0.1435 | time: 218.06ms | tokens processed: 174,084,096 | tok/sec: 18,784.15
# 43000 | lr: 1.00e-02 | loss: 0.1650 | time: 48.00ms | tokens processed: 176,132,096 | tok/sec: 85,329.77
# 43500 | lr: 1.00e-02 | loss: 0.1584 | time: 125.04ms | tokens processed: 178,180,096 | tok/sec: 32,758.38
# 44000 | lr: 1.00e-02 | loss: 0.1532 | time: 26.33ms | tokens processed: 180,228,096 | tok/sec: 155,549.94
# 44500 | lr: 1.00e-02 | loss: 0.1643 | time: 115.62ms | tokens processed: 182,276,096 | tok/sec: 35,424.97
# 45000 | lr: 1.00e-02 | loss: 0.1530 | time: 195.92ms | tokens processed: 184,324,096 | tok/sec: 20,906.06
# Evaluation TBD
# 45500 | lr: 1.00e-02 | loss: 0.1433 | time: 89.50ms | tokens processed: 186,372,096 | tok/sec: 45,767.22
# 46000 | lr: 1.00e-02 | loss: 0.1425 | time: 187.88ms | tokens processed: 188,420,096 | tok/sec: 21,801.26
# 46500 | lr: 1.00e-02 | loss: 0.1368 | time: 56.99ms | tokens processed: 190,468,096 | tok/sec: 71,873.28
# 47000 | lr: 1.00e-02 | loss: 0.1518 | time: 132.82ms | tokens processed: 192,516,096 | tok/sec: 30,838.98
# 47500 | lr: 1.00e-02 | loss: 0.1309 | time: 32.64ms | tokens processed: 194,564,096 | tok/sec: 125,501.27
# 48000 | lr: 1.00e-02 | loss: 0.1804 | time: 125.07ms | tokens processed: 196,612,096 | tok/sec: 32,749.14
# 48500 | lr: 1.00e-02 | loss: 0.1590 | time: 122.13ms | tokens processed: 198,660,096 | tok/sec: 33,537.86
# 49000 | lr: 1.00e-02 | loss: 0.1550 | time: 214.53ms | tokens processed: 200,708,096 | tok/sec: 19,092.50
# 49500 | lr: 1.00e-02 | loss: 0.1528 | time: 91.02ms | tokens processed: 202,756,096 | tok/sec: 45,002.11
# 50000 | lr: 1.00e-02 | loss: 0.1439 | time: 157.20ms | tokens processed: 204,804,096 | tok/sec: 26,056.44
# Evaluation TBD
# 50500 | lr: 9.85e-03 | loss: 0.1526 | time: 52.67ms | tokens processed: 206,852,096 | tok/sec: 77,763.00
# 51000 | lr: 9.61e-03 | loss: 0.1483 | time: 147.57ms | tokens processed: 208,900,096 | tok/sec: 27,756.74
# 51500 | lr: 9.38e-03 | loss: 0.1282 | time: 41.32ms | tokens processed: 210,948,096 | tok/sec: 99,131.41
# 52000 | lr: 9.15e-03 | loss: 0.1409 | time: 125.27ms | tokens processed: 212,996,096 | tok/sec: 32,697.90
# 52500 | lr: 8.91e-03 | loss: 0.1374 | time: 180.67ms | tokens processed: 215,044,096 | tok/sec: 22,670.84
# 53000 | lr: 8.68e-03 | loss: 0.1670 | time: 140.68ms | tokens processed: 217,092,096 | tok/sec: 29,114.77
# 53500 | lr: 8.45e-03 | loss: 0.1253 | time: 16.12ms | tokens processed: 219,140,096 | tok/sec: 254,110.00
# 54000 | lr: 8.22e-03 | loss: 0.1118 | time: 45.81ms | tokens processed: 221,188,096 | tok/sec: 89,420.73
# 54500 | lr: 7.98e-03 | loss: 0.1459 | time: 135.91ms | tokens processed: 223,236,096 | tok/sec: 30,137.58
# 55000 | lr: 7.75e-03 | loss: 0.1087 | time: 17.83ms | tokens processed: 225,284,096 | tok/sec: 229,683.54
# Evaluation TBD
# 55500 | lr: 7.52e-03 | loss: 0.1187 | time: 88.66ms | tokens processed: 227,332,096 | tok/sec: 46,197.97
# 56000 | lr: 7.29e-03 | loss: 0.1407 | time: 190.08ms | tokens processed: 229,380,096 | tok/sec: 21,549.34
# 56500 | lr: 7.05e-03 | loss: 0.1150 | time: 38.70ms | tokens processed: 231,428,096 | tok/sec: 105,836.90
# 57000 | lr: 6.82e-03 | loss: 0.1223 | time: 154.72ms | tokens processed: 233,476,096 | tok/sec: 26,473.54
# 57500 | lr: 6.59e-03 | loss: 0.1184 | time: 140.46ms | tokens processed: 235,524,096 | tok/sec: 29,162.22
# 58000 | lr: 6.36e-03 | loss: 0.1011 | time: 52.55ms | tokens processed: 237,572,096 | tok/sec: 77,947.88
# 58500 | lr: 6.12e-03 | loss: 0.0995 | time: 73.05ms | tokens processed: 239,620,096 | tok/sec: 56,071.72
# 59000 | lr: 5.89e-03 | loss: 0.0892 | time: 153.55ms | tokens processed: 241,668,096 | tok/sec: 26,674.70
# 59500 | lr: 5.66e-03 | loss: 0.1056 | time: 22.33ms | tokens processed: 243,716,096 | tok/sec: 183,420.20
# 60000 | lr: 5.43e-03 | loss: 0.1208 | time: 112.11ms | tokens processed: 245,764,096 | tok/sec: 36,534.41
# Evaluation TBD
# 60500 | lr: 5.19e-03 | loss: 0.1101 | time: 115.87ms | tokens processed: 247,812,096 | tok/sec: 35,349.16
# 61000 | lr: 4.96e-03 | loss: 0.0996 | time: 186.13ms | tokens processed: 249,860,096 | tok/sec: 22,005.92
# 61500 | lr: 4.73e-03 | loss: 0.1030 | time: 92.78ms | tokens processed: 251,908,096 | tok/sec: 44,148.75
# 62000 | lr: 4.50e-03 | loss: 0.0984 | time: 180.71ms | tokens processed: 253,956,096 | tok/sec: 22,665.93
# 62500 | lr: 4.26e-03 | loss: 0.1040 | time: 64.78ms | tokens processed: 256,004,096 | tok/sec: 63,231.02
# 63000 | lr: 4.03e-03 | loss: 0.0734 | time: 33.43ms | tokens processed: 258,052,096 | tok/sec: 122,541.79
# 63500 | lr: 3.80e-03 | loss: 0.0990 | time: 107.45ms | tokens processed: 260,100,096 | tok/sec: 38,121.49
# 64000 | lr: 3.57e-03 | loss: 0.0896 | time: 16.91ms | tokens processed: 262,148,096 | tok/sec: 242,242.94
# 64500 | lr: 3.33e-03 | loss: 0.0828 | time: 96.99ms | tokens processed: 264,196,096 | tok/sec: 42,229.86
# 65000 | lr: 3.10e-03 | loss: 0.0885 | time: 80.53ms | tokens processed: 266,244,096 | tok/sec: 50,860.37
# Evaluation TBD
# 65500 | lr: 2.87e-03 | loss: 0.0932 | time: 150.94ms | tokens processed: 268,292,096 | tok/sec: 27,136.58
# 66000 | lr: 2.64e-03 | loss: 0.0999 | time: 47.81ms | tokens processed: 270,340,096 | tok/sec: 85,667.62
# 66500 | lr: 2.40e-03 | loss: 0.0904 | time: 123.61ms | tokens processed: 272,388,096 | tok/sec: 33,136.73
# 67000 | lr: 2.17e-03 | loss: 0.0903 | time: 152.53ms | tokens processed: 274,436,096 | tok/sec: 26,854.29
# 67500 | lr: 1.94e-03 | loss: 0.0852 | time: 42.58ms | tokens processed: 276,484,096 | tok/sec: 96,202.65
# 68000 | lr: 1.71e-03 | loss: 0.0890 | time: 94.93ms | tokens processed: 278,532,096 | tok/sec: 43,147.94
# 68500 | lr: 1.47e-03 | loss: 0.0972 | time: 16.18ms | tokens processed: 280,580,096 | tok/sec: 253,117.87
# 69000 | lr: 1.24e-03 | loss: 0.0773 | time: 86.88ms | tokens processed: 282,628,096 | tok/sec: 47,143.82
# 69500 | lr: 1.01e-03 | loss: 0.0900 | time: 158.22ms | tokens processed: 284,676,096 | tok/sec: 25,888.54
# 70000 | lr: 7.75e-04 | loss: 0.0693 | time: 67.94ms | tokens processed: 286,724,096 | tok/sec: 60,289.97
# Evaluation TBD
# 70500 | lr: 5.43e-04 | loss: 0.0740 | time: 157.65ms | tokens processed: 288,772,096 | tok/sec: 25,982.04
# 71000 | lr: 3.10e-04 | loss: 0.0841 | time: 43.70ms | tokens processed: 290,820,096 | tok/sec: 93,733.09
# 71500 | lr: 7.77e-05 | loss: 0.0817 | time: 146.54ms | tokens processed: 292,868,096 | tok/sec: 27,951.65

# %%
completions = generate_completions(m, enc=tokenizer, max_length=40)
for completion in completions:
    print(completion)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-11-2771864451.py in <cell line: 0>()
# ----> 1 completions = generate_completions(m, enc=tokenizer, max_length=40)
#       2 for completion in completions:
#       3     print(completion)
#
# /content/jaxpt/src/jaxpt/infer.py in generate_completions(model, enc, prefix, num_completions, max_length, key)
#      92     x = jnp.tile(tokens, (num_completions, 1))
#      93
# ---> 94     x = generate_completion(x=x)  # Make sure you can do a forward pass
#      95     output = []
#      96     for i in range(num_completions):
#
# /content/jaxpt/src/jaxpt/infer.py in generate_slow(model, x, key, max_length, temperature, top_k)
#      41 ) -> jax.Array:
#      42     while x.shape[1] < max_length:
# ---> 43         logits = model(x) / temperature
#      44         logits = logits[:, -1, :]
#      45         x_next, key = top_k_sampling(logits, key, k=top_k)
#
# /content/jaxpt/src/jaxpt/models/smol_lm.py in __call__(self, idx, mask)
#     142         x = self.wte(idx)
#     143         for block in self.h:
# --> 144             x = block(x, mask)
#     145         x = self.rms_n_f(x)
#     146         logits = self.wte.attend(x)
#
# /content/jaxpt/src/jaxpt/models/smol_lm.py in __call__(self, x, mask)
#      97
#      98     def __call__(self, x, mask=None):
# ---> 99         x = self.attn(self.rms_n_1(x), mask=mask) + x
#     100         x = self.mlp(self.rms_n_2(x)) + x
#     101         return x
#
# /content/jaxpt/src/jaxpt/modules/attention.py in __call__(self, x, mask)
#     217         if self.key_cache is not None:
#     218             offset = self.key_cache.shape[1]
# --> 219         q = self.apply_rope(q, offset=offset)
#     220
#     221         if self.config.use_cache is True:
#
# /content/jaxpt/src/jaxpt/modules/position.py in apply_rope(self, v, offset)
#      77         v = v.swapaxes(1, 2)
#      78         omega = self.omega[offset : offset + v.shape[-2], :]
# ---> 79         a = v * jnp.cos(omega)
#      80         b = self.rotate_half(v) * jnp.sin(omega)
#      81         y = a + b
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/pjit.py in cache_miss(*args, **kwargs)
#     339
#     340     (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 341      pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342
#     343     maybe_fastpath_data = _get_fastpath_data(
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/pjit.py in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     193       args_flat = map(core.full_lower, args_flat)
#     194       core.check_eval_args(args_flat)
# --> 195       out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     196     else:
#     197       out_flat = pjit_p.bind(*args_flat, **p.params)
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/pjit.py in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1655       pgle_profiler=pgle_profiler,
#    1656       compiler_options_kvs=compiler_options_kvs,
# -> 1657   ).compile()
#    1658
#    1659   # This check is expensive so only do it if enable_checks is on.
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/interpreters/pxla.py in compile(self, compiler_options)
#    2444     compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2445     if self._executable is None or compiler_options_kvs:
# -> 2446       executable = UnloadedMeshExecutable.from_hlo(
#    2447           self._name, self._hlo, **self.compile_args,
#    2448           compiler_options_kvs=compiler_options_kvs)
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/interpreters/pxla.py in from_hlo(***failed resolving arguments***)
#    2957
#    2958     util.test_event("pxla_cached_compilation")
# -> 2959     xla_executable = _cached_compilation(
#    2960         hlo, name, mesh, spmd_lowering,
#    2961         tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/interpreters/pxla.py in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2755       "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2756       fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2757     xla_executable = compiler.compile_or_get_cached(
#    2758         backend, computation, dev, compile_options, host_callbacks,
#    2759         pgle_profiler)
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/compiler.py in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     471   else:
#     472     log_persistent_cache_miss(module_name, cache_key)
# --> 473     return _compile_and_write_cache(
#     474         backend,
#     475         computation,
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/compiler.py in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     688 ) -> xc.LoadedExecutable:
#     689   start_time = time.monotonic()
# --> 690   executable = backend_compile(
#     691       backend, computation, compile_options, host_callbacks
#     692   )
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     332   def wrapper(*args, **kwargs):
#     333     with TraceAnnotation(name, **decorator_kwargs):
# --> 334       return func(*args, **kwargs)
#     335     return wrapper
#     336   return wrapper
#
# /usr/local/lib/python3.11/dist-packages/jax/_src/compiler.py in backend_compile(backend, module, options, host_callbacks)
#     322     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     323     # to take in `host_callbacks`
# --> 324     return backend.compile(built_c, compile_options=options)
#     325   except xc.XlaRuntimeError as e:
#     326     for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

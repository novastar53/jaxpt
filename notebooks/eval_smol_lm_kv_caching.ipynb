# %% [markdown]
# # Let's Evaluate SmolLM

# %% [markdown]
# ### Configure the machine and install packages

# %%
from typing import Literal
import jax

platform : Literal["darwin", "colab", "cuda", "tpu"] = "darwin"

try:
    import google.colab
    platform = "colab"
except ImportError:
    devices = jax.devices()
    if any(d.platform == "gpu" for d in devices):
        platform = "cuda"
    if any(d.platform == "tpu" for d in devices):
        platform = "tpu"

print(f"Running on {platform}")

if platform == "colab":
    # !git clone https://github.com/novastar53/jaxpt
    # !cd jaxpt && git checkout main && git pull
    # !pip install tiktoken datasets --quiet
    #!pip uninstall -y tensorflow
# Out:
# Running on darwin

# %%
from pathlib import Path
import sys

if platform == "colab":
    jaxpt_dir = str(Path().absolute() / "jaxpt" / "src" )
else:
    jaxpt_dir = str(Path().absolute().parent / "src" )


sys.path.append(jaxpt_dir)
print(jaxpt_dir)
# Out:
# /Users/vikram/dev/jaxpt/src

# %%
import os


import warnings

import jax
from jax.sharding import Mesh, PartitionSpec, NamedSharding
import flax
import jax.numpy as jnp
import numpy as np

# Hardware setup
print("JAX version:", jax.__version__)
print("Flax version", flax.__version__)

devices = jax.devices()
num_devices = len(devices)
print("Available devices:", num_devices)

requested_device = "gpu"

jax.config.update("jax_platform_name", requested_device) # Make sure we're using the GPU

device = jax.default_backend()
if device != requested_device:
    warnings.warn(f"not using {requested_device}. Using {device}")
else:
    print(f"using {device}")


#####################################
##        jax.lax matmul presets   ##
#####################################
## 'ANY_F8_ANY_F8_F32',
## 'ANY_F8_ANY_F8_F32_FAST_ACCUM'
## 'ANY_F8_ANY_F8_ANY'
## 'ANY_F8_ANY_F8_ANY_FAST_ACCUM'
## 'F16_F16_F16'
## 'F16_F16_F32'
## 'BF16_BF16_BF16'
## 'BF16_BF16_F32'
## 'BF16_BF16_F32_X3'
## 'BF16_BF16_F32_X6'
## 'TF32_TF32_F32'
## 'TF32_TF32_F32_X3'
## 'F32_F32_F32'
## 'F64_F64_F64'
#####################################

jax.config.update("jax_default_matmul_precision", "BF16_BF16_F32") # Set the default precision for matrix multiplication

#jax.config.update("jax_enable_x64", True) # Make sure the highest precision is enabled in case we need
#os.environ["NVIDIA_TF32_OVERRIDE"] = "1"
#os.environ["JAX_ENABLE_X64"] = "False"

if device == "tpu":
    def list_tpu_memory():
        devices = jax.devices()
        for device in devices:
            if 'TPU' in str(device.device_kind):
                print(f"Device: {device}, Memory: {device.memory_stats()['bytes_limit']/(1024*1024)},  Used: {device.memory_stats()['bytes_in_use']/(1024*1024)}")

    list_tpu_memory()

# Set up device mesh


mesh = jax.sharding.Mesh(jax.devices(), ["devices"])

# Test the device
A = jnp.array(np.random.normal(size=(4096, 4096)), dtype=jnp.float32) # Make sure matmul is fast
# %timeit (A@A).block_until_ready()
# Out:
# JAX version: 0.6.2
# Flax version 0.10.6
# Available devices: 1
# /var/folders/x4/85_9sn3d1ng9q48ff6t3fw340000gn/T/ipykernel_2293/3250393803.py:26: UserWarning: not using gpu. Using cpu
#   warnings.warn(f"not using {requested_device}. Using {device}")
# 229 ms ± 34.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random
from datetime import datetime
import string
from jaxpt.checkpointers import save_checkpoint, load_checkpoint, load_checkpoint_from_gcloud

def generate_random_code(length=6):
    return ''.join(random.choices(string.ascii_lowercase, k=length))

timestamp = datetime.now().strftime("%Y%m%d")
random_code = generate_random_code()

run_dirname = f"run_{timestamp}_{random_code}"
print(f"Run: {run_dirname}")

if platform == "cuda":
  output_dir = Path("/home/ubuntu/alpha_training_runs") # Lambda Labs setup
else:
  output_dir = Path().absolute().parent  / "alpha_training_runs" # Local setup
# Out:
# Run: run_20250811_xecqow

# %%
from flax import nnx

from jaxpt.models import SmolLM, SmolLM_Config
from jaxpt.models.smol_lm import from_hf_pretrained
from jaxpt.utils import count_params, create_sharded_model

import tiktoken
from transformers import AutoTokenizer

key = jax.random.PRNGKey(1337)
rngs = nnx.Rngs(key)
config = SmolLM_Config(
                     name="HuggingFaceTB/SmolLM-135M",
                     dtype=jnp.bfloat16, \
                     vocab_size=49152,
                     n_layer=30,
                     block_size=2048,
                     n_head=9,
                     n_kv_head=3,
                     n_mlp_hidden=1536,
                     use_cache=True,
                     sdpa_implementation="cudnn" if device=="gpu" else "xla")
nnx.display(config)

with mesh:
    #m = create_sharded_model(SmolLM, config, rngs)
    m = from_hf_pretrained(config, rngs)

    graphdef, rngstate, state = nnx.split(m, nnx.RngState, ...)
    total_params = count_params(m)
    moe_params = count_params(m, "moe")

    print(f"Parameter Count: {total_params:,}")
    print(f"MOE Parameter Count: {moe_params:,}")
    print(f"Replicated Parameter Count: {total_params - moe_params:,}")
    nnx.display(state)
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_2fd50ef4759a43f190992d517e0b30f0" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_2fd50ef4759a43f190992d517e0b30f0")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_2fd50ef4759a43f190992d517e0b30f0")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Parameter Count: 134,515,008
# MOE Parameter Count: 0
# Replicated Parameter Count: 134,515,008
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_d962e09effbd4c5fb29c76a6d328c776" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d962e09effbd4c5fb29c76a6d328c776")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d962e09effbd4c5fb29c76a6d328c776")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_d962e09effbd4c5fb29c76a6d328c776")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>

# %% [markdown]
# ## Calculate Loss Value

# %%
from jaxpt.dataloaders import  BlendedCloudDataLoader, HuggingfaceDataLoader

train_dl = HuggingfaceDataLoader(batch_size=16,
                                 block_size=2048,
                                 device_rank=1,
                                 tokenizer="HuggingFaceTB/SmolLM-135M",
                                 dataset_paths=["HuggingFaceTB/smollm-corpus",
                                                "HuggingFaceTB/smollm-corpus"],
                                 dataset_names=["cosmopedia-v2",
                                                "fineweb-edu-dedup"],
                                 probabilities=[0.20,  0.80],
                                 label="train",
                                 random_seed=1337,
                                 buffer_size=10_000,
                                 streaming=True)

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./alpha-448101-282bc1b884cd.json"
'''
train_dl = BlendedCloudDataLoader(
    device_rank=1,
    block_size=2048,
    batch_size=16,
    bucket_names=["jaxpt_datasets", "jaxpt_datasets", "jaxpt_datasets"],
    bucket_prefixes=["smollm-corpus/processed/fineweb-edu-dedup",
    "smollm-corpus/processed/python-edu",
    "smollm-corpus/processed/cosmopedia-v2"],
    proportions=[87, 2, 11],
    label="train"
)
'''
# Out:
# Initializing tokenizer HuggingFaceTB/SmolLM-135M
# Resolving data files:   0%|          | 0/104 [00:00<?, ?it/s]
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Resolving data files:   0%|          | 0/104 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/104 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/234 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from jaxpt.dataloaders import  BlendedCloudDataLoader, HuggingfaceDataLoader
# ----> 3 train_dl = HuggingfaceDataLoader(batch_size=16,
#       4                                  block_size=2048,
#       5                                  device_rank=1,
#       6                                  tokenizer="HuggingFaceTB/SmolLM-135M",
#       7                                  dataset_paths=["HuggingFaceTB/smollm-corpus",
#       8                                                 "HuggingFaceTB/smollm-corpus"],
#       9                                  dataset_names=["cosmopedia-v2",
#      10                                                 "fineweb-edu-dedup"],
#      11                                  probabilities=[0.20,  0.80],
#      12                                  label="train",
#      13                                  random_seed=1337,
#      14                                  buffer_size=10_000,
#      15                                  streaming=True)
#      17 os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./alpha-448101-282bc1b884cd.json"
#      18 '''
#      19 train_dl = BlendedCloudDataLoader(
#      20     device_rank=1,
#    (...)     29 )
#      30 '''
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:327, in HuggingfaceDataLoader.__init__(self, batch_size, block_size, device_rank, tokenizer, dataset_paths, dataset_names, probabilities, label, random_seed, buffer_size, streaming, quiet)
#     324 self.iter_ds = iter(self.ds)
#     326 # Always set start_shard and start_shard_pos to 0 for HuggingfaceDataLoader
# --> 327 super().__init__(
#     328     batch_size,
#     329     block_size,
#     330     device_rank,
#     331     label,
#     332     quiet,
#     333     start_shard=0,
#     334     start_shard_pos=0,
#     335 )
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:64, in BaseDataLoader.__init__(self, batch_size, block_size, device_rank, label, quiet, start_shard, start_shard_pos)
#      62 self.cur_shard = start_shard
#      63 self.shard_pos = start_shard_pos
# ---> 64 self.shard = self._load_shard()
#      65 self.shard_size = len(self.shard)
#      67 if not quiet:
#
# File ~/dev/jaxpt/src/jaxpt/dataloaders.py:344, in HuggingfaceDataLoader._load_shard(self)
#     342 def _load_shard(self):
#     343     try:
# --> 344         example = next(self.iter_ds)
#     345     except StopIteration:
#     346         self.iter_ds = iter(self.ds)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:2270, in IterableDataset.__iter__(self)
#    2267         yield formatter.format_row(pa_table)
#    2268     return
# -> 2270 for key, example in ex_iterable:
#    2271     # no need to format thanks to FormattedExamplesIterable
#    2272     yield example
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:1856, in FormattedExamplesIterable.__iter__(self)
#    1849     formatter = get_formatter(
#    1850         self.formatting.format_type,
#    1851         features=self._features if not self.ex_iterable.is_typed else None,
#    1852         token_per_repo_id=self.token_per_repo_id,
#    1853     )
#    1854 if self.ex_iterable.iter_arrow:
#    1855     # feature casting (inc column addition) handled within self._iter_arrow()
# -> 1856     for key, pa_table in self._iter_arrow():
#    1857         batch = formatter.format_batch(pa_table)
#    1858         for example in _batch_to_examples(batch):
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:1879, in FormattedExamplesIterable._iter_arrow(self)
#    1877 if not self.features:
#    1878     yield from self.ex_iterable._iter_arrow()
# -> 1879 for key, pa_table in self.ex_iterable._iter_arrow():
#    1880     columns = set(pa_table.column_names)
#    1881     schema = self.features.arrow_schema
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:476, in RebatchedArrowExamplesIterable._iter_arrow(self)
#     474     previous_state = self.ex_iterable.state_dict()
#     475     self._state_dict["previous_state"] = previous_state
# --> 476 for key, pa_table in iterator:
#     477     for num_chunks_since_previous_state, chunk in enumerate(pa_table.to_reader(max_chunksize=self.batch_size)):
#     478         if num_chunks_to_skip > 1:
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:128, in _convert_to_arrow(iterable, batch_size, drop_last_batch)
#     126     return
#     127 iterator = iter(iterable)
# --> 128 for key, example in iterator:
#     129     iterator_batch = islice(iterator, batch_size - 1)
#     130     key_examples_list = [(key, example)] + list(iterator_batch)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:1535, in BufferShuffledExamplesIterable.__iter__(self)
#    1533 # this is the shuffle buffer that we keep in memory
#    1534 mem_buffer = []
# -> 1535 for x in self.ex_iterable:
#    1536     if len(mem_buffer) == buffer_size:  # if the buffer is full, pick and example from it
#    1537         i = next(indices_iterator)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:709, in CyclingMultiSourcesExamplesIterable.__iter__(self)
#     707 # let's pick one example from the iterator at index i
#     708 if nexts[i] is None:
# --> 709     nexts[i] = next(iterators[i], False)
#     710 result = nexts[i]
#     711 if self._state_dict:
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/iterable_dataset.py:374, in ShuffledDataSourcesArrowExamplesIterable.__iter__(self)
#     372 shard_example_idx_start = self._state_dict["shard_example_idx"] if self._state_dict else 0
#     373 shard_example_idx = 0
# --> 374 for key, pa_table in self.generate_tables_fn(**gen_kwags):
#     375     if shard_example_idx + len(pa_table) <= shard_example_idx_start:
#     376         shard_example_idx += len(pa_table)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/packaged_modules/parquet/parquet.py:90, in Parquet._generate_tables(self, files)
#      88 with open(file, "rb") as f:
#      89     parquet_fragment = ds.ParquetFileFormat().make_fragment(f)
# ---> 90     if parquet_fragment.row_groups:
#      91         batch_size = self.config.batch_size or parquet_fragment.row_groups[0].num_rows
#      92         try:
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/pyarrow/_dataset_parquet.pyx:385, in pyarrow._dataset_parquet.ParquetFileFragment.row_groups.__get__()
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/pyarrow/_dataset_parquet.pyx:392, in pyarrow._dataset_parquet.ParquetFileFragment.metadata.__get__()
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/pyarrow/_dataset_parquet.pyx:381, in pyarrow._dataset_parquet.ParquetFileFragment.ensure_complete_metadata()
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:89, in pyarrow.lib.check_status()
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/datasets/utils/file_utils.py:827, in _add_retries_to_file_obj_read_method.<locals>.read_with_retries(*args, **kwargs)
#     825 for retry in range(1, max_retries + 1):
#     826     try:
# --> 827         out = read(*args, **kwargs)
#     828         break
#     829     except (
#     830         _AiohttpClientError,
#     831         asyncio.TimeoutError,
#     832         requests.exceptions.ConnectionError,
#     833         requests.exceptions.Timeout,
#     834     ) as err:
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/huggingface_hub/hf_file_system.py:1007, in HfFileSystemFile.read(self, length)
#    1005         self.loc += len(out)
#    1006         return out
# -> 1007 return super().read(length)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/fsspec/spec.py:2083, in AbstractBufferedFile.read(self, length)
#    2080 if length == 0:
#    2081     # don't even bother calling fetch
#    2082     return b""
# -> 2083 out = self.cache._fetch(self.loc, self.loc + length)
#    2085 logger.debug(
#    2086     "%s read: %i - %i %s",
#    2087     self,
#    (...)   2090     self.cache._log_stats(),
#    2091 )
#    2092 self.loc += len(out)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/fsspec/caching.py:249, in ReadAheadCache._fetch(self, start, end)
#     247 end = min(self.size, end + self.blocksize)
#     248 self.total_requested_bytes += end - start
# --> 249 self.cache = self.fetcher(start, end)  # new block replaces old
#     250 self.start = start
#     251 self.end = self.start + len(self.cache)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/huggingface_hub/hf_file_system.py:961, in HfFileSystemFile._fetch_range(self, start, end)
#     950 headers = {
#     951     "range": f"bytes={start}-{end - 1}",
#     952     **self.fs._api._build_hf_headers(),
#     953 }
#     954 url = hf_hub_url(
#     955     repo_id=self.resolved_path.repo_id,
#     956     revision=self.resolved_path.revision,
#    (...)    959     endpoint=self.fs.endpoint,
#     960 )
# --> 961 r = http_backoff(
#     962     "GET",
#     963     url,
#     964     headers=headers,
#     965     retry_on_status_codes=(500, 502, 503, 504),
#     966     timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT,
#     967 )
#     968 hf_raise_for_status(r)
#     969 return r.content
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:310, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     307     kwargs["data"].seek(io_obj_initial_pos)
#     309 # Perform request and return if status_code is not in the retry list.
# --> 310 response = session.request(method=method, url=url, **kwargs)
#     311 if response.status_code not in retry_on_status_codes:
#     312     return response
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:96, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      94     logger.debug(f"Send: {_curlify(request)}")
#      95 try:
# ---> 96     return super().send(request, *args, **kwargs)
#      97 except requests.RequestException as e:
#      98     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import optax

@nnx.jit
def loss_fn(model, batch, targets):
    logits = model(batch)
    loss = optax.softmax_cross_entropy_with_integer_labels(logits, targets)
    return loss.mean()

for i in range(50):
  batch, targets = train_dl()
  batch = batch.squeeze()
  targets = targets.squeeze()
  loss = loss_fn(m, batch, targets)
  print(loss)
# Out:
# 3.1825829
# 3.329182
# 3.5408206
# 3.1804218
# 3.0701225
# 3.2831395
# 3.5010738
# 3.371111
# 3.2800155
# 3.139091
# 3.3757584
# 3.3705955
# 3.332045
# 3.288981
# 3.0803099
# 3.1970716
# 2.997715
# 3.2080798
# 3.205825
# 3.2289476
# 3.3084211
# 3.0274704
# 3.4236832
# 3.1799934
# 3.4887028
# 3.3575816
# 3.2652416
# 3.1851277
# 3.0785239
# 3.1555781
# 3.3177605
# 3.2568169
# 3.327516
# 3.1862893
# 3.3554664
# 3.457439
# 3.6374774
# 3.139883
# 3.3558655
# 3.313861
# 3.2596636
# 3.3892307
# 3.173217
# 3.2405252
# 3.535433
# 3.3071134
# 3.2969756
# 3.2431116
# 3.0303626
# 3.4645233

# %%
from functools import partial
from jaxpt.infer import generate_completion_fast


with mesh:
    # clear the model cache 
    for i in range(len(m.h)):
        m.h[i].attn.key_cache = None
        m.h[i].attn.value_cache = None

    enc = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-135M")
    completions = generate_completion_fast(m, enc=enc, num_completions=8,
                                    max_length=21,
                                    prefix="Once upon a time, there lived a")
    for completion in completions:
        print(completion)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       9     m.h[i].attn.value_cache = None
#      11 enc = AutoTokenizer.from_pretrained("HuggingFaceTB/SmolLM-135M")
# ---> 12 completions = generate_completion_fast(m, enc=enc, num_completions=8,
#      13                                 max_length=21,
#      14                                 prefix="Once upon a time, there lived a")
#      15 for completion in completions:
#      16     print(completion)
#
# File ~/dev/jaxpt/src/jaxpt/infer.py:86, in generate_completion_fast(model, enc, prefix, attn_mask, num_completions, max_length, temperature, key)
#      84 #attn_mask = jnp.ones((attn_mask.shape[0], 1), dtype=jnp.bool)
#      85 while x.shape[1] < max_length:
# ---> 86     x_next = _generate_step(model, x, attn_mask, temperature, key)
#      87     x = x_next
#      88 output = []
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/flax/nnx/transforms/compilation.py:350, in jit.<locals>.jit_wrapper(*args, **kwargs)
#     340 with graph.update_context(jit_wrapper):
#     341   pure_args, pure_kwargs = extract.to_tree(
#     342     (args, kwargs),
#     343     prefix=(in_shardings, kwarg_shardings)
#    (...)    348     ctxtag=jit_wrapper,
#     349   )
# --> 350   pure_args_out, pure_kwargs_out, pure_out = jitted_fn(
#     351     *pure_args, **pure_kwargs
#     352   )
#     353   _args_out, _kwargs_out, out = extract.from_tree(
#     354     (pure_args_out, pure_kwargs_out, pure_out),
#     355     merge_fn=_jit_merge_fn,
#     356     is_inner=False,
#     357     ctxtag=jit_wrapper,
#     358   )
#     359 return out
#
#     [... skipping hidden 1 frame]
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:139, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#     142     dispatch.check_arg(arg)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:686, in _infer_params(fun, ji, args, kwargs)
#     683   with (_internal_use_concrete_mesh(phys_mesh),
#     684         mesh_lib.use_abstract_mesh(phys_mesh.abstract_mesh)):
#     685     return _infer_params_internal(fun, ji, args, kwargs)
# --> 686 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:710, in _infer_params_internal(fun, ji, args, kwargs)
#     707 entry = _infer_params_cached(fun, ji, signature, avals, ctx_mesh)
#     709 if entry.pjit_params is None:
# --> 710   p, args_flat = _infer_params_impl(
#     711       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     712   if p.attrs_tracked or p.box_data or p.params['jaxpr'].jaxpr.is_high:
#     713     return p, p.consts + args_flat
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:606, in _infer_params_impl(***failed resolving arguments***)
#     599 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     600     in_shardings_treedef, in_shardings_leaves,
#     601     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     602     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     604 attr_token = _attr_cache_index(flat_fun, in_type)
# --> 606 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     607     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     609 if config.mutable_array_checks.value:
#     610   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:471, in cache.<locals>.memoized_fun(fun, *args)
#     469 if do_explain := explain and config.explain_cache_misses.value:
#     470   start = time.time()
# --> 471 ans = call(fun, *args)
#     472 if do_explain:
#     473   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1414, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1412     attrs_tracked = []
#    1413   else:
# -> 1414     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(fun, in_type)
#    1416 if config.debug_key_reuse.value:
#    1417   # Import here to avoid circular imports
#    1418   from jax.experimental.key_reuse._core import check_key_reuse_jaxpr  # pytype: disable=import-error
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:2292, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower)
#    2290 try:
#    2291   with core.set_current_trace(trace):
# -> 2292     ans = fun.call_wrapped(*in_tracers)
#    2293   _check_returned_jaxtypes(fun.debug_info, ans)
#    2294   out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:211, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     209 def call_wrapped(self, *args, **kwargs):
#     210   """Calls the transformed function"""
# --> 211   return self.f_transformed(*args, **kwargs)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:396, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     394 @transformation_with_aux2
#     395 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 396   ans = _fun(*args, **kwargs)
#     397   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     398   if _store:
#     399     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     400     # the bwd function in a custom_vjp
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/flax/nnx/transforms/compilation.py:129, in JitFn.__call__(self, *pure_args, **pure_kwargs)
#     121 def __call__(self, *pure_args, **pure_kwargs):
#     122   args, kwargs = extract.from_tree(
#     123     (pure_args, pure_kwargs),
#     124     merge_fn=_jit_merge_fn,
#     125     ctxtag=self.ctxtag,
#     126     is_inner=True,
#     127   )
# --> 129   out = self.f(*args, **kwargs)
#     131   args_out, kwargs_out = extract.clear_non_graph_nodes((args, kwargs))
#     132   pure_args_out, pure_kwargs_out, pure_out = extract.to_tree(
#     133     (args_out, kwargs_out, out),
#     134     prefix=(self.in_shardings, self.kwarg_shardings, self.out_shardings),
#     135     ctxtag=self.ctxtag,
#     136     split_fn=_jit_split_fn,
#     137   )
#
# File ~/dev/jaxpt/src/jaxpt/infer.py:18, in _generate_step(m, x, attn_mask, temperature, key)
#      16 @nnx.jit
#      17 def _generate_step(m, x, attn_mask, temperature, key):
# ---> 18     logits = m(x, mask=attn_mask) / temperature
#      19     x_new = logits[:, -1, :]
#      20     top_k_vals, top_k_indices = jax.lax.top_k(x_new, 50)
#
# File ~/dev/jaxpt/src/jaxpt/models/smol_lm.py:135, in SmolLM.__call__(self, idx, mask)
#     133 x = self.wte(idx)
#     134 for block in self.h:
# --> 135     x = block(x, mask)
#     136 x = self.rms_n_f(x)
#     137 logits = self.wte.attend(x)
#
# File ~/dev/jaxpt/src/jaxpt/models/smol_lm.py:91, in Block.__call__(self, x, mask)
#      89 def __call__(self, x, mask=None):
#      90     x = self.attn(self.rms_n_1(x), mask=mask) + x
# ---> 91     x = self.mlp(self.rms_n_2(x)) + x
#      92     return x
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/flax/nnx/nn/normalization.py:628, in RMSNorm.__call__(self, x, mask)
#     609 """Applies layer normalization on the input.
#     610
#     611 Args:
#    (...)    615   Normalized inputs (the same shape as inputs).
#     616 """
#     617 mean, var = _compute_stats(
#     618   x,
#     619   self.reduction_axes,
#    (...)    625   mask=mask,
#     626 )
# --> 628 return _normalize(
#     629   x,
#     630   mean,
#     631   var,
#     632   self.scale.value if self.scale else None,
#     633   None,
#     634   self.reduction_axes,
#     635   self.feature_axes,
#     636   self.dtype,
#     637   self.epsilon,
#     638 )
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/flax/nnx/nn/normalization.py:173, in _normalize(x, mean, var, scale, bias, reduction_axes, feature_axes, dtype, epsilon)
#     171 if scale is not None:
#     172   scale = scale.reshape(feature_shape)
# --> 173   mul *= scale
#     174   args.append(scale)
#     175 y *= mul
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1083, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1082 def op(self, *args):
# -> 1083   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:583, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     581 args = (other, self) if swap else (self, other)
#     582 if isinstance(other, _accepted_binop_types):
# --> 583   return binary_op(*args)
#     584 # Note: don't use isinstance here, because we don't want to raise for
#     585 # subclasses, e.g. NamedTuple objects that may override operators.
#     586 if type(other) in _rejected_binop_types:
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:182, in ufunc.__call__(self, out, where, *args)
#     180   raise NotImplementedError(f"where argument of {self}")
#     181 call = self.__static_props['call'] or self._call_vectorized
# --> 182 return call(*args)
#
#     [... skipping hidden 1 frame]
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:139, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#     142     dispatch.check_arg(arg)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:686, in _infer_params(fun, ji, args, kwargs)
#     683   with (_internal_use_concrete_mesh(phys_mesh),
#     684         mesh_lib.use_abstract_mesh(phys_mesh.abstract_mesh)):
#     685     return _infer_params_internal(fun, ji, args, kwargs)
# --> 686 return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:692, in _infer_params_internal(fun, ji, args, kwargs)
#     688 def _infer_params_internal(
#     689     fun: Callable, ji: PjitInfo, args: tuple[Any, ...], kwargs: dict[str, Any]
#     690   ) -> tuple[PjitParams, list[Any]]:
#     691   ctx_mesh = mesh_lib.get_concrete_mesh()
# --> 692   dbg = debug_info(
#     693       'jit', fun, args, kwargs, static_argnums=ji.static_argnums,
#     694       static_argnames=ji.static_argnames, sourceinfo=ji.fun_sourceinfo,
#     695       signature=ji.fun_signature)
#     697   any_boxes = any(isinstance(x, (Box, List)) for x in tree_leaves((args, kwargs)))
#     698   if config.dynamic_shapes.value or any_boxes:  # don't use the cache
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:619, in debug_info(traced_for, fun, args, kwargs, static_argnums, static_argnames, result_paths_thunk, sourceinfo, signature)
#     617 if signature is None:
#     618   signature = fun_signature(fun)
# --> 619 arg_names = _non_static_arg_names(signature, args, kwargs, static_argnums,
#     620                                   static_argnames)
#     621 return core.DebugInfo(traced_for, sourceinfo, arg_names, result_paths_thunk)
#
# File ~/dev/jaxpt/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:690, in _non_static_arg_names(fn_signature, args, kwargs, static_argnums, static_argnames)
#     688 if fn_signature is not None:
#     689   try:
# --> 690     ba = fn_signature.bind(*args_, **kwargs_)
#     691   except (ValueError, TypeError):
#     692     pass
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/inspect.py:3277, in Signature.bind(self, *args, **kwargs)
#    3272 def bind(self, /, *args, **kwargs):
#    3273     """Get a BoundArguments object, that maps the passed `args`
#    3274     and `kwargs` to the function's signature.  Raises `TypeError`
#    3275     if the passed arguments can not be bound.
#    3276     """
# -> 3277     return self._bind(args, kwargs)
#
# File ~/Library/Application Support/uv/python/cpython-3.12.8-macos-aarch64-none/lib/python3.12/inspect.py:3194, in Signature._bind(self, args, kwargs, partial)
#    3191 else:
#    3192     # We have a positional argument to process
#    3193     try:
# -> 3194         param = next(parameters)
#    3195     except StopIteration:
#    3196         raise TypeError('too many positional arguments') from None
#
# KeyboardInterrupt:
